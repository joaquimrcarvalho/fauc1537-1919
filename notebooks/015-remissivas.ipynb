# %% [markdown]
# **[EN]** English only
# # Cross references
#
# The digital version of the FA carries over a cross-reference mechanism from the card catalog. As was usual at the time, extra cards were inserted into the catalog to guide users searching for name variants of the main entry. These cards have a “base” name, followed the word “vide” and a “name expression”.
#
# This notebook analyses the cross-reference information in the FA.

# %% [markdown]
# To run this file: follow instructions in the README.md file in this directory.

# %% [markdown]
# #### This is a very long file. Use the outline view in the left pane to quickly jump to sections

# %% [markdown]
# ##  Setup

# %%
from timelinknb import current_time,current_machine, get_mhk_db
import ucalumni.config as alumniconf

db_name = alumniconf.mhk_db_name
db = get_mhk_db(db_name, connect_args={'connect_timeout': 3600})
print(current_machine,current_time,f'db={db_name}')
# Out:
# imac-jrc.local 2022-05-11 19:09:38.661894 db=ucalumni

# %% [markdown]
# Prepare a dataframe to collect the results of cross reference analysis

# %%
import pandas as pd

columns = ['data','sequential','random']
vars = ['vide','vide_plus',
        'see','see_matched','see_matched_ok','nodate_novide',
        'aka','nodate','nodate_novide','aka_matched','aka_matched_ok',
        'records_matched','records_matched_ok','records_error',
        'matched_pairs','matched_pairs_ok','records_see_aka','records_aka_see','records_aka_aka', 'records_see_see',
        'records_transitive','records_asymmetric']

match_info = pd.DataFrame(index=vars,columns=columns)
match_records = dict([(k,dict.fromkeys(columns)) for k in vars])
match_info.sort_index(inplace=True)
match_info
# Out:
#                    data sequential random
# aka                 NaN        NaN    NaN
# aka_matched         NaN        NaN    NaN
# aka_matched_ok      NaN        NaN    NaN
# matched_pairs       NaN        NaN    NaN
# matched_pairs_ok    NaN        NaN    NaN
# nodate              NaN        NaN    NaN
# nodate_novide       NaN        NaN    NaN
# nodate_novide       NaN        NaN    NaN
# records_aka_aka     NaN        NaN    NaN
# records_aka_see     NaN        NaN    NaN
# records_asymmetric  NaN        NaN    NaN
# records_error       NaN        NaN    NaN
# records_matched     NaN        NaN    NaN
# records_matched_ok  NaN        NaN    NaN
# records_see_aka     NaN        NaN    NaN
# records_see_see     NaN        NaN    NaN
# records_transitive  NaN        NaN    NaN
# see                 NaN        NaN    NaN
# see_matched         NaN        NaN    NaN
# see_matched_ok      NaN        NaN    NaN
# vide                NaN        NaN    NaN
# vide_plus           NaN        NaN    NaN

# %% [markdown]
# ## Get records which contain a "see" note (vide)
#
# Note that records with more than one faculty and/or more than one geographic name
# generate more than one line. So the number of lines in the data frame is greater
# than the number of records.
#
# **To obtain the real number of records in a data frame it is necessary to count the number of unique record identifiers (six-digit numbers) in the data frame index.**
#
# > nvide = len(vide.index.unique())

# %%
from timelinknb.pandas import attribute_to_df


# Get list of people with attribute nome-vide and add nome-geografico, nome-pai, entry date and faculdade
vide = attribute_to_df(
                    the_type='nome-vide',
                    person_info=True,
                    more_cols=['nome-geografico','faculdade','nome-pai','uc-entrada','uc-saida'],
                    sql_echo=False)
# drop columns that are not usefull
vide.drop(['nome-vide.date','nome-vide.obs','nome-geografico.date','nome-geografico.obs','nome-pai.date','nome-pai.obs','uc-entrada.date','uc-entrada.obs'],axis=1, inplace=True)
nvide = len(vide.index.unique())
print(current_machine,current_time,f'db={db_name}')
print("Number of records with 'vide' cross reference:'",nvide)
match_info.loc['vide','data'] = nvide
match_records['vide']['data'] = vide.index.unique()
print()
print(vide.info())
# Out:
# imac-jrc.local 2022-05-11 19:09:38.661894 db=ucalumni
# Number of records with 'vide' cross reference:' 8625
#
# <class 'pandas.core.frame.DataFrame'>
# Index:
#
# 19. https://pesquisa.auc.uc.pt/details?id=130281
#       * Nuno da Câmara	is tricky, because it combines note and vide, and the vide part has two names Nuno da Câmara (D.),
#         vide Nuno Casimiro da Câmara e Nuno José da Câmara it links with  130516 and 130517
#         Handling these requires changing the grammar rules, scheduled for next version.

# %% [markdown]
# ### Determine the type of cross reference
#
# __Forward cross references (“see”)__
# * Almost empty records with a name with “vide”
# * A few with more than one (…vide... e vide…)
# * No dates (empty “UnitDateInitial” field)
# * Other than the name:
#     * 93% place of birth
#     * 27% father’s name
#     * 23% faculty
#
# __Back cross references (“also knows as/aka”)__
# * Normal records with “vide” in the name.
# * Dates (valid “UnitDateInitial” field)
# * Contain all types of information:
#     * 97% place of birth
#     * 53% father’s name
#     * 99% faculty
#     * degrees, enrolment, and so on.
# * Can be matched with “see” records.
# * These records are the non preferred form of the name and should link to a preferred form.

# %% [markdown]
# #### "See"  or forward cross-references: "vide" and no dates
#
# These records are the non preferred form of the name and should link to a preferred form.

# %%
zdate_filter = vide['uc-entrada'] == '0000-00-00'
vide.loc[zdate_filter,'rec_type'] = 'see'

see_vide = vide[zdate_filter]
nsee_vide = len(see_vide.index.unique())
match_info.loc['see','data'] = nsee_vide
match_records['see']['data'] = list(see_vide.index.unique())
print("Number of vide records with zero dates (forward cross references):",nsee_vide)

nsee_vide_geo = len(see_vide[see_vide['nome-geografico'].notnull()].index.unique())
match_info.loc['see_geo','data'] = nsee_vide_geo
print(f"    of which {nsee_vide_geo} with place of birth {nsee_vide_geo/nsee_vide:.2%}")

nsee_vide_pai = len(see_vide[see_vide['nome-pai'].notnull()].index.unique())
match_info.loc['see_pai','data'] = nsee_vide_pai
print(f"    of which {nsee_vide_pai} with father's name  {nsee_vide_pai/nsee_vide:.2%}")

nsee_vide_fac = len(see_vide[see_vide['faculdade'].notnull()].index.unique())
match_info.loc['see_fac','data'] = nsee_vide_fac
print(f"    of which {nsee_vide_fac} with faculty        {nsee_vide_fac/nsee_vide:.2%}")

print()
base_vide_cols=['nome-vide','nome-geografico','faculdade','nome-pai']
# Out:
# Number of vide records with zero dates (forward cross references): 5563
#     of which 5153 with place of birth 92.63%
#     of which 1512 with father's name  27.18%
#     of which 1305 with faculty        23.46%

# %%
match_info.sort_index(inplace=True)
match_info.fillna(" ")
# Out:
#                     data sequential random
# aka
# aka_matched
# aka_matched_ok
# matched_pairs
# matched_pairs_ok
# nodate
# nodate_novide
# nodate_novide
# records_aka_aka
# records_aka_see
# records_asymmetric
# records_error
# records_matched
# records_matched_ok
# records_see_aka
# records_see_see
# records_transitive
# see                 5563
# see_fac             1305
# see_geo             5153
# see_matched
# see_matched_ok
# see_pai             1512
# vide                8625
# vide_plus

# %%
# Show some
see_vide.head()
# Out:
#                               name sex  nome-vide nome-geografico faculdade  \
# id
# 127765            André Vaz Cabaço   m        Vaz         Coimbra       NaN
# 127798     António Joaquim do Cabo   m    e Faria           Belém       NaN
# 127819  Álvaro de Madureira Cabral   m  Madureira          Lamego       NaN
# 128053   António da Fonseca Cabral   m    Fonseca        Samodães   Cânones
# 128061     António de Matos Cabral   m      Matos    Alhos Vedros   Cânones
#
#        faculdade.date faculdade.obs                     nome-pai  uc-entrada  \
# id
# 127765            NaN           NaN                          NaN  0000-00-00
# 127798            NaN           NaN                          NaN  0000-00-00
# 127819            NaN           NaN                          NaN  0000-00-00
# 128053     0000-00-00       Cânones  Sebastião da Fonseca Cabral  0000-00-00
# 128061     0000-00-00       Cânones         Tomé de Matos Cabral  0000-00-00
#
#           uc-saida uc-saida.date uc-saida.obs rec_type
# id
# 127765  0000-00-00    0000-00-00         None      see
# 127798  0000-00-00    0000-00-00         None      see
# 127819  0000-00-00    0000-00-00         None      see
# 128053  0000-00-00    0000-00-00         None      see
# 128061  0000-00-00    0000-00-00         None      see

# %% [markdown]
# #### "Aka"  or back references: records with "vide" other types of information
#
# These are the records that should be linked back to zero date vide records.
#
# There are too few of them!

# %%
# count vide record with a proper (non-zero) date
aka_filter = vide['uc-entrada'] != '0000-00-00'
vide.loc[aka_filter,'rec_type'] = 'aka'
aka_vide = vide[aka_filter]

naka_vide = len(set(aka_vide.index.values))
match_info.loc['aka','data'] = naka_vide
print("Number of records with vide and proper date (aka):",naka_vide)
match_records['aka']['data'] = list(aka_vide.index.unique())

naka_vide_geo = len(aka_vide[aka_vide['nome-geografico'].notnull()].index.unique())
match_info.loc['aka_geo','data'] = naka_vide_geo
print(f"    of which {naka_vide_geo} with place of birth {naka_vide_geo/naka_vide:.2%}")

naka_vide_pai = len(aka_vide[aka_vide['nome-pai'].notnull()].index.unique())
match_info.loc['aka_pai','data'] = naka_vide_pai
print(f"    of which {naka_vide_pai} with father's name  {naka_vide_pai/naka_vide:.2%}")

naka_vide_fac = len(aka_vide[aka_vide['faculdade'].notnull()].index.unique())
match_info.loc['aka_fac','data'] = naka_vide_fac
print(f"    of which {naka_vide_fac} with faculty        {naka_vide_fac/naka_vide:.2%}")

print("Number of records with vide and zero date (see):",nsee_vide)
# we subtract 
print("Number of zero date records in excess of dated vide records         :", nsee_vide-naka_vide)
match_info.sort_index(inplace=True)
# Out:
# Number of records with vide and proper date (aka): 3062
#     of which 2973 with place of birth 97.09%
#     of which 1619 with father's name  52.87%
#     of which 3035 with faculty        99.12%
# Number of records with vide and zero date (see): 5563
# Number of zero date records in excess of dated vide records         : 2501

# %%
match_info.fillna(" ")
# Out:
#                     data sequential random
# aka                 3062
# aka_fac             3035
# aka_geo             2973
# aka_matched
# aka_matched_ok
# aka_pai             1619
# matched_pairs
# matched_pairs_ok
# nodate              5763
# nodate_novide
# nodate_novide
# records_aka_aka
# records_aka_see
# records_asymmetric
# records_error
# records_matched
# records_matched_ok
# records_see_aka
# records_see_see
# records_transitive
# see                 5563
# see_fac             1305
# see_geo             5153
# see_matched
# see_matched_ok
# see_pai             1512
# vide                8625
# vide_plus

# %%
# Show some
aka_vide.head()
# Out:
#                                name sex       nome-vide    nome-geografico  \
# id
# 128000               António Cabral   m  Castelo Branco           Celorico
# 128013               António Cabral   m          Camelo           Ranhados
# 128142       Diogo de Morais Cabral   m          Morais               Mêda
# 128155                Fernão Cabral   m     Albuquerque  Celorico da Beira
# 128333  Inácio de Figueiredo Cabral   m     Albuquerque            Penalva
#
#        faculdade faculdade.date faculdade.obs           nome-pai  uc-entrada  \
# id
# 128000      Leis     1603-10-07          Leis  João Gil de Abreu  1603-10-07
# 128013   Cânones     1642-10-29       Cânones    Lourenço Cabral  1642-10-29
# 128142   Cânones     1681-10-28       Cânones                NaN  1681-10-28
# 128155   Cânones     1663-10-15       Cânones                NaN  1663-10-15
# 128333   Cânones     1655-10-22       Cânones                NaN  1655-10-22
#
#           uc-saida uc-saida.date uc-saida.obs rec_type
# id
# 128000  1616-05-16    1616-05-16         None      aka
# 128013  1651-05-21    1651-05-21         None      aka
# 128142  1689-10-01    1689-10-01         None      aka
# 128155  1674-07-24    1674-07-24         None      aka
# 128333  1662-07-21    1662-07-21         None      aka

# %% [markdown]
# ### Look at other records with no dates, even if they have no "vide" expression
#
# To test if all zero date records are part of the cross reference scheme.
# Maybe the "vide" expression was missed during input in the database.
#
# Frist collect all records th zero date.

# %%
from timelinknb.pandas import attribute_to_df
from timelinknb import Session

with Session() as session:
    session.begin()

# Get list of people with no start-date and add nome-geografico, nome-pai, nome-vide and faculdade
zero_date = attribute_to_df(
                    the_type='uc-entrada',
                    the_value='0000-00-00',
                    person_info=True,
                    more_cols=['nome-vide','nome-geografico','nome-pai','faculdade','uc-saida'],
                    sql_echo=False)
zero_date.drop(['nome-vide.date','nome-vide.obs','nome-geografico.date','nome-geografico.obs','nome-pai.date','nome-pai.obs','uc-entrada.date','uc-entrada.obs'],axis=1, inplace=True)                    
nzero_date = len(set(zero_date.index.unique()))
print()
print(current_machine,current_time,f'db={db_name}')
print("Total number of rows with zero date:", len(zero_date))
print("Total number of records with zero date:", nzero_date)
match_info.loc['nodate','data'] = nzero_date

base_vide_cols=['nome-vide','nome-geografico','faculdade','nome-pai']
zero_date[base_vide_cols].count(axis=0)
# Out:
# imac-jrc.local 2022-05-11 19:09:38.661894 db=ucalumni
# Total number of rows with zero date: 6061
# Total number of records with zero date: 5763
# nome-vide          5843
# nome-geografico    5605
# faculdade          1521
# nome-pai           1673
# dtype: int64

# %% [markdown]
# #### List of records with no date and no "vide": are they part of the cross references?
#
# These are zero date records with no vide information,
# which means that there are no name transformations
# to be used in searching of matching records.
# But since they have no dates they might be part of
# the cross-reference set.
#
# In late April 2022 there were around 200 records.

# %%
# From the zero date set filter those with no "vide" 
zd_no_vide = zero_date[zero_date['nome-vide'].isnull()]
nzd_no_vide = len(set(zd_no_vide.index.values))
print()
print("Number of records with zero date and no 'vide':",nzd_no_vide)
# Out:
# Number of records with zero date and no 'vide': 200

# %% [markdown]
# #### Check if the unit dates were left blank by mistake
#
# If a record with no unit dates contains neverthless dated information,
# then it would be possible to register the unit dates from that information,
# and the blank unit dates are an error.
#
# First collect all the attributes available for those "zero date no vide" records.

# %%
from timelinknb.pandas import group_attributes

zdnv_group = group_attributes(set(zd_no_vide.index.values))

# %% [markdown]
# Next search for attributes with valid dates in that set.

# %%
zdnv_with_dates = (zdnv_group['date']>'0000-00-00') & (zdnv_group['date'] < '1917-12-31')
false_zd = zdnv_group[zdnv_with_dates]
nfalse_zd = len(set(false_zd.index.values))
print("Number of records with dates in attributes but not unit dates:",nfalse_zd)
print("These are not cross-reference records, just records with unfilled unit dates")
print("Sample:")
false_zd.head(10)[['name','date','type','value','attr_obs']]
# Out:
# Number of records with dates in attributes but not unit dates: 59
# These are not cross-reference records, just records with unfilled unit dates
# Sample:
#                              name        date      type  \
# id
# 128851     Luís de Miranda Cabral  1695-02-23      grau
# 128851     Luís de Miranda Cabral  1695-02-23  grau.ano
# 128851     Luís de Miranda Cabral  1695-05-18      grau
# 128851     Luís de Miranda Cabral  1695-05-18  grau.ano
# 131475               Diogo Fialho  1656-03-30      grau
# 131475               Diogo Fialho  1656-03-30  grau.ano
# 137651  Manuel Pais de Figueiredo  1685-07-30      grau
# 137651  Manuel Pais de Figueiredo  1685-07-30  grau.ano
# 139433       Alexandre da Fonseca  1614-05-17      grau
# 139433       Alexandre da Fonseca  1614-05-17  grau.ano
#
#                             value  \
# id
# 128851          Bacharel em Artes
# 128851     Bacharel em Artes.1695
# 128851        Licenciado em Artes
# 128851   Licenciado em Artes.1695
# 131475        Licenciado em Artes
# 131475   Licenciado em Artes.1656
# 137651       Formatura em Cânones
# 137651  Formatura em Cânones.1685
# 139433        Licenciado em Artes
# 139433   Licenciado em Artes.1614
#
#                                                  attr_obs
# id
# 128851      Incorporação de Bacharel em Artes: 23.02.1695
# 128851      Incorporação de Bacharel em Artes: 23.02.1695
# 128851                                         18.05.1695
# 128851                                         18.05.1695
# 131475  Licenciado em Artes 30.03.1656: Atos e Graus L...
# 131475  Licenciado em Artes 30.03.1656: Atos e Graus L...
# 137651                               Formatura 30.07.1685
# 137651                               Formatura 30.07.1685
# 139433                     Licenciado em Artes 17.05.1614
# 139433                     Licenciado em Artes 17.05.1614

# %% [markdown]
# We remove those records from the possible cross reference aditions.
#
# In late April 2022 there were 60 of such record. They are not cross references.
#
# Removing those from the zero dated, no "vide" records, around 140 remain.

# %%
zd_no_vide_clean = zd_no_vide.drop(false_zd.index)
zd_no_vide_clean['rec_type'] = 'see'
nzd_no_vide_clean = len(zd_no_vide_clean.index.unique())
print()
print("Number of records with zero date and no 'vide' (cleaned):",nzd_no_vide_clean)
match_info.loc['nodate_novide','data'] = nzd_no_vide_clean
match_records['nodate_novide','data'] = zd_no_vide_clean.index.unique()
print("Information contained in these records:")
base_vide_cols=['nome-vide','nome-geografico','faculdade','nome-pai','uc-entrada']
zd_no_vide_clean[base_vide_cols].count(axis=0)
# Out:
# Number of records with zero date and no 'vide' (cleaned): 141
# Information contained in these records:
# nome-vide            0
# nome-geografico    132
# faculdade           79
# nome-pai            63
# uc-entrada         152
# dtype: int64

# %% [markdown]
# Lets see what they look like

# %%
zd_no_vide_clean[['name','nome-vide','nome-pai','nome-geografico','faculdade','faculdade.obs','uc-entrada','rec_type']].head().sort_values('name').fillna(" ")
# Out:
#                              name nome-vide          nome-pai nome-geografico  \
# id
# 128114      Belchior de Sá Cabral                                   Alfândega
# 129384       Damião Dias Caldeira                                    Estremoz
# 128371                João Cabral            António Teixeira   Torres Vedras
# 130534  Manuel Domingues Ferreira                                   Ferreiros
# 130359            Manuel Ferreira                                     Penalva
#
#        faculdade       faculdade.obs  uc-entrada rec_type
# id
# 128114   Cânones             Cânones  0000-00-00      see
# 129384      Leis                Leis  0000-00-00      see
# 128371                                0000-00-00      see
# 130534                                0000-00-00      see
# 130359     Artes  Faculdade inferida  0000-00-00      see

# %% [markdown]
# #### Add zero date records with no 'vide' to records to be matched
#
# We join the zero date no 'vide' records to the vide records,.
#
# We assume that zero date records are also "see also" records which were not flagged as 'vide' due to input variations.
#
# But we know this is not always the case, some of the zero date records are normal records where the unit dates were not recorded for some reason.

# %%
import pandas as pd

vide_plus = pd.concat([vide,zd_no_vide_clean])
nvide_plus = len(vide_plus.index.unique())
match_info.loc['vide_plus','data'] = nvide_plus
match_records['vide_plus']['data'] = vide_plus.index.unique()
print(f"Number of unique records involved in the cross references: {nvide_plus}")
vide_plus.info()
# Out:
# Number of unique records involved in the cross references: 8766
# <class 'pandas.core.frame.DataFrame'>
# Index: 9438 entries, 127765 to 316291
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             9438 non-null   object
#  1   sex              9438 non-null   object
#  2   nome-vide        9286 non-null   object
#  3   nome-geografico  8916 non-null   object
#  4   faculdade        4872 non-null   object
#  5   faculdade.date   4872 non-null   object
#  6   faculdade.obs    4853 non-null   object
#  7   nome-pai         3547 non-null   object
#  8   uc-entrada       9438 non-null   object
#  9   uc-saida         9438 non-null   object
#  10  uc-saida.date    9438 non-null   object
#  11  uc-saida.obs     0 non-null      object
#  12  rec_type         9438 non-null   object
# dtypes: object(13)
# memory usage: 1.3+ MB

# %% [markdown]
# #### Update information on "see" type referecences
#
# Taking into account the new zero date, no vide records (around 140)

# %%
see_vide = vide_plus[vide_plus['uc-entrada'] == '0000-00-00']

nsee_vide = len(see_vide.index.unique())
match_info.loc['see','data'] = nsee_vide
match_records['see']['data']=list(see_vide.index.unique())
print("Number of vide records with zero dates (forward cross references) updated:",nsee_vide)

nsee_vide_geo = len(see_vide[see_vide['nome-geografico'].notnull()].index.unique())
match_info.loc['see_geo','data'] = nsee_vide_geo
print(f"    of which {nsee_vide_geo} with place of birth {nsee_vide_geo/nsee_vide:.2%}")

nsee_vide_pai = len(see_vide[see_vide['nome-pai'].notnull()].index.unique())
match_info.loc['see_pai','data'] = nsee_vide_pai
print(f"    of which {nsee_vide_pai} with father's name  {nsee_vide_pai/nsee_vide:.2%}")

nsee_vide_fac = len(see_vide[see_vide['faculdade'].notnull()].index.unique())
match_info.loc['see_fac','data'] = nsee_vide_fac
print(f"    of which {nsee_vide_fac} with faculty        {nsee_vide_fac/nsee_vide:.2%}")
print()

base_vide_cols=['nome-vide','nome-geografico','faculdade','nome-pai']
# Out:
# Number of vide records with zero dates (forward cross references) updated: 5704
#     of which 5274 with place of birth 92.46%
#     of which 1569 with father's name  27.51%
#     of which 1378 with faculty        24.16%

# %% [markdown]
# #### Closer look at "see" references

# %% [markdown]
# ##### Presence of place of birth in zero date records
#
# Most of them have place of birth information.

# %%
see_vide_with_geo = see_vide[see_vide['nome-geografico'].notnull()]
nsee_vide_with_geo = len(set(see_vide_with_geo.index.values))
print("See references with geo info (unique records):",
       nsee_vide_with_geo,
       "out of",nsee_vide,
       f'= {nsee_vide_with_geo/nzero_date:.2%}')
print("Other information (note that some records have more than one geographic name)")
see_vide_with_geo[base_vide_cols].count(axis=0)
# Out:
# See references with geo info (unique records): 5274 out of 5704 = 91.51%
# Other information (note that some records have more than one geographic name)
# nome-vide          5433
# nome-geografico    5565
# faculdade          1392
# nome-pai           1639
# dtype: int64

# %% [markdown]
# ##### See references with no birth place
#
# Check which information is available when place of birth is missing.
#
# The values are similar to normal "see" records.

# %%
see_vide_nogeo = see_vide[see_vide['nome-geografico'].isnull()]
nsee_vide_nogeo = len(set(see_vide_nogeo.index.values))
print("Zero date records without geo info:",
       nsee_vide_nogeo,
       "out of",nzero_date,
       f'= {nsee_vide_nogeo/nzero_date:.2%}')
print()
print("Other information:")
see_vide_nogeo[base_vide_cols].count(axis=0)
# Out:
# Zero date records without geo info: 430 out of 5763 = 7.46%
#
# Other information:
# nome-vide          410
# nome-geografico      0
# faculdade           64
# nome-pai            20
# dtype: int64

# %% [markdown]
# ### Final ist of records involved in cross references

# %%
import pandas as pd

pd.set_option('display.max_rows',50)
vide_plus.info()
vide_plus.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9438 entries, 127765 to 316291
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             9438 non-null   object
#  1   sex              9438 non-null   object
#  2   nome-vide        9286 non-null   object
#  3   nome-geografico  8916 non-null   object
#  4   faculdade        4872 non-null   object
#  5   faculdade.date   4872 non-null   object
#  6   faculdade.obs    4853 non-null   object
#  7   nome-pai         3547 non-null   object
#  8   uc-entrada       9438 non-null   object
#  9   uc-saida         9438 non-null   object
#  10  uc-saida.date    9438 non-null   object
#  11  uc-saida.obs     0 non-null      object
#  12  rec_type         9438 non-null   object
# dtypes: object(13)
# memory usage: 1.3+ MB
#                               name sex       nome-vide nome-geografico  \
# id
# 127765            André Vaz Cabaço   m             Vaz         Coimbra
# 127798     António Joaquim do Cabo   m         e Faria           Belém
# 127819  Álvaro de Madureira Cabral   m       Madureira          Lamego
# 128000              António Cabral   m  Castelo Branco        Celorico
# 128013              António Cabral   m          Camelo        Ranhados
# 128053   António da Fonseca Cabral   m         Fonseca        Samodães
# 128061     António de Matos Cabral   m           Matos    Alhos Vedros
# 128066  António de Mendonça Cabral   m        Mendonça      Pernambuco
# 128093        António Pinto Cabral   m           Pinto          Grajal
# 128103       António Veloso Cabral   m          Veloso         Sanfins
#
#        faculdade faculdade.date faculdade.obs                     nome-pai  \
# id
# 127765       NaN            NaN           NaN                          NaN
# 127798       NaN            NaN           NaN                          NaN
# 127819       NaN            NaN           NaN                          NaN
# 128000      Leis     1603-10-07          Leis            João Gil de Abreu
# 128013   Cânones     1642-10-29       Cânones              Lourenço Cabral
# 128053   Cânones     0000-00-00       Cânones  Sebastião da Fonseca Cabral
# 128061   Cânones     0000-00-00       Cânones         Tomé de Matos Cabral
# 128066       NaN            NaN           NaN                          NaN
# 128093       NaN            NaN           NaN                          NaN
# 128103       NaN            NaN           NaN                          NaN
#
#         uc-entrada    uc-saida uc-saida.date uc-saida.obs rec_type
# id
# 127765  0000-00-00  0000-00-00    0000-00-00         None      see
# 127798  0000-00-00  0000-00-00    0000-00-00         None      see
# 127819  0000-00-00  0000-00-00    0000-00-00         None      see
# 128000  1603-10-07  1616-05-16    1616-05-16         None      aka
# 128013  1642-10-29  1651-05-21    1651-05-21         None      aka
# 128053  0000-00-00  0000-00-00    0000-00-00         None      see
# 128061  0000-00-00  0000-00-00    0000-00-00         None      see
# 128066  0000-00-00  0000-00-00    0000-00-00         None      see
# 128093  0000-00-00  0000-00-00    0000-00-00         None      see
# 128103  0000-00-00  0000-00-00    0000-00-00         None      see

# %%
match_info.sort_index(inplace=True)
match_info.fillna('')
# Out:
#                     data sequential random
# aka                 3062
# aka_fac             3035
# aka_geo             2973
# aka_matched
# aka_matched_ok
# aka_pai             1619
# matched_pairs
# matched_pairs_ok
# nodate              5763
# nodate_novide        141
# nodate_novide        141
# records_aka_aka
# records_aka_see
# records_asymmetric
# records_error
# records_matched
# records_matched_ok
# records_see_aka
# records_see_see
# records_transitive
# see                 5704
# see_fac             1378
# see_geo             5274
# see_matched
# see_matched_ok
# see_pai             1569
# vide                8625
# vide_plus           8766

# %% [markdown]
# ## Analyse geographic names for variations
#
# Birth place is key to maching, but there are many variations for the same place name
# and many spelling varitants.
#
# We make an index of variations in geographic names and
# find name matches within the set of names from similar spelled places.
#
# For similarity we use the so called "gestalt pattern matching" from the Python library see: https://docs.python.org/3/library/difflib.html
#
# The threshold ratio was determined empirically. It is not a problem that some false varitations are detected since
# a further check is done with matching the names.
#
# The following code compares all the the geographic names and prints out those considered to be variants of the same place, with
# the similarity ration. Note that this ratio is sensitive to length, and fails the threshold in short forms like "Algozo/Algoso" or
# when the two forms are of different lengths like "Poiares/Vila Nova de Poiares".
#
# Stil it detects many usefull variants.

# %%
import difflib

# we have many variations in geografic names
have_geoname_filter = vide_plus['nome-geografico'].notnull()
geonames_index = sorted(vide_plus[have_geoname_filter]['nome-geografico'].unique())
print("Number of different geo names:",len(geonames_index))
geo_similars = {}
diff_threshold = .85

for geo in [g for g in geonames_index if g is not None]:

    for similar in [s for s in geonames_index if s is not None and s > geo] :
        diff = difflib.SequenceMatcher(None, geo, similar).ratio()
        if  diff >= diff_threshold and geo is not None and similar is not None:
            pass
            print(f"{geo} / {similar} diff:{diff:.3}")
            geo_similars[geo] = geo_similars.get(geo,[]) + [similar]
            geo_similars[similar] = geo_similars.get(similar,[]) + [geo]
# Out:
# Number of different geo names: 1429
# Aguas Santas / Águas Santas diff:0.917
# Alcacer / Alcácer diff:0.857
# Alcaide / Alcaíde diff:0.857
# Alenquer / Alquer diff:0.857
# Alhos Vedras / Alhos Vedros diff:0.917
# Almalaguer / Almalaguez diff:0.9
# Sarzeda / Sarzedas diff:0.933
# Sarzeda / Sarzedo diff:0.857
# Sarzedas / Sarzedos diff:0.875
# Sarzedo / Sarzedos diff:0.933
# Sernancelhe / Sernancellhe diff:0.957
# Sertã / Setã diff:0.889
# Setubal / Setúbal diff:0.857
# Silvares / Silves diff:0.857
# Sousel / Souselas diff:0.857
# Sousel / Souselo diff:0.923
# São João Fontura / São João da Fontoura diff:0.889
# São João Fontura / São João de Fontoura diff:0.889
# São João da Fontoura / São João de Fontoura diff:0.95
# São João de Areias / São João de Areis diff:0.971
# São João de Cerveira / São João de Corveira diff:0.95
# São João de Corveira / São João de Covas diff:0.865
# São João de Corveira / São João de Loureiro diff:0.85
# São João de El-Rei / São João del-Rei diff:0.941
# São Mamede / SãoMamede diff:0.947
# São Martinho de Salreu / São Martinho de Sardoura diff:0.87
# São Martinho do Bispo / São Martinho do Campo diff:0.857
# São Martinho do Campo / São Martinho do Lago diff:0.878
# São Paio da Guarda / São Tiago da Guarda diff:0.865
# Talhas / Tinalhas diff:0.857
# Tancos / Trancoso diff:0.857
# Tavira / Traveira diff:0.857
# Teixoso / Teixôso diff:0.857
# Terra da Feira / Terra da feira diff:0.929
# Trevões / Trovões diff:0.857
# Tuizende / Tuizendes diff:0.941
# Vale de Prazeres / Vale dos Prazeres diff:0.909
# Vila Chã / Vilar Chão diff:0.889
# Vila Cova / Vila Nova diff:0.889
# Vila Cova de Sub Avô / Vila Cova de Sub-Avô diff:0.95
# Vila Cova de Sub Avô / Vila Nova de Sub Avô diff:0.95
# Vila Cova de Sub-Avô / Vila Nova de Sub Avô diff:0.9
# Vila Cova à Coelheira / Vila Cova á Coelheira diff:0.952
# Vila Flor / Vila Flôr diff:0.889
# Vila Nova d'Anços / Vila Nova de Anços diff:0.914
# Vila Nova de Casal / Vila Nova de Gaia diff:0.857
# Vila Nova de Monsarros / Vila de Monsarros diff:0.872
# Vila Ponte / Vila da Ponte diff:0.87
# Vila Real / Vila real diff:0.889
# Vila Real / vila Real diff:0.889
# Vila da Feira / Vilar da Beira diff:0.889
# Várzae de Meruge / Várzea de Meruge diff:0.938
# Várzae de Meruge / Várzea de Moruge diff:0.875
# Várzea / Várzeas diff:0.923
# Várzea de Meruge / Várzea de Moruge diff:0.938

# %% [markdown]
# ## Matching "vide" references
#
# Try to match "forward" and "backward" references by generating the target names from "vide"
# expressions

# %% [markdown]
# ### Generation of target names from "vide" expressions
#
#
# There are four types of "vide" expressions:
#
# 1. “Cut”: António Veloso Cabral, vide Veloso, result: António Veloso. The “vide” expression is a family name before the last; the target name is computed as the base name up to and including the “vide” expression; the resulting name is a shorter version of the base name, with the last family name(s) removed
# 2. “Add”: André de Campos, vide Cordeiro, result: André de Campos Cordeiro. The “vide” expression is not present in the base name; the target name is the base name with the “vide” expression added at the end; in some cases, the real target name will have and extra particle before the vide expression, like “de”, “e”, ... etc...).
# 3.	“Replace”: Adriano Sisnando Brotero de Avelar Quintino, vide Adriano Sisnando Brotero Quintino de Avelar, result: Adriano Sisnando Brotero Quintino de Avelar. The “vide” expression is a full name, sharing the first name with the base name. This happens when the transformation of family names cannot be expressed by “cut” and “add”, so the author of the card wrote the full target name after “vide” for clarity.
# 4.	“Partial replace”: Francisco António Campos, vide de Novais Campos, result: Francisco António de Novais Campos. The “vide” expression replaces part of the base name; the “base name” and the “vide” expression overlap at the end; the matched part in the “base name” is replaced by the “vide” expression.

# %% [markdown]
# #### Collect first names from database, filter rare ones
#
# We need the first names in the database for the next step.

# %%
# collect possible first names from current database
from timelinknb.pandas import attribute_values
from timelinknb import Session


# collect list of first names, ignore the less frequent ones
#
threshold = 5
pnomes = []
pnomes_table = attribute_values('nome-primeiro')
for id,linha in pnomes_table.iterrows():
    pnome = id
    count = linha['count']
    if count>threshold:
        pnomes.append(pnome)

print(f"Number of first names with more than {threshold} occurrences {len(pnomes)}")
print("Use this to copy to other places:")
print()
print("[")
for i in range(len(pnomes)):
    print(f"'{pnomes[i]}',", end='')
    if int((i+1)%5) == 0:
        print()
print("]")
# Out:
# Number of first names with more than 5 occurrences 279
# Use this to copy to other places:
#
# [
# 'Abel','Abílio','Acácio','Acúrcio','Adão',
# 'Adelino','Adolfo','Adriano','Adrião','Afonso',
# 'Agnelo','Agostinho','Aires','Albano','Alberto',
# 'Albino','Aleixo','Alexandre','Alfredo','Alípio',
# 'Álvaro','Amadeu','Amador','Amancio','Amândio',
# 'Amaro','Ambrósio','Américo','Anacleto','Anastácio',
# 'André','Ângelo','Aníbal','Aniceto','Anselmo',
# 'Antão','Antero','António','Antrónio','Apolinário',
# 'Arcanjo','Aristides','Armando','Arnaldo','Arsenio',
# 'Artur','Ascenso','Atanásio','Augusto','Aureliano',
# 'Aurélio','Avelino','Baltasar','Barnabé','Bartolomeu',
# 'Basílio','Batista','Belchior','Benjamim','Bento',
# 'Berardo','Bernardino','Bernardo','Boaventura','Bonifácio',
# 'Brás','Bruno','Caetano','Calisto','Camilo',
# 'Cândido','Carlos','Casimiro','Celestino','César',
# 'Cipriano','Cláudio','Clemente','Constantino','Cosme',
# 'Crisogono','Crispim','Cristiano','Cristóvão','Custódio',
# 'Dâmaso','Damião','Daniel','David','Delfim',
# 'Desidério','Diamantino','Dinis','Diogo','Dionísio',
# 'Domingos','Duarte','Edmundo','Eduardo','Egídio',
# 'Eleuterio','Elias','Elisío','Emídio','Emílio',
# 'Ernesto','Estácio','Estanislau','Estevão','Eugénio',
# 'Eurico','Eusébio','Eustáquio','Evaristo','Fabião',
# 'Fabricio','Faustino','Fausto','Feliciano','Felício',
# 'Felisberto','Felix','Fernando','Fernão','Filipe',
# 'Firmino','Florêncio','Fortunato','Fradique','Francisco',
# 'Frederico','Fructuoso','Frutuoso','Gabriel','Garcia',
# 'Gaspar','Gerardo','Germano','Gervásio','Gil',
# 'Giraldo','Gomes','Gonçalo','Gregório','Gualter',
# 'Guilherme','Gustavo','Heitor','Henrique','Henriques',
# 'Herculano','Hermano','Higidio','Hilário','Hipólito',
# 'Horácio','Ildefonso','Inácio','Inocêncio','Isidoro',
# 'Ivo','Jacinto','Jacome','Jaime','Januário',
# 'Jerónimo','João','Joaquim','Jordão','Jorge',
# 'José','Julião','Júlio','Justino','Lancerote',
# 'Lázaro','Leandro','Leão','Leonardo','Leonel',
# 'Leopoldo','Libânio','Lino','Lopo','Lourenço',
# 'Lucas','Luciano','Lúcio','Luís','Macário',
# 'Mamede','Manuel','Marçal','Marcelino','Marcos',
# 'Mariano','Mário','Martim','Martinho','Martins',
# 'Mateus','Matias','Mauricio','Maximiano','Máximo',
# 'Melchior','Mendo','Miguel','Narciso','Nicolau',
# 'Norberto','Nuno','Onofre','Óscar','Paio',
# 'Pantaleão','Pascoal','Patrício','Paulino','Paulo',
# 'Pedro','Plácido','Policarpo','Pompeu','Porfírio',
# 'Possidónio','Prudêncio','Quintino','Rafael','Raimundo',
# 'Ramiro','Raúl','Ricardo','Roberto','Rodrigo',
# 'Romão','Roque','Rosendo','Rufino','Rui',
# 'Salvador','Sancho','Santos','Sebastião','Semião',
# 'Serafim','Sérgio','Severino','Silvério','Silvestre',
# 'Simão','Simião','Simplicio','Teodoro','Teodósio',
# 'Teófilo','Teotónio','Timóteo','Tito','Tomás',
# 'Tomé','Torcato','Tristão','Urbano','Valentim',
# 'Valério','Vasco','Venâncio','Ventura','Veríssimo',
# 'Vicente','Virgílio','Viriato','Vital','Vitor',
# 'Vitoriano','Vitorino','Xavier','Zeferino',]

# %% [markdown]
# #### Apply vide expression transformation for records, get the target name
#
# Echo replacements that involve changing the first name, because they are error prone.

# %%
from os.path import commonprefix
import re


vide_plus['loookup']=''
vide_plus['vide_type']=''

for id,linha in vide_plus.iterrows():
    nome =  linha['name']
    if not pd.isnull(linha['nome-vide']) :
        nome_vide = linha['nome-vide']
        nomes = nome.split(" ")
        nomes_vide = nome_vide.split(" ")
        # find a common suffix (invert names, use commonprefix, invert result)
        terminacao_comum = commonprefix([nome[::-1],nome_vide[::-1]])[::-1]
        # check it is a separate name and not just common letters at the end
        # a proper family name should share a starting space 
        if len(terminacao_comum) > 0:
            if terminacao_comum[0] != ' ':
                terminacao_comum = ''    # not a separate name, abandom
            else:
                terminacao_comum = terminacao_comum.strip()
        # currently using common suffix lowers the matches why?
        # terminacao_comum = ''

        # Type CUT: vide is a inner part of the original name
        # e.g. André Vaz Cabaço, vide Vaz
        # but also Manuel de Almeida Cabral, vide de Almeida 
        pos = nome.find(nome_vide)
        if pos > -1:
            lookup_name = nome[0:pos] + nome_vide
            vtype="cut"
        # Type REP: vide name looks like a full name 
        # e.g. António de Abreu Bacelar de Azevedo, vide António Abreu Bacelar
        # relaxing the same first name rule, lots  of leaks
        #  This leaks a lot : elif len(nomes_vide)>1 and nomes_vide[0] in pnomes :
        elif nomes[0] == nomes_vide[0]:
            lookup_name = nome_vide 
            vtype='rep'
        # Type REPAP: vide overlaps end of name
        # e.g. Joaquim Carvalho, vide Ramos de Carvalho
        # but vide must not contain first name
        # in that case probably a REP
        # otherwise generates leaks and lowers mumbers of matches
        elif terminacao_comum > '':
            if not nomes_vide[0] in pnomes :
                lookup_name = re.sub(f'{terminacao_comum}$',nome_vide,nome)
                vtype='repap'
            else:  # if common termination and first name better replace
                lookup_name = nome_vide
                vtype='rep'              
        else:
            # TYPE ADD vide name is not part of original nor a full name
            # so it must be an aditional surname
            # e.g. Fernão Cabral, vide Albuquerque = Fernão Cabral Albuquerque
            lookup_name = nome+" "+nome_vide
            vtype='add'
    else:
        lookup_name = nome
        vtype='novid'
  
        
    # we try to recover cases where there was replacement of first name
    # they are missed by the REP amd REPAP rules above and end up 
    # producing lookup which are the sobreposition of two names
    # this was added by examining bad "ADD" and "REPAP" results
    # if the result is a long name (>5 names), both name and vide start
    # with first names and vide also long (>4) then probable a replace
    # that changes the first name.
    nomes_lookup = lookup_name.split()
    if vtype != 'rep' \
         and nomes[0] in pnomes and nomes_vide[0] in pnomes\
         and nomes[0] != nomes_vide[0]\
         and len(nomes_vide) > 3\
         and len(nomes_lookup) > 5:
        old_lookup = lookup_name
        lookup_name = nome_vide
        vtype = 'rep+'
        print(id,nome,"vide", nome_vide,"--->",lookup_name,"\n  instead of", old_lookup)

    # print(f'{type} :{id:7}{nome:40}{nome_vide:40} = {lookup_name}')
    vide_plus.loc[id,'lookup'] = lookup_name
    vide_plus.loc[id,'vide_type'] = vtype
# Out:
# 174974 Dionísio Dinis de Oliveira vide Dinis de Oliveira da Fonseca ---> Dinis de Oliveira da Fonseca
#   instead of Dionísio Dinis de Oliveira Dinis de Oliveira da Fonseca
# 175757 João Batista de Oliveira vide José Batista de Oliveira Baeina ---> José Batista de Oliveira Baeina
#   instead of João Batista de Oliveira José Batista de Oliveira Baeina
# 179121 João Xavier Mousinho da Silveira Gomide vide José Xavier Mousinho Gomide da Silveira ---> José Xavier Mousinho Gomide da Silveira
#   instead of João Xavier Mousinho da Silveira Gomide José Xavier Mousinho Gomide da Silveira
# 180061 João António Osório Pereira Gouveia vide Adriano Osório Pereira Guerra ---> Adriano Osório Pereira Guerra
#   instead of João António Osório Pereira Gouveia Adriano Osório Pereira Guerra
# 180742 Adriano Osório Pereira Guerra vide João António Pereira Cerenato ---> João António Pereira Cerenato
#   instead of Adriano Osório Pereira Guerra João António Pereira Cerenato
# 195729 Joaquim da Conceição vide Jacinto de São José ---> Jacinto de São José
#   instead of Joaquim da Conceição Jacinto de São José
# 197167 António Tavares vide Santos e vide Leitão ---> Santos e vide Leitão
#   instead of António Tavares Santos e vide Leitão
# 205068 Joaquim Rodrigues Couceiro vide José Rodrigues da Assunção ---> José Rodrigues da Assunção
#   instead of Joaquim Rodrigues Couceiro José Rodrigues da Assunção
# 214868 Tomás de Lemos vide Tomé Dias de Lemos ---> Tomé Dias de Lemos
#   instead of Tomás de Lemos Tomé Dias de Lemos
# 230176 Tomás Joaquim Lopes de Mariz e Silva vide Adriano Joaquim Lopes Mariz e Silva Monteiro ---> Adriano Joaquim Lopes Mariz e Silva Monteiro
#   instead of Tomás Joaquim Lopes de Mariz e Silva Adriano Joaquim Lopes Mariz e Silva Monteiro
# 230176 Tomás Joaquim Lopes de Mariz e Silva vide Adriano Joaquim Lopes Mariz e Silva Monteiro ---> Adriano Joaquim Lopes Mariz e Silva Monteiro
#   instead of Tomás Joaquim Lopes de Mariz e Silva Adriano Joaquim Lopes Mariz e Silva Monteiro
# 233204 Francisco António Moreira vide António Moreira da Silva ---> António Moreira da Silva
#   instead of Francisco António Moreira António Moreira da Silva
# 238735 Melchior de Matos Pereira vide Belchior de Matos Pereira ---> Belchior de Matos Pereira
#   instead of Melchior de Matos Pereira Belchior de Matos Pereira
# 239458 Tomás da Costa Pereira vide Tomé da Costa Pereira de Abreu ---> Tomé da Costa Pereira de Abreu
#   instead of Tomás da Costa Pereira Tomé da Costa Pereira de Abreu
# 239458 Tomás da Costa Pereira vide Tomé da Costa Pereira de Abreu ---> Tomé da Costa Pereira de Abreu
#   instead of Tomás da Costa Pereira Tomé da Costa Pereira de Abreu
# 243778 Francisco Ferraz vide Silvestre de Nossa Senhora ---> Silvestre de Nossa Senhora
#   instead of Francisco Ferraz Silvestre de Nossa Senhora
# 250994 Adriano Joaquim de Mariz e Silva Monteiro vide Tomás Joaquim Lopes de Maris e Silva ---> Tomás Joaquim Lopes de Maris e Silva
#   instead of Adriano Joaquim de Mariz e Silva Monteiro Tomás Joaquim Lopes de Maris e Silva
# 250994 Adriano Joaquim de Mariz e Silva Monteiro vide Tomás Joaquim Lopes de Maris e Silva ---> Tomás Joaquim Lopes de Maris e Silva
#   instead of Adriano Joaquim de Mariz e Silva Monteiro Tomás Joaquim Lopes de Maris e Silva
# 288307 Domingos José Cardoso de Oliveira vide Pedro Paulo Januário Marcondes e Cardoso ---> Pedro Paulo Januário Marcondes e Cardoso
#   instead of Domingos José Cardoso de Oliveira Pedro Paulo Januário Marcondes e Cardoso
# 288307 Domingos José Cardoso de Oliveira vide Pedro Paulo Januário Marcondes e Cardoso ---> Pedro Paulo Januário Marcondes e Cardoso
#   instead of Domingos José Cardoso de Oliveira Pedro Paulo Januário Marcondes e Cardoso

# %% [markdown]
# #### Collect stats on type of vide transformation applied

# %%
vide_types = vide_plus.groupby('vide_type').count()[['name']]
vide_types['perc'] = vide_types['name']/ vide_types['name'].sum()
vide_types
# Out:
#            name      perc
# vide_type
# add        4057  0.429858
# cut        4126  0.437169
# novid       152  0.016105
# rep        1057  0.111994
# rep+         20  0.002119
# repap        26  0.002755

# %% [markdown]
# #### Double check partial replace transformation
#
# * Partial replace:
#     * Francisco António Campos, vide de Novais Campos, result: Francisco António de Novais Campos.
#         * the “vide” expression replaces part of the base name;
#         * the “base name” and the “vide” expression overlap at the end;
#         * the matched part in the “base name” is replaced by the “vide” expression.
#
# They are sensistive to misspelling in first names.

# %%
# Check if we got many cases of vide with overlap, and if they are handled right
repap = vide_plus[['name','nome-vide','vide_type', 'lookup','nome-geografico','faculdade','uc-entrada']].sort_values(['name','nome-vide','vide_type', 'lookup'])
repap[repap.vide_type == 'repap']
# Out:
#                                          name  \
# id
# 151153                      António Barreiros
# 171604                      Belchior de Matos
# 171604                      Belchior de Matos
# 198283                               Manuel Pinto Tavares
# 213697                               Manuel Telo da Veiga
# 189878     Manuel de Jesus Távora de Jesus Castelo Branco
# 212238                               Manuel Pereira de Sá
# 248878                       Vasco Vasques Annes Mousinho
# 143834                         Veríssimo Lopes de Almeida
#
#                  nome-geografico                           faculdade  \
# id
# 151153                    Lisboa                                Leis
# 171604               Vila Viçosa                             Cânones
# 171604               Vila Viçosa                                Leis
# 192525                     Porto                                 NaN
# 130230                   Azeitão                                 NaN
# 135280                      Meãs                             Cânones
# 135280                      vila                             Cânones
# 209659                  Amarante                                 NaN
# 165045                Alvorninha                                 NaN
# 165046                Alvorninha                             Cânones
# 278030                    Parada                                 NaN
# 278030                     Viseu                                 NaN
# 245474                     Lousã                             Cânones
# 277264  Freixo de Espada à Cinta  Cursos jurídicos (Cânones ou Leis)
# 228003                   Verride                             Cânones
# 186019                   Abragão                             Cânones
# 211660                       NaN                                 NaN
# 204835                   Covilhã                                Leis
# 137116            Alcácer do Sal                             Cânones
# 148817                   Coimbra                             Cânones
# 198283                    Canedo                                 NaN
# 213697     São João da Pesqueira                                 NaN
# 189878                   Valezim                                 NaN
# 212238                  Barcelos                             Cânones
# 248878                   Setúbal                                 NaN
# 143834                     Porto                                 NaN
#
#         uc-entrada
# id
# 151153  1655-10-16
# 171604  1621-10-11
# 171604  1621-10-11
# 192525  0000-00-00
# 130230  0000-00-00
# 135280  1762-10-01
# 135280  1762-10-01
# 209659  0000-00-00
# 165045  0000-00-00
# 165046  1735-10-01
# 278030  0000-00-00
# 278030  0000-00-00
# 245474  1756-10-01
# 277264  0000-00-00
# 228003  1747-11-15
# 186019  1765-10-01
# 211660  0000-00-00
# 204835  1747-10-01
# 137116  0000-00-00
# 148817  1750-10-01
# 198283  0000-00-00
# 213697  0000-00-00
# 189878  0000-00-00
# 212238  0000-00-00
# 248878  0000-00-00
# 143834  0000-00-00

# %% [markdown]
# Current fails:
#
# * 135280	Francisco Tavares de Figueiredo	__vide__ Farncisco Xavier Tavares de Figueiredo	repap	Francisco Farncisco Xavier Tavares de Figueiredo __first name misspelled__
# * 245474    Jerónimo de Magalhães Mexia	jerónimo __vide__ josé de Macêdo Magalhães Mexia	repap	Jerónimo de jerónimo josé de Macêdo Magalhães ...	__first name misspelled__
# * 277264	José Luís Alves Feijó __vide__ Angelo do Santíssimo Sacramento Alves Feijó	repap	José Luís Angelo do Santíssimo Sacramento Alve...	__first name misspelled__
# * 228003	José da Fonseca Marques da Silva __vide__ da Fonseca da Silva	repap	José da Fonseca Marques da Fonseca da Silva: __bad expression should be a replace__
# * 204835    Luís de Figueiredo	__vide__ Figueiredo Lobo ou Lobo de Figueiredo	repap	Luís Figueiredo Lobo ou Lobo de Figueiredo __bad expression not understandable__

# %% [markdown]
# #### Remove particles from names
#
# To increase the chance of matches we make a copy of names and target names derived from "vide"
# without the particles that are used in Portuguese names (not very uniformely)

# %%
def remove_particles(name):
    particles = ("de","da","e","das","dos","do")
    return " ".join([n for n in name.split() if n not in particles])

vide_plus['name_sp'] = vide_plus['name'].apply(lambda name: remove_particles(name))
vide_plus['lookup_sp'] = vide_plus['lookup'].apply(lambda name: remove_particles(name))
vide_plus[vide_plus['name']!=vide_plus['name_sp']][['name','name_sp', 'lookup','lookup_sp']].head(10)
# Out:
#                                     name                        name_sp  \
# id
# 127798           António Joaquim do Cabo           António Joaquim Cabo
# 127819        Álvaro de Madureira Cabral        Álvaro Madureira Cabral
# 128053         António da Fonseca Cabral         António Fonseca Cabral
# 128061           António de Matos Cabral           António Matos Cabral
# 128066        António de Mendonça Cabral        António Mendonça Cabral
# 128125        Britaldo de Gouveia Cabral        Britaldo Gouveia Cabral
# 128142            Diogo de Morais Cabral            Diogo Morais Cabral
# 128159          Filipe de Gouveia Cabral          Filipe Gouveia Cabral
# 128244  Francisco Xavier da Veiga Cabral  Francisco Xavier Veiga Cabral
# 128295            João da Costa Cabreira            João Costa Cabreira
#
#                                  lookup                   lookup_sp
# id
# 127798  António Joaquim do Cabo e Faria  António Joaquim Cabo Faria
# 127819              Álvaro de Madureira            Álvaro Madureira
# 128053               António da Fonseca             António Fonseca
# 128061                 António de Matos               António Matos
# 128066              António de Mendonça            António Mendonça
# 128125              Britaldo de Gouveia            Britaldo Gouveia
# 128142                  Diogo de Morais                Diogo Morais
# 128159                Filipe de Gouveia              Filipe Gouveia
# 128244        Francisco Xavier da Veiga      Francisco Xavier Veiga
# 128295                    João da Costa                  João Costa

# %% [markdown]
# #### Save name transformations for reference
#
# Output table with the generation of target names from base names and vide expressions.
#
# File available at /inferences/cross-references/vide_transform.csv
#
# This table allows comparing between sucessive versions for fine tuning.

# %%
# save for change tracking
vide_plus[['name','name_sp','nome-vide','vide_type','lookup', 'lookup_sp']].sort_values('name_sp').to_csv('../inferences/remissivas/vide_transform.csv',sep=',')

# %% [markdown]
# ### Match

# %% [markdown]
# #### Sort by geographic name, name and lookup
#
# First attemp is to order the records so that matching cross references end up in consecutive rows.
# We sort by place of birth and inside place of birth by name and target vide name.
#
# This is a type of similarity filter, that puts many matches in sucessive rows.

# %%
# sort by naturalidade, 'lookup', 'name' (with the  name and lookup ordered alfabetically)
# this should put the vide pair in sucessive rows, but misses some cases due to ordering issues
cols = ['lookup_sp','name_sp']
vide_plus['sort_key'] = vide_plus[cols].apply(lambda row: '-'.join(sorted(row.values.astype(str))), axis=1)
vide_plus.sort_values(['nome-geografico','sort_key'], inplace=True)
vide_plus[['nome-geografico','sort_key', 'name_sp','lookup_sp','nome-vide','vide_type','uc-entrada','nome-pai','faculdade']].head(10)
# Out:
#        nome-geografico                                           sort_key  \
# id
# 198423      Constância  António Homem Magalhães-António Homem Magalhãe...
# 144388      Constância               Fernão Álvares-Fernão Álvares Temudo
# 202622      Constância               Fernão Álvares-Fernão Álvares Temudo
# 129617      Constância  João Claúdio Ferreira Calado-João Claúdio Ferr...
# 171438      Constância              João Veiga-João Veiga Mendes Nogueira
# 213495      Constância              João Veiga-João Veiga Mendes Nogueira
# 143676      Constância                  Julião Velho-Julião Velho Almeida
# 214577      Constância                  Julião Velho-Julião Velho Almeida
# 176277      Constância                 Manuel Costa-Manuel Costa Oliveira
# 203159      Constância                 Manuel Costa-Manuel Costa Oliveira
#
#                                    name_sp  \
# id
# 198423  António Homem Magalhães Corte Real
# 144388                      Fernão Álvares
# 202622               Fernão Álvares Temudo
# 129617        João Claúdio Ferreira Calado
# 171438          João Veiga Mendes Nogueira
# 213495                          João Veiga
# 143676                Julião Velho Almeida
# 214577                        Julião Velho
# 176277               Manuel Costa Oliveira
# 203159                        Manuel Costa
#
#                                     lookup_sp                      nome-vide  \
# id
# 198423                António Homem Magalhães                      Magalhães
# 144388                  Fernão Álvares Temudo                         Temudo
# 202622                         Fernão Álvares                        Álvares
# 129617  João Claúdio Ferreira Calado Oliveiro                       Oliveiro
# 171438                             João Veiga                  João da Veiga
# 213495             João Veiga Mendes Nogueira  João da Veiga Mendes Nogueira
# 143676                           Julião Velho                          Velho
# 214577                   Julião Velho Almeida                        Almeida
# 176277                           Manuel Costa                          Costa
# 203159                  Manuel Costa Oliveira                       Oliveira
#
#        vide_type  uc-entrada          nome-pai faculdade
# id
# 198423       cut  0000-00-00               NaN      Leis
# 144388       add  1573-11-13  Pantaleão Rosado   Cânones
# 202622       cut  0000-00-00               NaN       NaN
# 129617       add  0000-00-00               NaN       NaN
# 171438       cut  0000-00-00               NaN      Leis
# 213495       rep  1757-10-01               NaN      Leis
# 143676       cut  1663-07-10               NaN   Cânones
# 214577       add  0000-00-00               NaN       NaN
# 176277       cut  1672-01-24   Manuel da Costa   Cânones
# 203159       add  0000-00-00   Manuel da Costa       NaN

# %%
# we set records with no nome geográfico temporarly to a string
# so that we can have them together for consideration
vide_plus.loc[vide_plus['nome-geografico'].isnull(),'nome-geografico'] = '***NA***'

# %% [markdown]
# #### Sequential matching
#
# In late April around 3600 records found a match by this process.
#
# Bit some matches are inconsistent (assymetric or ambiguous).

# %%
def compare_names(name1, name2):
    return remove_particles(name1) == remove_particles(name2)

previous_lookup = ''
previous_nome = ''
previous_id = ''
previous_date = ''
sequential_matches = []

for id,linha in vide_plus.iterrows():
    nome = linha['name_sp']
    lookup_name = linha['lookup_sp']
    uc_date = linha['uc-entrada']
    rec_type = linha['rec_type']

    if compare_names(previous_lookup,nome)\
         and compare_names(previous_nome,lookup_name)\
         and id != previous_id:
        # we store the direction of the match see-aka or aka-see
        from_type = rec_type
        to_type = previous_rec_type
        to_tuple = (id,previous_id,f'{from_type}-{to_type}')
        from_tuple = (previous_id,id,f'{to_type}-{from_type}')
        if to_tuple in sequential_matches:
            # print("Skipping duplicate match",to_tuple)
            pass
        else:
            sequential_matches.append((id,previous_id,f'{from_type}-{to_type}'))
        if from_tuple in sequential_matches:
            # print("Skipping duplicate match",to_tuple)
            pass
        else:    
            sequential_matches.append((previous_id,id,f'{to_type}-{from_type}'))

    previous_id = id
    previous_nome = nome
    previous_lookup = lookup_name  
    previous_date = uc_date
    previous_rec_type = rec_type

vide_plus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9438 entries, 198423 to 230315
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             9438 non-null   object
#  1   sex              9438 non-null   object
#  2   nome-vide        9286 non-null   object
#  3   nome-geografico  9438 non-null   object
#  4   faculdade        4872 non-null   object
#  5   faculdade.date   4872 non-null   object
#  6   faculdade.obs    4853 non-null   object
#  7   nome-pai         3547 non-null   object
#  8   uc-entrada       9438 non-null   object
#  9   uc-saida         9438 non-null   object
#  10  uc-saida.date    9438 non-null   object
#  11  uc-saida.obs     0 non-null      object
#  12  rec_type         9438 non-null   object
#  13  loookup          9438 non-null   object
#  14  vide_type        9438 non-null   object
#  15  lookup           9438 non-null   object
#  16  name_sp          9438 non-null   object
#  17  lookup_sp        9438 non-null   object
#  18  sort_key         9438 non-null   object
# dtypes: object(19)
# memory usage: 1.7+ MB

# %% [markdown]
# ##### Analyse sequential match results

# %%
method = 'sequential'
match_records['matched_pairs'][method] = list(set(sequential_matches))
match_info.loc['matched_pairs'][method] = len(match_records['matched_pairs'][method])

# pairs 
pairs_see_aka = [(o,d,mtype) for (o,d,mtype) in sequential_matches if mtype == 'see-aka']
pairs_aka_see = [(o,d,mtype) for (o,d,mtype) in sequential_matches if mtype == 'aka-see']
pairs_aka_aka = [(o,d,mtype) for (o,d,mtype) in sequential_matches if mtype == 'aka-aka']
pairs_see_see = [(o,d,mtype) for (o,d,mtype) in sequential_matches if mtype == 'see-see']

# records
rec_matched = set([id for (id,d,t) in sequential_matches]+
                  [id for (o,id,t) in sequential_matches])
rec_see_aka = set([id for (id,d,t) in pairs_see_aka])
rec_aka_see = set([id for (o,id,t) in pairs_aka_see])
rec_see_see = set([id for (id,d,t) in pairs_see_see] +
                  [id for (o,id,t) in pairs_see_see])
rec_aka_aka = set([id for (id,d,t) in pairs_aka_aka] +
                  [id for (o,id,t) in pairs_aka_aka])

match_records['records_matched'][method] = list(rec_matched)
match_records['records_see_aka'][method] = list(rec_see_aka)
match_records['records_aka_see'][method] = list(rec_aka_see)
match_records['records_aka_aka'][method] = list(rec_aka_aka)
match_records['records_see_see'][method] = list(rec_see_see)

match_info.loc['records_matched'][method] = len(rec_matched)
match_info.loc['records_see_aka'][method] = len(rec_see_aka)
match_info.loc['records_aka_see'][method] = len(rec_aka_see)
match_info.loc['records_aka_aka'][method] = len(rec_aka_aka)
match_info.loc['records_see_see'][method] = len(rec_see_see)

# new
match_info.loc['aka_matched'][method] = len(rec_aka_see.union(rec_aka_aka))
match_records['aka_matched'][method] = list(rec_aka_see.union(rec_aka_aka))
match_info.loc['see_matched'][method] = len(rec_see_aka.union(rec_see_see))
match_records['see_matched'][method] = list(rec_see_aka.union(rec_see_see))

# %% [markdown]
# ##### Check for ambigous matches
# Look for records matched with more than one or involved in transitive matching (A->B->C)
#
# Note that sequential methid only matches symmetric links and so no asymmetric cases are generated in this method

# %%
import networkx as nx

method = 'sequential'

matched_pairs = match_records['matched_pairs'][method]
records = match_records['records_matched'][method]

matched_multiple = []
matched_single = []

origins = [o for (o,d,t) in matched_pairs]
destinations = [d for (o,d,t) in matched_pairs]
rec_in_matches = origins + destinations
for i in rec_in_matches:
    c = rec_in_matches.count(i)
    if c >2:
        matched_multiple.append(i)
    elif c == 1:
        matched_single.append(i)
matched_multiple = list(set(matched_multiple))
matched_single = list(set(matched_single))


# alternative method, perhaps more informative:
pairs_to_check = match_records['matched_pairs'][method]

asymmetric_pairs = []
for (o,d,t) in pairs_to_check:
    if t == 'see-aka':
        rt = 'aka-see'
    elif t == 'aka-see':
        rt = 'see-aka'
    else:
        rt = t
    if (d,o,rt) not in pairs_to_check:
        asymmetric_pairs.append((o,d,t))
        print("asymmetic match:",(o,d,t))

print("Records with more than one match      :", len(matched_multiple))
print("Records with just one match           :", len(matched_single))

G = nx.Graph()
simple_pairs = [(o,d) for (o,d,t) in matched_pairs]
G.add_edges_from(simple_pairs)
transitive  = [c for c in nx.connected_components(G) if len(c) > 2]
# number of records in ambiguous matches
amb_records = [item for amb in transitive for item in amb]
namb_records = len(set(amb_records))
print("Records in ambiguous matches          :", namb_records)
for amb in transitive:
    print(amb)
print("Are multiple in ambiguous?            :",set(matched_multiple).issubset(set(amb_records)))

rec_errors = set(amb_records).union(matched_multiple).union(matched_single)
rec_ok = set(records).difference(rec_errors)

match_records['records_error'][method] = list(rec_errors)
match_info.loc['records_error'][method] = len(rec_errors)
match_records['records_matched_ok'][method] = list(rec_ok)
match_info.loc['records_matched_ok'][method] = len(rec_ok)
match_records['records_asymmetric'][method] = list(matched_single)
match_info.loc['records_asymmetric'][method] = len(matched_single)
match_records['records_transitive'][method] = list(amb_records)
match_info.loc['records_transitive'][method] = namb_records

# new
aka = match_records['aka']['data']
aka_ok = set(aka).intersection(rec_ok)
see = match_records['see']['data']
see_ok = set(see).intersection(rec_ok)
match_info.loc['aka_matched_ok'][method] = len(aka_ok)
match_records['aka_matched_ok'][method] = list(aka_ok)
match_info.loc['see_matched_ok'][method] = len(see_ok)
match_records['see_matched_ok'][method] = list(see_ok)

pairs_ok = set([(o,d,t) for (o,d,t) in match_records['matched_pairs'][method]
                                                        if o not in rec_errors and d not in rec_errors])
match_records['matched_pairs_ok'][method] = list(pairs_ok)
match_info.loc['matched_pairs_ok'][method] = len(pairs_ok)

vide_plus.loc[matched_single,'match_error'] = False
vide_plus.loc[matched_single,'match_obs'] = "W01-Single match (asymmetric) "+method
vide_plus.loc[matched_multiple,'match_error'] = True
vide_plus.loc[matched_multiple,'match_obs'] = "E02-Multiple match "+method
vide_plus.loc[amb_records,'match_error'] = True
vide_plus.loc[amb_records,'match_obs'] = "E01-Ambiguity in match "+method

match_info.fillna('')
# Out:
# Records with more than one match      : 4
# Records with just one match           : 0
# Records in ambiguous matches          : 12
# {'183306', '235009', '183307'}
# {'169757', '162809', '136283'}
# {'255769', '206151', '203494'}
# {'278765', '181236', '178312'}
# Are multiple in ambiguous?            : True
#                     data sequential random
# aka                 3062
# aka_fac             3035
# aka_geo             2973
# aka_matched                    1913
# aka_matched_ok                 1907
# aka_pai             1619
# matched_pairs                  3644
# matched_pairs_ok               3628
# nodate              5763
# nodate_novide        141
# nodate_novide        141
# records_aka_aka                 200
# records_aka_see                1713
# records_asymmetric                0
# records_error                    12
# records_matched                3640
# records_matched_ok             3628
# records_see_aka                1713
# records_see_see                  14
# records_transitive               12
# see                 5704
# see_fac             1378
# see_geo             5274
# see_matched                    1727
# see_matched_ok                 1721
# see_pai             1569
# vide                8625
# vide_plus           8766

# %%
vide_plus.loc['217701']
# Out:
# name                                         José de Santo António
# sex                                                              m
# nome-vide                                                Lencastre
# nome-geografico                                           ***NA***
# faculdade                                                      NaN
# faculdade.date                                                 NaN
# faculdade.obs                                                  NaN
# nome-pai                                                       NaN
# uc-entrada                                              0000-00-00
# uc-saida                                                0000-00-00
# uc-saida.date                                           0000-00-00
# uc-saida.obs                                                  None
# rec_type                                                       see
# loookup
# vide_type                                                      add
# lookup                             José de Santo António Lencastre
# name_sp                                         José Santo António
# lookup_sp                             José Santo António Lencastre
# sort_key           José Santo António-José Santo António Lencastre
# match_error                                                    NaN
# match_obs                                                      NaN
# Name: 217701, dtype: object

# %% [markdown]
# ##### Show some of the ambiguous records
#
# pandas and timelink in colorful relation

# %%
from timelinknb.pandas import display_group_attributes

pd.set_option('display.max_rows',250)

no_show=['código-de-referência','data-do-registo','url','faculdade.ano','naturalidade.ano',
         'matricula-faculdade.ano','nome-apelido','nome-primeiro','nome-geografico.ano',
         'grau.ano','matricula-outra.ano','nome-geografico','instituta.ano']

show_only = 8
for ambiguous_records in transitive[:show_only]:
    display_group_attributes(ambiguous_records,
                             header_cols=['name','nome-vide','naturalidade','uc-entrada','faculdade','nome-pai'],
                             exclude_attributes=no_show,
                             sort_attributes=['date','type','value'],
                             cmap_name='Pastel1')
# Out:
# <style type="text/css">
# #T_82d03_row0_col0, #T_82d03_row0_col1, #T_82d03_row0_col2, #T_82d03_row0_col3, #T_82d03_row0_col4, #T_82d03_row0_col5, #T_82d03_row0_col6 {
#   background-color: #fbb4ae;
# }
# #T_82d03_row1_col0, #T_82d03_row1_col1, #T_82d03_row1_col2, #T_82d03_row1_col3, #T_82d03_row1_col4, #T_82d03_row1_col5, #T_82d03_row1_col6 {
#   background-color: #fed9a6;
# }
# #T_82d03_row2_col0, #T_82d03_row2_col1, #T_82d03_row2_col2, #T_82d03_row2_col3, #T_82d03_row2_col4, #T_82d03_row2_col5, #T_82d03_row2_col6 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_82d03">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_82d03_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_82d03_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_82d03_level0_col2" class="col_heading level0 col2" >nome-vide</th>
#       <th id="T_82d03_level0_col3" class="col_heading level0 col3" >naturalidade</th>
#       <th id="T_82d03_level0_col4" class="col_heading level0 col4" >uc-entrada</th>
#       <th id="T_82d03_level0_col5" class="col_heading level0 col5" >faculdade</th>
#       <th id="T_82d03_level0_col6" class="col_heading level0 col6" >nome-pai</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_82d03_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_82d03_row0_col0" class="data row0 col0" >183306</td>
#       <td id="T_82d03_row0_col1" class="data row0 col1" >António de Sousa</td>
#       <td id="T_82d03_row0_col2" class="data row0 col2" >António de Sousa Macedo</td>
#       <td id="T_82d03_row0_col3" class="data row0 col3" >Lisboa</td>
#       <td id="T_82d03_row0_col4" class="data row0 col4" >0000-00-00</td>
#       <td id="T_82d03_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_82d03_row0_col6" class="data row0 col6" >Gonçalo de Sousa</td>
#     </tr>
#     <tr>
#       <th id="T_82d03_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_82d03_row1_col0" class="data row1 col0" >235009</td>
#       <td id="T_82d03_row1_col1" class="data row1 col1" >António de Sousa</td>
#       <td id="T_82d03_row1_col2" class="data row1 col2" >Macedo</td>
#       <td id="T_82d03_row1_col3" class="data row1 col3" >Lisboa</td>
#       <td id="T_82d03_row1_col4" class="data row1 col4" >0000-00-00</td>
#       <td id="T_82d03_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_82d03_row1_col6" class="data row1 col6" >João</td>
#     </tr>
#     <tr>
#       <th id="T_82d03_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_82d03_row2_col0" class="data row2 col0" >183307</td>
#       <td id="T_82d03_row2_col1" class="data row2 col1" >António de Sousa de Macedo</td>
#       <td id="T_82d03_row2_col2" class="data row2 col2" >Sousa</td>
#       <td id="T_82d03_row2_col3" class="data row2 col3" >Lisboa</td>
#       <td id="T_82d03_row2_col4" class="data row2 col4" >1629-11-15</td>
#       <td id="T_82d03_row2_col5" class="data row2 col5" >Leis</td>
#       <td id="T_82d03_row2_col6" class="data row2 col6" >Gonçalo de Sousa</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_676d4_row0_col0, #T_676d4_row0_col1, #T_676d4_row0_col2, #T_676d4_row0_col3, #T_676d4_row0_col4, #T_676d4_row2_col0, #T_676d4_row2_col1, #T_676d4_row2_col2, #T_676d4_row2_col3, #T_676d4_row2_col4, #T_676d4_row4_col0, #T_676d4_row4_col1, #T_676d4_row4_col2, #T_676d4_row4_col3, #T_676d4_row4_col4, #T_676d4_row6_col0, #T_676d4_row6_col1, #T_676d4_row6_col2, #T_676d4_row6_col3, #T_676d4_row6_col4, #T_676d4_row8_col0, #T_676d4_row8_col1, #T_676d4_row8_col2, #T_676d4_row8_col3, #T_676d4_row8_col4, #T_676d4_row10_col0, #T_676d4_row10_col1, #T_676d4_row10_col2, #T_676d4_row10_col3, #T_676d4_row10_col4, #T_676d4_row12_col0, #T_676d4_row12_col1, #T_676d4_row12_col2, #T_676d4_row12_col3, #T_676d4_row12_col4 {
#   background-color: #fbb4ae;
# }
# #T_676d4_row1_col0, #T_676d4_row1_col1, #T_676d4_row1_col2, #T_676d4_row1_col3, #T_676d4_row1_col4, #T_676d4_row3_col0, #T_676d4_row3_col1, #T_676d4_row3_col2, #T_676d4_row3_col3, #T_676d4_row3_col4, #T_676d4_row5_col0, #T_676d4_row5_col1, #T_676d4_row5_col2, #T_676d4_row5_col3, #T_676d4_row5_col4, #T_676d4_row7_col0, #T_676d4_row7_col1, #T_676d4_row7_col2, #T_676d4_row7_col3, #T_676d4_row7_col4, #T_676d4_row9_col0, #T_676d4_row9_col1, #T_676d4_row9_col2, #T_676d4_row9_col3, #T_676d4_row9_col4, #T_676d4_row11_col0, #T_676d4_row11_col1, #T_676d4_row11_col2, #T_676d4_row11_col3, #T_676d4_row11_col4, #T_676d4_row13_col0, #T_676d4_row13_col1, #T_676d4_row13_col2, #T_676d4_row13_col3, #T_676d4_row13_col4 {
#   background-color: #fed9a6;
# }
_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_676d4_row2_col0" class="data row2 col0" >0000-00-00</td>
#       <td id="T_676d4_row2_col1" class="data row2 col1" >183306</td>
#       <td id="T_676d4_row2_col2" class="data row2 col2" >nome</td>
#       <td id="T_676d4_row2_col3" class="data row2 col3" >António de Sousa</td>
#       <td id="T_676d4_row2_col4" class="data row2 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_676d4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_676d4_row3_col0" class="data row3 col0" >0000-00-00</td>
#       <td id="T_676d4_row3_col1" class="data row3 col1" >235009</td>
#       <td id="T_676d4_row3_col2" class="data row3 col2" >nome</td>
#       <td id="T_676d4_row3_col3" class="data row3 col3" >António de Sousa</td>
#       <td id="T_676d4_row3_col4" class="data row3 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_676d4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_676d4_row4_col0" class="data row4 col0" >0000-00-00</td>
#       <td id="T_676d4_row4_col1" class="data row4 col1" >183306</td>
#       <td id="T_676d4_row4_col2" class="data row4 col2" >nome</td>
#       <td id="T_676d4_row4_col3" class="data row4 col3" >António de Sousa Macedo</td>
#       <td id="T_676d4_row4_col4" class="data row4 col4" >António de Sousa, vide António de Sousa Macedo</td>
#     </tr>
#     <tr>
#       <th id="T_676d4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_676d4_row5_col0" class="data row5 col0" >0000-00-00</td>
#       <td id="T_676d4_row5_col1" class="data row5 col1" >235009</td>
#       <td id="T_676d4_row5_col2" class="data row5 col2" >nome</td>
#       <td id="T_676d4_row5_col3" class="data row5 col3" >António de Sousa Macedo</td>
#       <td id="T_676d4_row5_col4" class="data row5 col4" >António de Sousa, vide Macedo</td>
#     </tr>
#     <tr>
#       <th id="T_676d4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_676d4_row6_col0" class="data row6 col0" >0000-00-00</td>
#       <td id="T_676d4_row6_col1" class="data row6 col1" >183306</td>
#       <td id="T_676d4_row6_col2" class="data row6 col2" >nome-pai</td>
#       <td id="T_676d4_row6_col3" class="data row6 col3" >Gonçalo de Sousa</td>
#       <td id="T_676d4_row6_col4" class="data row6 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_676d4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_676d4_row7_col0" class="data row7 col0" >0000-00-00</td>
#       <td id="T_676d4_row7_col1" class="data row7 col1" >235009</td>
#       <td id="T_676d4_row7_col2" class="data row7 col2" >nome-pai</td>
#       <td id="T_676d4_row7_col3" class="data row7 col3" >João</td>
#       <td id="T_676d4_row7_col4" class="data row7 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_676d4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_676d4_row8_col0" class="data row8 col0" >0000-00-00</td>
#       <td id="T_676d4_row8_col1" class="data row8 col1" >183306</td>
#       <td id="T_676d4_row8_col2" class="data row8 col2" >nome-vide</td>
#       <td id="T_676d4_row8_col3" class="data row8 col3" >António de Sousa Macedo</td>
#       <td id="T_676d4_row8_col4" class="data row8 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_676d4_l
# <style type="text/css">
# #T_63dac_row0_col0, #T_63dac_row0_col1, #T_63dac_row0_col2, #T_63dac_row0_col3, #T_63dac_row0_col4, #T_63dac_row0_col5, #T_63dac_row0_col6 {
#   background-color: #fbb4ae;
# }
# #T_63dac_row1_col0, #T_63dac_row1_col1, #T_63dac_row1_col2, #T_63dac_row1_col3, #T_63dac_row1_col4, #T_63dac_row1_col5, #T_63dac_row1_col6 {
#   background-color: #fed9a6;
# }
# #T_63dac_row2_col0, #T_63dac_row2_col1, #T_63dac_row2_col2, #T_63dac_row2_col3, #T_63dac_row2_col4, #T_63dac_row2_col5, #T_63dac_row2_col6 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_63dac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_63dac_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_63dac_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_63dac_level0_col2" class="col_heading level0 col2" >nome-vide</th>
#       <th id="T_63dac_level0_col3" class="col_heading level0 col3" >naturalidade</th>
#       <th id="T_63dac_level0_col4" class="col_heading level0 col4" >uc-entrada</th>
#       <th id="T_63dac_level0_col5" class="col_heading level0 col5" >faculdade</th>
#       <th id="T_63dac_level0_col6" class="col_heading level0 col6" >nome-pai</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63dac_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_63dac_row0_col0" class="data row0 col0" >136283</td>
#       <td id="T_63dac_row0_col1" class="data row0 col1" >Manuel Francisco de Ribolhos</td>
#       <td id="T_63dac_row0_col2" class="data row0 col2" >Manuel Francisco</td>
#       <td id="T_63dac_row0_col3" class="data row0 col3" >Ribolhos</td>
#       <td id="T_63dac_row0_col4" class="data row0 col4" >0000-00-00</td>
#       <td id="T_63dac_row0_col5" class="data row0 col5" >Cânones</td>
#       <td id="T_63dac_row0_col6" class="data row0 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_63dac_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_63dac_row1_col0" class="data row1 col0" >169757</td>
#       <td id="T_63dac_row1_col1" class="data row1 col1" >Manuel Francisco de Ribolhos</td>
#       <td id="T_63dac_row1_col2" class="data row1 col2" >Francisco</td>
#       <td id="T_63dac_row1_col3" class="data row1 col3" >Ribolhos</td>
#       <td id="T_63dac_row1_col4" class="data row1 col4" >0000-00-00</td>
#       <td id="T_63dac_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_63dac_row1_col6" class="data row1 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_63dac_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_63dac_row2_col0" class="data row2 col0" >162809</td>
#       <td id="T_63dac_row2_col1" class="data row2 col1" >Manuel Francisco</td>
#       <td id="T_63dac_row2_col2" class="data row2 col2" >Manuel Francisco de Ribolhos</td>
#       <td id="T_63dac_row2_col3" class="data row2 col3" >Ribolhos</td>
#       <td id="T_63dac_row2_col4" class="data row2 col4" >1756-10-01</td>
#       <td id="T_63dac_row2_col5" class="data row2 col5" >Cânones</td>
#       <td id="T_63dac_row2_col6" class="data row2 col6" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_eb407_row0_col0, #T_eb407_row0_col1, #T_eb407_row0_col2, #T_eb407_row0_col3, #T_eb407_row0_col4, #T_eb407_row1_col0, #T_eb407_row1_col1, #T_eb407_row1_col2, #T_eb407_row1_col3, #T_eb407_row1_col4, #T_eb407_row3_col0, #T_eb407_row3_col1, #T_eb407_row3_col2, #T_eb407_row3_col3, #T_eb407_row3_col4, #T_eb407_row5_col0, #T_eb407_row5_col1, #T_eb407_row5_col2, #T_eb407_row5_col3, #T_eb407_row5_col4, #T_eb407_row8_col0, #T_eb407_row8_col1, #T_eb407_row8_col2, #T_eb407_row8_col3, #T_eb407_row8_col4, #T_eb407_row9_col0, #T_eb407_row9_col1, #T_eb407_row9_col2, #T_eb407_row9_col3, #T_eb407_row9_col4, #T_eb407_row11_col0, #T_eb407_row11_col1, #T_eb407_row11_col2, #T_eb407_row11_col3, #T_eb407_row11_col4 {
#   background-color: #fbb4ae;
# }
# #T_eb407_row2_col0, #T_eb407_row2_col1, #T_eb407_row2_col2, #T_eb407_row2_col3, #T_eb407_row2_col4, #T_eb407_row4_col0, #T_eb407_row4_col1, #T_eb407_row4_col2, #T_eb407_row4_col3, #T_eb407_row4_col4, #T_eb407_row6_col0, #T_eb407_row6_col1, #T_eb407_row6_col2, #T_eb407_row6_col3, #T_eb407_row6_col4, #T_eb407_row7_col0, #T_eb407_row7_col1, #T_eb407_row7_col2, #T_eb407_row7_col3, #T_eb407_row7_col4, #T_eb407_row10_col0, #T_eb407_row10_col1, #T_eb407_row10_col2, #T_eb407_row10_col3, #T_eb407_row10_col4, #T_eb407_row12_col0, #T_eb407_row12_col1, #T_eb407_row12_col2, #T_eb407_row12_col3, #T_eb407_row12_col4 {
#   background-color: #fed9a6;
# }
# #T_eb407_row13_col0, #T_eb407_row13_col1, #T_eb407_row13_col2, #T_eb407_row13_col3, #T_eb407_row13_col4, #T_eb407_row14_col0, #T_eb407_row14_col1, #T_eb407_row14_col2, #T_eb407_row14_col3, #T_eb407_row14_col4, #T_eb407_row15_col0, #T_eb407_row15_col1, #T_eb407_row15_col2, #T_eb407_row15_col3, #T_eb407_row15_col4, #T_eb407_row16_col0, #T_eb407_row16_col1, #T_eb407_row16_col2, #T_eb407_row16_col3, #T_eb407_row16_col4, #T_eb407_row17_col0, #T_eb407_row17_col1, #T_eb407_row17_col2, #T_eb407_row17_col3, #T_eb407_row17_col4, #T_eb407_row18_col0, #T_eb407_row18_col1, #T_eb407_row18_col2, #T_eb407_row18_col3, #T_eb407_row18_col4, #T_eb407_row19_col0, #T_eb407_row19_col1, #T_eb407_row19_col2, #T_eb407_row19_col3, #T_eb407_row19_col4, #T_eb407_row20_col0, #T_eb407_row20_col1, #T_eb407_row20_col2, #T_eb407_row20_col3, #T_eb407_row20_col4, #T_eb407_row21_col0, #T_eb407_row21_col1, #T_eb407_row21_col2, #T_eb407_row21_col3, #T_eb407_row21_col4, #T_eb407_row22_col0, #T_eb407_row22_col1, #T_eb407_row22_col2, #T_eb407_row22_col3, #T_eb407_row22_col4, #T_eb407_row23_col0, #T_eb407_row23_col1, #T_eb407_row23_col2, #T_eb407_row23_col3, #T_eb407_row23_col4, #T_eb407_row24_col0, #T_eb407_row24_col1, #T_eb407_row24_col2, #T_eb407_row24_col3, #T_eb407_row24_col4 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_eb407">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb407_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_eb407_level0_col1" class="col_heading level0 col1" >id</th>
#       <th id="T_eb407_level0_col2" class="col_heading level0 col2" >type</th>
#       <th id="T_eb407_level0_col3" class="col_heading level0 col3" >value</th>
#       <th id="T_eb407_level0_col4" class="col_heading level0 col4" >attr_obs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb407_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eb407_row0_col0" class="data row0 col0" >0000-00-00</td>
#       <td id="T_eb407_row0_col1" class="data row0 col1" >136283</td>
#       <td id="T_eb407_row0_col2" class="data row0 col2" >faculdade</td>
#       <td id="T_eb407_row0_col3" class="data row0 col3" >Cânones</td>
#       <td id="T_eb407_row0_col4" class="data row0 col4" >Cânones</td>
#     </tr>
#     <tr>
#       <th id="T_eb407_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_eb407_row1_col0" class="data row1 col0" >0000-00-00</td>
#       <td id="T_eb407_row1_col1" class="data row1 col1" >136283</td>
#       <td id="T_eb407_row1_col2" class="data row1 col2" >naturalidade</td>
#       <td id="T_eb407_row1_col3" class="data row1 col3" >Ribolhos</td>
#       <td id="T_eb407_row1_col4" class="data row1 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_eb407_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_eb407_row2_col0" class="data row2 col0" >0000-00-00</td>
#       <td id="T_eb407_row2_col1" class="data row2 col1" >169757</td>
#       <td id="T_eb407_row2_col2" class="data row2 col2" >naturalidade</td>
#       <td id="T_eb407_row2_col3" class="data row2 col3" >Ribolhos</td>
#       <td id="T_eb407_row2_col4" class="data row2 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_eb407_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_eb407_row3_col0" class="data row3 col0" >0000-00-00</td>
#       <td id="T_eb407_row3_col1" class="data row3 col1" >136283</td>
#       <td id="T_eb407_row3_col2" class="data row3 col2" >nome</td>
#       <td id="T_eb407_row3_col3" class="data row3 col3" >Manuel Francisco</td>
#       <td id="T_eb407_row3_col4" class="data row3 col4" >Manuel Francisco de Ribolhos, vide Manuel Francisco</td>
#     </tr>
#     <tr>
#       <th id="T_eb407_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_eb407_row4_col0" class="data row4 col0" >0000-00-00</td>
#       <td id="T_eb407_row4_col1" class="data row4 col1" >169757</td>
#       <td id="T_eb407_row4_col2" class="data row4 col2" >nome</td>
#       <td id="T_eb407_row4_col3" class="data row4 col3" >Manuel Francisco</td>
#       <td id="T_eb407_row4_col4" class="data row4 col4" >Manuel Francisco de Ribolhos, vide Francisco</td>
#     </tr>
#     <tr>
#       <th id="T_eb407_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_eb407_row5_col0" class="data row5 col0" >0000-00-00</td>
#       <td id="T_eb407_row5_col1" class="data row5 col1" >136283</td>
#       <td id="T_eb407_row5_col2" class="data row5 col2" >nome</td>
#       <td id="T_eb407_row5_col3" class="data row5 col3" >Manuel Francisco de Ribolhos</td>
#       <td id="T_eb407_row5_col4" class="data row5 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_eb407_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_eb407_row6_col0" class="data row6 col0" >0000-00-00</td>
#       <td id="T_eb407_row6_col1" class="data row6 col1" >169757</td>
#       <td id="T_eb407_row6_col2" class="data row6 col2" >nome</td>
#       <td id="T_eb407_row6_col3" class="data row6 col3" >Manuel Francisco de Ribolhos</td>
#       <td id="T_eb407_row6_col4" class="data row6 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_eb407_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_eb407_row7_col0" class="data row7 col0" >0000-00-00</td>
#       <td id="T_eb407_row7_col1" class="data row7 col1" >169757</td>
#       <td id="T_eb407_row7_col2" class="data row7 col2" >nome-vide</td>
#       <td id="T_eb407_row7_col3" class="data row7 col3" >Francisco</td>
#       <td id="T_eb407_row7_col4" class="data row7 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_eb407_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_eb407_row8_col0" class="data row8 col0" >0000-00-00</td>
#       <td id="T_eb407_row8_col1" class="data row8 col1" >136283</td>
#       <td id="T_eb407_row8_col2" class="data row8 col2" >nome-vide</td>
#       <td id="T_eb407_row8_col3" class="data row8 col3" >Manuel Francisco</td>
#       <td id="T_eb407_row8_col4" class="data row8 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_eb407_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_eb407_row9_col0" class="data row9 col0" >0000-00-00</td>
#       <td id="T_eb407_row9_col1" class="data row9 col1" >136283</td>
#       <td id="T_eb407_row9_col2" class="data row9 col2" >uc-entrada</td>
#       <td id="T_eb407_row9_col3" class="data row9 col3" >0000-00-00</td>
#       <td id="T_eb407_row9_col4" class="data row9 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_eb407_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_eb407_row10_col0" class="data row10 col0" >0000-00-00</td>
#       <td id="T_eb407_r
# <style type="text/css">
# #T_279f8_row0_col0, #T_279f8_row0_col1, #T_279f8_row0_col2, #T_279f8_row0_col3, #T_279f8_row0_col4, #T_279f8_row0_col5, #T_279f8_row0_col6 {
#   background-color: #fbb4ae;
# }
# #T_279f8_row1_col0, #T_279f8_row1_col1, #T_279f8_row1_col2, #T_279f8_row1_col3, #T_279f8_row1_col4, #T_279f8_row1_col5, #T_279f8_row1_col6 {
#   background-color: #fed9a6;
# }
# #T_279f8_row2_col0, #T_279f8_row2_col1, #T_279f8_row2_col2, #T_279f8_row2_col3, #T_279f8_row2_col4, #T_279f8_row2_col5, #T_279f8_row2_col6 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_279f8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_279f8_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_279f8_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_279f8_level0_col2" class="col_heading level0 col2" >nome-vide</th>
#       <th id="T_279f8_level0_col3" class="col_heading level0 col3" >naturalidade</th>
#       <th id="T_279f8_level0_col4" class="col_heading level0 col4" >uc-entrada</th>
#       <th id="T_279f8_level0_col5" class="col_heading level0 col5" >faculdade</th>
#       <th id="T_279f8_level0_col6" class="col_heading level0 col6" >nome-pai</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_279f8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_279f8_row0_col0" class="data row0 col0" >206151</td>
#       <td id="T_279f8_row0_col1" class="data row0 col1" >Francisco Rodrigues de Valadares</td>
#       <td id="T_279f8_row0_col2" class="data row0 col2" >Rodrigues</td>
#       <td id="T_279f8_row0_col3" class="data row0 col3" >Vila Viçosa</td>
#       <td id="T_279f8_row0_col4" class="data row0 col4" >0000-00-00</td>
#       <td id="T_279f8_row0_col5" class="data row0 col5" >Cânones</td>
#       <td id="T_279f8_row0_col6" class="data row0 col6" >Rodrigo Rodrigues</td>
#     </tr>
#     <tr>
#       <th id="T_279f8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_279f8_row1_col0" class="data row1 col0" >203494</td>
#       <td id="T_279f8_row1_col1" class="data row1 col1" >Francisco Rodrigues</td>
#       <td id="T_279f8_row1_col2" class="data row1 col2" >Valadares</td>
#       <td id="T_279f8_row1_col3" class="data row1 col3" >Vila Viçosa</td>
#       <td id="T_279f8_row1_col4" class="data row1 col4" >1605-10-20</td>
#       <td id="T_279f8_row1_col5" class="data row1 col5" >Cânones</td>
#       <td id="T_279f8_row1_col6" class="data row1 col6" >Rodrigo Rodrigues</td>
#     </tr>
#     <tr>
#       <th id="T_279f8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_279f8_row2_col0" class="data row2 col0" >255769</td>
#       <td id="T_279f8_row2_col1" class="data row2 col1" >Francisco Rodrigues</td>
#       <td id="T_279f8_row2_col2" class="data row2 col2" >Valadares</td>
#       <td id="T_279f8_row2_col3" class="data row2 col3" >Vila Viçosa</td>
#       <td id="T_279f8_row2_col4" class="data row2 col4" >1605-10-20</td>
#       <td id="T_279f8_row2_col5" class="data row2 col5" >Cânones</td>
#       <td id="T_279f8_row2_col6" class="data row2 col6" >Rodrigo Rodrigues</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_49256_row0_col0, #T_49256_row0_col1, #T_49256_row0_col2, #T_49256_row0_col3, #T_49256_row0_col4, #T_49256_row1_col0, #T_49256_row1_col1, #T_49256_row1_col2, #T_49256_row1_col3, #T_49256_row1_col4, #T_49256_row2_col0, #T_49256_row2_col1, #T_49256_row2_col2, #T_49256_row2_col3, #T_49256_row2_col4, #T_49256_row3_col0, #T_49256_row3_col1, #T_49256_row3_col2, #T_49256_row3_col3, #T_49256_row3_col4, #T_49256_row4_col0, #T_49256_row4_col1, #T_49256_row4_col2, #T_49256_row4_col3, #T
_col1, #T_49256_row49_col2, #T_49256_row49_col3, #T_49256_row49_col4, #T_49256_row51_col0, #T_49256_row51_col1, #T_49256_row51_col2, #T_49256_row51_col3, #T_49256_row51_col4, #T_49256_row53_col0, #T_49256_row53_col1, #T_49256_row53_col2, #T_49256_row53_col3, #T_49256_row53_col4, #T_49256_row55_col0, #T_49256_row55_col1, #T_49256_row55_col2, #T_49256_row55_col3, #T_49256_row55_col4, #T_49256_row57_col0, #T_49256_row57_col1, #T_49256_row57_col2, #T_49256_row57_col3, #T_49256_row57_col4, #T_49256_row59_col0, #T_49256_row59_col1, #T_49256_row59_col2, #T_49256_row59_col3, #T_49256_row59_col4, #T_49256_row61_col0, #T_49256_row61_col1, #T_49256_row61_col2, #T_49256_row61_col3, #T_49256_row61_col4 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_49256">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_49256_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_49256_level0_col1" class="col_heading level0 col1" >id</th>
#       <th id="T_49256_level0_col2" class="col_heading level0 col2" >type</th>
#       <th id="T_49256_level0_col3" class="col_heading level0 col3" >value</th>
#       <th id="T_49256_level0_col4" class="col_heading level0 col4" >attr_obs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49256_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_49256_row0_col0" class="data row0 col0" >0000-00-00</td>
#       <td id="T_49256_row0_col1" class="data row0 col1" >206151</td>
#       <td id="T_49256_row0_col2" class="data row0 col2" >faculdade</td>
#       <td id="T_49256_row0_col3" class="data row0 col3" >Cânones</td>
#       <td id="T_49256_row0_col4" class="data row0 col4" >Cânones</td>
#     </tr>
#     <tr>
#       <th id="T_49256_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_49256_row1_col0" class="data row1 col0" >0000-00-00</td>
#       <td id="T_49256_row1_col1" class="data row1 col1" >206151</td>
#       <td id="T_49256_row1_col2" class="data row1 col2" >naturalidade</td>
#       <td id="T_49256_row1_col3" class="data row1 col3" >Vila Viçosa</td>
#       <td id="T_49256_row1_col4" class="data row1 col4" >None</td>
#     </tr>
# <style type="text/css">
# #T_1a443_row0_col0, #T_1a443_row0_col1, #T_1a443_row0_col2, #T_1a443_row0_col3, #T_1a443_row0_col4, #T_1a443_row0_col5, #T_1a443_row0_col6 {
#   background-color: #fbb4ae;
# }
# #T_1a443_row1_col0, #T_1a443_row1_col1, #T_1a443_row1_col2, #T_1a443_row1_col3, #T_1a443_row1_col4, #T_1a443_row1_col5, #T_1a443_row1_col6 {
#   background-color: #fed9a6;
# }
# #T_1a443_row2_col0, #T_1a443_row2_col1, #T_1a443_row2_col2, #T_1a443_row2_col3, #T_1a443_row2_col4, #T_1a443_row2_col5, #T_1a443_row2_col6 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_1a443">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1a443_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_1a443_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_1a443_level0_col2" class="col_heading level0 col2" >nome-vide</th>
#       <th id="T_1a443_level0_col3" class="col_heading level0 col3" >naturalidade</th>
#       <th id="T_1a443_level0_col4" class="col_heading level0 col4" >uc-entrada</th>
#       <th id="T_1a443_level0_col5" class="col_heading level0 col5" >faculdade</th>
#       <th id="T_1a443_level0_col6" class="col_heading level0 col6" >nome-pai</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a443_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1a443_row0_col0" class="data row0 col0" >181236</td>
#       <td id="T_1a443_row0_col1" class="data row0 col1" >António Gomes de Macedo</td>
#       <td id="T_1a443_row0_col2" class="data row0 col2" >Gomes</td>
#       <td id="T_1a443_row0_col3" class="data row0 col3" >Coimbra</td>
#       <td id="T_1a443_row0_col4" class="data row0 col4" >0000-00-00</td>
#       <td id="T_1a443_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_1a443_row0_col6" class="data row0 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_1a443_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1a443_row1_col0" class="data row1 col0" >178312</td>
#       <td id="T_1a443_row1_col1" class="data row1 col1" >António Gomes</td>
#       <td id="T_1a443_row1_col2" class="data row1 col2" >Macedo</td>
#       <td id="T_1a443_row1_col3" class="data row1 col3" >Coimbra</td>
#       <td id="T_1a443_row1_col4" class="data row1 col4" >1641-10-02</td>
#       <td id="T_1a443_row1_col5" class="data row1 col5" >Teologia</td>
#       <td id="T_1a443_row1_col6" class="data row1 col6" >Manuel Rodrigues</td>
#     </tr>
#     <tr>
#       <th id="T_1a443_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1a443_row2_col0" class="data row2 col0" >278765</td>
#       <td id="T_1a443_row2_col1" class="data row2 col1" >António Gomes</td>
#       <td id="T_1a443_row2_col2" class="data row2 col2" >Macedo</td>
#       <td id="T_1a443_row2_col3" class="data row2 col3" >Coimbra</td>
#       <td id="T_1a443_row2_col4" class="data row2 col4" >1749-04-26</td>
#       <td id="T_1a443_row2_col5" class="data row2 col5" >Medicina</td>
#       <td id="T_1a443_row2_col6" class="data row2 col6" >José Gomes</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_9b1a9_row0_col0, #T_9b1a9_row0_col1, #T_9b1a9_row0_col2, #T_9b1a9_row0_col3, #T_9b1a9_row0_col4, #T_9b1a9_row1_col0, #T_9b1a9_row1_col1, #T_9b1a9_row1_col2, #T_9b1a9_row1_col3, #T_9b1a9_row1_col4, #T_9b1a9_row2_col0, #T_9b1a9_row2_col1, #T_9b1a9_row2_col2, #T_9b1a9_row2_col3, #T_9b1a9_row2_col4, #T_9b1a9_row3_col0, #T_9b1a9_row3_col1, #T_9b1a9_row3_col2, #T_9b1a9_row3_col3, #T_9b1a9_row3_col4, #T_9b1a9_row4_col0, #T_9b1a9_row4_col1, #T_9b1a9_row4_col2, #T_9b1a9_row4_col3, #T_9b1a9_row4_col4, #T_9b1a9_row5_col0, #T_9b1a9_row5_col1, #T_9b1a9_row5_col2, #T_9b1a9_row5_col3, #T_9b1a9_row5_col4 {
#   background-color: #fbb4ae;
# }
# #T_9b1a9_row6_col0, #T_9b1a9_row6_col1, #T_9b1a9_row6_col2, #T_9b1a9_row6_col3, #T_9b1a9_row6_col4, #T_9b1a9_row7_col0, #T_9b1a9_row7_col1, #T_9b1a9_row7_col2, #T_9b1a9_row7_col3, #T_9b1a9_row7_col4, #T_9b1a9_row8_col0, #T_9b1a9_row8_col1, #T_9b1a9_row8_col2, #T_9b1a9_row8_col3, #T_9b1a9_row8_col4, #T_9b1a9_row9_col0, #T_9b1a9_row9_col1, #T_9b1a9_row9_col2, #T_9b1a9_row9_col3, #T_9b1a9_row9_col4, #T_9b1a9_row10_col0, #T_9b1a9_row10_col1, #T_9b1a9_row10_col2, #T_9b1a9_row10_col3, #T_9b1a9_row10_col4, #T_9b1a9_row11_col0, #T_9b1a9_row11_col1, #T_9b1a9_row11_col2, #T_9b1a9_row11_col3, #T_9b1a9_row11_col4, #T_9b1a9_row12_col0, #T_9b1a9_row12_col1, #T_9b1a9_row12_col2, #T_9b1a9_row12_col3, #T_9b1a9_row12_col4, #T_9b1a9_row13_col0, #T_9b
a9_row33_col2, #T_9b1a9_row33_col3, #T_9b1a9_row33_col4, #T_9b1a9_row34_col0, #T_9b1a9_row34_col1, #T_9b1a9_row34_col2, #T_9b1a9_row34_col3, #T_9b1a9_row34_col4, #T_9b1a9_row35_col0, #T_9b1a9_row35_col1, #T_9b1a9_row35_col2, #T_9b1a9_row35_col3, #T_9b1a9_row35_col4, #T_9b1a9_row36_col0, #T_9b1a9_row36_col1, #T_9b1a9_row36_col2, #T_9b1a9_row36_col3, #T_9b1a9_row36_col4, #T_9b1a9_row37_col0, #T_9b1a9_row37_col1, #T_9b1a9_row37_col2, #T_9b1a9_row37_col3, #T_9b1a9_row37_col4, #T_9b1a9_row38_col0, #T_9b1a9_row38_col1, #T_9b1a9_row38_col2, #T_9b1a9_row38_col3, #T_9b1a9_row38_col4 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_9b1a9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9b1a9_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_9b1a9_level0_col1" class="col_heading level0 col1" >id</th>
#       <th id="T_9b1a9_level0_col2" class="col_heading level0 col2" >type</th>
#       <th id="T_9b1a9_level0_col3" class="col_heading level0 col3" >value</th>
#       <th id="T_9b1a9_level0_col4" class="col_heading level0 col4" >attr_obs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9b1a9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9b1a9_row0_col0" class="data row0 col0" >0000-00-00</td>
#       <td id="T_9b1a9_row0_col1" class="data row0 col1" >181236</td>
#       <td id="T_9b1a9_row0_col2" class="data row0 col2" >naturalidade</td>
#       <td id="T_9b1a9_row0_col3" class="data row0 col3" >Coimbra</td>
#       <td id="T_9b1a9_row0_col4" class="data row0 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9b1a9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9b1a9_row1_col0" class="data row1 col0" >0000-00-00</td>
#       <td id="T_9b1a9_row1_col1" class="data row1 col1" >181236</td>
#       <td id="T_9b1a9_row1_col2" class="data row1 col2" >nome</td>
#       <td id="T_9b1a9_row1_col3" class="data row1 col3" >António Gomes</td>
#       <td id="T_9b1a9_row1_col4" class="data row1 col4" >António Gomes de Macedo, vide Gomes</td>
#     </tr>
#     <tr>
#       <th id="T_9b1a9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9b1a9_row2_col0" class="data row2 col0" >0000-00-00</td>
#       <td id="T_9b1a9_row2_col1" class="data row2 col1" >181236</td>
#       <td id="T_9b1a9_row2_col2" class="data row2 col2" >nome</td>
#       <td id="T_9b1a9_row2_col3" class="data row2 col3" >António Gomes de Macedo</td>
#       <td id="T_9b1a9_row2_col4" class="data row2 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9b1a9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9b1a9_row3_col0" class="data row3 col0" >0000-00-00</td>
#       <td id="T_9b1a9_row3_col1" class="data row3 col1" >181236</td>
#       <td id="T_9b1a9_row3_col2" class="data row3 col2" >nome-vide</td>
#       <td id="T_9b1a9_row3_col3" class="data row3 col3" >Gomes</td>
#       <td id="T_9b1a9_row3_col4" class="data row3 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9b1a9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9b1a9_row4_col0" class="data row4 col0" >0000-00-00</td>
#       <td id="T_9b1a9_row4_col1" class="data row4 col1" >181236</td>
#       <td id="T_9b1a9_row4_col2" class="data row4 col2" >uc-entrada</td>
#       <td id="T_9b1a9_row4_col3" class="data row4 col3" >0000-00-00</td>
#       <td id="T_9b1a9_row4_col4" class="data row4 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9b1a9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9b1a9_row5_col0" class="data row5 col0" >0000-00-00</td>
#       <td id="T_9b1a9_row5_col1" class="data row5 col1" >181236</td>
#       <td id="T_9b1a9_row5_col2" class="data row5 col2" >uc-saida</td>
#       <td id="T_9b1a9_row5_col3" class="data row5 col3" >0000-00-00</td>
#       <td id="T_9b1a9_row5_col4" class="data row5 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9b1a9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9b1a9_row6_col0" class="data row6 col0" >1641-10-02</td>
#       <td id="T_9b1a9_row6_col1" class="data row6 col1" >178312</td>
#       <td id="T_9b1a9_row6_col2" class="data row6 col2" >faculdade</td>
#       <td id="T_9b1a9_row6_col3" class="data row6 col3" >Teologia</td>
#       <td id="T_9b1a9_row6_col4" class="data row6 col4" >Teologia</td>
#     </tr>
#     <tr>
#       <th id="T_9b1a9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9b1a9_row7_col0" class="data row7 col0" >1641-10

# %% [markdown]
# ##### aka-aka matches in sequential mode
#
# In sequential mode we do not filter by record type so some aka-aka and see-see matches occur.
# matches

# %%
from timelinknb.pandas import display_group_attributes

no_show=['código-de-referência','data-do-registo','url','faculdade.ano','naturalidade.ano',
         'matricula-faculdade.ano','nome-apelido','nome-primeiro','nome-geografico.ano',
         'grau.ano','matricula-outra.ano','nome-geografico','instituta.ano']

pairs = match_records['matched_pairs']['sequential']
show_pairs = [(o,d,t) for o,d,t in pairs if t == 'aka-aka' and o<d]
show_only = 10
print(f"aka-aka matches in sequential mode (show only {show_only}) of {len(show_pairs)}:")
for o,d,t in show_pairs[:show_only]:
    display_group_attributes([o,d],
                             header_cols=['name','nome-vide','naturalidade','uc-entrada','faculdade','nome-pai'],
                             exclude_attributes=no_show,
                             sort_attributes=['date','type','value'],
                             cmap_name='Pastel1')
# Out:
# aka-aka matches in sequential mode (show only 10) of 100:
# <style type="text/css">
# #T_40042_row0_col0, #T_40042_row0_col1, #T_40042_row0_col2, #T_40042_row0_col3, #T_40042_row0_col4, #T_40042_row0_col5, #T_40042_row0_col6 {
#   background-color: #fbb4ae;
# }
# #T_40042_row1_col0, #T_40042_row1_col1, #T_40042_row1_col2, #T_40042_row1_col3, #T_40042_row1_col4, #T_40042_row1_col5, #T_40042_row1_col6 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_40042">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40042_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_40042_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_40042_level0_col2" class="col_heading level0 col2" >nome-vide</th>
#       <th id="T_40042_level0_col3" class="col_heading level0 col3" >naturalidade</th>
#       <th id="T_40042_level0_col4" class="col_heading level0 col4" >uc-entrada</th>
#       <th id="T_40042_level0_col5" class="col_heading level0 col5" >faculdade</th>
#       <th id="T_40042_level0_col6" class="col_heading level0 col6" >nome-pai</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40042_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_40042_row0_col0" class="data row0 col0" >143239</td>
#       <td id="T_40042_row0_col1" class="data row0 col1" >Jerónimo de Almeida</td>
#       <td id="T_40042_row0_col2" class="data row0 col2" >Ribeiro</td>
#       <td id="T_40042_row0_col3" class="data row0 col3" >Ferreira</td>
#       <td id="T_40042_row0_col4" class="data row0 col4" >1553-10-00</td>
#       <td id="T_40042_row0_col5" class="data row0 col5" >Leis</td>
#       <td id="T_40042_row0_col6" class="data row0 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_40042_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_40042_row1_col0" class="data row1 col0" >163231</td>
#       <td id="T_40042_row1_col1" class="data row1 col1" >Jerónimo de Almeida Ribeiro</td>
#       <td id="T_40042_row1_col2" class="data row1 col2" >Almeida</td>
#       <td id="T_40042_row1_col3" class="data row1 col3" >Ferreira</td>
#       <td id="T_40042_row1_col4" class="data row1 col4" >1560-01-24</td>
#       <td id="T_40042_row1_col5" class="data row1 col5" >Cânones</td>
#       <td id="T_40042_row1_col6" class="data row1 col6" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T
col4 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_cabff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cabff_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_cabff_level0_col1" class="col_heading level0 col1" >id</th>
#       <th id="T_cabff_level0_col2" class="col_heading level0 col2" >type</th>
#       <th id="T_cabff_level0_col3" class="col_heading level0 col3" >value</th>
#       <th id="T_cabff_level0_col4" class="col_heading level0 col4" >attr_obs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cabff_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cabff_row0_col0" class="data row0 col0" >1553-00-00:1555-06-00</td>
#       <td id="T_cabff_row0_col1" class="data row0 col1" >143239</td>
#       <td id="T_cabff_row0_col2" class="data row0 col2" >instituta</td>
#       <td id="T_cabff_row0_col3" class="data row0 col3" >1553-00-00:1555-06-00</td>
#       <td id="T_cabff_row0_col4" class="data row0 col4" >curso: 1 curso de Instituta, 1 de Código desde Outubro de 1553 a Junho de 1555</td>
#     </tr>
#     <tr>
#       <th id="T_cabff_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cabff_row1_col0" class="data row1 col0" >1553-10-00</td>
#       <td id="T_cabff_row1_col1" class="data row1 col1" >143239</td>
#       <td id="T_cabff_row1_col2" class="data row1 col2" >faculdade</td>
#       <td id="T_cabff_row1_col3" class="data row1 col3" >Leis</td>
#       <td id="T_cabff_row1_col4" class="data row1 col4" >Leis</td>
#     </tr>
#     <tr>
#       <th id="T_cabff_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cabff_row2_col0" class="data row2 col0" >1553-10-00</td>
#       <td id="T_cabff_row2_col1" class="data row2 col1" >143239</td>
#       <td id="T_cabff_row2_col2" class="data row2 col2" >naturalidade</td>
#       <td id="T_cabff_row2_col3" class="data row2 col3" >Ferreira</td>
#       <td id="T_cabff_row2_col4" class="data row2 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_cabff_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cabff_row3_col0" class="data row3 col0" >1553-10-00</td>
#       <td id="T_cabff_row3_col1" class="data row3 col1" >143239</td>
#       <td id="T_cabff_row3_col2" class="data row3 col2" >nome</td>
#       <td id="T_cabff_row3_col3" class="data row3 col3" >Jerónimo de Almeida</td>
#       <td id="T_cabff_row3_col4" class="data row3 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_cabff_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cabff_row4_col0" class="data row4 col0" >1553-10-00</td>
#       <td id="T_cabff_row4_col1" class="data row4 col1" >143239</td>
#       <td id="T_cabff_row4_col2" class="data row4 col2" >nome</td>
#       <td id="T_cabff_row4_col3" class="data row4 col3" >Jerónimo de Almeida Ribeiro</td>
#       <td id="T_cabff_row4_col4" class="data row4 col4" >Jerónimo de Almeida, vide Ribeiro</td>
#     </tr>
#     <tr>
#       <th id="T_cabff_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cabff_row5_col0" class="data row5 col0" >1553-10-00</td>
#       <td id="T_cabff_row5_col1" class="data row5 col1" >143239</td>
#       <td id="T_cabff_row5_col2" class="data row5 col2" >nome-vide</td>
#       <td id="T_cabff_row5_col3" class="data row5 col3" >Ribeiro</td>
#       <td id="T_cabff_row5_col4" class="data row5 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_cabff_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cabff_row6_col0" class="data row6 col0" >1553-10-00</td>
#       <td id="T_cabff_row6_col1" class="data row6 col1" >143239</td>
#       <td id="T_cabff_row6_col2" class="data row6 col2" >uc-entrada</td>
#       <td id="T_cabff_row6_col3" class="data row6 col3" >1553-10-00</td>
#       <td id="T_cabff_row6_col4" class="data row6 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_cabff_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cabff_row7_col0" class="data row7 col0" >1553-10-00</td>
#       <td id="T_cabff_row7_col1" class="data row7 col1" >143239</td>
#       <td id="T_cabff_row7_col2" class="data row7 col2" >uc-entrada.ano</td>
#       <td id="T_cabff_row7_col3" class="data row7 col3" >1553</td>
#       <td id="T_cabff_row7_col4" class="data row7 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_cabff_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cabff_row8_col0" class="data row8 col0" >1559-07-27</td>
#       <td id="T_cabff_row8_col1" class="data row8 col1" >143239</td>
#       <td id="T_cabff_row8_col2" class="data row8 col2" >exame</td>
#       <td id="T_cabff_row8_col3" class="data row8 col3" >Exame para Bacharel</td>
#       <td id="T_cabff_row8_col4" class="data row8 col4" > 27.07.1559</td>
#     </tr>
#     <tr>
#       <th id="T_cabff_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_cabff_row9_col0" class="data row9 col0" >1559-07-27</td>
#       <td id="T_cabff_row9_col1" class="data row9 col1" >143239</td>
#       <td id="T_cabff_row9_col2" class="data row9 col2" >grau</td>
#       <td id="T_cabff_row9_col3" class="data row9 col3" >Bacharel em Leis</td>
#       <td id="T_cabff_row9_col4" class="data row9 col4" >"1559/07/27"</td>
#     </tr>
#     <tr>
#       <th id="T_cabff_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_cabff_row10_col0" class="data row10 col0" >1559-07-27</td>
#       <td id="T_cabff_row10_col1" class="data row10 col1" >143239</td>
#       <td id="T_cabff_row10_col2" class="data row10 col2"
# <style type="text/css">
# #T_243d1_row0_col0, #T_243d1_row0_col1, #T_243d1_row0_col2, #T_243d1_row0_col3, #T_243d1_row0_col4, #T_243d1_row0_col5, #T_243d1_row0_col6 {
#   background-color: #fbb4ae;
# }
# #T_243d1_row1_col0, #T_243d1_row1_col1, #T_243d1_row1_col2, #T_243d1_row1_col3, #T_243d1_row1_col4, #T_243d1_row1_col5, #T_243d1_row1_col6 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_243d1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_243d1_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_243d1_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_243d1_level0_col2" class="col_heading level0 col2" >nome-vide</th>
#       <th id="T_243d1_level0_col3" class="col_heading level0 col3" >naturalidade</th>
#       <th id="T_243d1_level0_col4" class="col_heading level0 col4" >uc-entrada</th>
#       <th id="T_243d1_level0_col5" class="col_heading level0 col5" >faculdade</th>
#       <th id="T_243d1_level0_col6" class="col_heading level0 col6" >nome-pai</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_243d1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_243d1_row0_col0" class="data row0 col0" >129553</td>
#       <td id="T_243d1_row0_col1" class="data row0 col1" >Manuel de Castro Caldeira</td>
#       <td id="T_243d1_row0_col2" class="data row0 col2" >Castro</td>
#       <td id="T_243d1_row0_col3" class="data row0 col3" >Abrantes</td>
#       <td id="T_243d1_row0_col4" class="data row0 col4" >1601-10-14</td>
#       <td id="T_243d1_row0_col5" class="data row0 col5" >Cursos jurídicos (Cânones ou Leis)</td>
#       <td id="T_243d1_row0_col6" class="data row0 col6" >Lopo Castro</td>
#     </tr>
#     <tr>
#       <th id="T_243d1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_243d1_row1_col0" class="data row1 col0" >191232</td>
#       <td id="T_243d1_row1_col1" class="data row1 col1" >Manuel de Castro</td>
#       <td id="T_243d1_row1_col2" class="data row1 col2" >Caldeira</td>
#       <td id="T_243d1_row1_col3" class="data row1 col3" >Abrantes</td>
#       <td id="T_243d1_row1_col4" class="data row1 col4" >1601-10-14</td>
#       <td id="T_243d1_row1_col5" class="data row1 col5" >Medicina</td>
#       <td id="T_243d1_row1_col6" class="data row1 col6" >Lopo de Castro</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_7885f_row0_col0, #T_7885f_row0_col1, #T_7885f_row0_col2, #T_7885f_row0_col3, #T_7885f_row0_col4, #T_7885f_row2_col0, #T_7885f_row2_col1, #T_7885f_row2_col2, #T_7885f_row2_col3, #T_7885f_row2_col4, #T_7885f_row4_col0, #T_7885f_row4_col1, #T_7885f_row4_col2, #T_7885f_row4_col3, #T_7885f_row4_col4, #T_7885f_row6_col0, #T_7885f_row6_col1, #T_7885f_row6_col2, #T_7885f_row6_col3, #T_7885f_row6_col4, #T_7885f_row8_col0, #T_7885f_row8_col1, #T_7885f_row8_col2, #T_7885f_row8_col3, #T_7885f_row8_col4, #T_7885f_row10_col0, #T_7885f_row10_col1, #T_7885f_row10_col2, #T_7885f_row10_col3, #T_7885f_row10_col4, #T_7885f_row13_col0, #T_7885f_row13_col1, #T_7885f_row13_col2, #T_7885f_row13_col3, #T_7885f_row13_col4, #T_7885f_row14_col0, #T_7885f_row14_col1, #T_7885f_row14_col2, #T_7885f_row14_col3, #T_7885f_row14_col4, #T_7885f_row16_col0, #T_7885f_row16_col1, #T_7885f_row16_col2, #T_7885f_row16_col3, #T_7885f_row16_col4, #T_7885f_row18_col0, #T_7885f_row18_col1, #T_7885f_row18_col2, #T_7885f_row18_col3, #T_7885f_row18_col4, #T_7885f_row19_col0, #T_7885f_row19_col1, #T_7885f_row19_col2, #T_7885f_row19_col3, #T_7885f_row19_col4, #T_7885f_row23_col0, #T_7885f_row23_col1, #T_7885f_row23_col2, #T_7885f_row23_col3, #T_7885f_row23_col4 {
#   background-color: #fbb4ae;
# }
# #T_7885f_row1_col0, #T_7885f_row1_col1, #T_7885f_row1_col2, #T_7885f_row1_col3, #T_7885f_row1_col4, #T_7885f_row3_col0, #T_7885f_row3_col1, #T_7885f_row3_col2, #T_7885f_row3_col3, #T_7885f_row3_col4, #T_7885f_row5_col0, #T_7885f_row5_col1, #T_7885f_row5_col2, #T_7885f_row5_col3, #T_7885f_row5_col4, #T_7885f_row7_col0, #T_7885f_row7_col1, #T_7885f_row7_col2, #T_7885f_row7_col3, #T_7885f_row7_col4, #T_7885f_row9_col0, #T_7885f_row9_col1, #T_7885f_row9_col2, #T_7885f_row9_col3, #T_7885f_row9_col4, #T_7885f_row11_col0, #T_7885f_row11_col1, #T_7885f_row11_col2, #T_7885f_row11_col3, #T_7885f_row11_col4, #T_7885f_row12_col0, #T_7885f_row12_col1, #T_7885f_row12_col2, #T_7885f_row12_col3, #T_7885f_row12_col4, #T_7885f_row15_col0, #T_7885f_row15_col1, #T_7885f_row15_col2, #T_7885f_row15_col3, #T_7885f_row15_col4, #T_7885f_row17_col0, #T_7885f_row17_col1, #T_7885f_row17_col2, #T_7885f_row17_col3, #T_7885f_row17_col4, #T_7885f_row20_col0, #T_7885f_row20_col1, #T_7885f_row20_col2, #T_7885f_row20_col3, #T_7885f_row20_col4, #T_7885f_row21_col0, #T_7885f_row21_col1, #T_7885f_row21_col2, #T_7885f_row21_col3, #T_7885f_row21_col4, #T_7885f_row22_col0, #T_7885f_row22_col1, #T_7885f_row22_col2, #T_7885f_row22_col3, #T_7885f_row22_col4 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_7885f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7885f_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_7885f_level0_col1" class="col_heading level0 col1" >id</th>
#       <th id="T_7885f_level0_col2" class="col_heading level0 col2" >type</th>
#       <th id="T_7885f_level0_col3" class="col_heading level0 col3" >value</th>
#       <th id="T_7885f_level0_col4" class="col_heading level0 col4" >attr_obs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7885f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7885f_row0_col0" class="data row0 col0" >1601-10-14</td>
#       <td id="T_7885f_row0_col1" class="data row0 col1" >129553</td>
#       <td id="T_7885f_row0_col2" class="data row0 col2" >faculdade</td>
#       <td id="T_7885f_row0_col3" class="data row0 col3" >Cursos jurídicos (Cânones ou Leis)</td>
#       <td id="T_7885f_row0_col4" class="data row0 col4" >Faculdade inferida</td>
#     </tr>
#     <tr>
#       <th id="T_7885f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7885f_row1_col0" class="data row1 col0" >1601-10-14</td>
#       <td id="T_7885f_row1_col1" class="data row1 col1" >191232</td>
#       <td id="T_7885f_row1_col2" class="data row1 col2" >faculdade</td>
#       <td id="T_7885f_row1_col3" class="data row1 col3" >Medicina</td>
#       <td id="T_7885f_row1_col4" class="data row1 col4" >Medicina</td>
#     </tr>
#     <tr>
#       <th id="T_7885f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7885f_row2_col0" class="data row2 col0" >1601-10-14</td>
#       <td id="T_7885f_row2_col1" class="data row2 col1" >129553</td>
#       <td id="T_7885f_row2_col2" class="data row2 col2" >instituta</td>
#       <td id="T_7885f_row2_col3" class="data row2 col3" >1601-10-14</td>
#       <td id="T_7885f_row2_col4" class="data row2 col4" >14.10.1601 1601-10-14</td>
#     </tr>
#     <tr>
#       <th id="T_7885f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7885f_row3_col0" class="data row3 col0" >1601-10-14</td>
#       <td id="T_7885f_row3_col1" class="data row3 col1" >191232</td>
#       <td id="T_7885f_row3_col2" class="data row3 col2" >instituta</td>
#       <td id="T_7885f_row3_col3" class="data row3 col3" >1601-10-14</td>
#       <td id="T_7885f_row3_col4" class="data row3 col4" >14.10.1601 1601-10-14</td>
#     </tr>
#     <tr>
#       <th id="T_7885f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7885f_row4_col0" class="data row4 col0" >1601-10-14</td>
#       <td id="T_7885f_row4_col1" class="data row4 col1" >129553</td>
#       <td id="T_7885f_row4_col2" class="data row4 col2" >naturalidade</td>
#       <td id="T_7885f_row4_col3" class="data row4 col3" >Abrantes</td>
#       <td id="T_7885f_row4_col4" class="data row4 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7885f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7885f_row5_col0" class="data row5 col0" >1601-10-14</td>
#       <td id="T_7885f_row5_col1" class="data row5 col1" >191232</td>
#       <td id="T_7885f_row5_col2" class="data row5 col2" >naturalidade</td>
#       <td id="T_7885f_row5_col3" class="data row5 col3" >Abrantes</td>
#       <td id="T_7885f_row5_col4" class="data row5 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7885f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7885f_row6_col0" class="data row6 col0" >1601-10-14</td>
#       <td id="T_7885f_row6_col1" class="data row6 col1" >129553</td>
#       <td id="T_7885f_row6_col2" class="data row6 col2" >nome</td>
#       <td id="T_7885f_row6_col3" class="data row6 col3" >Manuel de Castro</td>
#       <td id="T_7885f_row6_col4" class="data row6 col4" >Manuel de Castro Caldeira, vide Castro</td>
#     </tr>
#     <tr>
#       <th id="T_7885f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7885f_row7_col0" class="data row7 col0" >1601-10-14</td>
#       <td id="T_7885f_row7_col1" class="data row7 col1" >191232</td>
#       <td id="T_7885f_row7_col2" class="data row7 col2" >nome</td>
#       <td id="T_7885f_row7_col3" class="data row7 col3" >Manuel de Castro</td>
#       <td id="T_7885f_row7_col4" class="data row7 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7885f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7885f_row8_col0" class="data row8 col0" >1601-10-14</td>
#       <td id="T_7885f_row8_col1" class="data row8 col1" >129553</td>
#       <td id="T_7885f_row8_col2" class="data row8 col2" >nome</td>
#       <td id="T_7885f_row8_col3" class="data row8 col3" >Manuel de Castro Caldeira</td>
#       <td id="T_7885f_row8_col4" class="data row8 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7885f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7885f_row9_col0" class="data row9 col0" >1601-10-14</td>
#       <td id="T_7885f_row9_col1" class="data row9 col1" >191232</td>
#       <td id="T_7885f_row9_col2" class="data row9 col2" >nome</td>
#       <td id="T_7885f_row9_col3" class="data row9 col3" >Manuel de Castro Caldeira</td>
#       <td id="T_7885f_row9_col4" class="data row9 col4" >Manuel de Castro, vide Caldeira</td>
#     </tr>
#     <tr>
#       <th id="T_7885f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7885f_row10_col0" class="data row10 col0" >1601-10-14</td>
#       <td id="T_7885f_row10_col1" class="data row10 col1" >129553</td>
#       <td id="T_7885f_row10_col2" class="data row10 c
# <style type="text/css">
# #T_22aa4_row0_col0, #T_22aa4_row0_col1, #T_22aa4_row0_col2, #T_22aa4_row0_col3, #T_22aa4_row0_col4, #T_22aa4_row0_col5, #T_22aa4_row0_col6 {
#   background-color: #fbb4ae;
# }
# #T_22aa4_row1_col0, #T_22aa4_row1_col1, #T_22aa4_row1_col2, #T_22aa4_row1_col3, #T_22aa4_row1_col4, #T_22aa4_row1_col5, #T_22aa4_row1_col6 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_22aa4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_22aa4_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_22aa4_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_22aa4_level0_col2" class="col_heading level0 col2" >nome-vide</th>
#       <th id="T_22aa4_level0_col3" class="col_heading level0 col3" >naturalidade</th>
#       <th id="T_22aa4_level0_col4" class="col_heading level0 col4" >uc-entrada</th>
#       <th id="T_22aa4_level0_col5" class="col_heading level0 col5" >faculdade</th>
#       <th id="T_22aa4_level0_col6" class="col_heading level0 col6" >nome-pai</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22aa4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_22aa4_row0_col0" class="data row0 col0" >167251</td>
#       <td id="T_22aa4_row0_col1" class="data row0 col1" >Pedro Simões Esteves</td>
#       <td id="T_22aa4_row0_col2" class="data row0 col2" >Simões</td>
#       <td id="T_22aa4_row0_col3" class="data row0 col3" >Campo Maior</td>
#       <td id="T_22aa4_row0_col4" class="data row0 col4" >1665-10-19</td>
#       <td id="T_22aa4_row0_col5" class="data row0 col5" >Cursos jurídicos (Cânones ou Leis)</td>
#       <td id="T_22aa4_row0_col6" class="data row0 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_22aa4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_22aa4_row1_col0" class="data row1 col0" >231579</td>
#       <td id="T_22aa4_row1_col1" class="data row1 col1" >Pedro Simões</td>
#       <td id="T_22aa4_row1_col2" class="data row1 col2" >Pedro Simões Esteves</td>
#       <td id="T_22aa4_row1_col3" class="data row1 col3" >Campo Maior</td>
#       <td id="T_22aa4_row1_col4" class="data row1 col4" >1665-10-19</td>
#       <td id="T_22aa4_row1_col5" class="data row1 col5" >Cânones</td>
#       <td id="T_22aa4_row1_col6" class="data row1 col6" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_
_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a7f8d_row6_col0" class="data row6 col0" >1665-10-19</td>
#       <td id="T_a7f8d_row6_col1" class="data row6 col1" >231579</td>
#       <td id="T_a7f8d_row6_col2" class="data row6 col2" >naturalidade</td>
#       <td id="T_a7f8d_row6_col3" class="data row6 col3" >Campo Maior</td>
#       <td id="T_a7f8d_row6_col4" class="data row6 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a7f8d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a7f8d_row7_col0" class="data row7 col0" >1665-10-19</td>
#       <td id="T_a7f8d_row7_col1" class="data row7 col1" >167251</td>
#       <td id="T_a7f8d_row7_col2" class="data row7 col2" >nome</td>
#       <td id="T_a7f8d_row7_col3" class="data row7 col3" >Pedro Simões</td>
#       <td id="T_a7f8d_row7_col4" class="data row7 col4" >Pedro Simões Esteves, vide Simões</td>
#     </tr>
#     <tr>
#       <th id="T_a7f8d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a7f8d_row8_col0" class="data row8 col0" >1665-10-19</td>
#       <td id="T_a7f8d_row8_col1" class="data row8 col1" >231579</td>
#       <td id="T_a7f8d_row8_col2" class="data row8 col2" >nome</td>
#       <td id="T_a7f8d_row8_col3" class="data row8 col3" >Pedro Simões</td>
#       <td id="T_a7f8d_row8_col4" class="data row8 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a7f8d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a7f8d_row9_col0" class="data row9 col0" >1665-10-19</td>
#       <td id="T_a7f8d_row9_col1" class="data row9 col1" >167251</td>
#       <td id="T_a7f8d_row9_col2" class="data row9 col2" >nome</td>
#       <td id="T_a7f8d_row9_col3" class="data row9 col3" >Pedro Simões Esteves</td>
#       <td id="T_a7f8d_row9_col4" class="data row9 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a7f8d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a7f8d_row10_col0" class="data row10 col0" >1665-10-19</td>
#       <td id="T_a7f8d_row10_col1" class="data row10 col1" >231579</td>
#       <td id="T_a7f8d_row10_col2" class="data row10 col2" >nome</td>
#       <td id="T_a7f8d_row10_col3" class="data row10 col3" >Pedro Simões Esteves</td>
#       <td id="T_a7f8d_row10_c
# <style type="text/css">
# #T_87a09_row0_col0, #T_87a09_row0_col1, #T_87a09_row0_col2, #T_87a09_row0_col3, #T_87a09_row0_col4, #T_87a09_row0_col5, #T_87a09_row0_col6 {
#   background-color: #fbb4ae;
# }
# #T_87a09_row1_col0, #T_87a09_row1_col1, #T_87a09_row1_col2, #T_87a09_row1_col3, #T_87a09_row1_col4, #T_87a09_row1_col5, #T_87a09_row1_col6 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_87a09">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87a09_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_87a09_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_87a09_level0_col2" class="col_heading level0 col2" >nome-vide</th>
#       <th id="T_87a09_level0_col3" class="col_heading level0 col3" >naturalidade</th>
#       <th id="T_87a09_level0_col4" class="col_heading level0 col4" >uc-entrada</th>
#       <th id="T_87a09_level0_col5" class="col_heading level0 col5" >faculdade</th>
#       <th id="T_87a09_level0_col6" class="col_heading level0 col6" >nome-pai</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87a09_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_87a09_row0_col0" class="data row0 col0" >149046</td>
#       <td id="T_87a09_row0_col1" class="data row0 col1" >Bernardo José de Azevedo</td>
#       <td id="T_87a09_row0_col2" class="data row0 col2" >Vieira</td>
#       <td id="T_87a09_row0_col3" class="data row0 col3" >Paredes</td>
#       <td id="T_87a09_row0_col4" class="data row0 col4" >1725-10-01</td>
#       <td id="T_87a09_row0_col5" class="data row0 col5" >Cânones</td>
#       <td id="T_87a09_row0_col6" class="data row0 col6" >José de Azevedo Vieira</td>
#     </tr>
#     <tr>
#       <th id="T_87a09_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_87a09_row1_col0" class="data row1 col0" >216902</td>
#       <td id="T_87a09_row1_col1" class="data row1 col1" >Bernardo José de Azevedo Vieira</td>
#       <td id="T_87a09_row1_col2" class="data row1 col2" >Azevedo</td>
#       <td id="T_87a09_row1_col3" class="data row1 col3" >Paredes</td>
#       <td id="T_87a09_row1_col4" class="data row1 col4" >1726-10-01</td>
#       <td id="T_87a09_row1_col5" class="data row1 col5" >Cânones</td>
#       <td id="T_87a09_row1_col6" class="data row1 col6" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_a805a_row0_col0, #T_a805a_row0_col1, #T_a805a_row0_col2, #T_a805a_row0_col3, #T_a805a_row0_col4, #T_a805a_row1_col0, #T_a805a_row1_col1, #T_a805a_row1_col2, #T_a805a_row1_col3, #T_a805a_row1_col4, #T_a805a_row2_col0, #T_a805a_row2_col1, #T_a805a_row2_col2, #T_a805a_row2_col3, #T_a805a_row2_col4, #T_a805a_row3_col0, #T_a805a_row3_col1, #T_a805a_row3_col2, #T_a805a_row3_col3, #T_a805a_row3_col4, #T_a805a_row4_col0, #T_a805a_row4_col1, #T_a805a_row4_col2, #T_a805a_row4_col3, #T_a805a_row4_col4, #T_a805a_row5_col0, #T_a805a_row5_col1, #T_a805a_row5_col2, #T_a805a_row5_col3, #T_a805a_row5_col4, #T_a805a_row6_col0, #T_a805a_row6_col1, #T_a805a_row6_col2, #T_a805a_row6_col3, #T_a805a_row6_col4, #T_a805a_row7_col0, #T_a805a_row7_col1, #T_a805a_row7_col2, #T_a805a_row7_col3, #T_a805a_row7_col4, #T_a805a_row8_col0, #T_a805a_row8_col1, #T_a805a_row8_col2, #T_a805a_row8_col3, #T_a805a_row8_col4, #T_a805a_row9_col0, #T_a805a_row9_col1, #T_a805a_row9_col2, #T_a805a_row9_col3, #T_a805a_row9_col4, #T_a805a_row10_col0, #T_a805a_row10_col1, #T_a805a_row10_col2, #T_a805a_row10_col3, #T_a805a_row10_col4, #T_a805a_row12_col0, #T_a805a_row12_col1, #T_a805a_row12_col2, #T_a805a_row12_col3, #T_a805a_row12_col4, #T_a805a_row20_col0, #T_a805a_row20_col1, #T_a805a_row20_col2, #T_a805a_row20_col3, #T_a805a_row20_col4, #T_a805a_row22_col0, #T_a805a_row22_col1, #T_a805a_row22_col2, #T_a805a_row22_col3, #T_a805a_row22_col4, #T_a805a_row24_col0, #T_a805a_row24_col1, #T_a805a_row24_col2, #T_a805a_row24_col3, #T_a805a_row24_col4, #T_a805a_row28_col0, #T_a805a_row28_col1, #T_a805a_row28_col2, #T_a805a_row28_col3, #T_a805a_row28_col4, #T_a805a_row29_col0, #T_a805a_row29_col1, #T_a805a_row29_col2, #T_a805a_row29_col3, #T_a805a_row29_col4, #T_a805a_row30_col0, #T_a805a_row30_col1, #T_a805a_row30_col2, #T_a805a_row30_col3, #T_a805a_row30_col4 {
#   background-color: #fbb4ae;
# }
# #T_a805a_row11_col0, #T_a805a_row11_col1, #T_a805a_row11_col2, #T_a805a_row11_col3, #T_a805a_row11_col4, #T_a805a_row13_col0, #T_a805a_row13_col1, #T_a805a_row13_col2, #T_a805a_row13_col3, #T_a805a_row13_col4, #T_a805a_row14_col0, #T_a805a_row14_col1, #T_a805a_row14_col2, #T_a805a_row14_col3, #T_a805a_row14_col4, #T_a805a_row15_col0, #T_a805a_row15_col1, #T_a805a_row15_col2, #T_a805a_row15_col3, #T_a805a_row15_col4, #T_a805a_row16_col0, #T_a805a_row16_col1, #T_a805a_row16_col2, #T_a805a_row16_col3, #T_a805a_row16_col4, #T_a805a_row17_col0, #T_a805a_row17_col1, #T_a805a_row17_col2, #T_a805a_row17_col3, #T_a805a_row17_col4, #T_a805a_row18_col0, #T_a805a_row18_col1, #T_a805a_row18_col2, #T_a805a_row18_col3, #T_a805a_row18_col4, #T_a805a_row19_col0, #T_a805a_row19_col1, #T_a805a_row19_col2, #T_a805a_row19_col3, #T_a805a_row19_col4, #T_a805a_row21_col0, #T_a805a_row21_col1, #T_a805a_row21_col2, #T_a805a_row21_col3, #T_a805a_row21_col4, #T_a805a_row23_col0, #T_a805a_row23_col1, #T_a805a_row23_col2, #T_a805a_row23_col3, #T_a805a_row23_col4, #T_a805a_row25_col0, #T_a805a_row25_col1, #T_a805a_row25_col2, #T_a805a_row25_col3, #T_a805a_row25_col4, #T_a805a_row26_col0, #T_a805a_row26_col1, #T_a805a_row26_col2, #T_a805a_row26_col3, #T_a805a_row26_col4, #T_a805a_row27_col0, #T_a805a_row27_col1, #T_a805a_row27_col2, #T_a805a_row27_col3, #T_a805a_row27_col4 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_a805a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a805a_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_a805a_level0_col1" class="col_heading level0 col1" >id</th>
#       <th id="T_a805a_level0_col2" class="col_heading level0 col2" >type</th>
#       <th id="T_a805a_level0_col3" class="col_heading level0 col3" >value</th>
#       <th id="T_a805a_level0_col4" class="col_heading level0 col4" >attr_obs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a805a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a805a_row0_col0" class="data row0 col0" >1725-10-01</td>
#       <td id="T_a805a_row0_col1" class="data row0 col1" >149046</td>
#       <td id="T_a805a_row0_col2" class="data row0 col2" >faculdade</td>
#       <td id="T_a805a_row0_col3" class="data row0 col3" >Cânones</td>
#       <td id="T_a805a_row0_col4" class="data row0 col4" >Cânones</td>
#     </tr>
#     <tr>
#       <th id="T_a805a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a805a_row1_col0" class="data row1 col0" >1725-10-01</td>
#       <td id="T_a805a_row1_col1" class="data row1 col1" >149046</td>
#       <td id="T_a805a_row1_col2" class="data row1 col2" >instituta</td>
#       <td id="T_a805a_row1_col3" class="data row1 col3" >1725-10-01</td>
#       <td id="T_a805a_row1_col4" class="data row1 col4" >01.10.1725 1725-10-01</td>
#     </tr>
#     <tr>
#       <th id="T_a805a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a805a_row2_col0" class="data row2 col0" >1725-10-01</td>
#       <td id="T_a805a_row2_col1" class="data row2 col1" >149046</td>
#       <td id="T_a805a_row2_col2" class="data row2 col2" >naturalidade</td>
#       <td id="T_a805a_row2_col3" class="data row2 col3" >Paredes</td>
#       <td id="T_a805a_row2_col4" class="data row2 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a805a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a805a_row3_col0" class="data row3 col0" >1725-10-01</td>
#       <td id="T_a805a_row3_col1" class="data row3 col1" >149046</td>
#       <td id="T_a805a_row3_col2" class="data row3 col2" >nome</td>
#       <td id="T_a805a_row3_col3" class="data row3 col3" >Bernardo José de Azevedo</td>
#       <td id="T_a805a_row3_col4" class="data row3 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a805a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a805a_row4_col0" class="data row4 col0" >1725-10-01</td>
#       <td id="T_a805a_row4_col1" class="data row4 col1" >149046</td>
#       <td id="T_a805a_row4_col2" class="data row4 col2" >nome</td>
#       <td id="T_a805a_row4_col3" class="data row4 col3" >Bernardo José de Azevedo Vieira</td>
#       <td id="T_a805a_row4_col4" class="data row4 col4" >Bernardo José de Azevedo, vide Vieira</td>
#     </tr>
#     <tr>
#       <th id="T_a805a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a805a_row5_col0" class="data row5 col0" >1725-10-01</td>
#       <td id="T_a805a_row5_col1" class="data row5 col1" >149046</td>
#       <td id="T_a805a_row5_col2" class="data row5 col2" >nome-nota</td>
#       <td id="T_a805a_row5_col3" class="data row5 col3" >padre</td>
#       <td id="T_a805a_row5_col4" class="data row5 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a805a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a805a_row6_col0" class="data row6 col0" >1725-10-01</td>
#       <td id="T_a805a_row6_col1" class="data row6 col1" >149046</td>
#       <td id="T_a805a_row6_col2" class="data row6 col2" >nome-pai</td>
#       <td id="T_a805a_row6_col3" class="data row6 col3" >José de Azevedo Vieira</td>
#       <td id="T_a805a_row6_col4" class="data row6 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a805a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a805a_row7_col0" class="data row7 col0" >1725-10-01</td>
#       <td id="T_a805a_row7_col1" class="data row7 col1" >149046</td>
#       <td id="T_a805a_row7_col2" class="data row7 col2" >nome-vide</td>
#       <td id="T_a805a_row7_col3" class="data row7 col3" >Vieira</td>
#       <td id="T_a805a_row7_col4" class="data row7 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a805a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a805a_row8_col0" class="data row8 col0" >1725-10-01</td>
#       <td id="T_a805a_row8_col1" class="data row8 col1" >149046</td>
#       <td id="T_a805a_row8_col2" class="data row8 col2" >padre</td>
#       <td id="T_a805a_row8_col3" class="data row8 col3" >sim</td>
#       <td id="T_a805a_row8_col4" class="data row8 col4" >padre</td>
#     </tr>
#     <tr>
#       <th id="T_a805a_level0_row9" class="row_heading level0 row9" >9</th>
#       <
# <style type="text/css">
# #T_4ce3b_row0_col0, #T_4ce3b_row0_col1, #T_4ce3b_row0_col2, #T_4ce3b_row0_col3, #T_4ce3b_row0_col4, #T_4ce3b_row0_col5, #T_4ce3b_row0_col6 {
#   background-color: #fbb4ae;
# }
# #T_4ce3b_row1_col0, #T_4ce3b_row1_col1, #T_4ce3b_row1_col2, #T_4ce3b_row1_col3, #T_4ce3b_row1_col4, #T_4ce3b_row1_col5, #T_4ce3b_row1_col6 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_4ce3b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4ce3b_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_4ce3b_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_4ce3b_level0_col2" class="col_heading level0 col2" >nome-vide</th>
#       <th id="T_4ce3b_level0_col3" class="col_heading level0 col3" >naturalidade</th>
#       <th id="T_4ce3b_level0_col4" class="col_heading level0 col4" >uc-entrada</th>
#       <th id="T_4ce3b_level0_col5" class="col_heading level0 col5" >faculdade</th>
#       <th id="T_4ce3b_level0_col6" class="col_heading level0 col6" >nome-pai</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ce3b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4ce3b_row0_col0" class="data row0 col0" >210366</td>
#       <td id="T_4ce3b_row0_col1" class="data row0 col1" >Joaquim José Ribeiro de Vasconcelos</td>
#       <td id="T_4ce3b_row0_col2" class="data row0 col2" >Joaquim José Ribeiro</td>
#       <td id="T_4ce3b_row0_col3" class="data row0 col3" >Baía, Brasil</td>
#       <td id="T_4ce3b_row0_col4" class="data row0 col4" >1779-10-26</td>
#       <td id="T_4ce3b_row0_col5" class="data row0 col5" >Filosofia</td>
#       <td id="T_4ce3b_row0_col6" class="data row0 col6" >João Ribeiro de Vasconcelos</td>
#     </tr>
#     <tr>
#       <th id="T_4ce3b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4ce3b_row1_col0" class="data row1 col0" >163896</td>
#       <td id="T_4ce3b_row1_col1" class="data row1 col1" >Joaquim José Ribeiro</td>
#       <td id="T_4ce3b_row1_col2" class="data row1 col2" >Vasconcelos</td>
#       <td id="T_4ce3b_row1_col3" class="data row1 col3" >Baía</td>
#       <td id="T_4ce3b_row1_col4" class="data row1 col4" >1781-11-05</td>
#       <td id="T_4ce3b_row1_col5" class="data row1 col5" >Matemática</td>
#       <td id="T_4ce3b_row1_col6" class="data row1 col6" >João Ribeiro de Vasconcelos</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_4ac7a_row0_col0, #T_4ac7a_row0_col1, #T_4ac7a_row0_col2, #T_4ac7a_row0_col3, #T_4ac7a_row0_col4, #T_4ac7a_row1_col0, #T_4ac7a_row1_col1, #T_4ac7a_row1_col2, #T_4ac7a_row1_col3, #T_4ac7a_row1_col4, #T_4ac7a_row2_col0, #T_4ac7a_row2_col1, #T_4ac7a_row2_col2, #T_4ac7a_row2_col3, #T_4ac7a_row2_col4, #T_4ac7a_row3_col0, #T_4ac7a_row3_col1, #T_4ac7a_row3_col2, #T_4ac7a_row3_col3, #T_4ac7a_row3_col4, #T_4ac7a_row4_col0, #T_4ac7a_row4_col1, #T_4ac7a_row4_col2, #T_4ac7a_row4_col3, #T_4ac7a_row4_col4, #T_4ac7a_row5_col0, #T_4ac7a_row5_col1, #T_4ac7a_row5_col2, #T_4ac7a_row5_col3, #T_4ac7a_row5_col4, #T_4ac7a_row6_col0, #T_4ac7a_row6_col1, #T_4ac7a_row6_col2, #T_4ac7a_row6_col3, #T_4ac7a_row6_col4, #T_4ac7a_row7_col0, #T_4ac7a_row7_col1, #T_4ac7a_row7_col2, #T_4ac7a_row7_col3, #T_4ac7a_row7_col4, #T_4ac7a_row8_col0, #T_4ac7a_row8_col1, #T_4ac7a_row8_col2, #T_4ac7a_row8_col3, #T_4ac7a_row8_col4, #T_4ac7a_row9_col0, #T_4ac7a_row9_col1, #T_4ac7a_row9_col2, #T_4ac7a_row9_col3, #T_4ac7a_row9_col4, #T_4ac7a_row10_col0, #T_4ac7a_row10_col1, #T_4ac7a_row10_col2, #T_4ac7a_row10_col3, #T_4ac7a_row10_col4, #T_4ac7a_row11_col0, #T_4ac7a_row11_col1, #T_4ac7a_row11_col2, #T_4ac7a_row11_col3, #T_4ac7a_row11_col4, #T_4ac7a_row12_col0, #T_4ac7a_row12_col1, #T_4ac7a_row12_col2, #T_4ac7a_row12_col3, #T_4ac7a_row12_col4, #T_4ac7a_row13_col0, #T_4ac7a_row13_col1, #T_4ac7a_row13_col2, #T_4ac7a_row13_col3, #T_4ac7a_row13_col4 {
#   background-color: #fbb4ae;
# }
# #T_4ac7a_row14_col0, #T_4ac7a_row14_col1, #T_4ac7a_row14_col2, #T_4ac7a_row14_col3, #T_4ac7a_row14_col4, #T_4ac7a_row15_col0, #T_4ac7a_row15_col1, #T_4ac7a_row15_col2, #T_4ac7a_row15_col3, #T_4ac7a_row15_col4, #T_4ac7a_row16_col0, #T_4ac7a_row16_col1, #T_4ac7a_row16_col2, #T_4ac7a_row16_col3, #T_4ac7a_row16_col4, #T_4ac7a_row17_col0, #T_4ac7a_row17_col1, #T_4ac7a_row17_col2, #T_4ac7a_row17_col3, #T_4ac7a_row17_col4, #T_4ac7a_row18_col0, #T_4ac7a_row18_col1, #T_4ac7a_row18_col2, #T_4ac7a_row18_col3, #T_4ac7a_row18_col4, #T_4ac7a_row19_col0, #T_4ac7a_row19_col1, #T_4ac7a_row19_col2, #T_4ac7a_row19_col3, #T_4ac7a_row19_col4, #T_4ac7a_row20_col0, #T_4ac7a_row20_col1, #T_4ac7a_row20_col2, #T_4ac7a_row20_col3, #T_4ac7a_row20_col4, #T_4ac7a_row21_col0, #T_4ac7a_row21_col1, #T_4ac7a_row21_col2, #T_4ac7a_row21_col3, #T_4ac7a_row21_col4, #T_4ac7a_row22_col0, #T_4ac7a_row22_col1, #T_4ac7a_row22_col2, #T_4ac7a_row22_col3, #T_4ac7a_row22_col4, #T_4ac7a_row23_col0, #T_4ac7a_row23_col1, #T_4ac7a_row23_col2, #T_4ac7a_row23_col3, #T_4ac7a_row23_col4, #T_4ac7a_row24_col0, #T_4ac7a_row24_col1, #T_4ac7a_row24_col2, #T_4ac7a_row24_col3, #T_4ac7a_row24_col4, #T_4ac7a_row25_col0, #T_4ac7a_row25_col1, #T_4ac7a_row25_col2, #T_4ac7a_row25_col3, #T_4ac7a_row25_col4, #T_4ac7a_row26_col0, #T_4ac7a_row26_col1, #T_4ac7a_row26_col2, #T_4ac7a_row26_col3, #T_4ac7a_row26_col4 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_4ac7a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4ac7a_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_4ac7a_level0_col1" class="col_heading level0 col1" >id</th>
#       <th id="T_4ac7a_level0_col2" class="col_heading level0 col2" >type</th>
#       <th id="T_4ac7a_level0_col3" class="col_heading level0 col3" >value</th>
#       <th id="T_4ac7a_level0_col4" class="col_heading level0 col4" >attr_obs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ac7a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4ac7a_row0_col0" class="data row0 col0" >1779-10-26</td>
#       <td id="T_4ac7a_row0_col1" class="data row0 col1" >210366</td>
#       <td id="T_4ac7a_row0_col2" class="data row0 col2" >faculdade</td>
#       <td id="T_4ac7a_row0_col3" class="data row0 col3" >Filosofia</td>
#       <td id="T_4ac7a_row0_col4" class="data row0 col4" >Filosofia</td>
#     </tr>
#     <tr>
#       <th id="T_4ac7a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4ac7a_row1_col0" class="data row1 col0" >1779-10-26</td>
#       <td id="T_4ac7a_row1_col1" class="data row1 col1" >210366</td>
#       <td id="T_4ac7a_row1_col2" class="data row1 col2" >matricula-faculdade</td>
#       <td id="T_4ac7a_row1_col3" class="data row1 col3" >Filosofia</td>
#       <td id="T_4ac7a_row1_col4" class="data row1 col4" >(obrigado)</td>
#     </tr>
#     <tr>
# ...
#   background-color: #fbb4ae;
# }
_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0adc9_row1_col0" class="data row1 col0" >1578-10-08</td>
#       <td id="T_0adc9_row1_col1" class="data row1 col1" >266159</td>
#       <td id="T_0adc9_row1_col2" class="data row1 col2" >instituta</td>
#       <td id="T_0adc9_row1_col3" class="data row1 col3" >1578-10-08</td>
#       <td id="T_0adc9_row1_col4" class="data row1 col4" >"1578/10/08 1578-10-08"</td>
#     </tr>
#     <tr>
#       <th id="T_0adc9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0adc9_row2_col0" class="data row2 col0" >1578-10-08</td>
#       <td id="T_0adc9_row2_col1" class="data row2 col1" >266159</td>
#       <td id="T_0adc9_row2_col2" class="data row2 col2" >naturalidade</td>
#       <td id="T_0adc9_row2_col3" class="data row2 col3" >Lisboa</td>
#       <td id="T_0adc9_row2_col4" class="data row2 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_0adc9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0adc9_row3_col0" class="data row3 col0" >1578-10-08</td>
#       <td id="T_0adc9_row3_col1" class="data row3 col1" >266159</td>
#       <td id="T_0adc9_row3_col2" class="data row3 col2" >nome</td>
#       <td id="T_0adc9_row3_col3" class="data row3 col3" >Domingos Antunes</td>
#       <td id="T_0adc9_row3_col4" class="data row3 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_0adc9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0adc9_row4_col0" class="data row4 col0" >1578-10-08</td>
#       <td id="T_0adc9_row4_col1" class="data row4 col1" >266159</td>
#       <td id="T_0adc9_row4_col2" class="data row4 col2" >nome</td>
#       <td id="T_0adc9_row4_col3" class="data row4 col3" >Domingos Antunes de Abreu</td>
#       <td id="T_0adc9_row4_col4" class="data row4 col4" >Domingos Antunes, vide de Abreu</td>
#     </tr>
#     <tr>
#       <th id="T_0adc9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0adc9_row5_col0" class="data row5 col0" >1578-10-08</td>
#       <td id="T_0adc9_row5_col1" class="data row5 col1" >266159</td>
#       <td id="T_0adc9_row5_col2" class="data row5 col2" >nome-pai</td>
#       <td id="T_0adc9_row5_col3" class="data row5 col3" >Brás Dias de Abreu</td>
#       <td id="T_0adc9_row5_col4" class="data row5 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_0adc9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0adc9_row6_col0" class="data row6 col0" >1578-10-08</td>
#       <td id="T_0adc9_row6_col1" class="data row6 col1" >266159</td>
#       <td id="T_0adc9_row6_col2" class="data row6 col2" >nome-vide</td>
#       <td id="T_0adc9_row6_col3" class="data row6 col3" >de Abreu</td>
#       <td id="T_0adc9_row6_col4" class="data row6 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_0adc9_level0_row7" clas
# <style type="text/css">
# #T_bb720_row0_col0, #T_bb720_row0_col1, #T_bb720_row0_col2, #T_bb720_row0_col3, #T_bb720_row0_col4, #T_bb720_row0_col5, #T_bb720_row0_col6 {
#   background-color: #fbb4ae;
# }
# #T_bb720_row1_col0, #T_bb720_row1_col1, #T_bb720_row1_col2, #T_bb720_row1_col3, #T_bb720_row1_col4, #T_bb720_row1_col5, #T_bb720_row1_col6 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_bb720">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bb720_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_bb720_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_bb720_level0_col2" class="col_heading level0 col2" >nome-vide</th>
#       <th id="T_bb720_level0_col3" class="col_heading level0 col3" >naturalidade</th>
#       <th id="T_bb720_level0_col4" class="col_heading level0 col4" >uc-entrada</th>
#       <th id="T_bb720_level0_col5" class="col_heading level0 col5" >faculdade</th>
#       <th id="T_bb720_level0_col6" class="col_heading level0 col6" >nome-pai</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb720_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bb720_row0_col0" class="data row0 col0" >213910</td>
#       <td id="T_bb720_row0_col1" class="data row0 col1" >Rui Lopes da Veiga</td>
#       <td id="T_bb720_row0_col2" class="data row0 col2" >Lopes</td>
#       <td id="T_bb720_row0_col3" class="data row0 col3" >Coimbra</td>
#       <td id="T_bb720_row0_col4" class="data row0 col4" >1558-02-03</td>
#       <td id="T_bb720_row0_col5" class="data row0 col5" >Artes</td>
#       <td id="T_bb720_row0_col6" class="data row0 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_bb720_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bb720_row1_col0" class="data row1 col0" >253753</td>
#       <td id="T_bb720_row1_col1" class="data row1 col1" >Rui Lopes</td>
#       <td id="T_bb720_row1_col2" class="data row1 col2" >da Veiga</td>
#       <td id="T_bb720_row1_col3" class="data row1 col3" >Coimbra</td>
#       <td id="T_bb720_row1_col4" class="data row1 col4" >1568-12-23</td>
#       <td id="T_bb720_row1_col5" class="data row1 col5" >Leis</td>
#       <td id="T_bb720_row1_col6" class="data row1 col6" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_77f94_row0_col0, #T_77f94_row0_col1, #T_77f94_row0_col2, #T_77f94_row0_col3, #T_77f94_row0_col4, #T_77f94_row1_col0, #T_77f94_row1_col1, #T_77f94_row1_col2, #T_77f94_row1_col3, #T_77f94_row1_col4, #T_77f94_row2_col0, #T_77f94_row2_col1, #T_77f94_row2_col2, #T_77f94_row2_col3, #T_77f94_row2_col4, #T_77f94_row3_col0, #T_77f94_row3_col1, #T_77f94_row3_col2, #T_77f94_row3_col3, #T_77f94_row3_col4, #T_77f94_row4_col0, #T_77f94_row4_col1, #T_77f94_row4_col2, #T_77f94_row4_col3, #T_77f94_row4_col4, #T_77f94_row5_col0, #T_77f94_row5_col1, #T_77f94_row5_col2, #T_77f94_row5_col3, #T_77f94_row5_col4, #T_77f94_row6_col0, #T_77f94_row6_col1, #T_77f94_row6_col2, #T_77f94_row6_col3, #T_77f94_row6_col4, #T_77f94_row7_col0, #T_77f94_row7_col1, #T_77f94_row7_col2, #T_77f94_row7_col3, #T_77f94_row7_col4, #T_77f94_row8_col0, #T_77f94_row8_col1, #T_77f94_row8_col2, #T_77f94_row8_col3, #T_77f94_row8_col4, #T_77f94_row9_col0, #T_77f94_row9_col1, #T_77f94_row9_col2, #T_77f94_row9_col3, #T_77f94_row9_col4, #T_77f94_row10_col0, #T_77f94_row10_col1, #T_77f94_row10_col2, #T_77f94_row10_col3, #T_77f94_row10_col4, #T_77f94_row22_col0, #T_77f94_row22_col1, #T_77f94_row22_col2, #T_77f94_row22_col3, #T_77f94_row22_col4 {
#   background-color: #fbb4ae;
# }
# #T_77f94_row11_col0, #T_77f94_row11_col1, #T_77f94_row11_col2, #T_77f94_row11_col3, #T_77f94_row11_col4, #T_77f94_row12_col0, #T_77f94_row12_col1, #T_77f94_row12_col2, #T_77f94_row12_col3, #T_77f94_row12_col4, #T_77f94_row13_col0, #T_77f94_row13_col1, #T_77f94_row13_col2, #T_77f94_row13_col3, #T_77f94_row13_col4, #T_77f94_row14_col0, #T_77f94_row14_col1, #T_77f94_row14_col2, #T_77f94_row14_col3, #T_77f94_row14_col4, #T_77f94_row15_col0, #T_77f94_row15_col1, #T_77f94_row15_col2, #T_77f94_row15_col3, #T_77f94_row15_col4, #T_77f94_row16_col0, #T_77f94_row16_col1, #T_77f94_row16_
row5_col4" class="data row5 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_77f94_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_77f94_row6_col0" class="data row6 col0" >1558-02-03</td>
#       <td id="T_77f94_row6_col1" class="data row6 col1" >213910</td>
#       <td id="T_77f94_row6_col2" class="data row6 col2" >uc-entrada</td>
#       <td id="T_77f94_row6_col3" class="data row6 col3" >1558-02-03</td>
#       <td id="T_77f94_row6_col4" class="data row6 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_77f94_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_77f94_row7_col0" class="data row7 col0" >1558-02-03</td>
#       <td id="T_77f94_row7_col1" class="data row7 col1" >213910</td>
#       <td id="T_77f94_row7_col2" class="data row7 col2" >uc-entrada.ano</td>
#       <td id="T_77f94_row7_col3" class="data row7 col3" >1558</td>
#       <td id="T_77f94_row7_col4" class="data row7 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_77f94_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_77f94_row8_col0" class="data row8 col0" >1560-05-23</td>
#       <td id="T_77f94_row8_col1" class="data row8 col1" >213910</td>
#       <td id="T_77f94_row8_col2" class="data row8 col2" >grau</td>
#       <td id="T_77f94_row8_col3" class="data row8 col3" >Licenciado em Artes</td>
#       <td id="T_77f94_row8_col4" class="data row8 col4" >23.05.1560</td>
#     </tr>
#     <tr>
#       <th id="T_77f94_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_77f94_row9_col0" class="data row9 col0" >1560-05-23</td>
#       <td id="T_77f94_row9_col1" class="data row9 col1" >213910</td>
#       <td id="T_77f94_row9_col2" class="data row9 col2" >uc-saida</td>
#       <td id="T_77f94_row9_col3" class="data row9 col3" >1560-05-23</td>
#       <td id="T_77f94_row9_col4" class="data row9 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_77f94_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_77f94_row10_col0" class="data row10 col0" >1560-05-23</td>
#       <td id="T_77f94_row10_col1" class="data row10 col1" >213910</td>
#       <td id="T_77f94_row10_col2" class="data row10 col2" >uc-saida.ano</td>
#       <td id="T_77f94_row10_col3" class="data row10 col3" >1560</td>
#       <td id="T_77f94_row10_col4" class="data row10 col4" >None</td>
#     </tr

# %%
vide_plus.loc['217701']
# Out:
# name                                         José de Santo António
# sex                                                              m
# nome-vide                                                Lencastre
# nome-geografico                                           ***NA***
# faculdade                                                      NaN
# faculdade.date                                                 NaN
# faculdade.obs                                                  NaN
# nome-pai                                                       NaN
# uc-entrada                                              0000-00-00
# uc-saida                                                0000-00-00
# uc-saida.date                                           0000-00-00
# uc-saida.obs                                                  None
# rec_type                                                       see
# loookup
# vide_type                                                      add
# lookup                             José de Santo António Lencastre
# name_sp                                         José Santo António
# lookup_sp                             José Santo António Lencastre
# sort_key           José Santo António-José Santo António Lencastre
# match_error                                                    NaN
# match_obs                                                      NaN
# Name: 217701, dtype: object

# %% [markdown]
# #### Non sequential matching

# %%
import pandas as pd
import numpy as np

vide_plus['match_error']=False

previous_geo_name = ''

# list of record to need to be debugged
# use a break point in "pass" statement of the "if" 
#  at the start of the loop
# problematic = ['169888','169890','214417']  # add to list what you what to debug
#
# 211703 See matches 168662 which in turn matches 211704 e 211706
problematic = ['168662','211703','211704','211706'] 


# Loop through the vide records
random_matches = []
for id,linha in vide_plus.iterrows():

    if id in problematic:
        pass  # do breakpoint here to debug problematic records

    nome = linha['name_sp']
    lookup_name = linha['lookup_sp']
    nome_geo = linha['nome-geografico']
    rec_type = linha['rec_type']

    # we now check for similar geo names
    # and load names from variants
    if nome_geo != previous_geo_name:
        simile = geo_similars.get(nome_geo,[])
        if len(simile) > 0 :
            # we have similar geo names
            local_records = vide_plus[vide_plus['nome-geografico'].isin([nome_geo] + simile)]
            pass
        else:   # if no variants just load names with this place of birth
            local_records = vide_plus[vide_plus['nome-geografico'] == nome_geo]

        previous_geo_name = nome_geo

    # search for records with name matching the vide expression of this record
    candidates = []

    found_lookup_name = local_records['name_sp']==lookup_name

    for cid,same_name in local_records[found_lookup_name].iterrows():
        if same_name['lookup_sp'] == nome and cid != id:
            candidates.append(cid)

    # if nothing found search for records with vide expression equal to this one
    if len(candidates) == 0:
        found_lookup_name = local_records['lookup_sp']==lookup_name

        for cid,same_name in local_records[found_lookup_name].iterrows():
            if same_name['lookup_sp'] == nome and cid != id:
                candidates.append(cid)
    
    if len(candidates) > 0:  # we found some candidates
        for cand in candidates:
            mrec_type = vide_plus.loc[[cand]].iloc[0]['rec_type']
            mtype = f'{rec_type}-{mrec_type}'
            match = (id,cand,mtype)
            if match not in random_matches:
                random_matches.append(match)

# %% [markdown]
# ##### Analyse results (random)

# %%
method = 'random'
match_records['matched_pairs'][method] = list(set(random_matches))
match_info.loc['matched_pairs'][method] = len(match_records['matched_pairs'][method])

# pairs 
pairs_see_aka = [(o,d,mtype) for (o,d,mtype) in random_matches if mtype == 'see-aka']
pairs_aka_see = [(o,d,mtype) for (o,d,mtype) in random_matches if mtype == 'aka-see']
pairs_aka_aka = [(o,d,mtype) for (o,d,mtype) in random_matches if mtype == 'aka-aka']
pairs_see_see = [(o,d,mtype) for (o,d,mtype) in random_matches if mtype == 'see-see']


# records
rec_matched = set([id for (id,d,t) in random_matches]+
                  [id for (o,id,t) in random_matches])
rec_see_aka = set([id for (id,d,t) in pairs_see_aka])
rec_aka_see = set([id for (o,id,t) in pairs_aka_see])
rec_see_see = set([id for (id,d,t) in pairs_see_see] +
                  [id for (o,id,t) in pairs_see_see])
rec_aka_aka = set([id for (id,d,t) in pairs_aka_aka] +
                  [id for (o,id,t) in pairs_aka_aka])

match_records['records_matched'][method] = list(rec_matched)
match_records['records_see_aka'][method] = list(rec_see_aka)
match_records['records_aka_see'][method] = list(rec_aka_see)
match_records['records_aka_aka'][method] = list(rec_aka_aka)
match_records['records_see_see'][method] = list(rec_see_see)

match_info.loc['records_matched'][method] = len(rec_matched)
match_info.loc['records_see_aka'][method] = len(rec_see_aka)
match_info.loc['records_aka_see'][method] = len(rec_aka_see)
match_info.loc['records_aka_aka'][method] = len(rec_aka_aka)
match_info.loc['records_see_see'][method] = len(rec_see_see)

# new
match_info.loc['aka_matched'][method] = len(rec_aka_see.union(rec_aka_aka))
match_records['aka_matched'][method] = list(rec_aka_see.union(rec_aka_aka))
match_info.loc['see_matched'][method] = len(rec_see_aka.union(rec_see_see))
match_records['see_matched'][method] = list(rec_see_aka.union(rec_see_see))

matched_rand_df = pd.DataFrame(random_matches, columns=['from','to','type'])
matched_rand_df.groupby('type').count()
# Out:
#          from    to
# type
# aka-aka   218   218
# aka-see  1769  1769
# see-aka  1796  1796
# see-see    21    21

# %% [markdown]
# #####  Check the matches for errors (random)

# %%
import networkx as nx

method = 'random'

matched_pairs = match_records['matched_pairs'][method]
records = match_records['records_matched'][method]

matched_multiple = []
matched_single = []

origins = [o for (o,d,t) in matched_pairs]
destinations = [d for (o,d,t) in matched_pairs]
rec_in_matches = origins + destinations
for i in rec_in_matches:
    c = rec_in_matches.count(i)
    if c >2:
        matched_multiple.append(i)
    elif c == 1:
        matched_single.append(i)
matched_multiple = list(set(matched_multiple))
matched_single = list(set(matched_single))

print("Records with more than two matches    :", len(matched_multiple))
print("Records asymmetric (one match only)   :", len(matched_single))

G = nx.Graph()
simple_pairs = [(o,d) for (o,d,t) in matched_pairs]
G.add_edges_from(simple_pairs)
transitive  = [c for c in nx.connected_components(G) if len(c) > 2]
# number of records in ambiguous matches
amb_records = [item for amb in transitive for item in amb]
namb_records = len(set(amb_records))
print("Records in ambiguous matches          :", namb_records)
for amb in transitive:
    print(amb)
print("Are multiple in ambiguous             :",set(matched_multiple).issubset(set(amb_records)))

rec_errors = set(amb_records).union(matched_multiple).union(matched_single)
rec_ok = set(records).difference(rec_errors)

match_records['records_error'][method] = list(rec_errors)
match_info.loc['records_error'][method] = len(rec_errors)
match_records['records_matched_ok'][method] = list(rec_ok)
match_info.loc['records_matched_ok'][method] = len(rec_ok)
match_records['records_asymmetric'][method] = list(matched_single)
match_info.loc['records_asymmetric'][method] = len(matched_single)
match_records['records_transitive'][method] = list(amb_records)
match_info.loc['records_transitive'][method] = namb_records

# new
aka = match_records['aka']['data']
aka_ok = set(aka).intersection(rec_ok)
see = match_records['see']['data']
see_ok = set(see).intersection(rec_ok)
match_info.loc['aka_matched_ok'][method] = len(aka_ok)
match_records['aka_matched_ok'][method] = list(aka_ok)
match_info.loc['see_matched_ok'][method] = len(see_ok)
match_records['see_matched_ok'][method] = list(see_ok)

pairs_ok = set([(o,d,t) for (o,d,t) in match_records['matched_pairs'][method]
                                                        if o not in rec_errors and d not in rec_errors])
match_records['matched_pairs_ok'][method] = list(pairs_ok)
match_info.loc['matched_pairs_ok'][method] = len(pairs_ok)

vide_plus.loc[matched_single,'match_error'] = False # we dont consider a single match an error
vide_plus.loc[matched_single,'match_obs'] = "W01-Single match (asymmetric) "+method
vide_plus.loc[matched_multiple,'match_error'] = True
vide_plus.loc[matched_multiple,'match_obs'] = "E02-Multiple match "+method
vide_plus.loc[amb_records,'match_error'] = True
vide_plus.loc[amb_records,'match_obs'] = "E03-Ambiguity in match "+method
match_info.fillna('')
# Out:
# Records with more than two matches    : 38
# Records asymmetric (one match only)   : 76
# Records in ambiguous matches          : 116
# {'238842', '233035', '238845'}
# {'142386', '142388', '171377'}
# {'160196', '160158', '152482'}
# {'266130', '146547', '266114'}
# {'194771', '201515', '316381'}
# {'226697', '226704', '195422'}
# {'132440', '238066', '186417', '186310', '186309'}
# {'208873', '243481', '208877'}
# {'152890', '243711', '152894'}
# {'238488', '238487', '226966'}
# {'242102', '238985', '242104'}
# {'233838', '206540', '206536'}
# {'222156', '189891', '189900'}
# {'240879', '147410', '240882'}
# {'183306', '235009', '183307'}
# {'164823', '166756', '164824'}
# {'169888', '169890', '214147'}
# {'153316', '139166', '139146'}
# {'169757', '162809', '136283'}
# {'172677', '172681', '190285'}
# {'221393', '233103', '233094'}
# {'143426', '175731', '175730'}
# {'203487', '206151', '161932', '255769', '203494'}
# {'210090', '232128', '232079'}
# {'253465', '212857', '252907'}
# {'134102', '191654', '191659'}
# {'254410', '201728', '201733'}
# {'233525', '233524', '245070'}
# {'193320', '199474', '199475'}
# {'231025', '169177', '231024'}
# {'146206', '245531', '245530'}
# {'222615', '172529', '222621'}
# {'251536', '216361', '251534'}
# {'239516', '230251', '230250'}
# {'278765', '181236', '178312'}
# {'171093', '248881', '171095'}
# {'211703', '168662', '211706', '211704'}
# Are multiple in ambiguous             : True
#                     data sequential random
# aka                 3062
# aka_fac             3035
# aka_geo             2973
# aka_matched                    1913   1970
# aka_matched_ok                 1907   1897
# aka_pai             1619
# matched_pairs                  3644   3804
# matched_pairs_ok               3628   3614
# nodate              5763
# nodate_novide        141
# nodate_novide        141
# records_aka_aka                 200    216
# records_aka_see                1713   1754
# records_asymmetric                0     76
# records_error                    12    190
# records_matched                3640   3804
# records_matched_ok             3628   3614
# records_see_aka                1713   1781
# records_see_see                  14     24
# records_transitive               12    116
# see                 5704
# see_fac             1378
# see_geo             5274
# see_matched                    1727   1796
# see_matched_ok                 1721   1717
# see_pai             1569
# vide                8625
# vide_plus           8766

# %% [markdown]
# ##### Show some of the ambiguous records

# %%
pd.set_option('display.max_rows',250)

no_show=['código-de-referência','data-do-registo','url','faculdade.ano','naturalidade.ano',
         'matricula-faculdade.ano','nome-apelido','nome-primeiro','nome-geografico.ano',
         'grau.ano','matricula-outra.ano','nome-geografico','instituta.ano']

show_only = 6
for ambiguous_records in transitive[:show_only]:
    display_group_attributes(ambiguous_records,
                             header_cols=['name','nome-vide','naturalidade','uc-entrada','faculdade','nome-pai'],
                             exclude_attributes=no_show,
                             sort_attributes=['date','type','value'],
                             cmap_name='Pastel1')
# Out:
# <style type="text/css">
# #T_1829d_row0_col0, #T_1829d_row0_col1, #T_1829d_row0_col2, #T_1829d_row0_col3, #T_1829d_row0_col4, #T_1829d_row0_col5, #T_1829d_row0_col6 {
#   background-color: #fbb4ae;
# }
# #T_1829d_row1_col0, #T_1829d_row1_col1, #T_1829d_row1_col2, #T_1829d_row1_col3, #T_1829d_row1_col4, #T_1829d_row1_col5, #T_1829d_row1_col6 {
#   background-color: #fed9a6;
# }
# #T_1829d_row2_col0, #T_1829d_row2_col1, #T_1829d_row2_col2, #T_1829d_row2_col3, #T_1829d_row2_col4, #T_1829d_row2_col5, #T_1829d_row2_col6 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_1829d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1829d_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_1829d_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_1829d_level0_col2" class="col_heading level0 col2" >nome-vide</th>
#       <th id="T_1829d_level0_col3" class="col_heading level0 col3" >naturalidade</th>
#       <th id="T_1829d_level0_col4" class="col_heading level0 col4" >uc-entrada</th>
#       <th id="T_1829d_level0_col5" class="col_heading level0 col5" >faculdade</th>
#       <th id="T_1829d_level0_col6" class="col_heading level0 col6" >nome-pai</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1829d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1829d_row0_col0" class="data row0 col0" >233035</td>
#       <td id="T_1829d_row0_col1" class="data row0 col1" >Miguel Soares</td>
#       <td id="T_1829d_row0_col2" class="data row0 col2" >Pereira</td>
#       <td id="T_1829d_row0_col3" class="data row0 col3" >Porto</td>
#       <td id="T_1829d_row0_col4" class="data row0 col4" >0000-00-00</td>
#       <td id="T_1829d_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_1829d_row0_col6" class="data row0 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_1829d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1829d_row1_col0" class="data row1 col0" >238842</td>
#       <td id="T_1829d_row1_col1" class="data row1 col1" >Miguel Soares Pereira</td>
#       <td id="T_1829d_row1_col2" class="data row1 col2" >Soares</td>
#       <td id="T_1829d_row1_col3" class="data row1 col3" >Porto</td>
#       <td id="T_1829d_row1_col4" class="data row1 col4" >1594-11-07</td>
#       <td id="T_1829d_row1_col5" class="data row1 col5" >Cânones</td>
#       <td id="T_1829d_row1_col6" class="data row1 col6" >Bernardino Pereira</td>
#     </tr>
#     <tr>
#       <th id="T_1829d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1829d_row2_col0" class="data row2 col0" >238845</td>
#       <td id="T_1829d_row2_col1" class="data row2 col1" >Miguel Soares Pereira</td>
#       <td id="T_1829d_row2_col2" class="data row2 col2" >Soares</td>
#       <td id="T_1829d_row2_col3" class="data row2 col3" >Porto</td>
#       <td id="T_1829d_row2_col4" class="data row2 col4" >1600-11-20</td>
#       <td id="T_1829d_row2_col5" class="data row2 col5" >Cânones</td>
#       <td id="T_1829d_row2_col6" class="data row2 col6" >Leonardo Pereira</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_2fae3_row0_col0, #T_2fae3_row0_col1, #T_2fae3_row0_col2, #T_2fae3_row0_col3, #T_2fae3_row0_col4, #T_2fae3_row1_col0, #T_2fae3_row1_col1, #T_2fae3_row1_col2, #T_2fae3_row1_col3, #T_2fae3_row1_col4, #T_2fae3_row2_col0, #T_2fae3_row2_col1, #T_2fae3_row2_col2, #T_2fae3_row2_col3, #T_2fae3_row2_col4, #T_2fae3_row3_col0, #T_2fae3_row3_col1, #T_2fae3_row3_col2, #T_2fae3_row3_col3, #T_2fae3_row3_col4, #T_2fae3_row4_col0, #T_2fae3_row4_col1, #T_2fae3_row4_col2, #T_2fae3_row4_col3, #T_2fae3_row4_col4, #T_2fae3_row5_col0, #T_2fae3_row5_col1, #T_2fae3_row5_col2, #T_2fae3_row5_col3, #T_2fae3_row5_col4 {
#   background-color: #fbb4ae;
# }
# #T_2fae3_row6_col0, #T_2fae3_row6_col1, #T_2fae3_row6_col2, #T_2fae3_row6_col3, #T_2fae3_row6_col4, #T_2fae3_row7_col0, #T_2fae3_row7_col1, #T_2fae3_row7_col2, #T_2fae3_row7_col3, #T_2fae3_row7_col4, #T_2fae3_row8_col0, #T_2fae3_row8_col1, #T_2fae3_row8_col2, #T_2fae3_row8_col3, #T_2fae3_row8_col4, #T_2fae3_row9_col0, #T_2fae3_row9_col1, #T_2fae3_row9_col2, #T_2fae3_row9_col3, #T_2fae3_row9_col4, #T_2fae3_row10_col0, #T_2fae3_row10_col1, #T_2fae3_row10_col2, #T_2fae3_row10_col3, #T_2fae3_row10_col4, #T_2fae3_row11_col0, #T_2fae3_row11_col1, #T_2fae3_row11_col2, #T_2fae3_row11_col3, #T_2fae3_row11_col4, #T_2fae3_row12_col0, #T_2fae3_row12_col1, #T_2fae3_row12_col2, #T_2fae3_row12_col3, #T_2fae3_row12_col4, #T_2fae3_row13_col0, #T_2fae3_row13_col1, #T_2fae3_row13_col2, #T_2fae3_row13_col3, #T_2fae3_row13_col4, #T_2fae3_row14_col0, #T_2fae3_row14_col1, #T_2fae3_row14_col2, #T_2fae3_row14_col3, #T_2fae3_row14_col4, #T_2fae3_row15_col0, #T_2fae3_row15_col1, #T_2fae3_row15_col2, #T_2fae3_row15_col3, #T_2fae3_row15_col4, #T_2fae3_row16_col0, #T_2fae3_row16_col1, #T_2fae3_row16_col2, #T_2fae3_row16_col3, #T_2fae3_row16_col4, #T_2fae3_row17_col0, #T_2fae3_row17_col1, #T_2fae3_row17_col2, #T_2fae3_row17_col3, #T_2fae3_row17_col4, #T_2fae3_row18_col0, #T_2fae3_row18_col1, #T_2fae3_row18_col2, #T_2fae3_row18_col3, #T_2fae3_row18_col4, #T_2fae3_row20_col0, #T_2fae3_row20_col1, #T_2fae3_row20_col2, #T_2fae3_row20_col3, #T_2fae3_row20_col4, #T_2fae3_row30_col0, #T_2fae3_row30_col1, #T_2fae3_row30_col2, #T_2fae3_row30_col3, #T_2fae3_row30_col4, #T_2fae3_row33_col0, #T_2fae3_row33_col1, #T_2fae3_row33_col2, #T_2fae3_row33_col3, #T_2fae3_row33_col4, #T_2fae3_row35_col0, #T_2fae3_row35_col1, #T_2fae3_row35_col2, #T_2fae3_row35_col3, #T_2fae3_row35_col4, #T_2fae3_row36_col0, #T_2fae3_row36_col1, #T_2fae3_row36_col2, #T_2fae3_row36_col3, #T_2fae3_row36_col4 {
#   background-color: #fed9a6;
# }
# #T_2fae3_row19_col0, #T_2fae3_row19_col1, #T_2fae3_row19_col2, #T_2fae3_row19_col3, #T_2fae3_row19_col4, #T_2fae3_row21_col0, #T_2fae3_row21_col1, #T_2fae3_row21_col2, #T_2fae3_row21_col3, #T_2fae3_row21_col4, #T_2fae3_row22_col0, #T_2fae3_row22_col1, #T_2fae3_row22_col2, #T_2fae3_row22_col3, #T_2fae3_row22_col4, #T_2fae3_row23_col0, #T_2fae3_row23_col1, #T_2fae3_row23_col2, #T_2fae3_row23_col3, #T_2fae3_row23_col4, #T_2fae3_row24_col0, #T_2fae3_row24_col1, #T_2fae3_row24_col2, #T_2fae3_row24_col3, #T_2fae3_row24_col4, #T_2fae3_row25_col0, #T_2fae3_row25_col1, #T_2fae3_row25_col2, #T_2fae3_row25_col3, #T_2fae3_row25_col4, #T_2fae3_row26_col0, #T_2fae3_row26_col1, #T_2fae3_row26_col2, #T_2fae3_row26_col3, #T_2fae3_row26_col4, #T_2fae3_row27_col0, #T_2fae3_row27_col1, #T_2fae3_row27_col2, #T_2fae3_row27_col3, #T_2fae3_row27_col4, #T_2fae3_row28_col0, #T_2fae3_row28_col1, #T_2fae3_row28_col2, #T_2fae3_row28_col3, #T_2fae3_row28_col4, #T_2fae3_row29_col0, #T_2fae3_row29_col1, #T_2fae3_row29_col2, #T_2fae3_row29_col3, #T_2fae3_row29_col4, #T_2fae3_row31_col0, #T_2fae3_row31_col1, #T_2fae3_row31_col2, #T_2fae3_row31_col3, #T_2fae3_row31_col4, #T_2fae3_row32_col0, #T_2fae3_row32_col1, #T_2fae3_row32_col2, #T_2fae3_row32_col3, #T_2fae3_row32_col4, #T_2fae3_row34_col0, #T_2fae3_row34_col1, #T_2fae3_row34_col2, #T_2fae3_row34_col3, #T_2fae3_row34_col4, #T_2fae3_row37_col0, #T_2fae3_row37_col1, #T_2fae3_row37_col2, #T_2fae3_row37_col3, #T_2fae3_row37_col4, #T_2fae3_row38_col0, #T_2fae3_row38_col1, #T_2fae3_row38_col2, #T_2fae3_row38_col3, #T_2fae3_row38_col4, #T_2fae3_row39_col0, #T_2fae3_row39_col1, #T_2fae3_row39_col2, #T_2fae3_row39_col3, #T_2fae3_row39_col4, #T_2fae3_row40_col0, #T_2fae3_row40_col1, #T_2fae3_row40_col2, #T_2fae3_row40_col3, #T_2fae3_row40_col4, #T_2fae3_row41_col0, #T_2fae3_row41_col1, #T_2fae3_row41_col2, #T_2fae3_row41_col3, #T_2fae3_row41_col4, #T_2fae3_row42_col0, #T_2fae3_row42_col1, #T_2fae3_row42_col2, #T_2fae3_row42_col3, #T_2fae3_row42_col4 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_2fae3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2fae3_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_2fae3_level0_col1" class="col_heading level0 col1" >id</th>
#       <th id="T_2fae3_level0_col2" class="col_heading level0 col2" >type</th>
#       <th id="T_2fae3_level0_col3" class="col_heading level0 col3" >value</th>
#       <th id="T_2fae3_level0_col4" class="col_heading level0 col4" >attr_obs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2fae3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2fae3_row0_col0" class="data row0 col0" >0000-00-00</td>
#       <td id="T_2fae3_row0_col1" class="data row0 col1" >233035</td>
#       <td id="T_2fae3_row0_col2" class="data row0 col2" >naturalidade</td>
#       <td id="T_2fae3_row0_col3" class="data row0 col3" >Porto</td>
#       <td id="T_2fae3_row0_col4" class="data row0 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2fae3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2fae3_row1_col0" class="data row1 col0" >0000-00-00</td>
#       <td id="T_2fae3_row1_col1" class="data row1 col1" >233035</td>
#       <td id="T_2fae3_row1_col2" class="data row1 col2" >nome</td>
#       <td id="T_2fae3_row1_col3" class="data row1 col3" >Miguel Soares</td>
#       <td id="T_2fae3_row1_col4" class="data row1 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2fae3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2fae3_row2_col0" class="data row2 col0" >0000-00-00</td>
#       <td id="T_2fae3_row2_col1" class="data row2 col1" >233035</td>
#       <td id="T_2fae3_row2_col2" class="data row2 col2" >nome</td>
#       <td id="T_2fae3_row2_col3" class="data row2 col3" >Miguel Soares Pereira</td>
#       <td id="T_2fae3_row2_col4" class="data row2 col4" >Miguel Soares, vide Pereira</td>
#     </tr>
#     <tr>
#       <th id="T_2fae3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2fae3_row3_col0" class="data row3 col0" >0000-00-00</td>
#       <td id="T_2fae3_row3_col1" class="data row3 col1" >233035</td>
#       <td id="T_2fae3_row3_col2" class="data row3 col2" >nome-vide</td>
#       <td id="T_2fae3_row3_col3" class="data row3 col3" >Pereira</td>
#       <td id="T_2fae3_row3_col4" class="data row3 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2fae3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2fae3_row4_col0" class="data row4 col0" >0000-00-00</td>
#       <td id="T_2fae3_row4_col1" class="data row4 col1" >233035</td>
#       <td id="T_2fae3_row4_col2" class="data row4 col2" >uc-entrada</td>
#       <td id="T_2fae3_row4_col3" class="data row4 col3" >0000-00-00</td>
#       <td id="T_2fae3_row4_col4" class="data row4 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2fae3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2fae3_row5_col0" class="data row5 col0" >0000-00-00</td>
#       <td id="T_2fae3_row5_col1" class="data row5 col1" >233035</td>
#       <td id="T_2fae3_row5_col2" class="data row5 col2" >uc-saida</td>
#       <td id="T_2fae3_row5_col3" class="data row5 col3" >0000-00-00</td>
#       <td id="T_2fae3_row5_col4" class="data row5 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2fae3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2fae3_row6_col0" class="data row6 col0" >1594-11-07</td>
#       <td id="T_2fae3_row6_col1
# <style type="text/css">
# #T_2cdd3_row0_col0, #T_2cdd3_row0_col1, #T_2cdd3_row0_col2, #T_2cdd3_row0_col3, #T_2cdd3_row0_col4, #T_2cdd3_row0_col5, #T_2cdd3_row0_col6 {
#   background-color: #fbb4ae;
# }
# #T_2cdd3_row1_col0, #T_2cdd3_row1_col1, #T_2cdd3_row1_col2, #T_2cdd3_row1_col3, #T_2cdd3_row1_col4, #T_2cdd3_row1_col5, #T_2cdd3_row1_col6 {
#   background-color: #fed9a6;
# }
# #T_2cdd3_row2_col0, #T_2cdd3_row2_col1, #T_2cdd3_row2_col2, #T_2cdd3_row2_col3, #T_2cdd3_row2_col4, #T_2cdd3_row2_col5, #T_2cdd3_row2_col6 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_2cdd3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2cdd3_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_2cdd3_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_2cdd3_level0_col2" class="col_heading level0 col2" >nome-vide</th>
#       <th id="T_2cdd3_level0_col3" class="col_heading level0 col3" >naturalidade</th>
#       <th id="T_2cdd3_level0_col4" class="col_heading level0 col4" >uc-entrada</th>
#       <th id="T_2cdd3_level0_col5" class="col_heading level0 col5" >faculdade</th>
#       <th id="T_2cdd3_level0_col6" class="col_heading level0 col6" >nome-pai</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2cdd3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2cdd3_row0_col0" class="data row0 col0" >142386</td>
#       <td id="T_2cdd3_row0_col1" class="data row0 col1" >André de Matos de Almada</td>
#       <td id="T_2cdd3_row0_col2" class="data row0 col2" >Matos</td>
#       <td id="T_2cdd3_row0_col3" class="data row0 col3" >Lisboa</td>
#       <td id="T_2cdd3_row0_col4" class="data row0 col4" >0000-00-00</td>
#       <td id="T_2cdd3_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_2cdd3_row0_col6" class="data row0 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2cdd3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2cdd3_row1_col0" class="data row1 col0" >142388</td>
#       <td id="T_2cdd3_row1_col1" class="data row1 col1" >André de Matos de Almada</td>
#       <td id="T_2cdd3_row1_col2" class="data row1 col2" >Matos</td>
#       <td id="T_2cdd3_row1_col3" class="data row1 col3" >Lisboa</td>
#       <td id="T_2cdd3_row1_col4" class="data row1 col4" >1576-10-01</td>
#       <td id="T_2cdd3_row1_col5" class="data row1 col5" >Leis</td>
#       <td id="T_2cdd3_row1_col6" class="data row1 col6" >Jerónimo de Matos</td>
#     </tr>
#     <tr>
#       <th id="T_2cdd3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2cdd3_row2_col0" class="data row2 col0" >171377</td>
#       <td id="T_2cdd3_row2_col1" class="data row2 col1" >André de Matos</td>
#       <td id="T_2cdd3_row2_col2" class="data row2 col2" >Almada</td>
#       <td id="T_2cdd3_row2_col3" class="data row2 col3" >Lisboa</td>
#       <td id="T_2cdd3_row2_col4" class="data row2 col4" >1639-11-07</td>
#       <td id="T_2cdd3_row2_col5" class="data row2 col5" >Cânones</td>
#       <td id="T_2cdd3_row2_col6" class="data row2 col6" >Fernão de Matos</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_cc6ea_row0_col0, #T_cc6ea_row0_col1, #T_cc6ea_row0_col2, #T_cc6ea_row0_col3, #T_cc6ea_row0_col4, #T_cc6ea_row1_col0, #T_cc6ea_row1_col1, #T_cc6ea_row1_col2, #T_cc6ea_row1_col3, #T_cc6ea_row1_col4, #T_cc6ea_row2_col0, #T_cc6ea_row2_col1, #T_cc6ea_row2_col2, #T_cc6ea_row2_col3, #T_cc6ea_row2_col4, #T_cc6ea_row3_col0, #T_cc6ea_row3_col1, #T_cc6ea_row3_col2, #T_cc6ea_row3_col3, #T_cc6ea_row3_col4, #T_cc6ea_row4_col0, #T_cc6ea_row4_col1, #T_cc6ea_row4_col2, #T_cc6ea_row4_col3, #T_cc6ea_row4_col4, #T_cc6ea_row5_col0, #T_cc6ea_row5_col1, #T_cc6ea_row5_col2, #T_cc6ea_row5_col3, #T_cc6ea_row5_col4 {
#   background-color: #fbb4ae;
# }
# #T_cc6ea_row6_col0, #T_cc6ea_row6_col1, #T_cc6ea_row6_col2, #T_cc6ea_row6_col3, #T_cc6ea_row6_col4, #T_cc6ea_row7_col0, #T_cc6ea_row7_col1, #T_cc6ea_row7_col2, #T_cc6ea_row7_col3, #T_cc6ea_row7_col4, #T_cc6ea_row8_col0, #T_cc6ea_row8_col1, #T_cc6ea_row8_col2, #T_cc6ea_row8_col3, #T_cc6ea_row8_col4, #T_cc6ea_row9_col0, #T_cc6ea_row9_col1, #T_cc6ea_row9_col2, #T_cc6ea_row9_col3, #T_cc6ea_row9_col4, #T_cc6ea_row10_col0, #T_cc6ea_row10_col1, #T_cc6ea_row10_col2, #T_cc6ea_row10_col3, #T_cc6ea_row10_col4, #T_cc6ea_row11_col0, #T_cc6ea_row11_col1, #T_cc6ea_row11_col2, #T_cc6ea_row11_col3, #T_cc6ea_row11_col4, #T_cc6ea_row12_col0, #T_cc6ea_row12_col1, #T_cc6ea_row12_col2, #T_cc6ea_row12_col3, #T_cc6ea_row12_col4, #T_cc6ea_row13_col0, #T_cc6ea_row13_col1, #T_cc6ea_row13_col2, #T_cc6ea_row13_col3, #T_cc6ea_row13_col4, #T_cc6ea_row14_col0, #T_cc6ea_row14_col1, #T_cc6ea_row14_col2, #T_cc6ea_row14_col3, #T_cc6ea_row14_col4, #T_cc6ea_row15_col0, #T_cc6ea_row15_col1, #T_cc6ea_row15_col2, #T_cc6ea_row15_col3, #T_cc6ea_row15_col4, #T_cc6ea_row16_col0, #T_cc6ea_row16_col1, #T_cc6ea_row16_col2, #T_cc6ea_row16_col3
level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cc6ea_row6_col0" class="data row6 col0" >1576-10-01</td>
#       <td id="T_cc6ea_row6_col1" class="data row6 col1" >142388</td>
#       <td id="T_cc6ea_row6_col2" class="data row6 col2" >faculdade</td>
#       <td id="T_cc6ea_row6_col3" class="data row6 col3" >Leis</td>
#       <td id="T_cc6ea
# <style type="text/css">
# #T_b793d_row0_col0, #T_b793d_row0_col1, #T_b793d_row0_col2, #T_b793d_row0_col3, #T_b793d_row0_col4, #T_b793d_row0_col5, #T_b793d_row0_col6 {
#   background-color: #fbb4ae;
# }
# #T_b793d_row1_col0, #T_b793d_row1_col1, #T_b793d_row1_col2, #T_b793d_row1_col3, #T_b793d_row1_col4, #T_b793d_row1_col5, #T_b793d_row1_col6 {
#   background-color: #fed9a6;
# }
# #T_b793d_row2_col0, #T_b793d_row2_col1, #T_b793d_row2_col2, #T_b793d_row2_col3, #T_b793d_row2_col4, #T_b793d_row2_col5, #T_b793d_row2_col6 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_b793d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b793d_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_b793d_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_b793d_level0_col2" class="col_heading level0 col2" >nome-vide</th>
#       <th id="T_b793d_level0_col3" class="col_heading level0 col3" >naturalidade</th>
#       <th id="T_b793d_level0_col4" class="col_heading level0 col4" >uc-entrada</th>
#       <th id="T_b793d_level0_col5" class="col_heading level0 col5" >faculdade</th>
#       <th id="T_b793d_level0_col6" class="col_heading level0 col6" >nome-pai</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b793d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b793d_row0_col0" class="data row0 col0" >152482</td>
#       <td id="T_b793d_row0_col1" class="data row0 col1" >Brás Ribeiro da Fonseca</td>
#       <td id="T_b793d_row0_col2" class="data row0 col2" >Ribeiro</td>
#       <td id="T_b793d_row0_col3" class="data row0 col3" >Nabainhos</td>
#       <td id="T_b793d_row0_col4" class="data row0 col4" >0000-00-00</td>
#       <td id="T_b793d_row0_col5" class="data row0 col5" >Leis</td>
#       <td id="T_b793d_row0_col6" class="data row0 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b793d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b793d_row1_col0" class="data row1 col0" >160158</td>
#       <td id="T_b793d_row1_col1" class="data row1 col1" >Brás Ribeiro</td>
#       <td id="T_b793d_row1_col2" class="data row1 col2" >Fonseca</td>
#       <td id="T_b793d_row1_col3" class="data row1 col3" >Nabainhos</td>
#       <td id="T_b793d_row1_col4" class="data row1 col4" >1640-10-09</td>
#       <td id="T_b793d_row1_col5" class="data row1 col5" >Leis</td>
#       <td id="T_b793d_row1_col6" class="data row1 col6" >Miguel Ribeiro</td>
#     </tr>
#     <tr>
#       <th id="T_b793d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b793d_row2_col0" class="data row2 col0" >160196</td>
#       <td id="T_b793d_row2_col1" class="data row2 col1" >Brás Ribeiro</td>
#       <td id="T_b793d_row2_col2" class="data row2 col2" >Fonseca</td>
#       <td id="T_b793d_row2_col3" class="data row2 col3" >Nabainhos</td>
#       <td id="T_b793d_row2_col4" class="data row2 col4" >1640-10-09</td>
#       <td id="T_b793d_row2_col5" class="data row2 col5" >Leis</td>
#       <td id="T_b793d_row2_col6" class="data row2 col6" >Miguel Ribeiro</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_6e0d9_row0_col0, #T_6e0d9_row0_col1, #T_6e0d9_row0_col2, #T_6e0d9_row0_col3, #T_6e0d9_row0_col4, #T_6e0d9_row1_col0, #T_6e0d9_row1_col1, #T_6e0d9_row1_col2, #T_6e0d9_row1_col3, #T_6e0d9_row1_col4, #T_6e0d9_row2_col0, #T_6e0d9_row2_col1, #T_6e0d9_row2_col2, #T_6e0d9_row2_col3, #T_6e0d9_row2_col4, #T_6e0d9_row3_col0, #T_6e0d9_row3_col1, #T_6e0d9_row3_col2, #T_6e0d9_row3_col3, #T_6e0d9_row3_col4, #T_6e0d9_row4_col0, #T_6e0d9_row4_col1, #T_6e0d9_row4_col2, #T_6e0d9_row4_col3, #T_6e0d9_row4_col4, #T_6e0d9_row5_col0, #T_6e0d9_row5_col1, #T_6e0d9_row5_col2, #T_6e0d9_row5_col3, #T_6e0d9_row5_col4, #T_6e0d9_row6_col0, #T_6e0d9_row6_col1, #T_6e0d9_row6_col2, #T_6e0d9_row6_col3, #T_6e0d9_row6_col4 {
#   background-color: #fbb4ae;
# }
# #T_6e0d9_row7_col0, #T_6e0d9_row7_col1, #T_6e0d9_row7_col2, #T_6e0d9_row7_col3, #T_6e0d9_row7_col4, #T_6e0d9_row9_col0, #T_6e0d9_row9_col1, #T_6e0d9_row9_col2, #T_6e0d9_row9_col3, #T_6e0d9_row9_col4, #T_6e0d9_row11_col0, #T_6e0d9_row11_col1, #T_6e0d9_row11_col2, #T_6e0d9_row11_col3, #T_6e0d9_row11_col4, #T_6e0d9_row13_col0, #T_6e0d9_row13_col1, #T_6e0d9_row13_col2, #T_6e0d9_row13_col3, #T_6e0d9_row13_col4, #T_6e0d9_row15_col0, #T_6e0d9_row15_col1, #T_6e0d9_row15_col2, #T_6e0d9_row15_col3, #T_6e0d9_row15_col4, #T_6e0d9_row17_col0, #T_6e0d9_row17_col1, #T_6e0d9_row17_col2, #T_6e0d9_row17_col3, #T_6e0d9_row17_col4, #T_6e0d9_row19_col0, #T_6e0d9_row19_col1, #T_6e0d9_row19_col2, #T_6e0d9_row19_col3, #T_6e0d9_row19_col4, #T_6e0d9_row21_col0, #T_6e0d9_row21_col1, #T_6e0d9_row21_col2, #T_6e0d9_row21_col3, #T_6e0d9_row21_col4, #T_6e0d9_row23_col0, #T_6e0d9_row23_col1, #T_6e0d9_row23_col2, #T_6e0d9_row23_col3, #T_6e0d9_row23_col4, #T_6e0d9_row25_col0, #T_6e0d9_row25_col1, #T_6e0d9_row25_col2, #T_6e0d9_row25_col3, #T_6e0d9_row25_col4, #T_6e0d9_row27_col0, #T_6e0d9_row27_col1, #T_6e0d9_row27_col2, #T_6e0d9_row27_col3, #T_6e0d9_row27_col4, #T_6e0d9_row29_col0, #T_6e0d9_row29_col1, #T_6e0d9_row29_col2, #T_6e0d9_row29_col3, #T_6e0d9_row29_col4, #T_6e0d9_row31_col0, #T_6e0d9_row31_col1, #T_6e0d9_row31_col2, #T_6e0d9_row31_col3, #T_6e0d9_row31_col4, #T_6e0d9_row33_col0, #T_6e0d9_row33_col1, #T_6e0d9_row33_col2, #T_6e0d9_row33_col3, #T_6e0d9_row33_col4, #T_6e0d9_row35_col0, #T_6e0d9_row35_col1, #T_6e0d9_row35_col2, #T_6e0d9_row35_col3, #T_6e0d9_row35_col4, #T_6e0d9_row37_col0, #T_6e0d9_row37_col1, #T_6e0d9_row37_col2, #T_6e0d9_row37_col3, #T_6e0d9_row37_col4, #T_6e0d9_row39_col0, #T_6e0d9_row39_col1, #T_6e0d9_row39_col2, #T_6e0d9_row39_col3, #T_6e0d9_row39_col4, #T_6e0d9_row40_col0, #T_6e0d9_row40_col1, #T_6e0d9_row40_col2, #T_6e0d9_row40_col3, #T_6e0d9_row40_col4, #T_6e0d9_row41_col0, #T_6e0d9_row41_col1, #T_6e0d9_row41_col2, #T_6e0d9_row41_col3, #T_6e0d9_row41_col4, #T_6e0d9_row42_col0, #T_6e0d9_row42_col1, #T_6e0d9_row42_col2, #T_6e0d9_row42_col3, #T_6e0d9_row42_col4 {
#   background-color: #fed9a6;
# }
# #T_6e0d9_row8_col0, #T_6e0d9_row8_col1, #T_6e0d9_row8_col2, #T_6e0d9_row8_col3, #T_6e0d9_row8_col4, #T_6e0d9_row10_col0, #T_6e0d9_row10_col1, #T_6e0d9_row10_col2, #T_6e0d9_row10_col3, #T_6e0d9_row10_col4, #T_6e0d9_row12_col0, #T_6e0d9_row12_col1, #T_6e0d9_row12_col2, #T_6e0d9_row12_col3, #T_6e0d9_row12_col4, #T_6e0d9_row14_col0, #T_6e0d9_row14_col1, #T_6e0d9_row14_col2, #T_6e0d9_row14_col3, #T_6e0d9_row14_col4, #T_6e0d9_row16_col0, #T_6e0d9_row16_col1, #T_6e0d9_row16_col2, #T_6e0d9_row16_col3, #T_6e0d9_row16_col4, #T_6e0d9_row18_col0, #T_6e0d9_row18_col1, #T_6e0d9_row18_col2, #T_6e0d9_row18_col3, #T_6e0d9_row18_col4, #T_6e0d9_row20_col0, #T_6e0d9_row20_col1, #T_6e0d9_row20_col2, #T_6e0d9_row20_col3, #T_6e0d9_row20_col4, #T_6e0d9_row22_col0, #T_6e0d9_row22_col1, #T_6e0d9_row22_col2, #T_6e0d9_row22_col3, #T_6e0d9_row22_col4, #T_6e0d9_row24_col0, #T_6e0d9_row24_col1, #T_6e0d9_row24_col2, #T_6e0d9_row24_col3, #T_6e0d9_row24_col4, #T_6e0d9_row26_col0, #T_6e0d9_row26_col1, #T_6e0d9_row26_col2, #T_6e0d9_row26_col3, #T_6e0d9_row26_col4, #T_6e0d9_row28_col0, #T_6e0d9_row28_col1, #T_6e0d9_row28_col2, #T_6e0d9_row28_col3, #T_6e0d9_row28_col4, #T_6e0d9_row30_col0, #T_6e0d9_row30_col1, #T_6e0d9_row30_col2, #T_6e0d9_row30_col3, #T_6e0d9_row30_col4, #T_6e0d9_row32_col0, #T_6e0d9_row32_col1, #T_6e0d9_row32_col2, #T_6e0d9_row32_col3, #T_6e0d9_row32_col4, #T_6e0d9_row34_col0, #T_6e0d9_row34_col1, #T_6e0d9_row34_col2, #T_6e0d9_row34_col3, #T_6e0d9_row34_col4, #T_6e0d9_row36_col0, #T_6e0d9_row36_col1, #T_6e0d9_row36_col2, #T_6e0d9_row36_col3, #T_6e0d9_row36_col4, #T_6e0d9_row38_col0, #T_6e0d9_row38_col1, #T_6e0d9_row38_col2, #T_6e0d9_row38_col3, #T_6e0d9_row38_col4, #T_6e0d9_row43_col0, #T_6e0d9_row43_col1, #T_6e0d9_row43_col2, #T_6e0d9_row43_col3, #T_6e0d9_row43_col4, #T_6e0d9_row44_col0, #T_6e0d9_row44_col1, #T_6e0d9_row44_col2, #T_6e0d9_row44_col3, #T_6e0d9_row44_col4, #T_6e0d9_row45_col0, #T_6e0d9_row45_col1, #T_6e0d9_row45_col2, #T_6e0d9_row45_col3, #T_6e0d9_row45_col4, #T_6e0d9_row46_col0, #T_6e0d9_row46_col1, #T_6e0d9_row46_col2, #T_6e0d9_row46_col3, #T_6e0d9_row46_col4, #T_6e0d9_row47_col0, #T_6e0d9_row47_col1, #T_6e0d9_row47_col2, #T_6e0d9_row47_col3, #T_6e0d9_row47_col4 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_6e0d9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e0d9_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_6e0d9_level0_col1" class="col_heading level0 col1" >id</th>
#       <th id="T_6e0d9_level0_col2" class="col_heading level0 col2" >type</th>
#       <th id="T_6e0d9_level0_col3" class="col_heading level0 col3" >value</th>
#       <th id="T_6e0d9_level0_col4" class="col_heading level0 col4" >attr_obs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e0d9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6e0d9_row0_col0" class="data row0 col0" >0000-00-00</td>
#       <td id="T_6e0d9_row0_col1" class="data row0 col1" >152482</td>
#       <td id="T_6e0d9_row0_col2" class="data row0 col2" >faculdade</td>
#       <td id="T_6e0d9_row0_col3" class="data row0 col3" >Leis</td>
#       <td id="T_6e0d9_row0_col4" class="data row0 col4" >Leis</td>
#     </tr>
#     <tr>
#       <th id="T_6e0d9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6e0d9_row1_col0" class="data row1 col0" >0000-00-00</td>
#       <td id="T_6e0d9_row1_col1" class="data row1 col1" >152482</td>
#       <td id="T_6e0d9_row1_col2" class="data row1 col2" >naturalidade</td>
#       <td id="T_6e0d9_row1_col3" class="data row1 col3" >Nabainhos</td>
#       <td id="T_6e0d9_row1_col4" class="data row1 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_6e0d9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6e0d9_row2_col0" class="data row2 col0" >0000-00-00</td>
#       <td id="T_6e0d9_row2_col1" class="data row2 col1" >152482</td>
#       <td id="T_6e0d9_row2_col2" class="data row2 col2" >nome</td>
#       <td id="T_6e0d9_row2_col3" class="data row2 col3" >Brás Ribeiro</td>
#       <td id="T_6e0d9_row2_col4" class="data row2 col4" >Brás Ribeiro da Fonseca, vide Ribeiro</td>
#     </tr>
#     <tr>
#       <th id="T_6e0d9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6e0d9_row3_col0" class="data row3 col0" >0000-00-00</td>
#       <td id="T_6e0d9_row3_col1" class="data row3 col1" >152482</td>
#       <td id="T_6e0d9_row3_col2" class="data row3 col2" >nome</td>
#       <td id="T_6e0d9_row3_col3" class="data row3 col3" >Brás Ribeiro da Fonseca</td>
#       <td id="T_6e0d9_row3_col4" class="data row3 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_6e0d9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6e0d9_row4_col0" class="data row4 col0" >0000-00-00</td>
#       <td id="T_6e0d9_row4_col1" class="data row4 col1" >152482</td>
#       <td id="T_6e0d9_row4_col2" class="data row4 col2" >nome-vide</td>
#       <td id="T_6e0d9_row4_col3" class="data row4 col3" >Ribeiro</td>
#       <td id="T_6e0d9_row4_col4" class="data row4 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_6e0d9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6e
# <style type="text/css">
# #T_acc0a_row0_col0, #T_acc0a_row0_col1, #T_acc0a_row0_col2, #T_acc0a_row0_col3, #T_acc0a_row0_col4, #T_acc0a_row0_col5, #T_acc0a_row0_col6 {
#   background-color: #fbb4ae;
# }
# #T_acc0a_row1_col0, #T_acc0a_row1_col1, #T_acc0a_row1_col2, #T_acc0a_row1_col3, #T_acc0a_row1_col4, #T_acc0a_row1_col5, #T_acc0a_row1_col6 {
#   background-color: #fed9a6;
# }
# #T_acc0a_row2_col0, #T_acc0a_row2_col1, #T_acc0a_row2_col2, #T_acc0a_row2_col3, #T_acc0a_row2_col4, #T_acc0a_row2_col5, #T_acc0a_row2_col6 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_acc0a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_acc0a_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_acc0a_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_acc0a_level0_col2" class="col_heading level0 col2" >nome-vide</th>
#       <th id="T_acc0a_level0_col3" class="col_heading level0 col3" >naturalidade</th>
#       <th id="T_acc0a_level0_col4" class="col_heading level0 col4" >uc-entrada</th>
#       <th id="T_acc0a_level0_col5" class="col_heading level0 col5" >faculdade</th>
#       <th id="T_acc0a_level0_col6" class="col_heading level0 col6" >nome-pai</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_acc0a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_acc0a_row0_col0" class="data row0 col0" >266114</td>
#       <td id="T_acc0a_row0_col1" class="data row0 col1" >Rafael dos Anjos de Andrade</td>
#       <td id="T_acc0a_row0_col2" class="data row0 col2" >dos Anjos</td>
#       <td id="T_acc0a_row0_col3" class="data row0 col3" >Lisboa</td>
#       <td id="T_acc0a_row0_col4" class="data row0 col4" >0000-00-00</td>
#       <td id="T_acc0a_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_acc0a_row0_col6" class="data row0 col6" >Nicolau Ferreira</td>
#     </tr>
#     <tr>
#       <th id="T_acc0a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_acc0a_row1_col0" class="data row1 col0" >146547</td>
#       <td id="T_acc0a_row1_col1" class="data row1 col1" >Rafael dos Anjos de Andrade</td>
#       <td id="T_acc0a_row1_col2" class="data row1 col2" >dos Anjos</td>
#       <td id="T_acc0a_row1_col3" class="data row1 col3" >Lisboa</td>
#       <td id="T_acc0a_row1_col4" class="data row1 col4" >1640-10-01</td>
#       <td id="T_acc0a_row1_col5" class="data row1 col5" >Medicina</td>
#       <td id="T_acc0a_row1_col6" class="data row1 col6" >Nicolau Ferreira</td>
#     </tr>
#     <tr>
#       <th id="T_acc0a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_acc0a_row2_col0" class="data row2 col0" >266130</td>
#       <td id="T_acc0a_row2_col1" class="data row2 col1" >Rafael dos Anjos</td>
#       <td id="T_acc0a_row2_col2" class="data row2 col2" >de Andrade</td>
#       <td id="T_acc0a_row2_col3" class="data row2 col3" >Lisboa</td>
#       <td id="T_acc0a_row2_col4" class="data row2 col4" >1640-10-01</td>
#       <td id="T_acc0a_row2_col5" class="data row2 col5" >Medicina</td>
#       <td id="T_acc0a_row2_col6" class="data row2 col6" >Nicolau Ferreira</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_11e1c_row0_col0, #T_11e1c_row0_col1, #T_11e1c_row0_col2, #T_11e1c_row0_col3, #T_11e1c_row0_col4, #T_11e1c_row1_col0, #T_11e1c_row1_col1, #T_11e1c_row1_col2, #T_11e1c_row1_col3, #T_11e1c_row1_col4, #T_11e1c_row2_col0, #T_11e1c_row2_col1, #T_11e1c_row2_col2, #T_11e1c_row2_col3, #T_11e1c_row2_col4, #T_11e1c_row3_col0, #T_11e1c_row3_col1, #T_11e1c_row3_col2, #T_11e1c_row3_col3, #T_11e1c_row3_col4, #T_11e1c_row4_col0, #T_11e1c_row4_col1, #T_11e1c_row4_col2, #T_11e1c_row4_col3, #T_11e1c_row4_col4, #T_11e1c_row5_col0, #T_11e1c_row5_col1, #T_11e1c_row5_col2, #T_11e1c_row5_col3, #T_11e1c_row5_col4, #T_11e1c_row6_col0, #T_11e1c_row6_col1, #T_11e1c_row6_col2, #T_11e1c_row6_col3, #T_11e1c_row6_col4 {
#   background-color: #fbb4ae;
# }
# #T_11e1c_row7_col0, #T_11e1c_row7_col1, #T_11e1c_row7_col2, #T_11e1c_row7_col3, #T_11e1c_row7_col4, #T_11e1c_row9_col0, #T_11e1c_row9_col1, #T_11e1c_row9_col2, #T_11e1c_row9_col3, #T_11e1c_row9_col4, #T_11e1c_row11_col0, #T_11e1c_row11_col1, #T_11e1c_row11_col2, #T_11e1c_row11_col3, #T_11e1c_row11_col4, #T_11e1c_row13_col0, #T_11e1c_row13_col1, #T_11e1c_row13_col2, #T_11e1c_row13_col3, #T_11e1c_row13_col4, #T_11e1c_row15_col0, #T_11e1c_row15_col1, #T_11e1c_row15_col2, #T_11e1c_row15_col3, #T_11e1c_row15_col4, #T_11e1c_row17_col0, #T_11e1c_row17_col1, #T_11e1c_row17_col2, #T_11e1c_row17_col3, #T_11e1c_row17_col4, #T_11e1c_row20_col0, #T_11e1c_row20_col1, #T_11e1c_row20_col2, #T_11e1c_row20_col3, #T_11e1c_row20_col4, #T_11e1c_row21_col0, #T_11e1c_row21_col1, #T_11e1c_row21_col2, #T_11e1c_row21_col3, #T_11e1c_row21_col4, #T_11e1c_row23_col0, #T_11e1c_row23_col1, #T_11e1c_row23_col2, #T_11e1c_row23_col3, #T_11e1c_row23_col4, #T_11e1c_row25_col0, #T_11e1c_row25_col1, #T_11e1c_row25_col2, #T_11e1c_row25_col3, #T_11e1c_row25_col4, #T_11e1c_row27_col0, #T_11e1c_row27_col1, #T_11e1c_row27_col2, #T_11e1c_row27_col3, #T_11e1c_row27_col4 {
#   background-color: #fed9a6;
# }
# #T_11e1c_row8_col0, #T_11e1c_row8_col1, #T_11e1c_row8_col2, #T_11e1c_row8_col3, #T_11e1c_row8_col4, #T_11e1c_row10_col0, #T_11e1c_row10_col1, #T_11e1c_row10_col2, #T_11e1c_row10_col3, #T_11e1c_row10_col4, #T_11e1c_row12_col0, #T_11e1c_row12_col1, #T_11e1c_row12_col2, #T_11e1c_row12_col3, #T_11e1c_row12_col4, #T_11e1c_row14_col0, #T_11e1c_row14_col1, #T_11e1c_row14_col2, #T_11e1c_row14_col3, #T_11e1c_row14_col4, #T_11e1c_row16_col0, #T_11e1c_row16_col1, #T_11e1c_row16_col2, #T_11e1c_row16_col3, #T_11e1c_row16_col4, #T_11e1c_row18_col0, #T_11e1c_row18_col1, #T_11e1c_row18_col2, #T_11e1c_row18_col3, #T_11e1c_row18_col4, #T_11e1c_row19_col0, #T_11e1c_row19_col1, #T_11e1c_row19_col2, #T_11e1c_row19_col3, #T_11e1c_row19_col4, #T_11e1c_row22_col0, #T_11e1c_row22_col1, #T_11e1c_row22_col2, #T_11e1c_row22_col3, #T_11e1c_row22_col4, #T_11e1c_row24_col0, #T_11e1c_row24_col1, #T_11e1c_row24_col2, #T_11e1c_row24_col3, #T_11e1c_row24_col4, #T_11e1c_row26_col0, #T_11e1c_row26_col1, #T_11e1c_row26_col2, #T_11e1c_row26_col3, #T_11e1c_row26_col4, #T_11e1c_row28_col0, #T_11e1c_row28_col1, #T_11e1c_row28_col2, #T_11e1c_row28_col3, #T_11e1c_row28_col4 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_11e1c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_11e1c_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_11e1c_level0_col1" class="col_heading level0 col1" >id</th>
#       <th id="T_11e1c_level0_col2" class="col_heading level0 col2" >type</th>
#       <th id="T_11e1c_level0_col3" class="col_heading level0 col3" >value</th>
#       <th id="T_11e1c_level0_col4" class="col_heading level0 col4" >attr_obs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11e1c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_11e1c_row0_col0" class="data row0 col0" >0000-00-00</td>
#       <td id="T_11e1c_row0_col1" class="data row0 col1" >266114</td>
#       <td id="T_11e1c_row0_col2" class="data row0 col2" >naturalidade</td>
#       <td id="T_11e1c_row0_col3" class="data row0 col3" >Lisboa</td>
#       <td id="T_11e1c_row0_col4" class="data row0 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_11e1c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_11e1c_row1_col0" class="data row1 col0" >0000-00-00</td>
#       <td id="T_11e1c_row1_col1" class="data row1 col1" >266114</td>
#       <td id="T_11e1c_row1_col2" class="data row1 col2" >nome</td>
#       <td id="T_11e1c_row1_col3" class="data row1 col3" >Rafael dos Anjos</td>
#       <td id="T_11e1c_row1_col4" class="data row1 col4" >Rafael dos Anjos de Andrade, vide dos Anjos</td>
#     </tr>
#     <tr>
#       <th id="T_11e1c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_11e1c_row2_col0" class="data row2 col0" >0000-00-00</td>
#       <td id="T_11e1c_row2_col1" class="data row2 col1" >266114</td>
#       <td id="T_11e1c_row2_col2" class="data row2 col2" >nome</td>
#       <td id="T_11e1c_row2_col3" class="data row2 col3" >Rafael dos Anjos de Andrade</td>
#       <td id="T_11e1c_row2_col4" class="data row2 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_11e1c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_11e1c_row3_col0" class="data row3 col0" >0000-00-00</td>
#       <td id="T_11e1c_row3_col1" class="data row3 col1" >266114</td>
#       <td id="T_11e1c_row3_col2" class="data row3 col2" >nome-pai</td>
#       <td id="T_11e1c_row3_col3" class="data row3 col3" >Nicolau Ferreira</td>
#       <td id="T_11e1c_row3_col4" class="data row3 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_11e1c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_11e1c_row4_col0" class="data row4 col0" >0000-00-00</td>
#       <td id="T_11e1c_row4_col1" class="data row4 col1" >266114</td>
#       <td id="T_11e1c_row4_col2" class="data row4 col2" >nome-vide</td>
#       <td id="T_11e1c_row4_col3" class="data row4 col3" >dos Anjos</td>
#       <td id="T_11e1c_row4_col4" class="data row4 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_11e1c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_11e1c_row5_col0" class="data row5 col0" >0000-00-00</td>
#       <td id="T_11e1c_row5_col1" class="data row5 col1" >266114</td>
#       <td id="T_11e1c_row5_col2" class="data row5 col2" >uc-entrada</td>
#       <td id="T_11e1c_row5_col3" class="data row5 col3" >0000-00-00</td>
#       <td id="T_11e1c_row5_col4" class="data row5 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_11e1c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_11e1c_row6_col0" class="data row6 col0" >0000-00-00</td>
#       <td id="T_11e1c_row6_col1" class="data row6 col1" >266114</td>
#       <td id="T_11e1c_row6_col2" class="data row6 col2" >uc-saida</td>
#       <td id="T_11e1c_row6_col3" class="data row6 col3" >0000-00-00</td>
#       <td id="T_11e1c_row6_col4" class="data row6 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_11e1c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_11e1c_row7_col0" class="data row7 col0" >1640-10-01</td>
#       <td id="T_11e1c_row7_col1" class="data row7 col1" >146547</td>
#       <td id="T_11e1c_row7_col2" class="data row7 col2" >faculdade</td>
#       <td id="T_11e1c_row7_col3" class="data row7 col3" >Medicina</td>
#       <td id="T_11e1c_row7_col4" class="data row7 col4" >Medicina</td>
#     </tr>
#     <tr>
#       <th id="T_11e1c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_11e1c_row8_col0" class="data row8 col0" >1640-10-01</td>
#       <td id="T_11e1c_row8_col1" class="data row8 col1" >266130</td>
#       <td id="T_11e1c_row8_col2" class="data row8 col2" >faculdade</td>
#       <td id="T_11e1c_row8_col3" class="data row8 col3" >Medicina</td>
#       <td id="T_11e1c_row8_col4" class="data row8 col4" >Medicina</td>
#     </tr>
#     <tr>
#       <th id="T_11e1c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_11e1c_row9_col0" class="data row9 col0" >1640-10-01</td>
#       <td id="T_11e1c_row9_col1" class="data row9 col1" >146547</td>
#       <td id="T_11e1c_row9_col2" class="data row9 c
# <style type="text/css">
# #T_d0590_row0_col0, #T_d0590_row0_col1, #T_d0590_row0_col2, #T_d0590_row0_col3, #T_d0590_row0_col4, #T_d0590_row0_col5, #T_d0590_row0_col6 {
#   background-color: #fbb4ae;
# }
# #T_d0590_row1_col0, #T_d0590_row1_col1, #T_d0590_row1_col2, #T_d0590_row1_col3, #T_d0590_row1_col4, #T_d0590_row1_col5, #T_d0590_row1_col6 {
#   background-color: #fed9a6;
# }
# #T_d0590_row2_col0, #T_d0590_row2_col1, #T_d0590_row2_col2, #T_d0590_row2_col3, #T_d0590_row2_col4, #T_d0590_row2_col5, #T_d0590_row2_col6 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_d0590">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d0590_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_d0590_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_d0590_level0_col2" class="col_heading level0 col2" >nome-vide</th>
#       <th id="T_d0590_level0_col3" class="col_heading level0 col3" >naturalidade</th>
#       <th id="T_d0590_level0_col4" class="col_heading level0 col4" >uc-entrada</th>
#       <th id="T_d0590_level0_col5" class="col_heading level0 col5" >faculdade</th>
#       <th id="T_d0590_level0_col6" class="col_heading level0 col6" >nome-pai</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0590_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d0590_row0_col0" class="data row0 col0" >201515</td>
#       <td id="T_d0590_row0_col1" class="data row0 col1" >Manuel José de Magalhães Teixeira</td>
#       <td id="T_d0590_row0_col2" class="data row0 col2" >Manuel José</td>
#       <td id="T_d0590_row0_col3" class="data row0 col3" >Braga</td>
#       <td id="T_d0590_row0_col4" class="data row0 col4" >0000-00-00</td>
#       <td id="T_d0590_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_d0590_row0_col6" class="data row0 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d0590_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d0590_row1_col0" class="data row1 col0" >194771</td>
#       <td id="T_d0590_row1_col1" class="data row1 col1" >Manuel José</td>
#       <td id="T_d0590_row1_col2" class="data row1 col2" >Magalhães Teixeira</td>
#       <td id="T_d0590_row1_col3" class="data row1 col3" >Braga</td>
#       <td id="T_d0590_row1_col4" class="data row1 col4" >1735-01-30</td>
#       <td id="T_d0590_row1_col5" class="data row1 col5" >Cânones</td>
#       <td id="T_d0590_row1_col6" class="data row1 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_
col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_24994_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_24994_row5_col0" class="data row5 col0" >0000-00-00</td>
#       <td id="T_24994_row5_col1" class="data row5 col1" >201515</td>
#       <td id="T_24994_row5_col2" class="data row5 col2" >uc-saida</td>
#       <td id="T_24994_row5_col3" class="data row5 col3" >0000-00-00</td>
#       <td id="T_24994_row5_col4" class="data row5 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_24994_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_24994_row6_col0" class="data row6 col0" >1735-01-30</td>
#       <td id="T_24994_row6_col1" class="data row6 col1" >194771</td>
#       <td id="T_24994_row6_col2" class="data row6 col2" >faculdade</td>
#       <td id="T_24994_row6_col3" class="data row6 col3" >Cânones</td>
#       <td id="T_24994_row6_col4" class="data row6 col4" >Cânones</td>
#     </tr>
#     <tr>
#       <th id="T_24994_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_24994_row7_col0" class="data row7 col0" >1735-01-30</td>
#       <td id="T_24994_row7_col1" class="data row7 col1" >194771</td>
#       <td id="T_24994_row7_col2" class="data row7 col2" >instituta</td>
#       <td id="T_24994_row7_col3" class="data row7 col3" >1735-01-30</td>
#       <td id="T_24994_row7_col4" class="data row7 col4" >30.01.1735 1735-01-30</td>
#     </tr>
#     <tr>
#       <th id="T_24994_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_24994_row8_col0" class="data row8 col0" >1735-01-30</td>
#       <td id="T_24994_row
# <style type="text/css">
# #T_c0cf8_row0_col0, #T_c0cf8_row0_col1, #T_c0cf8_row0_col2, #T_c0cf8_row0_col3, #T_c0cf8_row0_col4, #T_c0cf8_row0_col5, #T_c0cf8_row0_col6 {
#   background-color: #fbb4ae;
# }
# #T_c0cf8_row1_col0, #T_c0cf8_row1_col1, #T_c0cf8_row1_col2, #T_c0cf8_row1_col3, #T_c0cf8_row1_col4, #T_c0cf8_row1_col5, #T_c0cf8_row1_col6 {
#   background-color: #fed9a6;
# }
# #T_c0cf8_row2_col0, #T_c0cf8_row2_col1, #T_c0cf8_row2_col2, #T_c0cf8_row2_col3, #T_c0cf8_row2_col4, #T_c0cf8_row2_col5, #T_c0cf8_row2_col6 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_c0cf8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c0cf8_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_c0cf8_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_c0cf8_level0_col2" class="col_heading level0 col2" >nome-vide</th>
#       <th id="T_c0cf8_level0_col3" class="col_heading level0 col3" >naturalidade</th>
#       <th id="T_c0cf8_level0_col4" class="col_heading level0 col4" >uc-entrada</th>
#       <th id="T_c0cf8_level0_col5" class="col_heading level0 col5" >faculdade</th>
#       <th id="T_c0cf8_level0_col6" class="col_heading level0 col6" >nome-pai</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0cf8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c0cf8_row0_col0" class="data row0 col0" >195422</td>
#       <td id="T_c0cf8_row0_col1" class="data row0 col1" >Francisco Xavier</td>
#       <td id="T_c0cf8_row0_col2" class="data row0 col2" >da Silva</td>
#       <td id="T_c0cf8_row0_col3" class="data row0 col3" >Lisboa</td>
#       <td id="T_c0cf8_row0_col4" class="data row0 col4" >0000-00-00</td>
#       <td id="T_c0cf8_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_c0cf8_row0_col6" class="data row0 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c0cf8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c0cf8_row1_col0" class="data row1 col0" >226704</td>
#       <td id="T_c0cf8_row1_col1" class="data row1 col1" >Francisco Xavier da Silva</td>
#       <td id="T_c0cf8_row1_col2" class="data row1 col2" >Xavier</td>
#       <td id="T_c0cf8_row1_col3" class="data row1 col3" >Lisboa</td>
#       <td id="T_c0cf8_row1_col4" class="data row1 col4" >1725-11-26</td>
#       <td id="T_c0cf8_row1_col5" class="data row1 col5" >Cânones</td>
#       <td id="T_c0cf8_row1_col6" class="data row1 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c0cf8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c0cf8_row2_col0" class="data row2 col0" >226697</td>
#       <td id="T_c0cf8_row2_col1" class="data row2 col1" >Francisco Xavier da Silva</td>
#       <td id="T_c0cf8_row2_col2" class="data row2 col2" >Francisco Xavier</td>
#       <td id="T_c0cf8_row2_col3" class="data row2 col3" >Lisboa</td>
#       <td id="T_c0cf8_row2_col4" class="data row2 col4" >1760-12-15</td>
#       <td id="T_c0cf8_row2_col5" class="data row2 col5" >Cânones</td>
#       <td id="T_c0cf8_row2_col6" class="data row2 col6" >Manuel Nunes</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_658b3_row0_col0, #T_658b3_row0_col1, #T_658b3_row0_col2, #T_658b3_row0_col3, #T_658b3_row0_col4, #T_658b3_row1_col0, #T_658b3_row1_col1, #T_658b3_row1_col2, #T_658b3_row1_col3, #T_658b3_row1_col4, #T_658b3_row2_col0, #T_658b3_row2_col1, #T_658b3_row2_col2, #T_658b3_row2_col3, #T_658b3_row2_col4, #T_658b3_row3_col0, #T_658b3_row3_col1, #T_658b3_row3_col2, #T_658b3_row3_col3, #T_658b3_row3_col4, #T_658b3_row4_col0, #T_658b3_row4_col1, #T_658b3_row4_col2, #T_658b3_row4_col3, #T_658b3_row4_col4, #T_658b3_row5_col0, #T_658b3_row5_col1, #T_658b3_row5_col2, #T_658b3_row5_col3, #T_658b3_row5_col4 {
#   background-color: #fbb4ae;
# }
# #T_658b3_row6_col0, #T_658b3_row6_col1, #T_658b3_row6_col2, #T_658b3_row6_col3, #T_658b3_row6_col4, #T_658b3_row7_col0, #T_658b3_row7_col1, #T_658b3_row7_col2, #T_658b3_row7_col3, #T_658b3_row7_col4, #T_658b3_row8_col0, #T_658b3_row8_col1, #T_658b3_row8_col2, #T_658b3_row8_col3, #T_658b3_row8_col4, #T_658b3_row9_col0, #T_658b3_row9_col1, #T_658b3_row9_col2, #T_658b3_row9_col3, #T_658b3_row9_col4, #T_658b3_row10_col0, #T_658b3_row10_col1, #T_658b3_row10_col2, #T_658b3_row10_col3, #T_658b3_row10_col4, #T_658b3_row11_col0, #T_658b3_row11_col1, #T_658b3_row11_col2, #T_658b3_row11_col3, #T_658b3_row11_col4, #T_658b3_row12_col0, #T_658b3_row12_col1, #T_658b3_row12_col2, #T_658b3_row12_col3, #T_658b3_row12_col4, #T_658b3_row13_col0, #T_658b3_row13_col1, #T_658b3_row13_col2, #T_658b3_row13_col3, #T_658b3_row13_col4, #T_658b3_row14_col0, #T_658b3_row14_col1, #T_658b3_row14_col2, #T_658b3_row14_col3, #T_658b3_row14_col4, #T_658b3_row15_col0, #T_658b3_row15_col1, #T_658b3_row15_col2, #T_658b3_row15_col3, #T_658b3_row15_col4, #T_658b3_row16_col0, #T_658b3_row16_col1, #T_658b3_row
_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_658b3_row1_col0" class="data row1 col0" >0000-00-00</td>
#       <td id="T_658b3_row1_col1" class="data row1 col1" >195422</td>
#       <td id="T_658b3_row1_col2" class="data row1 col2" >nome</td>
#       <td id="T_658b3_row1_col3" class="data row1 col3" >Francisco Xavier</td>
#       <td id="T_658b3_row1_col4" class="data row1 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_658b3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_658b3_row2_col0" class="data row2 col0" >0000-00-00</td>
#       <td id="T_658b3_row2_col1" class="data row2 col1" >195422</td>
#       <td id="T_658b3_row2_col2" class="data row2 col2" >nome</td>
#       <td id="T_658b3_row2_col3" class="data row2 col3" >Francisco Xavier da Silva</td>
#       <td id="T_658b3_row2_col4" class="data row2 col4" >Francisco Xavier, vide da Silva</td>
#     </tr>
#     <tr>
#       <th id="T_658b3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_658b3_row3_col0" class="data row3 col0" >0000-00-00</td>
#       <td id="T_658b3_row3_col1" class="data row3 col1" >195422</td>
#       <td id="T_658b3_row3_col2" class="data row3 col2" >nome-vide</td>
#       <td id="T_658b3_row3_col3" class="data row3 col3" >da Silva</td>
#       <td id="T_658b3_row3_col4" class="data row3 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_658b3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_658b3_row4_col0" class="data row4 col0" >0000-00-00</td>
#       <td id="T_658b3_row4_col1" class="data row4 col1" >195422</td>
#       <td id="T_658b3_row4_col2" class="data row4 col2" >uc-entrada</td>
#       <td id="T_658b3_row4_col3" class="data row4 col3" >0000-00-00</td>
#       <td id="T_658b3_row4_col4" class="data row4 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_658b3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_658b3_row5_col0" class="data row5 col0" >0000-00-00</td>
#       <td id="T_658b3_row5_col1" class="data row5 col1" >195422</td>
#       <td id="T_658b3_row5_col2" class="data row5 col2" >uc-saida</td>
#       <td id="T_658b3_row5_col3" class="data row5 col3" >0000-00-00</td>
#       <td id="T_658b3_row5_col4" class="data row5 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_658b3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_658b3_row6_col0" class="data row6 col0" >1725-11-26</td>
#       <td id="T_658b3_row6_col1" class="data row6 col1" >226704</td>
#       <td id="T_658b3_row6_col2" class="data row6 col2" >faculdade</td>
#       <td id="T_658b3_row6_col3" class="data row6 col3" >Cânones</td>
#       <td id="T_658b3_row6_col4" class="data row6 col4" >Cânones</td>
#     </tr>
#     <tr>
#       <th id="T_658b3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_658b3_row7_col0" class="data row7 col0" >1725-11-26</td>
#       <td id="T_658b3_row7_col1" class="data row7 col1" >226704</td>
#       <td id="T_658b3_row7_col2" class="data row7 col2" >matricula-faculdade</td>
#       <td id="T_658b3_row7_col3" class="data row7 col3" >Cânones</td>
#       <td id="T_658b3_row7_col4" class="data row7 col4" >26.11.1725</td>
#     </tr>

# %% [markdown]
# #### Show some of the aka-aka records (potential duplicates)

# %%
from timelinknb.pandas import display_group_attributes

no_show=['código-de-referência','data-do-registo','url','faculdade.ano','naturalidade.ano',
         'matricula-faculdade.ano','nome-apelido','nome-primeiro','nome-geografico.ano',
         'grau.ano','matricula-outra.ano','nome-geografico','instituta.ano']

pairs = match_records['matched_pairs']['random']
show_pairs = [(o,d,t) for o,d,t in pairs if t == 'aka-aka' and o<d]
show_only = 4
print(f"aka-aka matches in sequential mode (show only {show_only}) of {len(show_pairs)}:")
for o,d,t in show_pairs[:show_only]:
    display_group_attributes([o,d],
                             header_cols=['name','nome-vide','naturalidade','uc-entrada','faculdade','nome-pai'],
                             exclude_attributes=no_show,
                             sort_attributes=['date','type','value'],
                             cmap_name='Pastel1')
# Out:
# aka-aka matches in sequential mode (show only 4) of 109:
# <style type="text/css">
# #T_6c2b1_row0_col0, #T_6c2b1_row0_col1, #T_6c2b1_row0_col2, #T_6c2b1_row0_col3, #T_6c2b1_row0_col4, #T_6c2b1_row0_col5, #T_6c2b1_row0_col6 {
#   background-color: #fbb4ae;
# }
# #T_6c2b1_row1_col0, #T_6c2b1_row1_col1, #T_6c2b1_row1_col2, #T_6c2b1_row1_col3, #T_6c2b1_row1_col4, #T_6c2b1_row1_col5, #T_6c2b1_row1_col6 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_6c2b1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c2b1_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_6c2b1_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_6c2b1_level0_col2" class="col_heading level0 col2" >nome-vide</th>
#       <th id="T_6c2b1_level0_col3" class="col_heading level0 col3" >naturalidade</th>
#       <th id="T_6c2b1_level0_col4" class="col_heading level0 col4" >uc-entrada</th>
#       <th id="T_6c2b1_level0_col5" class="col_heading level0 col5" >faculdade</th>
#       <th id="T_6c2b1_level0_col6" class="col_heading level0 col6" >nome-pai</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c2b1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6c2b1_row0_col0" class="data row0 col0" >143239</td>
#       <td id="T_6c2b1_row0_col1" class="data row0 col1" >Jerónimo de Almeida</td>
#       <td id="T_6c2b1_row0_col2" class="data row0 col2" >Ribeiro</td>
#       <td id="T_6c2b1_row0_col3" class="data row0 col3" >Ferreira</td>
#       <td id="T_6c2b1_row0_col4" class="data row0 col4" >1553-10-00</td>
#       <td id="T_6c2b1_row0_col5" class="data row0 col5" >Leis</td>
#       <td id="T_6c2b1_row0_col6" class="data row0 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_6c2b1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6c2b1_row1_col0" class="data row1 col0" >163231</td>
#       <td id="T_6c2b1_row1_col1" class="data row1 col1" >Jerónimo de Almeida Ribeiro</td>
#       <td id="T_6c2b1_row1_col2" class="data row1 col2" >Almeida</td>
#       <td id="T_6c2b1_row1_col3" class="data row1 col3" >Ferreira</td>
#       <td id="T_6c2b1_row1_col4" class="data row1 col4" >1560-01-24</td>
#       <td id="T_6c2b1_row1_col5" class="data row1 col5" >Cânones</td>
#       <td id="T_6c2b1_row1_col6" class="data row1 col6" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_71cdf_row0_col0, #T_71cdf_row0_col1, #T_71cdf_row0_col2, #T_71cdf_row0_col3, #T_71cdf_row0_col4, #T_71cdf_row1_col0, #T_71cdf_row1_col1, #T_71cdf_row1_col2, #T_71cdf_row1_col3, #T_71cdf_row1_col4, #T_71cdf_row2_col0, #T_71cdf_row2_col1, #T_71cdf_row2_col2, #T_71cdf_row2_col3, #T_71cdf_row2_col4, #T_71cdf_row3_col0, #T_71cdf_row3_col1, #T_71cdf_row3_col2, #T_71cdf_row3_col3, #T_71cdf_row3_col4, #T_71cdf_row4_col0, #T_71cdf_row4_col1, #T_71cdf_row4_col2, #T_71cdf_row4_col3, #T_71cdf_row4_col4, #T_71cdf_row5_col0, #T_71cdf_row5_col1, #T_71cdf_row5_col2, #T_71cdf_row5_col3, #T_71cdf_row5_col4, #T_71cdf_row6_col0, #T_71cdf_row6_col1, #T_71cdf_row6_col2, #
_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_71cdf_row9_col0" class="data row9 col0" >1559-07-27</td>
#       <td id="T_71cdf_row9_col1" class="data row9 col1" >143239</td>
#       <td id="T_71cdf_row9_col2" class="data row9 col2" >grau</td>
#       <td id="T_71cdf_row9_col3" class="data row9 col3" >Bacharel em Leis</td>
#       <td id="T_71cdf_row9_col4" class="data row9 col4" >"1559/07/27"</td>
#     </tr>
#     <tr>
#       <th id="T_71cdf_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_71cdf_row10_col0" class="data row10 col0" >1559-07-27</td>
#       <td id="T_71cdf_row10_col1" class="data row10 col1" >143239</td>
#       <td id="T_71cdf_row10_col2" class="data row10 col2"
# <style type="text/css">
# #T_184ab_row0_col0, #T_184ab_row0_col1, #T_184ab_row0_col2, #T_184ab_row0_col3, #T_184ab_row0_col4, #T_184ab_row0_col5, #T_184ab_row0_col6 {
#   background-color: #fbb4ae;
# }
# #T_184ab_row1_col0, #T_184ab_row1_col1, #T_184ab_row1_col2, #T_184ab_row1_col3, #T_184ab_row1_col4, #T_184ab_row1_col5, #T_184ab_row1_col6 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_184ab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_184ab_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_184ab_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_184ab_level0_col2" class="col_heading level0 col2" >nome-vide</th>
#       <th id="T_184ab_level0_col3" class="col_heading level0 col3" >naturalidade</th>
#       <th id="T_184ab_level0_col4" class="col_heading level0 col4" >uc-entrada</th>
#       <th id="T_184ab_level0_col5" class="col_heading level0 col5" >faculdade</th>
#       <th id="T_184ab_level0_col6" class="col_heading level0 col6" >nome-pai</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_184ab_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_184ab_row0_col0" class="data row0 col0" >129553</td>
#       <td id="T_184ab_row0_col1" class="data row0 col1" >Manuel de Castro Caldeira</td>
#       <td id="T_184ab_row0_col2" class="data row0 col2" >Castro</td>
#       <td id="T_184ab_row0_col3" class="data row0 col3" >Abrantes</td>
#       <td id="T_184ab_row0_col4" class="data row0 col4" >1601-10-14</td>
#       <td id="T_184ab_row0_col5" class="data row0 col5" >Cursos jurídicos (Cânones ou Leis)</td>
#       <td id="T_184ab_row0_col6" class="data row0 col6" >Lopo Castro</td>
#     </tr>
#     <tr>
#       <th id="T_184ab_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_184ab_row1_col0" class="data row1 col0" >191232</td>
#       <td id="T_184ab_row1_col1" class="data row1 col1" >Manuel de Castro</td>
#       <td id="T_184ab_row1_col2" class="data row1 col2" >Caldeira</td>
#       <td id="T_184ab_row1_col3" class="data row1 col3" >Abrantes</td>
#       <td id="T_184ab_row1_col4" class="data row1 col4" >1601-10-14</td>
#       <td id="T_184ab_row1_col5" class="data row1 col5" >Medicina</td>
#       <td id="T_184ab_row1_col6" class="data row1 col6" >Lopo de Castro</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_8aae9_row0_col0, #T_8aae9_row0_col1, #T_8aae9_row0_col2, #T_8aae9_row0_col3, #T_8aae9_row0_col4, #T_8aae9_row2_col0, #T_8aae9_row2_col1, #T_8aae9_row2_col2, #T_8aae9_row2_col3, #T_8aae9_row2_col4, #T_8aae9_row4_col0, #T_8aae9_row4_col1, #T_8aae9_row4_col2, #T_8aae9_row4_col3, #T_8aae9_row4_col4, #T_8aae9_row6_col0, #T_8aae9_row6_col1, #T_8aae9_row6_col2, #T_8aae9_row6_col3, #T_8aae9_row6_col4
_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8aae9_row8_col0" class="data row8 col0" >1601-10-14</td>
#       <td id="T_8aae9_row8_col1" class="data row8 col1" >129553</td>
#       <td id="T_8aae9_row8_col2" class="data row8 col2" >nome</td>
#       <td id="T_8aae9_row8_col3" class="data row8 col3" >Manuel de Castro Caldeira</td>
#       <td id="T_8aae9_row8_col4" class="data row8 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_8aae9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8aae9_row9_col0" class="data row9 col0" >1601-10-14</td>
#       <td id="T_8aae9_row9_col1" class="data row9 col1" >191232</td>
#       <td id="T_8aae9_row9_col2" class="data row9 col2" >nome</td>
#       <td id="T_8aae9_row9_col3" class="data row9 col3" >Manuel de Castro Caldeira</td>
#       <td id="T_8aae9_row9_col4" class="data row9 col4" >Manuel de Castro, vide Caldeira</td>
#     </tr>
#     <tr>
#       <th id="T_8aae9_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_8aae9_row10_col0" class="data row10 col0" >1601-10-14</td>
#       <td id="T_8aae9_row10_col1" class="data row10 col1" >129553</td>
#       <td id="T_8aae9_row10_col2" class="data row10 c
# <style type="text/css">
# #T_e3ac3_row0_col0, #T_e3ac3_row0_col1, #T_e3ac3_row0_col2, #T_e3ac3_row0_col3, #T_e3ac3_row0_col4, #T_e3ac3_row0_col5, #T_e3ac3_row0_col6 {
#   background-color: #fbb4ae;
# }
# #T_e3ac3_row1_col0, #T_e3ac3_row1_col1, #T_e3ac3_row1_col2, #T_e3ac3_row1_col3, #T_e3ac3_row1_col4, #T_e3ac3_row1_col5, #T_e3ac3_row1_col6 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_e3ac3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3ac3_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_e3ac3_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_e3ac3_level0_col2" class="col_heading level0 col2" >nome-vide</th>
#       <th id="T_e3ac3_level0_col3" class="col_heading level0 col3" >naturalidade</th>
#       <th id="T_e3ac3_level0_col4" class="col_heading level0 col4" >uc-entrada</th>
#       <th id="T_e3ac3_level0_col5" class="col_heading level0 col5" >faculdade</th>
#       <th id="T_e3ac3_level0_col6" class="col_heading level0 col6" >nome-pai</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3ac3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e3ac3_row0_col0" class="data row0 col0" >167251</td>
#       <td id="T_e3ac3_row0_col1" class="data row0 col1" >Pedro Simões Esteves</td>
#       <td id="T_e3ac3_row0_col2" class="data row0 col2" >Simões</td>
#       <td id="T_e3ac3_row0_col3" class="data row0 col3" >Campo Maior</td>
#       <td id="T_e3ac3_row0_col4" class="data row0 col4" >1665-10-19</td>
#       <td id="T_e3ac3_row0_col5" class="data row0 col5" >Cursos jurídicos (Cânones ou Leis)</td>
#       <td id="T_e3ac3_row0_col6" class="data row0 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_e3ac3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e3ac3_row1_col0" class="data row1 col0" >231579</td>
#       <td id="T_e3ac3_row1_col1" class="data row1 col1" >Pedro Simões</td>
#       <td id="T_e3ac3_row1_col2" class="data row1 col2" >Pedro Simões Esteves</td>
#       <td id="T_e3ac3_row1_col3" class="data row1 col3" >Campo Maior</td>
#       <td id="T_e3ac3_row1_col4" class="data row1 col4" >1665-10-19</td>
#       <td id="T_e3ac3_row1_col5" class="data row1 col5" >Cânones</td>
#       <td id="T_e3ac3_row1_col6" class="data row1 col6" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_83369_row0_col0, #T_83369_row0_col1, #T_83369_row0_col2, #T_83369_row0_col3, #T_83369_row0_col4, #T_83369_row2_col0, #T_83369_row2_col1, #T_83369_row2_col2, #T_83369_row2_col3, #T_83369_row2_col4, #T_83369_row4_col0, #T_83369_row4_col1, #T_83369_row4_col2, #T_83369_row4_col3, #T_83369_row4_col4, #T_83369_row6_col0, #T_83369_row6_col1, #T_83369_row6_col2, #T_83369_row6_col3, #T_83369_row6_col4, #T_83369_row8_col0, #T_83369_row8_col1, #T_83369_row8_col2, #T_83369_row8_col3, #T_83369_row8_col4, #T_83369_row10_col0, #T_83369_row10_col1, #T_83369_row10_col2, #T_83369_row10_col3, #T_83369_row10_col4, #T_83369_row11_col0, #T_83369_row11_col1, #T_83369_row11_col2, #T_83369_row11_col3, #T_83369_row11_col4, #T_83369_row14_col0, #T_83369_row14_col1, #T_83369_row14_col2, #T_83369_row14_col3, #T_83369_row14_col4, #T_83369_row16_col0, #T_83369_row16_col1, #T_83369_row16_col2, #T_83369_row16_col3, #T_83369_row16_col4, #T_83369_row19_col0, #T_83369_row19_col1, #T_83369_row19_col2, #T_83369_row19_col3, #T_83369_row19_col4, #T_83369_row20_col0, #T_83369_row20_col1, #T_83369_row20_col2, #T_83369_row20_col3, #T_83369_row20_col4, #T_83369_row21_col0, #T_83369_row21_col1, #T_83369_row21_col2, #T_83369_row21_col3, #T_83369_row21_col4 {
#   background-color: #fbb4ae;
# }
# #T_83369_row1_col0, #T_83369_row1_col1, #T_83369_row1_col2, #T_83369_row1_col3, #T_83369_row1_col4, #T_83369_row3_col0, #T_83369_row3_col1, #T_83369_row3_col2, #T_83369_row3_col3, #T_83369_row3_col4, #T_83369_row5_col0, #T_83369_row5_col1, #T_83369_row5_col2, #T_83369_row5_col3, #T_83369_row5_col4, #T_83369_row7_col0, #T_83369_row7_col1, #T_83369_row7_col2, #T_83369_row7_col3, #T_83369_row7_col4, #T_83369_row9_col0, #T_83369_row9_col1, #T_83369_row9_col2, #T_83369_row9_col3, #T_83369_row9_col4, #T_83369_row12_col0, #T_83369_row12_col1, #T_83369_row12_col2, #T_83369_row12_col3, #T_83369_row12_col4, #T_83369_row13_col0, #T_83369_row13_col1, #T_83369_row13_col2, #T_83369_row13_col3, #T_83369_row13_col4, #T_83369_row15_col0, #T_83369_row15_col1, #T_83369_row15_col2, #T_83369_row15_col3, #T_83369_row15_col4, #T_83369_row17_col0, #T_83369_row17_col1, #T_83369_row17_col2, #T_83369_row17_col3, #T_83369_row17_col4, #T_83369_row18_col0, #T_83369_row18_col1, #T_83369_row18_col2, #T_83369_row18_col3, #T_83369_row18_col4, #T_83369_row22_col0, #T_83369_row22_col1, #T_83369_row22_col2, #T_83369_row22_col3, #T_83369_row22_col4 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_83369">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83369_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_83369_level0_col1" class="col_heading level0 col1" >id</th>
#       <th id="T_83369_level0_col2" class="col_heading level0 col2" >type</th>
#       <th id="T_83369_level0_col3" class="col_heading level0 col3" >value</th>
#       <th id="T_83369_level0_col4" class="col_heading level0 col4" >attr_obs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83369_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_83369_row0_col0" class="data row0 col0" >1665-03-21</td>
#       <td id="T_83369_row0_col1" class="data row0 col1" >231579</td>
#       <td id="T_83369_row0_col2" class="data row0 col2" >grau</td>
#       <td id="T_83369_row0_col3" class="data row0 col3" >Bacharel em Artes</td>
#       <td id="T_83369_row0_col4" class="data row0 col4" >Bacharel em Artes 21.03.1665</td>
#     </tr>
#     <tr>
#       <th id="T_83369_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_83369_row1_col0" class="data row1 col0" >1665-10-19</td>
#       <td id="T_83369_row1_col1" class="data row1 col1" >167251</td>
#       <td id="T_83369_row1_col2" class="data row1 col2" >faculdade</td>
#       <td id="T_83369_row1_col3" class="data row1 col3" >Cursos jurídicos (Cânones ou Leis)</td>
#       <td id="T_83369_row1_col4" class="data row1 col4" >Faculdade inferida</td>
#     </tr>
#     <tr>
#       <th id="T_83369_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_83369_row2_col0" class="data row2 col0" >1665-10-19</td>
#       <td id="T_83369_row2_col1" class="data row2 col1" >231579</td>
#       <td id="T_83369_row2_col2" class="data row2 col2" >faculdade</td>
#       <td id="T_83369_row2_col3" class="data row2 col3" >Cânones</td>
#       <td id="T_83369_row2_col4" class="data row2 col4" >Cânones</td>
#     </tr>
#     <tr>
#       <th id="T_83369_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_83369_row3_col0" class="data row3 col0" >1665-10-19</td>
#       <td id="T_83369_row3_col1" class="data row3 col1" >167251</td>
#       <td id="T_83369_row3_col2" class="data row3 col2" >instituta</td>
#       <td id="T_83369_row3_col3" class="data row3 col3" >1665-10-19</td>
#       <td id="T_83369_row3_col4" class="data row3 col4" >19.10.1665 1665-10-19</td>
#     </tr>
#     <tr>
#       <th id="T_83369_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_83369_row4_col0" class="data row4 col0" >1665-10-19</td>
#       <td id="T_83369_row4_col1" class="data row4 col1" >231579</td>
#       <td id="T_83369_row4_col2" class="data row4 col2" >instituta</td>
#       <td id="T_83369_row4_col3" class="data row4 col3" >1665-10-19</td>
#       <td id="T_83369_row4_col4" class="data row4 col4" >19.10.1665 1665-10-19</td>
#     </tr>
#     <tr>
#       <th id="T_83369_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_83369_row5_col0" class="data row5 col0" >1665-10-19</td>
#       <td id="T_83369_row5_col1" class="data row5 col1" >167251</td>
#       <td id="T_83369_row5_col2" class="data row5 col2" >naturalidade</td>
#       <td id="T_83369_row5_col3" class="data row5 col3" >Campo Maior</td>
#       <td id="T_83369_row5_col4" class="data row5 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_83369_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_83369_row6_col0" class="data row6 col0" >1665-10-19</td>
#       <td id="T_83369_row6_col1" class="data row6 col1" >231579</td>
#       <td id="T_83369_row6_col2" class="data row6 col2" >naturalidade</td>
#       <td id="T_83369_row6_col3" class="data row6 col3" >Campo Maior</td>
#       <td id="T_83369_row6_col4" class="data row6 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_83369_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_83369_row7_col0" class="data row7 col0" >1665-10-19</td>
#       <td id="T_83369_row7_col1" class="data row7 col1" >167251</td>
#       <td id="T_83369_row7_col2" class="data row7 col2" >nome</td>
#       <td id="T_83369_row7_col3" class="data row7 col3" >Pedro Simões</td>
#       <td id="T_83369_row7_col4" class="data row7 col4" >Pedro Simões Esteves, vide Simões</td>
#     </tr>
#     <tr>
#       <th id="T_83369_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_83369_row8_col0" class="data row8 col0" >1665-10-19</td>
#       <td id="T_83369_row8_col1" class="data row8 col1" >231579</td>
#       <td id="T_83369_row8_col2" class="data row8 col2" >nome</td>
#       <td id="T_83369_row8_col3" class="data row8 col3" >Pedro Simões</td>
#       <td id="T_83369_row8_col4" class="data row8 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_83369_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_83369_row9_col0" class="data row9 col0" >1665-10-19</td>
#       <td id="T_83369_row9_col1" class="data row9 col1" >167251</td>
#       <td id="T_83369_row9_col2" class="data row9 col2" >nome</td>
#       <td id="T_83369_row9_col3" class="data row9 col3" >Pedro Simões Esteves</td>
#       <td id="T_83369_row9_col4" class="data row9 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_83369_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_83369_row10_col0" class="data row10 col0" >1665-10-19</td>
#       <td id="T_83369_row10_col1" class="data row10 col1" >231579</td>
#       <td id="T_83369_row10_col2" class="data row10 col2" >nome</td>
#       <td id="T_83369_row10_col3" class="data row10 col3" >Pedro Simões Esteves</td>
#       <td id="T_83369_row10_c
# <style type="text/css">
# #T_51b9e_row0_col0, #T_51b9e_row0_col1, #T_51b9e_row0_col2, #T_51b9e_row0_col3, #T_51b9e_row0_col4, #T_51b9e_row0_col5, #T_51b9e_row0_col6 {
#   background-color: #fbb4ae;
# }
# #T_51b9e_row1_col0, #T_51b9e_row1_col1, #T_51b9e_row1_col2, #T_51b9e_row1_col3, #T_51b9e_row1_col4, #T_51b9e_row1_col5, #T_51b9e_row1_col6 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_51b9e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_51b9e_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_51b9e_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_51b9e_level0_col2" class="col_heading level0 col2" >nome-vide</th>
#       <th id="T_51b9e_level0_col3" class="col_heading level0 col3" >naturalidade</th>
#       <th id="T_51b9e_level0_col4" class="col_heading level0 col4" >uc-entrada</th>
#       <th id="T_51b9e_level0_col5" class="col_heading level0 col5" >faculdade</th>
#       <th id="T_51b9e_level0_col6" class="col_heading level0 col6" >nome-pai</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_51b9e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_51b9e_row0_col0" class="data row0 col0" >149046</td>
#       <td id="T_51b9e_row0_col1" class="data row0 col1" >Bernardo José de Azevedo</td>
#       <td id="T_51b9e_row0_col2" class="data row0 col2" >Vieira</td>
#       <td id="T_51b9e_row0_col3" class="data row0 col3" >Paredes</td>
#       <td id="T_51b9e_row0_col4" class="data row0 col4" >1725-10-01</td>
#       <td id="T_51b9e_row0_col5" class="data row0 col5" >Cânones</td>
#       <td id="T_51b9e_row0_col6" class="data row0 col6" >José de Azevedo Vieira</td>
#     </tr>
#     <tr>
#       <th id="T_51b9e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_51b9e_row1_col0" class="data row1 col0" >216902</td>
#       <td id="T_51b9e_row1_col1" class="data row1 col1" >Bernardo José de Azevedo Vieira</td>
#       <td id="T_51b9e_row1_col2" class="data row1 col2" >Azevedo</td>
#       <td id="T_51b9e_row1_col3" class="data row1 col3" >Paredes</td>
#       <td id="T_51b9e_row1_col4" class="data row1 col4" >1726-10-01</td>
#       <td id="T_51b9e_row1_col5" class="data row1 col5" >Cânones</td>
#       <td id="T_51b9e_row1_col6" class="data row1 col6" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_7b7af_row0_col0, #T_7b7af_row0_col1, #T_7b7af_row0_col2, #T_7b7af_row0_col3, #T_7b7af_row0_col4, #T_7b7af_row1_col0, #T_7b7af_row1_col1, #T_7b7af_row1_col2, #T_7b7af_row1_col3, #T_7b7af_row1_col4, #T_7b7af_row2_col0, #T_7b7af_row2_col1, #T_7b7af_row2_col2, #T_7b7af_row2_col3, #T_7b7af_row2_col4, #T_7b7af_row3_col0, #T_7b7af_row3_col1, #T_7b7af_row3_col2, #T_7b7af_row3_col3, #T_7b7af_row3_col4, #T_7b7af_row4_col0, #T_7b7af_row4_col1, #T_7b7af_row4_col2, #T_7b7af_row4_col3, #T_7b7af_row4_col4, #T_7b7af_row5_col0, #T_7b7af_row5_col1, #T_7b7af_row5_col2, #T_7b7af_row5_col3, #T_7b7af_row5_col4, #T_7b7af_row6_col0, #T_7b7af_row6_col1, #T_7b7af_row6_col2, #T_7b7af_row6_col3, #T_7b7af_row6_col4, #T_7b7af_row7_col0, #T_7b7af_row7_col1, #T_7b7af_row7_col2, #T_7b7af_row7_col3, #T_7b7af_row7_col4, #T_7b7af_row8_col0, #T_7b7af_row8_col1, #T_7b7af_row8_col2, #T_7b7af_row8_col3, #T_7b7af_row8_col4, #T_7b7af_row9_col0, #T_7b7af_row9_col1, #T_7b7af_row9_col2, #T_7b7af_row9_col3, #T_7b7af_row9_col4, #T_7b7af_row10_col0, #T_7b7af_row10_col1, #T_7b7af_row10_col2, #T_7b7af_row10_col3, #T_7b7af_row10_col4, #T_7b7af_row12_col0, #T_7b7af_row12_col1, #T_7b7af_row12_col2, #T_7b7af_row12_col3, #T_7b7af_row12_col4, #T_7b7af_row20_col0, #T_7b7af_row20_col1, #T_7b7af_row20_col2, #T_7b7af_row20_col3, #T_7b7af_row20_col4, #T_7b7af_row22_col0, #T_7b7af_row22_col1, #T_7b7af_row22_col2, #T_7b7af_row22_col3, #T_7b7af_row22_col4, #T_7b7af_row24_col0, #T_7b7af_row24_col1, #T_7b7af_row24_col2, #T_7b7af_row24_col3, #T_7b7af_row24_col4, #T_7b7af_row28_col0, #T_7b7af_row28_col1, #T_7b7af_row28_col2, #T_7b7af_row28_col3, #T_7b7af_row28_col4, #T_7b7af_row29_col0, #T_7b7af_row29_col1, #T_7b7af_row29_col2, #T_7b7af_row29_col3, #T_7b7af_row29_col4, #T_7b7af_row30_col0, #T_7b7af_row30_col1, #T_7b7af_row30_col2, #T_7b7af_row30_col3, #T_7b7af_row30_col4 {
#   background-color: #fbb4ae;
# }
# #T_7b7af_row11_col0, #T_7b7af_row11_col1, #T_7b7af_row11_col2, #T_7b7af_row11_col3, #T_7b7af_row11_col4, #T_7b7af_row13_col0, #T_7b7af_row13_col1, #T_7b7af_row13_col2, #T_7b7af_row13_col3, #T_7b7af_row13_col4, #T_7b7af_row14_col0, #T_7b7af_row14_col1, #T_7b7af_row14_col2, #T_7b7af_row14_col3, #T_7b7af_row14_col4, #T_7b7af_row15_col0, #T_7b7af_row15_col1, #T_7b7af_row15_col2, #T_7b7af_row15_col3, #T_7b7af_row15_col4, #T_7b7af_row16_col0, #T_7b7af_row16_col1, #T_7b7af_row16_col2, #T_7b7af_row16_col3, #T_7b7af_row16_col4, #T_7b7af_row17_col0, #T_7b7af_row17_col1, #T_7b7af_row17_col2, #T_7b7af_row17_col3, #T_7b7af_row17_col4, #T_7b7af_row18_col0, #T_7b7af_row18_col1, #T_7b7af_row18_col2, #T_7b7af_row18_col3, #T_7b7af_row18_col4, #T_7b7af_row19_col0, #T_7b7af_row19_col1, #T_7b7af_row19_col2, #T_7b7af_row19_col3, #T_7b7af_row19_col4, #T_7b7af_row21_col0, #T_7b7af_row21_col1, #T_7b7af_row21_col2, #T_7b7af_row21_col3, #T_7b7af_row21_col4, #T_7b7af_row23_col0, #T_7b7af_row23_col1, #T_7b7af_row23_col2, #T_7b7af_row23_col3, #T_7b7af_row23_col4, #T_7b7af_row25_col0, #T_7b7af_row25_col1, #T_7b7af_row25_col2, #T_7b7af_row25_col3, #T_7b7af_row25_col4, #T_7b7af_row26_col0, #T_7b7af_row26_col1, #T_7b7af_row26_col2, #T_7b7af_row26_col3, #T_7b7af_row26_col4, #T_7b7af_row27_col0, #T_7b7af_row27_col1, #T_7b7af_row27_col2, #T_7b7af_row27_col3, #T_7b7af_row27_col4 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_7b7af">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7b7af_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_7b7af_level0_col1" class="col_heading level0 col1" >id</th>
#       <th id="T_7b7af_level0_col2" class="col_heading level0 col2" >type</th>
#       <th id="T_7b7af_level0_col3" class="col_heading level0 col3" >value</th>
#       <th id="T_7b7af_level0_col4" class="col_heading level0 col4" >attr_obs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b7af_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7b7af_row0_col0" class="data row0 col0" >1725-10-01</td>
#       <td id="T_7b7af_row0_col1" class="data row0 col1" >149046</td>
#       <td id="T_7b7af_row0_col2" class="data row0 col2" >faculdade</td>
#       <td id="T_7b7af_row0_col3" class="data row0 col3" >Cânones</td>
#       <td id="T_7b7af_row0_col4" class="data row0 col4" >Cânones</td>
#     </tr>
#     <tr>
#       <th id="T_7b7af_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7b7af_row1_col0" class="data row1 col0" >1725-10-01</td>
#       <td id="T_7b7af_row1_col1" class="data row1 col1" >149046</td>
#       <td id="T_7b7af_row1_col2" class="data row1 col2" >instituta</td>
#       <td id="T_7b7af_row1_col3" class="data row1 col3" >1725-10-01</td>
#       <td id="T_7b7af_row1_col4" class="data row1 col4" >01.10.1725 1725-10-01</td>
#     </tr>
#     <tr>
#       <th id="T_7b7af_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7b7af_row2_col0" class="data row2 col0" >1725-10-01</td>
#       <td id="T_7b7af_row2_col1" class="data row2 col1" >149046</td>
#       <td id="T_7b7af_row2_col2" class="data row2 col2" >naturalidade</td>
#       <td id="T_7b7af_row2_col3" class="data row2 col3" >Paredes</td>
#       <td id="T_7b7af_row2_col4" class="data row2 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7b7af_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7b7af_row3_col0" class="data row3 col0" >1725-10-01</td>
#       <td id="T_7b7af_row3_col1" class="data row3 col1" >149046</td>
#       <td id="T_7b7af_row3_col2" class="data row3 col2" >nome</td>
#       <td id="T_7b7af_row3_col3" class="data row3 col3" >Bernardo José de Azevedo</td>
#       <td id="T_7b7af_row3_col4" class="data row3 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7b7af_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7b7af_row4_col0" class="data row4 col0" >1725-10-01</td>
#       <td id="T_7b7af_row4_col1" class="data row4 col1" >149046</td>
#       <td id="T_7b7af_row4_col2" class="data row4 col2" >nome</td>
#       <td id="T_7b7af_row4_col3" class="data row4 col3" >Bernardo José de Azevedo Vieira</td>
#       <td id="T_7b7af_row4_col4" class="data row4 col4" >Bernardo José de Azevedo, vide Vieira</td>
#     </tr>
#     <tr>
#       <th id="T_7b7af_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7b7af_row5_col0" class="data row5 col0" >1725-10-01</td>
#       <td id="T_7b7af_row5_col1" class="data row5 col1" >149046</td>
#       <td id="T_7b7af_row5_col2" class="data row5 col2" >nome-nota</td>
#       <td id="T_7b7af_row5_col3" class="data row5 col3" >padre</td>
#       <td id="T_7b7af_row5_col4" class="data row5 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7b7af_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7b7af_row6_col0" class="data row6 col0" >1725-10-01</td>
#       <td id="T_7b7af_row6_col1" class="data row6 col1" >149046</td>
#       <td id="T_7b7af_row6_col2" class="data row6 col2" >nome-pai</td>
#       <td id="T_7b7af_row6_col3" class="data row6 col3" >José de Azevedo Vieira</td>
#       <td id="T_7b7af_row6_col4" class="data row6 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7b7af_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7b7af_row7_col0" class="data row7 col0" >1725-10-01</td>
#       <td id="T_7b7af_row7_col1" class="data row7 col1" >149046</td>
#       <td id="T_7b7af_row7_col2" class="data row7 col2" >nome-vide</td>
#       <td id="T_7b7af_row7_col3" class="data row7 col3" >Vieira</td>
#       <td id="T_7b7af_row7_col4" class="data row7 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7b7af_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7b7af_row8_col0" class="data row8 col0" >1725-10-01</td>
#       <td id="T_7b7af_row8_col1" class="data row8 col1" >149046</td>
#       <td id="T_7b7af_row8_col2" class="data row8 col2" >padre</td>
#       <td id="T_7b7af_row8_col3" class="data row8 col3" >sim</td>
#       <td id="T_7b7af_row8_col4" class="data row8 col4" >padre</td>
#     </tr>
#     <tr>
#       <th id="T_7b7af_level0_row9" class="row_heading level0 row9" >9</th>
#       <

# %%
vide_plus.loc['217701']
# Out:
# name                                         José de Santo António
# sex                                                              m
# nome-vide                                                Lencastre
# nome-geografico                                           ***NA***
# faculdade                                                      NaN
# faculdade.date                                                 NaN
# faculdade.obs                                                  NaN
# nome-pai                                                       NaN
# uc-entrada                                              0000-00-00
# uc-saida                                                0000-00-00
# uc-saida.date                                           0000-00-00
# uc-saida.obs                                                  None
# rec_type                                                       see
# loookup
# vide_type                                                      add
# lookup                             José de Santo António Lencastre
# name_sp                                         José Santo António
# lookup_sp                             José Santo António Lencastre
# sort_key           José Santo António-José Santo António Lencastre
# match_error                                                  False
# match_obs                                                      NaN
# Name: 217701, dtype: object

# %%
# set back the missing nome_geografico to null
no_geo_filter = vide_plus['nome-geografico'] == '***NA***'
vide_plus.loc[no_geo_filter,'nome-geografico'] = np.nan
print(len(vide_plus[vide_plus['nome-geografico'] == '***NA***']))
vide_plus.info()
# Out:
# 0
# <class 'pandas.core.frame.DataFrame'>
# Index: 9438 entries, 198423 to 230315
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             9438 non-null   object
#  1   sex              9438 non-null   object
#  2   nome-vide        9286 non-null   object
#  3   nome-geografico  8916 non-null   object
#  4   faculdade        4872 non-null   object
#  5   faculdade.date   4872 non-null   object
#  6   faculdade.obs    4853 non-null   object
#  7   nome-pai         3547 non-null   object
#  8   uc-entrada       9438 non-null   object
#  9   uc-saida         9438 non-null   object
#  10  uc-saida.date    9438 non-null   object
#  11  uc-saida.obs     0 non-null      object
#  12  rec_type         9438 non-null   object
#  13  loookup          9438 non-null   object
#  14  vide_type        9438 non-null   object
#  15  lookup           9438 non-null   object
#  16  name_sp          9438 non-null   object
#  17  lookup_sp        9438 non-null   object
#  18  sort_key         9438 non-null   object
#  19  match_error      9438 non-null   bool
#  20  match_obs        205 non-null    object
# dtypes: bool(1), object(20)
# memory usage: 1.8+ MB

# %% [markdown]
# Why:
# * 230791	Abrantes	Manuel Fernandes da Silveira	None	Manuel Fernandes da Silveira	Fernandes da Silveira	0000-00-00	NaN
# * 230756	Abrantes	Manuel Fernandes da Silveira	None	Manuel da Silveira	Manuel Fernandes da Silveira	1598-10-12	Leis

# %% [markdown]
# ### Merge the result of the two methods, check for errors, again
#
# Since we are mixing matches from two different methods it can happen that, together, they introduce new errrors,  specially transitive matches.

# %%
import networkx as nx
method = 'data'  # short for merged methods

matched_rand_pairs = match_records['matched_pairs']['random']
matched_seq_pairs = match_records['matched_pairs']['sequential']
matched_pairs = list(set(matched_rand_pairs + matched_seq_pairs))
print("Number of matched pairs (union of both methods)  :",len(matched_pairs))
match_records['matched_pairs'][method] = matched_pairs
match_info.loc['matched_pairs',method] = len(matched_pairs)

rec_errors_seq = match_records['records_error']['sequential']
rec_errors_rand = match_records['records_error']['random']


# And now filter, this is necessary because error detected are different in each method
matched_multiple = []
matched_single = []

origins = [o for (o,d,t) in matched_pairs]
destinations = [d for (o,d,t) in matched_pairs]
rec_in_matches = origins + destinations
for i in rec_in_matches:
    c = rec_in_matches.count(i)
    if i == '172681':
        pass
    if c >2:
        matched_multiple.append(i)
    elif c == 1:
        matched_single.append(i)
  
        
matched_multiple = list(set(matched_multiple))
matched_single = list(set(matched_single))
print("Number of matches random              :",len(matched_rand_pairs))
print("Number of matches sequential          :",len(matched_seq_pairs))
print("Number of matches both                :",len(matched_pairs))
print("Records with more than two matches    :", len(matched_multiple))
print("Records with just one match           :", len(matched_single))

# alternative method, perhaps more informative:
pairs_to_check = matched_pairs
print()
print("The following pairs have to reverse match:")
asymmetric_pairs = []
for (o,d,t) in matched_pairs:
    if t == 'see-aka':
        rt = 'aka-see'
    elif t == 'aka-see':
        rt = 'see-aka'
    else:
        rt = t
    if (d,o,rt) not in matched_pairs:
        asymmetric_pairs.append((o,d,t))
        print((o,d,t))

# now test for transitivity
G = nx.Graph()
simple_pairs = [(o,d) for (o,d,t) in matched_pairs]
G.add_edges_from(simple_pairs)
transitive  = [c for c in nx.connected_components(G) if len(c) > 2]

# number of records in ambiguous matchesamb_records = [item for amb in transitive for item in amb]
namb_records = len(set(amb_records))
print("Records in ambiguous matches          :", namb_records)

match_records['records_transitive'][method] = list(amb_records)
match_info.loc['records_transitive'][method] = namb_records

for amb in transitive:
    print(amb)
print("Are multiple in ambiguous             :",set(matched_multiple).issubset(set(amb_records)))

vide_plus.loc[matched_single,'match_error'] = False
vide_plus.loc[matched_single,'match_obs'] = "W01-Single match (asymmetric) "+method

vide_plus.loc[matched_multiple,'match_error'] = True
vide_plus.loc[matched_multiple,'match_obs'] = "E03-Multiple match"+method

vide_plus.loc[amb_records,'match_error'] = True
vide_plus.loc[amb_records,'match_obs'] = "E04-Ambiguity in match "+method

# do a new list of records in error
rec_errors = set(amb_records).union(matched_multiple)

records = set(rec_in_matches)
rec_ok = records.difference(rec_errors)

print("Records involved in matches           :", len(records))
print("Records matched without errors        :", len(rec_ok))
print("Records matched with errors           :", len(rec_errors))

match_records['records_error'][method] = list(rec_errors)
match_info.loc['records_error'][method] = len(rec_errors)
match_records['records_matched_ok'][method] = list(rec_ok)
match_info.loc['records_matched_ok'][method] = len(rec_ok)
match_records['records_matched'][method] = list(records)
match_info.loc['records_matched'][method] = len(records)

aka = match_records['aka']['data']
aka_ok = set(aka).intersection(rec_ok)
see = match_records['see']['data']
see_ok = set(see).intersection(rec_ok)
match_info.loc['aka_matched_ok'][method] = len(aka_ok)
match_records['aka_matched_ok'][method] = list(aka_ok)
match_info.loc['see_matched_ok'][method] = len(see_ok)
match_records['see_matched_ok'][method] = list(see_ok)

pairs_ok = set([(o,d,t) for (o,d,t) in match_records['matched_pairs'][method]
                                                        if o not in rec_errors and d not in rec_errors])
match_records['matched_pairs_ok'][method] = list(pairs_ok)
match_info.loc['matched_pairs_ok'][method] = len(pairs_ok)
# Out:
# Number of matched pairs (union of both methods)  : 3818
# Number of matches random              : 3804
# Number of matches sequential          : 3644
# Number of matches both                : 3818
# Records with more than two matches    : 38
# Records with just one match           : 76
#
# The following pairs have to reverse match:
# ('241026', '241012', 'see-aka')
# ('177796', '184419', 'aka-see')
# ('234767', '203369', 'see-aka')
# ('212796', '242752', 'see-aka')
# ('225717', '173224', 'aka-see')
# ('164227', '248237', 'see-aka')
# ('223100', '252345', 'see-aka')
# ('195505', '160216', 'see-aka')
# ('221053', '207054', 'see-aka')
# ('209320', '151354', 'see-aka')
# ('181367', '214929', 'see-aka')
# ('206278', '151170', 'see-aka')
# ('130534', '163482', 'see-aka')
# ('206505', '158689', 'see-aka')
# ('182659', '233550', 'aka-see')
# ('186417', '238066', 'see-see')
# ('166987', '163021', 'aka-see')
# ('203487', '206151', 'see-see')
# ('199474', '193320', 'see-aka')
# ('136704', '227086', 'see-see')
# ('204089', '196842', 'see-aka')
# ('184271', '239847', 'see-aka')
# ('129384', '139423', 'see-aka')
# ('134006', '247449', 'see-aka')
# ('235056', '142554', 'see-aka')
# ('233397', '230482', 'see-aka')
# ('148963', '182602', 'see-aka')
# ('230791', '230756', 'see-aka')
# ('205772', '209662', 'see-aka')
# ('200713', '226997', 'aka-see')
# ('251029', '131947', 'see-aka')
# ('186417', '132440', 'see-aka')
# ('140367', '208712', 'see-aka')
# ('128114', '211581', 'see-aka')
# ('149251', '179399', 'see-aka')
# ('203487', '161932', 'see-aka')
# ('241346', '197630', 'see-aka')
# ('198768', '188508', 'aka-see')
# ('256874', '141866', 'see-aka')
# ('185191', '181415', 'see-aka')
# ('194373', '128907', 'see-aka')
# ('252478', '245318', 'see-aka')
# Records in ambiguous matches          : 116
# {'238842', '233035', '238845'}
# {'142386', '142388', '171377'}
# {'160196', '160158', '152482'}
# {'266130', '146547', '266114'}
# {'194771', '201515', '316381'}
# {'226697', '226704', '195422'}
# {'132440', '238066', '186417', '186310', '186309'}
# {'208873', '243481', '208877'}
# {'152890', '243711', '152894'}
# {'238488', '238487', '226966'}
# {'242102', '238985', '242104'}
# {'233838', '206540', '206536'}
# {'222156', '189891', '189900'}
# {'240879', '147410', '240882'}
# {'183306', '235009', '183307'}
# {'164823', '166756', '164824'}
# {'169888', '169890', '214147'}
# {'153316', '139166', '139146'}
# {'169757', '162809', '136283'}
# {'172677', '172681', '190285'}
# {'221393', '233103', '233094'}
# {'143426', '175731', '175730'}
# {'203487', '206151', '161932', '255769', '203494'}
# {'210090', '232128', '232079'}
# {'253465', '212857', '252907'}
# {'134102', '191654', '191659'}
# {'254410', '201728', '201733'}
# {'233525', '233524', '245070'}
# {'193320', '199474', '199475'}
# {'231025', '169177', '231024'}
# {'146206', '245531', '245530'}
# {'222615', '172529', '222621'}
# {'251536', '216361', '251534'}
# {'239516', '230251', '230250'}
# {'278765', '181236', '178312'}
# {'171093', '248881', '171095'}
# {'211703', '168662', '211706', '211704'}
# Are multiple in ambiguous             : True
# Records involved in matches           : 3818
# Records matched without errors        : 3702
# Records matched with errors           : 116

# %% [markdown]
# Detect asymmetries in matches with no errors (asymmetries are not considered errors)

# %%
method = 'data'  # short for merged methods

pairs_ok = match_records['matched_pairs_ok'][method]
# pairs 
pairs_see_aka = [(o,d,mtype) for (o,d,mtype) in pairs_ok if mtype == 'see-aka']
pairs_aka_see = [(o,d,mtype) for (o,d,mtype) in pairs_ok if mtype == 'aka-see']
pairs_aka_aka = [(o,d,mtype) for (o,d,mtype) in pairs_ok if mtype == 'aka-aka']
pairs_see_see = [(o,d,mtype) for (o,d,mtype) in pairs_ok if mtype == 'see-see']

aka_in_see_aka = [d for (o,d,mtype) in pairs_ok if mtype == 'see-aka']
aka_in_aka_see = [o for (o,d,mtype) in pairs_ok if mtype == 'aka-see']
asymmetry_aka = sorted(list(set(aka_in_see_aka) ^ set(aka_in_aka_see)))

print("Asymmetry for aka:", asymmetry_aka )
print("N Asymmetry for aka:", len(asymmetry_aka) )

see_in_see_aka = [o for (o,d,mtype) in pairs_ok if mtype == 'see-aka']
see_in_aka_see = [d for (o,d,mtype) in pairs_ok if mtype == 'aka-see']
asymmetry_see = sorted(list(set(see_in_see_aka) ^ set(see_in_aka_see)))

print("Asymmetry for see:", asymmetry_see )
print("N Asymmetry for see:", len(asymmetry_see))

# alternative method, perhaps more informative:
print()
pairs_to_check = pairs_ok
print("Asymmetric matches: for each match bellow the reverse one was not found")
asymmetric_pairs = []
for (o,d,t) in pairs_to_check:
    if t == 'see-aka':
        rt = 'aka-see'
    elif t == 'aka-see':
        rt = 'see-aka'
    else:
        rt = t
    if (d,o,rt) not in pairs_to_check:
        asymmetric_pairs.append((o,d,t))
        print((o,d,t))

asymmetric_records = set([o for (o,d,t) in asymmetric_pairs] + [d for (o,d,t) in asymmetric_pairs])
print()

match_info.loc['records_asymmetric',method] = len(asymmetric_records)
match_records['records_asymmetric'][method] = list(asymmetric_records)
# records
rec_matched = set([id for (id,d,t) in pairs_ok]+
                  [id for (o,id,t) in pairs_ok])
rec_see_aka = set([id for (id,d,t) in pairs_see_aka])
rec_aka_see = set([id for (o,id,t) in pairs_aka_see])
rec_see_see = set([id for (id,d,t) in pairs_see_see] +
                  [id for (o,id,t) in pairs_see_see])
rec_aka_aka = set([id for (id,d,t) in pairs_aka_aka] +
                  [id for (o,id,t) in pairs_aka_aka])

match_records['records_see_aka'][method] = list(rec_see_aka)
match_records['records_aka_see'][method] = list(rec_aka_see)
match_records['records_aka_aka'][method] = list(rec_aka_aka)
match_records['records_see_see'][method] = list(rec_see_see)

match_info.loc['records_see_aka'][method] = len(rec_see_aka)
match_info.loc['records_aka_see'][method] = len(rec_aka_see)
match_info.loc['records_aka_aka'][method] = len(rec_aka_aka)
match_info.loc['records_see_see'][method] = len(rec_see_see)

# new
match_info.loc['aka_matched'][method] = len(rec_aka_see.union(rec_aka_aka))
match_records['aka_matched'][method] = list(rec_aka_see.union(rec_aka_aka))
match_info.loc['see_matched'][method] = len(rec_see_aka.union(rec_see_see))
match_records['see_matched'][method] = list(rec_see_aka.union(rec_see_see))

matched_rand_df = pd.DataFrame(pairs_ok, columns=['from','to','type'])
matched_rand_df.groupby('type').count()
# Out:
# Asymmetry for aka: ['128907', '131947', '139423', '141866', '142554', '151170', '151354', '158689', '160216', '163482', '166987', '177796', '179399', '181415', '182602', '182659', '196842', '197630', '198768', '200713', '203369', '207054', '208712', '209662', '211581', '214929', '225717', '230482', '230756', '239847', '241012', '242752', '245318', '247449', '248237', '252345']
# N Asymmetry for aka: 36
# Asymmetry for see: ['128114', '129384', '130534', '134006', '140367', '148963', '149251', '163021', '164227', '173224', '181367', '184271', '184419', '185191', '188508', '194373', '195505', '204089', '205772', '206278', '206505', '209320', '212796', '221053', '223100', '226997', '230791', '233397', '233550', '234767', '235056', '241026', '241346', '251029', '252478', '256874']
# N Asymmetry for see: 36
#
# Asymmetric matches: for each match bellow the reverse one was not found
# ('241026', '241012', 'see-aka')
# ('177796', '184419', 'aka-see')
# ('234767', '203369', 'see-aka')
# ('212796', '242752', 'see-aka')
# ('225717', '173224', 'aka-see')
# ('164227', '248237', 'see-aka')
# ('223100', '252345', 'see-aka')
# ('195505', '160216', 'see-aka')
# ('221053', '207054', 'see-aka')
# ('209320', '151354', 'see-aka')
# ('181367', '214929', 'see-aka')
# ('206278', '151170', 'see-aka')
# ('130534', '163482', 'see-aka')
# ('206505', '158689', 'see-aka')
# ('182659', '233550', 'aka-see')
# ('166987', '163021', 'aka-see')
# ('136704', '227086', 'see-see')
# ('204089', '196842', 'see-aka')
# ('184271', '239847', 'see-aka')
# ('129384', '139423', 'see-aka')
# ('134006', '247449', 'see-aka')
# ('235056', '142554', 'see-aka')
# ('233397', '230482', 'see-aka')
# ('148963', '182602', 'see-aka')
# ('230791', '230756', 'see-aka')
# ('205772', '209662', 'see-aka')
# ('200713', '226997', 'aka-see')
# ('251029', '131947', 'see-aka')
# ('140367', '208712', 'see-aka')
# ('128114', '211581', 'see-aka')
# ('149251', '179399', 'see-aka')
# ('241346', '197630', 'see-aka')
# ('198768', '188508', 'aka-see')
# ('256874', '141866', 'see-aka')
# ('185191', '181415', 'see-aka')
# ('194373', '128907', 'see-aka')
# ('252478', '245318', 'see-aka')
#          from    to
# type
# aka-aka   188   188
# aka-see  1722  1722
# see-aka  1746  1746
# see-see     9     9

# %%
match_info.fillna("")
# Out:
#                     data sequential random
# aka                 3062
# aka_fac             3035
# aka_geo             2973
# aka_matched         1910       1913   1970
# aka_matched_ok      1940       1907   1897
# aka_pai             1619
# matched_pairs       3818       3644   3804
# matched_pairs_ok    3665       3628   3614
# nodate              5763
# nodate_novide        141
# nodate_novide        141
# records_aka_aka      188        200    216
# records_aka_see     1722       1713   1754
# records_asymmetric    74          0     76
# records_error        116         12    190
# records_matched     3818       3640   3804
# records_matched_ok  3702       3628   3614
# records_see_aka     1746       1713   1781
# records_see_see       10         14     24
# records_transitive   116         12    116
# see                 5704
# see_fac             1378
# see_geo             5274
# see_matched         1756       1727   1796
# see_matched_ok      1762       1721   1717
# see_pai             1569
# vide                8625
# vide_plus           8766

# %% [markdown]
# ##### Check role of no date novide records in assymetries matches
#
# Since these records have no "vide" expression they do not generate the symmetric name forookup.

# %%
see_with_no_vide = set(match_records['vide_plus']['data']) - set(match_records['vide']['data'])
print("Number of records with see and no vide: ",len(see_with_no_vide))
asymmetric_see_no_vide = list(set(asymmetric_records).intersection(see_with_no_vide))
print("See no vide part in asymmetric matches: ",len(asymmetric_see_no_vide),set(asymmetric_records).intersection(see_with_no_vide))
# Out:
# Number of records with see and no vide:  141
# See no vide part in asymmetric matches:  22 {'181367', '251029', '195505', '185191', '252478', '209320', '140367', '134006', '149251', '184271', '129384', '256874', '194373', '204089', '130534', '233397', '234767', '164227', '223100', '128114', '148963', '136704'}

# %% [markdown]
# ##### Check asymmetric pairs

# %%
match_list = asymmetric_pairs

pd.set_option('display.max_rows',250)

no_show=['código-de-referência','data-do-registo','url','faculdade.ano','naturalidade.ano',
         'matricula-faculdade.ano','nome-apelido','nome-primeiro','nome-geografico.ano',
         'grau.ano','matricula-outra.ano','nome-geografico','instituta.ano']

show_only = 6
for (o,d,t) in match_list[:show_only]:
    print(o,d,t)
    display_group_attributes([o,d],
                             header_cols=['uc-entrada','name','nome-vide','naturalidade','faculdade','nome-pai'],
                             exclude_attributes=no_show,
                             sort_attributes=['date','type','value'],
                             cmap_name='Pastel1')
# Out:
# 241026 241012 see-aka
# <style type="text/css">
# #T_b454e_row0_col0, #T_b454e_row0_col1, #T_b454e_row0_col2, #T_b454e_row0_col3, #T_b454e_row0_col4, #T_b454e_row0_col5, #T_b454e_row0_col6 {
#   background-color: #fbb4ae;
# }
# #T_b454e_row1_col0, #T_b454e_row1_col1, #T_b454e_row1_col2, #T_b454e_row1_col3, #T_b454e_row1_col4, #T_b454e_row1_col5, #T_b454e_row1_col6 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_b454e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b454e_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_b454e_level0_col1" class="col_heading level0 col1" >uc-entrada</th>
#       <th id="T_b454e_level0_col2" class="col_heading level0 col2" >name</th>
#       <th id="T_b454e_level0_col3" class="col_heading level0 col3" >nome-vide</th>
#       <th id="T_b454e_level0_col4" class="col_heading level0 col4" >naturalidade</th>
#       <th id="T_b454e_level0_col5" class="col_heading level0 col5" >faculdade</th>
#       <th id="T_b454e_level0_col6" class="col_heading level0 col6" >nome-pai</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b454e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b454e_row0_col0" class="data row0 col0" >241026</td>
#       <td id="T_b454e_row0_col1" class="data row0 col1" >0000-00-00</td>
#       <td id="T_b454e_row0_col2" class="data row0 col2" >Luís Alves Mergulhão</td>
#       <td id="T_b454e_row0_col3" class="data row0 col3" >Luís Alves Mergulhão</td>
#       <td id="T_b454e_row0_col4" class="data row0 col4" >Lisboa</td>
#       <td id="T_b454e_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_b454e_row0_col6" class="data row0 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b454e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b454e_row1_col0" class="data row1 col0" >241012</td>
#       <td id="T_b454e_row1_col1" class="data row1 col1" >1601-10-29</td>
#       <td id="T_b454e_row1_col2" class="data row1 col2" >Luís de Mergulhão</td>
#       <td id="T_b454e_row1_col3" class="data row1 col3" >Luís Alves Mergulhão</td>
#       <td id="T_b454e_row1_col4" class="data row1 col4" >Lisboa</td>
#       <td id="T_b454e_row1_col5" class="data row1 col5" >Leis</td>
#       <td id="T_b454e_row1_col6" class="data row1 col6" >Diogo Mergulhão</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_44703_row0_col0, #T_44703_row0_col1, #T_44703_row0_col2, #T_44703_row0_col3, #T_44703_row0_col4, #T_44703_row1_col0, #T_44703_row1_col1, #T_44703_row1_col2, #T_44703_row1_col3, #T_44703_row1_col4, #T_44703_row2_col0, #T_44703_row2_col1, #T_44703_row2_col2, #T_44703_row2_col3, #T_44703_row2_col4, #T_44703_row3_col0, #T_44703_row3_col1, #T_44703_row3_col2, #T_44703_row3_col3, #T_44703_row3_col4, #T_44703_row4_col0, #T_44703_row4_col1, #T_44703_row4_col2, #T_44703_row4_col3, #T_44703_row4_col4, #T_44703_row5_col0, #T_44703_row5_col1, #T_44703_row5_col2, #T_44703_row5_col3, #T_44703_row5_col4 {
#   background-color: #fbb4ae;
# }
# #T_44703_row6_col0, #T_44703_row6_col1, #T_44703_row6_col2, #T_44703_row6_col3, #T_44703_row6_col4, #T_44703_row7_col0, #T_44703_row7_col1, #T_44703_row7_col2, #T_44703_row7_col3, #T_44703_row7_col4, #T_44703_row8_col0, #T_44703_row8_col1, #T_44703_row8_col2, #T_44703_row8_col3, #T_44703_row8_col4, #T_44703_row9_col0, #T_44703_row9_col1, #T_44703_row9_col2, #T_44703_row9_col3, #T_44703_row9_col4, #T_44703_row10_col0, #T_44703_row10_col1, #T_44703_row10_col2, #T_44703_row10_col3, #T_44703_row10_col4, #T_44703_row11_col0, #T_44703_row11_col1, #T_44703_row11_col2, #T_44703_row11_col3, #T_44703_row11_col4, #T_44703_row12_col0, #T_44703_row12_col1, #T_44703_row12_col2, #T_44703_row12_col3, #T_44703_row12_col4, #T_44703_row13_col0, #T_44703_row13_col1, #T_44703_row13_col2, #T_44703_row13_col3, #T_44703_row13_col4, #T_44703_row14_col0, #T_44703_row14_col1, #T_44703_row14_col2, #T_44703_row14_col3, #T_44703_row14_col4, #T_44703_row15_col0, #T_44703_row15_col1, #T_44703_row15_col2, #T_44703_row15_col3, #T_44703_row15_col4, #T_
row5_col4" class="data row5 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_44703_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_44703_row6_col0" class="data row6 col0" >1601-10-29</td>
#       <td id="T_44703_row6_col1" class="data row6 col1" >241012</td>
#       <td id="T_44703_row6_col2" class="data row6 col2" >faculdade</td>
#       <td id="T_44703_row6_col3" class="data row6 col3" >Leis</td>
#       <td id="T_44703_row6_col4" class="data row6 col4" >Leis</td>
#     </tr>
#     <tr>
#       <th id="T_44703_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_44703_row7_col0" class="data row7 col0" >1601-10-29</td>
#       <td id="T_44703_row7_col1" class="data row7 col1" >241012</td>
#       <td id="T_44703_row7_col2" class="data row7 col2" >instituta</td>
#       <td id="T_44703_row7_col3" class="data row7 col3" >1601-10-29</td>
#       <td id="T_44703_row7_col4" class="data row7 col4" >29.10.1601 1601-10-29</td>
#     </tr>
#     <tr>
#       <th id="T_44703_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_44703_row8_col0" class="data row8 col0" >1601-10-29</td>
#       <td id="T_44703_row8_col1" class="data row8 col1" >241012</td>
#       <td id="T_44703_row8_col2" class="data row8 col2" >naturalidade</td>
#       <td id="T_44703_row8_col3" class="data row8 col3" >Lisboa</td>
#       <td id="T_44703_row8_col4" class="data row8 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_44703_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_44703_row9_col0" class="data row9 col0" >1601-10-29</td>
#       <td id="T_44703_row9_col1" class="data row9 col1" >241012</td>
#       <td id="T_44703_row9_col2" class="data row9 col2" >nome</td>
#       <td id="T_44703_row9_col3" class="data row9 col3" >Luís Alves Mergulhão</td>
#       <td id="T_44703_row9_col4" class="data row9 col4" >Luís de Mergulhão, vide Luís Alves Mergulhão</td>
#     </tr>
#     <tr>
#       <th id="T_44703_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_44703_row10_col0" class="data row10 col0" >1601-10-29</td>
#       <td id="T_44703_row10_col1" class="data row10 col1" >241012</td>
#       <td id="T_44703_row10_col2" class="data row10 col2" >nome</td>
#       <td id="T_44703_row1
# 177796 184419 aka-see
# <style type="text/css">
# #T_3fd4a_row0_col0, #T_3fd4a_row0_col1, #T_3fd4a_row0_col2, #T_3fd4a_row0_col3, #T_3fd4a_row0_col4, #T_3fd4a_row0_col5, #T_3fd4a_row0_col6 {
#   background-color: #fbb4ae;
# }
# #T_3fd4a_row1_col0, #T_3fd4a_row1_col1, #T_3fd4a_row1_col2, #T_3fd4a_row1_col3, #T_3fd4a_row1_col4, #T_3fd4a_row1_col5, #T_3fd4a_row1_col6 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_3fd4a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3fd4a_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_3fd4a_level0_col1" class="col_heading level0 col1" >uc-entrada</th>
#       <th id="T_3fd4a_level0_col2" class="col_heading level0 col2" >name</th>
#       <th id="T_3fd4a_level0_col3" class="col_heading level0 col3" >nome-vide</th>
#       <th id="T_3fd4a_level0_col4" class="col_heading level0 col4" >naturalidade</th>
#       <th id="T_3fd4a_level0_col5" class="col_heading level0 col5" >faculdade</th>
#       <th id="T_3fd4a_level0_col6" class="col_heading level0 col6" >nome-pai</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3fd4a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3fd4a_row0_col0" class="data row0 col0" >184419</td>
#       <td id="T_3fd4a_row0_col1" class="data row0 col1" >0000-00-00</td>
#       <td id="T_3fd4a_row0_col2" class="data row0 col2" >Domingos Marques</td>
#       <td id="T_3fd4a_row0_col3" class="data row0 col3" >Giraldes</td>
#       <td id="T_3fd4a_row0_col4" class="data row0 col4" >Idanha-a-Nova</td>
#       <td id="T_3fd4a_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_3fd4a_row0_col6" class="data row0 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3fd4a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3fd4a_row1_col0" class="data row1 col0" >177796</td>
#       <td id="T_3fd4a_row1_col1" class="data row1 col1" >1658-10-15</td>
#       <td id="T_3fd4a_row1_col2" class="data row1 col2" >Domingos Marques Giraldes</td>
#       <td id="T_3fd4a_row1_col3" class="data row1 col3" >Giraldes</td>
#       <td id="T_3fd4a_row1_col4" class="data row1 col4" >Idanha-a-Nova</td>
#       <td id="T_3fd4a_row1_col5" class="data row1 col5" >Cânones</td>
#       <td id="T_3fd4a_row1_col6" class="data row1 col6" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_5d08e_row0_col0, #T_5d08e_row0_col1, #T_5d08e_row0_col2, #T_5d08e_row0_col3, #T_5d08e_row0_col4, #T_5d08e_row1_col0, #T_5d08e_row1_col1, #T_5d08e_row1_col2, #T_5d08e_row1_col3, #T_5d08e_row1_col4, #T_5d08e_row2_col0, #T_5d08e_row2_col1, #T_5d08e_row2_col2, #T_5d08e_row2_col3, #T_5d08e_row2_col4, #T_5d08e_row3_col0, #T_5d08e_row3_col1, #T_5d08e_row3_col2, #T_5d08e_row3_col3, #T_5d08e_row3_col4, #T_5d08e_row4_col0, #T_5d08e_row4_col1, #T_5d08e_row4_col2, #T_5d08e_row4_col3, #T_5d08e_row4_col4, #T_5d08e_row5_col0, #T_5d08e_row5_col1, #T_5d08e_row5_col2, #T_5d08e_row5_col3, #T_5d08e_row5_col4 {
#   background-color: #fbb4ae;
# }
# #T_5d08e_row6_col0, #T_5d08e_row6_col1, #T_5d08e_row6_col2, #T_5d08e_row6_col3, #T_5d08e_row6_col4, #T_5d08e_row7_col0, #T_5d08e_row7_col1, #T_5d08e_row7_col2, #T_5d08e_row7_col3, #T_5d08e_row7_col4, #T_5d08e_row8_col0, #T_5d08e_row8_col1, #T_5d08e_row8_col2, #T_5d08e_row8_col3, #T_5d08e_row8_col4, #T_5d08e_row9_col0, #T_5d08e_row9_col1, #T_5d08e_row9_col2, #T_5d08e_row9_col3, #T_5d08e_row9_col4, #T_5d08e_row10_col0, #T_5d08e_row10_col1, #T_5d08e_row10_col2, #T_5d08e_row10_col3, #T_5d08e_row10_col4, #T_5d08e_row11_col0, #T_5d08e_row11_col1, #T_5d08e_row11_col2, #T_5d08e_row11_col3, #T_5d08e_row11_col4, #T_5d08e_row12_col0, #T_5d08e_row12_col1, #T_5d08e_row12_col2, #T_5d08e_row12_col3, #T_5d08e_row12_col4, #T_5d08e_row13_col0, #T_5d08e_row13_col1, #T_5d08e_row13_col2, #T_5d08e_row13_col3, #T_5d08e_row13_col4, #T_5d08e_row14_col0, #T_5d08e_row14_col1, #T_5d08e_row14_col2, #T_5d08e_row14_col3, #T_5d08e_row14_col4, #T_5d08e_row15_col0, #T_5d08e_row15_col1, #T_5d08e_row15_col2, #T_5d08e_row15_col3, #T_5d08e_row15_col4, #T_5d08e_row16_col0, #T_5d08e_row16_col1, #T_5d08e_row16_col2, #T_5d08e_row16_col3, #T_5d08e_row16_col4, #T_5d08e_row17_col0, #T_5d08e_row17_col1, #T_5d08e_row17_col2, #T_5d08e_row17_col3, #T_5d08e_row17_col4, #T_5d08e_row18_col0, #T_5d08e_row18_col1, #T_5d08e_row18_col2, #T_5d08e_row18_col3, #T_5d08e_row18_col4, #T_5d08e_row19_col0, #T_5d08e_row19_col1, #T_5d08e_row19_col2, #T_5d08e_row19_col3, #T_5d08e_row19_col4, #T_5d08e_row20_col0, #T_5d08e_row20_col1, #T_5d08e_row20_col2, #T_5d08e_row20_col3, #T_5d08e_row20_col4, #T_5d08e_row21_col0, #T_5d08e_row21_col1, #T_5d08e_row21_col2, #T_5d08e_row21_col3, #T_5d08e_row21_col4, #T_5d08e_row22_col0, #T_5d08e_row22_col1, #T_5d08e_row22_col2, #T_5d08e_row22_col3, #T_5d08e_row22_col4, #T_5d08e_row23_col0, #T_5d08e_row23_col1, #T_5d08e_row23_col2, #T_5d08e_row23_col3, #T_5d08e_row23_col4 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_5d08e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5d08e_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_5d08e_level0_col1" class="col_heading level0 col1" >id</th>
#       <th id="T_5d08e_level0_col2" class="col_heading level0 col2" >type</th>
#       <th id="T_5d08e_level0_col3" class="col_heading level0 col3" >value</th>
#       <th id="T_5d08e_level0_col4" class="col_heading level0 col4" >attr_obs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5d08e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5d08e_row0_col0" class="data row0 col0" >0000-00-00</td>
#       <td id="T_5d08e_row0_col1" class="data row0 col1" >184419</td>
#       <td id="T_5d08e_row0_col2" class="data row0 col2" >naturalidade</td>
#       <td id="T_5d08e_row0_col3" class="data row0 col3" >Idanha-a-Nova</td>
#       <td id="T_5d08e_row0_col4" class="data row0 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_5d08e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5d08e_row1_col0" class="data row1 col0" >0000-00-00</td>
#       <td id="T_5d08e_row1_col1" class="data row1 col1" >184419</td>
#       <td id="T_5d08e_row1_col2" class="data row1 col2" >nome</td>
#       <td id="T_5d08e_row1_col3" class="data row1 col3" >Domingos Marques</td>
#       <td id="T_5d08e_row1_col4" class="data row1 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_5d08e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5d08e_row2_col0" class="data row2 col0" >0000-00-00</td>
#       <td id="T_5d08e_row2_col1" class="data row2 col1" >184419</td>
#       <td id="T_5d08e_row2_col2" class="data row2 col2" >nome</td>
#       <td id="T_5d08e_row2_col3" class="data row2 col3" >Domingos Marques Giraldes</td>
#       <td id="T_5d08e_row2_col4" class="data row2 col4" >Domingos Marques, vide Giraldes</td>
#     </tr>
#     <tr>
#       <th id="T_5d08e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5d08e_row3_col0" class="data row3 col0" >0000-00-00</td>
#       <td id="T_5d08e_row3_col1" class="data row3 col1" >184419</td>
#       <td id="T_5d08e_row3_col2" class="data row3 col2" >nome-vide</td>
#       <td id="T_5d08e_row3_col3" class="data row3 col3" >Giraldes</td>
#       <td id="T_5d08e_row3_col4" class="data row3 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_5d08e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5d08e_row4_col0" class="data row4 col0" >0000-00-00</td>
#       <td id="T_5d08e_row4_col1" class="data row4 col1" >184419</td>
#       <td id="T_5d08e_row4_col2" class="data row4 col2" >uc-entrada</td>
#       <td id="T_5d08e_row4_col3" class="data row4 col3" >0000-00-00</td>
#       <td id="T_5d08e_row4_col4" class="data row4 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_5d08e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5d08e_row5_col0" class="data row5 col0" >0000-00-00</td>
#       <td id="T_5d08e_row5_col1" class="data row5 col1" >184419</td>
#       <td id="T_5d08e_row5_col2" class="data row5 col2" >uc-saida</td>
#       <td id="T_5d08e_row5_col3" class="data row5 col3" >0000-00-00</td>
#       <td id="T_5d08e_row5_col4" class="data row5 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_5d08e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5d08e_row6_col0" class="data row6 col0" >1658-10-15</td>
#       <td id="T_5d08e_row6_col1" class="data row6 col1" >177796</td>
#       <td id="T_5d08e_row6_col2" class="data row6 col2" >faculdade</td>
#       <td id="T_5d08e_row6_col3" class="data row6 col3" >Cânones</td>
#       <td id="T_5d08e_row6_col4" class="data row6 col4" >Cânones</td>
#     </tr>
#     <tr>
#       <th id="T_5d08e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5d08e_row7_col0" class="data row7 col0" >1658-10-15</td>
#       <td id="T_5d08e_row7_col1" class="data row7 col1" >177796</td>
#       <td id="T_5d08e_row7_col2" class="data row7 col2" >instituta</td>
#       <td id="T_5d08e_row7_col3" class="data row7 col3" >1658-10-15</td>
#       <td id="T_5d08e_row7_col4" class="data row7 col4" >15.10.1658 1658-10-15</td>
#     </tr>
#     <tr>
#       <th id="T_5d08e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5d08e_row8_col0" class="data row8 col0" >1658-10-15</td>
#       <td id="T_5d08e_row8_col1" class="data row8 col1" >177796</td>
#       <td id="T_5d08e_row8_col2" class="data row8 col2" >naturalidade</td>
#       <td id="T_5d08e_row8_col3" class="data row8 col3" >Idanha-a-Nova</td>
#       <td id="T_5d08e_row8_col4" class="data row8 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_5d08e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5d08e_row9_col0" class="data row9 col0" >1658-10-15</td>
#       <td id="T_5d08e_row9_col1" class="data row9 col1" >177796</td>
#       <td id="T_5d08e_row9_col2" class="data row9 col2" >nome</td>
#       <td id="T_5d08e_row9_col3" class="data row9 col3" >Domingos Marques Giraldes</td>
#       <td id="T_5d08e_row9_col4" class="data row9 col4" >Domingos Marques Giraldes, vide Giraldes</td>
#     </tr>
#     <tr>
#       <th id="T_5d08e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5d08e_row10_col0" class="data row10 col0" >1658-10-15</td>
#       <td id="T_5d08e_row10_col1" class="data row10 col1" >177796</td>
#       <td id="T_5d08e_row10_col2" class="data row10 col2" >nome</td>
#       <td id="T_5d08e_row10_col3
# 234767 203369 see-aka
# <style type="text/css">
# #T_2e1fc_row0_col0, #T_2e1fc_row0_col1, #T_2e1fc_row0_col2, #T_2e1fc_row0_col3, #T_2e1fc_row0_col4, #T_2e1fc_row0_col5, #T_2e1fc_row0_col6 {
#   background-color: #fbb4ae;
# }
# #T_2e1fc_row1_col0, #T_2e1fc_row1_col1, #T_2e1fc_row1_col2, #T_2e1fc_row1_col3, #T_2e1fc_row1_col4, #T_2e1fc_row1_col5, #T_2e1fc_row1_col6 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_2e1fc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e1fc_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_2e1fc_level0_col1" class="col_heading level0 col1" >uc-entrada</th>
#       <th id="T_2e1fc_level0_col2" class="col_heading level0 col2" >name</th>
#       <th id="T_2e1fc_level0_col3" class="col_heading level0 col3" >nome-vide</th>
#       <th id="T_2e1fc_level0_col4" class="col_heading level0 col4" >naturalidade</th>
#       <th id="T_2e1fc_level0_col5" class="col_heading level0 col5" >faculdade</th>
#       <th id="T_2e1fc_level0_col6" class="col_heading level0 col6" >nome-pai</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e1fc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2e1fc_row0_col0" class="data row0 col0" >234767</td>
#       <td id="T_2e1fc_row0_col1" class="data row0 col1" >0000-00-00</td>
#       <td id="T_2e1fc_row0_col2" class="data row0 col2" >Francisco Leitão Pereira</td>
#       <td id="T_2e1fc_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_2e1fc_row0_col4" class="data row0 col4" >Índia</td>
#       <td id="T_2e1fc_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_2e1fc_row0_col6" class="data row0 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2e1fc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2e1fc_row1_col0" class="data row1 col0" >203369</td>
#       <td id="T_2e1fc_row1_col1" class="data row1 col1" >1550-10-10</td>
#       <td id="T_2e1fc_row1_col2" class="data row1 col2" >Francisco Leitão</td>
#       <td id="T_2e1fc_row1_col3" class="data row1 col3" >Pereira</td>
#       <td id="T_2e1fc_row1_col4" class="data row1 col4" >Índia, Goa</td>
#       <td id="T_2e1fc_row1_col5" class="data row1 col5" >Cânones</td>
#       <td id="T_2e1fc_row1_col6" class="data row1 col6" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_a8cb1_row0_col0, #T_a8cb1_row0_col1, #T_a8cb1_row0_col2, #T_a8cb1_row0_col3, #T_a8cb1_row0_col4, #T_a8cb1_row1_col0, #T_a8cb1_row1_col1, #T_a8cb1_row1_col2, #T_a8cb1_row1_col3, #T_a8cb1_row1_col4, #T_a8cb1_row2_col0, #T_a8cb1_row2_col1, #T_a8cb1_row2_col2, #T_a8cb1_row2_col3, #T_a8cb1_row2_col4, #T_a8cb1_row3_col0, #T_a8cb1_row3_col1, #T_a8cb1_row3_col2, #T_a8cb1_row3_col3, #T_a8cb1_row3_col4 {
#   background-color: #fbb4ae;
# }
# #T_a8cb1_row4_col0, #T_a8cb1_row4_col1, #T_a8cb1_row4_col2, #T_a8cb1_row4_col3, #T_a8cb1_row4_col4, #T_a8cb1_row5_col0, #T_a8cb1_row5_col1, #T_a8cb1_row5_col2, #T_a8cb1_row5_col3, #T_a8cb1_row5_col4, #T_a8cb1_row6_col0, #T_a8cb1_row6_col1, #T_a8cb1_row6_col2, #T_a8cb1_row6_col3, #T_a8cb1_row6_col4, #T_a8cb1_row7_col0, #T_a8cb1_row7_col1, #T_a8cb1_row7_col2, #T_a8cb1_row7_col3, #T_a8cb1_row7_col4, #T_a8cb1_row8_col0, #T_a8cb1_row8_col1, #T_a8cb1_row8_col2, #T_a8cb1_row8_col3, #T_a8cb1_row8_col4, #T_a8cb1_row9_col0, #T_a8cb1_row9_col1, #T_a8cb1_row9_col2, #T_a8cb1_row9_col3, #T_a8cb1_row9_col4, #T_a8cb1_row10_col0, #T_a8cb1_row10_col1, #T_a8cb1_row10_col2, #T_a8cb1_row10_col3, #T_a8cb1_row10_col4, #T_a8cb1_row11_col0, #T_a8cb1_row11_col1, #T_a8cb1_row11_col2, #T_a8cb1_row11_col3, #T_a8cb1_row11_col4, #T_a8cb1_row12_col0, #T_a8cb1_row12_col1, #T_a8cb1_row12_col2, #T_a8cb1_row12_col3, #T_a8cb1_row12_col4, #T_a8cb1_row13_col0, #T_a8cb1_row13_col1, #T_a8cb1_row13_col2, #T_a8cb1_row13_col3, #T_a8cb1_row13_col4, #T_a8cb1_row14_col0, #T_a8cb1_row14_col1, #T_a8cb1_row14_col2, #T_a8cb1_row14_col3, #T_a8cb1_row14_col4, #T_a8cb1_row15_col0, #T_a8cb1_row15_col1, #T_a8cb1_row15_col2, #T_a8cb1_row15_col3, #T_a8cb1_row15_col4 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_a8cb1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8cb1_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_a8cb1_level0_col1" class="col_heading level0 col1" >id</th>
#       <th id="T_a8cb1_level0_col2" class="col_heading level0 col2" >type</th>
#       <th id="T_a8cb1_level0_col3" class="col_heading level0 col3" >value</th>
#       <th id="T_a8cb1_level0_col4" class="col_heading level0 col4" >attr_obs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8cb1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a8cb1_row0_col0" class="data row0 col0" >0000-00-00</td>
#       <td id="T_a8cb1_row0_col1" class="data row0 col1" >234767</td>
#       <td id="T_a8cb1_row0_col2" class="data row0 col2" >naturalidade</td>
#       <td id="T_a8cb1_row0_col3" class="data row0 col3" >Índia</td>
#       <td id="T_a8cb1_row0_col4" class="data row0 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a8cb1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a8cb1_row1_col0" class="data row1 col0" >0000-00-00</td>
#       <td id="T_a8cb1_row1_col1" class="data row1 col1" >234767</td>
#       <td id="T_a8cb1_row1_col2" class="data row1 col2" >nome</td>
#       <td id="T_a8cb1_row1_col3" class="data row1 col3" >Francisco Leitão Pereira</td>
#       <td id="T_a8cb1_row1_col4" class="data row1 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a8cb1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a8cb1_row2_col0" class="data row2 col0" >0000-00-00</td>
#       <td id="T_a8cb1_row2_col1" class="data row2 col1" >234767</td>
#       <td id="T_a8cb1_row2_col2" class="data row2 col2" >uc-entrada</td>
#       <td id="T_a8cb1_row2_col3" class="data row2 col3" >0000-00-00</td>
#       <td id="T_a8cb1_row2_col4" class="data row2 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a8cb1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a8cb1_row3_col0" class="data row3 col0" >0000-00-00</td>
#       <td id="T_a8cb1_row3_col1" class="data row3 col1" >234767</td>
#       <td id="T_a8cb1_row3_col2" class="data row3 col2" >uc-saida</td>
#       <td id="T_a8cb1_row3_col3" class="data row3 col3" >0000-00-00</td>
#       <td id="T_a8cb1_row3_col4" class="data row3 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a8cb1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a8cb1_row4_col0" class="data row4 col0" >1550-10-10</td>
#       <td id="T_a8cb1_row4_col1" class="data row4 col1" >203369</td>
#       <td id="T_a8cb1_row4_col2" class="data row4 col2" >faculdade</td>
#       <td id="T_a8cb1_row4_col3" class="data row4 col3" >Cânones</td>
#       <td id="T_a8cb1_row4_col4" class="data row4 col4" >Faculdade inferida</td>
#     </tr>
#     <tr>
#       <th id="T_a8cb1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a8cb1_row5_col0" class="data row5 col0" >1550-10-10</td>
#       <td id="T_a8cb1_row5_col1" class="data row5 col1" >203369</td>
#       <td id="T_a8cb1_row5_col2" class="data row5 col2" >instituta</td>
#       <td id="T_a8cb1_row5_col3" class="data row5 col3" >1550-10-10</td>
#       <td id="T_a8cb1_row5_col4" class="data row5 col4" >"""
#                 1 curso em Instituta 10.10.1550: 2 meses em Cânones - Junho e Julho de 1556 - em Cânones, 10 meses de Outubro de 1557 a 31.07.1558 a 23.07.1559
#             """</td>
#     </tr>
#     <tr>
#       <th id="T_a8cb1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a8cb1_row6_col0" class="data row6 col0" >1550-10-10</td>
#       <td id="T_a8cb1_row6_col1" class="data row6 col1" >203369</td>
#       <td id="T_a8cb1_row6_col2" class="data row6 col2" >naturalidade</td>
#       <td id="T_a8cb1_row6_col3" class="data row6 col3" >Índia, Goa</td>
#       <td id="T_a8cb1_row6_col4" class="data row6 col4" >Índia (Goa)</td>
#     </tr>
#     <tr>
#       <th id="T_a8cb1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a8cb1_row7_col0" class="data row7 col0" >1550-10-10</td>
#       <td id="T_a8cb1_row7_col1" class="data row7 col1" >203369</td>
#       <td id="T_a8cb1_row7_col2" class="data row7 col2" >nome</td>
#       <td id="T_a8cb1_row7_col3" class="data row7 col3" >Francisco Leitão</td>
#       <td id="T_a8cb1_row7_col4" class="data row7 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a8cb1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a8cb1_row8_col0" class="data row8 col0" >1550-10-10</td>
#       <td id="T_a8cb1_row8_col1" class="data row8 col1" >203369</td>
#       <td id="T_a8cb1_row8_col2" class="data row8 col2" >nome</td>
#       <td id="T_a8cb1_row8_col3" class="data row8 col3" >Francisco Leitão Pereira</td>
#       <td id="T_a8cb1_row8_col4" class="data row8 col4" >Francisco Leitão, vide Pereira</td>
#     </tr>
#     <tr>
#       <th id="T_a8cb1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a8cb1_row9_col0" class="data row9 col0" >1550-10-10</td>
#       <td id="T_a8cb1_row9_col1" class="data row9 col1" >203369</td>
#       <td id="T_a8cb1_row9_col2" class="data row9 col2" >nome-vide</td>
#       <td id="T_a8cb1_row9_col3" class="data row9 col3" >Pereira</td>
#       <td id="T_a8cb1_row9_col4" class="data row9 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a8cb1_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a8cb1_row10_col0" class="data row10 col0" >1550-10-10</td>
#       <td id="T_a8cb1_row10_col1" class="data row10 col1" >203369</td>
#       <td id="T_a8cb1_row10_col2" class="data row10 col2" >uc-entrada</td>
#       <td id="T_a8cb1_row10_col3" class="data row10 col3" >1550-10-10</td>
#       <td id="T_a8cb1_row10_col4" class="data row10 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a8cb1_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a8cb1_row11_col0" class="data row11 col0" >1550-10-10</td>
#       <td id="T_a8cb1_row11_col1" class="data row11 col1" >203369</td>
#       <td id="T_a8cb1_row11_col2" class="data row11 col2" >uc-entrada.ano</td>
#       <td id="T_a8cb1_row11_col3" class="data row11 col3" >1550</td>
#       <td id="T_a8cb1_row11_col4" class="data row11 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a8cb1_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a8cb1_row12_col0" class=
# 212796 242752 see-aka
# <style type="text/css">
# #T_df249_row0_col0, #T_df249_row0_col1, #T_df249_row0_col2, #T_df249_row0_col3, #T_df249_row0_col4, #T_df249_row0_col5, #T_df249_row0_col6 {
#   background-color: #fbb4ae;
# }
# #T_df249_row1_col0, #T_df249_row1_col1, #T_df249_row1_col2, #T_df249_row1_col3, #T_df249_row1_col4, #T_df249_row1_col5, #T_df249_row1_col6, #T_df249_row2_col0, #T_df249_row2_col1, #T_df249_row2_col2, #T_df249_row2_col3, #T_df249_row2_col4, #T_df249_row2_col5, #T_df249_row2_col6 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_df249">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_df249_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_df249_level0_col1" class="col_heading level0 col1" >uc-entrada</th>
#       <th id="T_df249_level0_col2" class="col_heading level0 col2" >name</th>
#       <th id="T_df249_level0_col3" class="col_heading level0 col3" >nome-vide</th>
#       <th id="T_df249_level0_col4" class="col_heading level0 col4" >naturalidade</th>
#       <th id="T_df249_level0_col5" class="col_heading level0 col5" >faculdade</th>
#       <th id="T_df249_level0_col6" class="col_heading level0 col6" >nome-pai</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_df249_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_df249_row0_col0" class="data row0 col0" >212796</td>
#       <td id="T_df249_row0_col1" class="data row0 col1" >0000-00-00</td>
#       <td id="T_df249_row0_col2" class="data row0 col2" >Manuel Mendes</td>
#       <td id="T_df249_row0_col3" class="data row0 col3" >Mendes</td>
#       <td id="T_df249_row0_col4" class="data row0 col4" >Viana do Alentejo</td>
#       <td id="T_df249_row0_col5" class="data row0 col5" >Cânones</td>
#       <td id="T_df249_row0_col6" class="data row0 col6" >Manuel Mendes Pimentel</td>
#     </tr>
#     <tr>
#       <th id="T_df249_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_df249_row1_col0" class="data row1 col0" >242752</td>
#       <td id="T_df249_row1_col1" class="data row1 col1" >1612-10-27</td>
#       <td id="T_df249_row1_col2" class="data row1 col2" >Manuel Mendes Pimentel</td>
#       <td id="T_df249_row1_col3" class="data row1 col3" >Mendes</td>
#       <td id="T_df249_row1_col4" class="data row1 col4" >Viana do Alentejo</td>
#       <td id="T_df249_row1_col5" class="data row1 col5" >Cânones</td>
#       <td id="T_df249_row1_col6" class="data row1 col6" >Manuel Mendes Pimentel</td>
#     </tr>
#     <tr>
#       <th id="T_df249_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_df249_row2_col0" class="data row2 col0" >242752</td>
#       <td id="T_df249_row2_col1" class="data row2 col1" >1612-10-27</td>
#       <td id="T_df249_row2_col2" class="data row2 col2" >Manuel Mendes Pimentel</td>
#       <td id="T_df249_row2_col3" class="data row2 col3" >Mendes</td>
#       <td id="T_df249_row2_col4" class="data row2 col4" >Viana do Alentejo</td>
#       <td id="T_df249_row2_col5" class="data row2 col5" >Leis</td>
#       <td id="T_df249_row2_col6" class="data row2 col6" >Manuel Mendes Pimentel</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_c4e71_row0_col0, #T_c4e71_row0_col1, #T_c4e71_row0_col2, #T_c4e71_row0_col3, #T_c4e71_row0_col4, #T_c4e71_row1_col0, #T_c4e71_row1_col1, #T_c4e71_row1_col2, #T_c4e71_row1_col3, #T_c4e71_row1_col4, #T_c4e71_row2_col0, #T_c4e71_row2_col1, #T_c4e71_row2_col2, #T_c4e71_row2_col3, #T_c4e71_row2_col4, #T_c4e71_row3_col0, #T_c4e71_row3_col1, #T_c4e71_row3_col2, #T_c4e71_row3_col3, #T_c4e71_row3_col4, #T_c4e71_row4_col0, #T_c4e71_row4_col1, #T_c4e71_row4_col2, #T_c4e71_row4_col3, #T_c4e71_row4_col4, #T_c4e71_row5_col0, #T_c4e71_row5_col1, #T_c4e71_row5_col2, #T_c4e71_row5_col3, #T_c4e71_row5_col4, #T_c4e71_row6_col0, #T_c4e71_row6_col1, #T_c4e71_row6_col2, #T_c4e71_row6_col3, #T_c4e71_row6_col4, #T_c4e71_row7_col0, #T_c4e71_row7_col1, #T_c4e71_row7_col2, #T_c4e71_row7_col3, #T_c4e71_row7_col4 {
#   background-color: #fbb4ae;
# }
# #T_c4e71_row8_col0, #T_c4e71_row8_col1, #T_c4e71_row8_col2, #T_c4e71_row8_col3, #T_c4e71_row8_col4, #T_c4e71_row9_col0, #T_c4e71_row9_col1, #T_c4e71_row9_col2, #T_c4e71_row9_col3, #T_c4e71_row9_col4, #T_c4e71_row10_col0, #T_c4e71_row10_col1, #T_c4e71_row10_col2, #T_c4e71_row10_col3, #T_c4e71_row10_col4, #T_c4e71_row11_col0, #T_c4e71_row11_col1, #T_c4e71_row11_col2, #T_c4e71_row11_col3, #T_c4e71_row11_col4, #T_c4e71_row12_col0, #T_c4e71_row12_col1, #T_c4e71_row12_col2, #T_c4e71_row12_col3, #T_c4e71_row12_col4, #T_c4e71_row13_col0, #T_c4e71_row13_col1, #T_c4e71_row13_col2, #T_c4e71_row13_col3, #T_c4e71_row13_col4, #T_c4e71_row14_col0, #T_c4e71_row14_col1, #T_c4e71_row14_col2, #T_c4e71_row14_col3, #T_c4e71_row14_col4, #T_c4e71_row15_col0, #T_c4e71_row15_col1, #T_c4e71_row15_col2, #T_c4e71_row15_col3, #T_c4e71_row15_col4, #T_c4e71_row16_col0, #T_c4e71_row16_col1, #T_c4e71_row16_col2, #T_c4e71_row16_col3, #T_c4e71_row16_col4, #T_c4e71_row17_col0, #T_c4e71_row17_col1, #T_c4e71_row17_col2, #T_c4e71_row17_col3, #T_c4e71_row17_col4, #T_c4e71_row18_col0, #T_c4e71_row18_col1, #T_c4e71_row18_col2, #T_c4e71_row18_col3, #T_c4e71_row18_col4, #T_c4e71_row19_col0, #T_c4e71_row19_col1, #T_c4e71_row19_col2, #T_c4e71_row19_col3, #T_c4e71_row19_col4, #T_c4e71_row20_col0, #T_c4e71_row20_col1, #T_c4e71_row20_col2, #T_c4e71_row20_col3, #T_c4e71_row20_col4, #T_c4e71_row21_col0, #T_c4e71_row21_col1, #T_c4e71_row21_col2, #T_c4e71_row21_col3, #T_c4e71_row21_col4, #T_c4e71_row22_col0, #T_c4e71_row22_col1, #T_c4e71_row22_col2, #T_c4e71_row22_col3, #T_c4e71_row22_col4, #T_c4e71_row23_col0, #T_c4e71_row23_col1, #T_c4e71_row23_col2, #T_c4e71_row23_col3, #T_c4e71_row23_col4, #T_c4e71_row24_col0, #T_c4e71_row24_col1, #T_c4e71_row24_col2, #T_c4e71_row24_col3, #T_c4e71_row24_col4, #T_c4e71_row25_col0, #T_c4e71_row25_col1, #T_c4e71_row25_col2, #T_c4e71_row25_col3, #T_c4e71_row25_col4, #T_c4e71_row26_col0, #T_c4e71_row26_col1, #T_c4e71_row26_col2, #T_c4e71_row26_col3, #T_c4e71_row26_col4, #T_c4e71_row27_col0, #T_c4e71_row27_col1, #T_c4e71_row27_col2, #T_c4e71_row27_col3, #T_c4e71_row27_col4 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_c4e71">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c4e71_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_c4e71_level0_col1" class="col_heading level0 col1" >id</th>
#       <th id="T_c4e71_level0_col2" class="col_heading level0 col2" >type</th>
#       <th id="T_c4e71_level0_col3" class="col_heading level0 col3" >value</th>
#       <th id="T_c4e71_level0_col4" class="col_heading level0 col4" >attr_obs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c4e71_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c4e71_row0_col0" class="data row0 col0" >0000-00-00</td>
#       <td id="T_c4e71_row0_col1" class="data row0 col1" >212796</td>
#       <td id="T_c4e71_row0_col2" class="data row0 col2" >faculdade</td>
#       <td id="T_c4e71_row0_col3" class="data row0 col3" >Cânones</td>
#       <td id="T_c4e71_row0_col4" class="data row0 col4" >Cânones</td>
#     </tr>
#     <tr>
#       <th id="T_c4e71_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c4e71_row1_col0" class="data row1 col0" >0000-00-00</td>
#       <td id="T_c4e71_row1_col1" class="data row1 col1" >212796</td>
#       <td id="T_c4e71_row1_col2" class="data row1 col2" >naturalidade</td>
#       <td id="T_c4e71_row1_col3" class="data row1 col3" >Viana do Alentejo</td>
#       <td id="T_c4e71_row1_col4" class="data row1 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_c4e71_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c4e71_row2_col0" class="data row2 col0" >0000-00-00</td>
#       <td id="T_c4e71_row2_col1" class="data row2 col1" >212796</td>
#       <td id="T_c4e71_row2_col2" class="data row2 col2" >nome</td>
#       <td id="T_c4e71_row2_col3" class="data row2 col3" >Manuel Mendes</td>
#       <td id="T_c4e71_row2_col4" class="data row2 col4" >Manuel Mendes, vide Mendes</td>
#     </tr>
#     <tr>
#       <th id="T_c4e71_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c4e71_row3_col0" class="data row3 col0" >0000-00-00</td>
#       <td id="T_c4e71_row3_col1" class="data row3 col1" >212796</td>
#       <td id="T_c4e71_row3_col2" class="data row3 col2" >nome</td>
#       <td id="T_c4e71_row3_col3" class="data row3 col3" >Manuel Mendes</td>
#       <td id="T_c4e71_row3_col4" class="data row3 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_c4e71_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c4e71_row4_col0" class="data row4 col0" >0000-00-00</td>
#       <td id="T_c4e71_row4_col1" class="data row4 col1" >212796</td>
#       <td id="T_c4e71_row4_col2" class="data row4 col2" >nome-pai</td>
#       <td id="T_c4e71_row4_col3" class="data row4 col3" >Manuel Mendes Pimentel</td>
#       <td id="T_c4e71_row4_col4" class="data row4 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_c4e71_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c4e71_row5_col0" class="data row5 col0" >0000-00-00</td>
#       <td id="T_c4e71_row5_col1" class="data row5 col1" >212796</td>
#       <td id="T_c4e71_row5_col2" class="data row5 col2" >nome-vide</td>
#       <td id="T_c4e71_row5_col3" class="data row5 col3" >Mendes</td>
#       <td id="T_c4e71_row5_col4" class="data row5 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_c4e71_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c4e71_row6_col0" class="data row6 col0" >0000-00-00</td>
#       <td id="T_c4e71_row6_col1" class="data row6 col1" >212796</td>
#       <td id="T_c4e71_row6_col2" class="data row6 col2" >uc-entrada</td>
#       <td id="T_c4e71_row6_col3" class="data row6 col3" >0000-00-00</td>
#       <td id="T_c4e71_row6_col4" class="data row6 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_c4e71_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c4e71_row7_col0" class="data row7 col0" >0000-00-00</td>
#       <td id="T_c4e71_row7_col1" class="data row7 col1" >212796</td>
#       <td id="T_c4e71_row7_col2" class="data row7 col2" >uc-saida</td>
#       <td id="T_c4e71_row7_col3" class="data row7 col3" >0000-00-00</td>
#       <td id="T_c4e71_row7_col4" class="data row7 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_c4e71_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c4e71_row8_col0" class="data row8 col0" >1612-10-27</td>
#       <td id="T_c4e71_row8_col1" class="data row8 col1" >242752</td>
#       <td id="T_c4e71_row8_col2" class="data row8 col2" >faculdade</td>
#       <td id="T_c4e71_row8_col3" class="data row8 col3" >Cânones</td>
#       <td id="T_c4e71_row8_col4" class="data row8 col4" >Faculdade corrigida</td>
#     </tr>
#     <tr>
#       <th id="T_c4e71_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c4e71_row9_col0" class="data row9 col0" >1612-10-27</td>
#       <td id="T_c4e71_row9_col1" class="data row9 col1" >242752</td>
#       <td id="T_c4e71_row9_col2" class="data row9 col2" >faculdade</td>
#       <td id="T_c4e71_row9_col3" class="data row9 col3" >Leis</td>
#       <td id="T_c4e71_row9_col4" class="data row9 col4" >Facu
# 225717 173224 aka-see
# <style type="text/css">
# #T_8ace8_row0_col0, #T_8ace8_row0_col1, #T_8ace8_row0_col2, #T_8ace8_row0_col3, #T_8ace8_row0_col4, #T_8ace8_row0_col5, #T_8ace8_row0_col6 {
#   background-color: #fbb4ae;
# }
# #T_8ace8_row1_col0, #T_8ace8_row1_col1, #T_8ace8_row1_col2, #T_8ace8_row1_col3, #T_8ace8_row1_col4, #T_8ace8_row1_col5, #T_8ace8_row1_col6 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_8ace8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8ace8_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_8ace8_level0_col1" class="col_heading level0 col1" >uc-entrada</th>
#       <th id="T_8ace8_level0_col2" class="col_heading level0 col2" >name</th>
#       <th id="T_8ace8_level0_col3" class="col_heading level0 col3" >nome-vide</th>
#       <th id="T_8ace8_level0_col4" class="col_heading level0 col4" >naturalidade</th>
#       <th id="T_8ace8_level0_col5" class="col_heading level0 col5" >faculdade</th>
#       <th id="T_8ace8_level0_col6" class="col_heading level0 col6" >nome-pai</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ace8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8ace8_row0_col0" class="data row0 col0" >173224</td>
#       <td id="T_8ace8_row0_col1" class="data row0 col1" >0000-00-00</td>
#       <td id="T_8ace8_row0_col2" class="data row0 col2" >João Nunes</td>
#       <td id="T_8ace8_row0_col3" class="data row0 col3" >Rogado</td>
#       <td id="T_8ace8_row0_col4" class="data row0 col4" >Terena</td>
#       <td id="T_8ace8_row0_col5" class="data row0 col5" >Leis</td>
#       <td id="T_8ace8_row0_col6" class="data row0 col6" >André Rogado</td>
#     </tr>
#     <tr>
#       <th id="T_8ace8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8ace8_row1_col0" class="data row1 col0" >225717</td>
#       <td id="T_8ace8_row1_col1" class="data row1 col1" >1587-10-03</td>
#       <td id="T_8ace8_row1_col2" class="data row1 col2" >João Nunes Rogado</td>
#       <td id="T_8ace8_row1_col3" class="data row1 col3" >Rogado</td>
#       <td id="T_8ace8_row1_col4" class="data row1 col4" >Terena</td>
#       <td id="T_8ace8_row1_col5" class="data row1 col5" >Leis</td>
#       <td id="T_8ace8_row1_col6" class="data row1 col6" >André Rogado</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_920c7_row0_col0, #T_920c7_row0_col1, #T_920c7_row0_col2, #T_920c7_row0_col3, #T_920c7_row0_col4, #T_920c7_row1_col0, #T_920c7_row1_col1, #T_920c7_row1_col2, #T_920c7_row1_col3, #T_920c7_row1_col4, #T_920c7_row2_col0, #T_920c7_row2_col1, #T_920c7_row2_col2, #T_920c7_row2_col3, #T_920c7_row2_col4, #T_920c7_row3_col0, #T_920c7_row3_col1, #T_920c7_row3_col2, #T_920c7_row3_col3, #T_920c7_row3_col4, #T_920c7_row4_col0, #T_920c7_row4_col1, #T_920c7_row4_col2, #T_920c7_row4_col3, #T_920c7_row4_col4, #T_920c7_row5_col0, #T_920c7_row5_col1, #T_920c7_row5_col2, #T_920c7_row5_col3, #T_920c7_row5_col4, #T_920c7_row6_col0, #T_920c7_row6_col1, #T_920c7_row6_col2, #T_920c7_row6_col3, #T_920c7_row6_col4, #T_920c7_row7_col0, #T_920c7_row7_col1, #T_920c7_row7_col2, #T_920c7_row7_col3, #T_920c7_row7_col4 {
_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_920c7_row1_col0" class="data row1 col0" >0000-00-00</td>
#       <td id="T_920c7_row1_col1" class="data row1 col1" >173224</td>
#       <td id="T_920c7_row1_col2" class="data row1 col2" >naturalidade</td>
#       <td id="T_920c7_row1_col3" class="data row1 col3" >Terena</td>
#       <td id="T_920c7_row1_col4" class="data row1 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_920c7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_920c7_row2_col0" class="data row2 col0" >0000-00-00</td>
#       <td id="T_920c7_row2_col1" class="data row2 col1" >173224</td>
#       <td id="T_920c7_row2_col2" class="data row2 col2" >nome</td>
#       <td id="T_920c7_row2_col3" class="data row2 col3" >João Nunes</td>
#       <td id="T_920c7_row2_col4" class="data row2 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_920c7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_920c7_row3_col0" class="data row3 col0" >0000-00-00</td>
#       <td id="T_920c7_row3_col1" class="data row3 col1" >173224</td>
#       <td id="T_920c7_row3_col2" class="data row3 col2" >nome</td>
#       <td id="T_920c7_row3_col3" class="data row3 col3" >João Nunes Rogado</td>
#       <td id="T_920c7_row3_col4" class="data row3 col4" >João Nunes, vide Rogado</td>
#     </tr>
#     <tr>
#       <th id="T_920c7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_920c7_row4_col0" class="data row4 col0" >0000-00-00</td>
#       <td id="T_920c7_row4_col1" class="data row4 col1" >173224</td>
#       <td id="T_920c7_row4_col2" class="data row4 col2" >nome-pai</td>
#       <td id="T_920c7_row4_col3" class="data row4 col3" >André Rogado</td>
#       <td id="T_920c7_row4_col4" class="data row4 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_920c7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_920c7_row5_col0" class="data row5 col0" >0000-00-00</td>
#       <td id="T_920c7_row5_col1" class="data row5 col1" >173224</td>
#       <td id="T_920c7_row5_col2" class="data row5 col2" >nome-vide</td>
#       <td id="T_920c7_row5_col3" class="data row5 col3" >Rogado</td>
#       <td id="T_920c7_row5_col4" class="data row5 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_920c7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_920c7_row6_col0" class="data row6 col0" >0000-00-00</td>
#       <td id="T_920c7_row6_col1" class="data row6 col1" >173224</td>
#       <td id="T_920c7_row6_col2" class="data row6 col2" >uc-entrada</td>
#       <td id="T_920c7_row6_col3" class="data row6 col3" >0000-00-00</td>
#       <td id="T_920c7_row6_col4" class="data row6 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_920c7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_920c7_row7_col0" class="data row7 col0" >0000-00-00</td>
#       <td id="T_920c7_row7_col1" class="data row7 col1" >173224</td>
#       <td id="T_920c7_row7_col2" class="data row7 col2" >uc-saida</td>
#       <td id="T_920c7_row7_col3" class="data row7 col3" >0000-00-00</td>
#       <td id="T_920c7_row7_col4" class="data row7 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_920c7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_920c7_row8_col0" class="data row8 col0" >1587-10-03</td>
#       <td id="T_920c7_row8_col1" class="data row8 col1" >225717</td>
#       <td id="T_920c7_row8_col2" class="data row8 col2" >faculdade</td>
#       <td id="T_920c7_row8_col3" class="data row8 col3" >Leis</td>
#       <td id="T_920c7_row8_col4" class="data row8 col4" >Leis</td>
#     </tr>
#     <tr>
#       <th id="T_920c7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_920c7_row9_col0" class="data row9 col0" >1587-10-03</td>
#       <td id="T_920c7_row9_col1" class="data row9 col1" >225717</td>
#       <td id="T_920c7_row9_col2" class="data row9 col2" >matricula-faculdade</td>
#       <td id="T_920c7_row9_col3" class="data row9 col3" >Leis</td>
#       <td id="T_920c7_row9_col4" class="data row9 col4" >1587.10.03</td>
#     </tr>
#     <tr>
#       <th id="T_920c7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_920c7_row10_col0"
# 164227 248237 see-aka
# <style type="text/css">
# #T_35cb8_row0_col0, #T_35cb8_row0_col1, #T_35cb8_row0_col2, #T_35cb8_row0_col3, #T_35cb8_row0_col4, #T_35cb8_row0_col5, #T_35cb8_row0_col6 {
#   background-color: #fbb4ae;
# }
# #T_35cb8_row1_col0, #T_35cb8_row1_col1, #T_35cb8_row1_col2, #T_35cb8_row1_col3, #T_35cb8_row1_col4, #T_35cb8_row1_col5, #T_35cb8_row1_col6 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_35cb8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35cb8_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_35cb8_level0_col1" class="col_heading level0 col1" >uc-entrada</th>
#       <th id="T_35cb8_level0_col2" class="col_heading level0 col2" >name</th>
#       <th id="T_35cb8_level0_col3" class="col_heading level0 col3" >nome-vide</th>
#       <th id="T_35cb8_level0_col4" class="col_heading level0 col4" >naturalidade</th>
#       <th id="T_35cb8_level0_col5" class="col_heading level0 col5" >faculdade</th>
#       <th id="T_35cb8_level0_col6" class="col_heading level0 col6" >nome-pai</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35cb8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_35cb8_row0_col0" class="data row0 col0" >164227</td>
#       <td id="T_35cb8_row0_col1" class="data row0 col1" >0000-00-00</td>
#       <td id="T_35cb8_row0_col2" class="data row0 col2" >Aires Fernandes Freire</td>
#       <td id="T_35cb8_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_35cb8_row0_col4" class="data row0 col4" >Lisboa</td>
#       <td id="T_35cb8_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_35cb8_row0_col6" class="data row0 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_35cb8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_35cb8_row1_col0" class="data row1 col0" >248237</td>
#       <td id="T_35cb8_row1_col1" class="data row1 col1" >1552-00-00</td>
#       <td id="T_35cb8_row1_col2" class="data row1 col2" >Aires Fernandes</td>
#       <td id="T_35cb8_row1_col3" class="data row1 col3" >Freire</td>
#       <td id="T_35cb8_row1_col4" class="data row1 col4" >Lisboa</td>
#       <td id="T_35cb8_row1_col5" class="data row1 col5" >Cânones</td>
#       <td id="T_35cb8_row1_col6" class="data row1 col6" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_a4318_row0_col0, #T_a4318_row0_col1, #T_a4318_row0_col2, #T_a4318_row0_col3, #T_a4318_row0_col4, #T_a4318_row1_col0, #T_a4318_row1_col1, #T_a4318_row1_col2, #T_a4318_row1_col3, #T_a4318_row1_col4, #T_a4318_row2_col0, #T_a4318_row2_col1, #T_a4318_row2_col2, #T_a4318_row2_col3, #T_a4318_row2_col4, #T_a4318_row3_col0, #T_a4318_row3_col1, #T_a4318_row3_col2, #T_a4318_row3_col3, #T_a4318_row3_col4 {
#   background-color: #fbb4ae;
# }
# #T_a4318_row4_col0, #T_a4318_row4_col1, #T_a4318_row4_col2, #T_a4318_row4_col3, #T_a4318_row4_col4, #T_a4318_row5_col0, #T_a4318_row5_col1, #T_a4318_row5_col2, #T_a4318_row5_col3, #T_a4318_row5_col4, #T_a4318_row6_col0, #T_a4318_row6_col1, #T_a4318_row6_col2, #T_a4318_row6_col3, #T_a4318_row6_col4, #T
row5_col4" class="data row5 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a4318_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a4318_row6_col0" class="data row6 col0" >1552-00-00</td>
#       <td id="T_a4318_row6_col1" class="data row6 col1" >248237</td>
#       <td id="T_a4318_row6_col2" class="data row6 col2" >nome</td>
#       <td id="T_a4318_row6_col3" class="data row6 col3" >Aires Fernandes</td>
#       <td id="T_a4318_row6_col4" class="data row6 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a4318_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a4318_row7_col0" class="data row7 col0" >1552-00-00</td>
#       <td id="T_a4318_row7_col1" class="data row7 col1" >248237</td>
#       <td id="T_a4318_row7_col2" class="data row7 col2" >nome</td>
#       <td id="T_a4318_row7_col3" class="data row7 col3" >Aires Fernandes Freire</td>
#       <td id="T_a4318_row7_col4" class="data row7 col4" >Aires Fernandes, vide Freire</td>
#     </tr>
#     <tr>
#       <th id="T_a4318_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a4318_row8_col0" class="data row8 col0" >1552-00-00</td>
#       <td id="T_a4318_row8_col1" class="data row8 col1" >248237</td>
#       <td id="T_a4318_row8_col2" class="data row8 col2" >nome-vide</td>
#       <td id="T_a4318_row8_col3" class="data row8 col3" >Freire</td>
#       <td id="T_a4318_row8_col4" class="data row8 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a4318_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a4318_row9_col0" class="data row9 col0" >1552-00-00</td>
#       <td id="T_a4318_row9_col1" class="data row9 col1" >248237</td>
#       <td id="T_a4318_row9_col2" class="data row9 col2" >uc-entrada</td>
#       <td id="T_a4318_row9_col3" class="data row9 col3" >1552-00-00</td>
#       <td id="T_a4318_row9_col4" class="data row9 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a4318_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a4318_row10_col0" class="data row10 col0" >1552-00-00</td>
#       <td id="T_a4318_row10_col1" class="data row10 col1" >248237</td>
#       <td id="T_a4318_row10_col2" class="data row10 col2" >uc-entrada.ano</td>
#       <td id="T_a4318_row10_col3" class="data row10 col3" >1552</td>
#       <td id="T_a4318_row10_col4" class="data row10 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a4318_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a4318_row11_col0" class="data row11 col0" >1556-05-10</td>
#       <td id="T_a4318_row11_col1" class="data row11 col1" >248237</td>
#       <td id="T_a4318_row11_col2" class="data row11 col2" >grau</td>
#       <td id="T_a4318_row11_col3" class="data row11 col3" >Bacharel em Cânones</td>
#       <td id="T_a4318_row11_col4" class="data row11 col4" >Exame para Bacharel 10.05.1556 e grau de Bacharel em dito ano</td>
#     </tr>
#     <tr>
#       <th id="T_a4318_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a4318_row12_col0" class="data row12 col0" >1556-05-10</td>
#       <td id="T_a4318_row12_col1" class="data row12 col1" >248237</td>
#       <td id="T_a4318_row12_col2" class="data row12 col2" >uc-saida</td>
#       <td id="T_a4318_row12_col3" class="data row12 col3"

# %% [markdown]
# Add match information to the records

# %%
import pandas as pd

pairs = match_records['matched_pairs_ok']['data']
def get_match(id,pairs):
    match_list = [(d,mtype) for (o,d,mtype) in pairs if o == id]
    if len(match_list) == 0:
        return (None,None)
    else:
        return match_list[0]

ids = vide_plus.index.values
matches = [get_match(id,pairs) for id in ids]
cols = pd.DataFrame(matches,columns=['match','match_type'], index=ids)
vide_plus = pd.concat([vide_plus,cols],axis=1)

# %% [markdown]
# ## Match results

# %% [markdown]
# ### Match general statistics

# %%
nvide_plus = match_info.loc['vide_plus','data']
match_info.fillna("")
vars_perc_vide = ['aka','aka_fac','aka_geo','aka_pai',
                'nodate','nodate_novide',
                'records_matched','records_matched_ok',
                'records_see_aka','records_see_see',
                'records_aka_see','records_aka_aka',
                'records_transitive',
                'vide','vide_plus']

match_info.loc[vars_perc_vide,'perc_vide_plus'] = match_info.loc[vars_perc_vide,'data']/nvide_plus

nrec_matched = match_info.loc['records_matched_ok','data']
vars_perc_matches = ['records_matched_ok',
                     'records_see_aka','records_see_see',
                     'records_aka_see','records_aka_aka',
                     'records_transitive']
match_info.loc[vars_perc_matches,'perc_matched_ok'] = match_info.loc[vars_perc_matches,'data']/nrec_matched
                     
nsee = match_info.loc['see','data']
vars_perc_see = ['see_matched','see_matched_ok','records_see_aka','records_see_see', 'see','see_fac','see_geo','see_pai']
match_info.loc[vars_perc_see,'perc_type'] = match_info.loc[vars_perc_see,'data']/nsee
match_info.loc[vars_perc_see,'type'] = 'see'


naka = match_info.loc['aka','data']
vars_perc_aka = ['aka','aka_matched','aka_matched_ok','aka_fac','aka_geo','aka_pai','records_aka_see','records_aka_aka']
match_info.loc[vars_perc_aka,'perc_type'] = match_info.loc[vars_perc_aka,'data']/naka
match_info.loc[vars_perc_aka,'type'] = 'aka'


nmatched_pairs = match_info.loc['matched_pairs','data']
vars_perc_matched = ['matched_pairs','matched_pairs_ok']
match_info.loc[vars_perc_matched,'perc_type'] = match_info.loc[vars_perc_matched,'data']/nmatched_pairs
match_info.loc[vars_perc_matched,'type'] = 'matched_pairs'

nrec_matched = match_info.loc['records_matched','data']
vars_perc_rec_matched = ['records_matched','records_matched_ok','records_transitive']
match_info.loc[vars_perc_rec_matched,'perc_type'] = match_info.loc[vars_perc_rec_matched,'data']/nrec_matched
match_info.loc[vars_perc_rec_matched,'type'] = 'records_mached'

# %%
match_info.fillna(" ")
# Out:
#                     data sequential random perc_vide_plus perc_matched_ok  \
# aka                 3062                         0.349304
# aka_fac             3035                         0.346224
# aka_geo             2973                         0.339151
# aka_matched         1910       1913   1970
# aka_matched_ok      1940       1907   1897
# aka_pai             1619                         0.184691
# matched_pairs       3818       3644   3804
# matched_pairs_ok    3665       3628   3614
# nodate              5763                         0.657426
# nodate_novide        141                         0.016085
# nodate_novide        141                         0.016085
# records_aka_aka      188        200    216       0.021446        0.050783
# records_aka_see     1722       1713   1754       0.196441        0.465154
# records_asymmetric    74          0     76
# records_error        116         12    190
# records_matched     3818       3640   3804       0.435546
# records_matched_ok  3702       3628   3614       0.422313             1.0
# records_see_aka     1746       1713   1781       0.199179        0.471637
# records_see_see       10         14     24       0.001141        0.002701
# records_transitive   116         12    116       0.013233        0.031334
# see                 5704
# see_fac             1378
# see_geo             5274
# see_matched         1756       1727   1796
# see_matched_ok      1762       1721   1717
# see_pai             1569
# vide                8625                         0.983915
# vide_plus           8766                              1.0
#
#                    perc_type            type
# aka                      1.0             aka
# aka_fac             0.991182             aka
# aka_geo             0.970934             aka
# aka_matched         0.623775             aka
# aka_matched_ok      0.633573             aka
# aka_pai             0.528739             aka
# matched_pairs            1.0   matched_pairs
# matched_pairs_ok    0.959927   matched_pairs
# nodate
# nodate_novide
# nodate_novide
# records_aka_aka     0.061398             aka
# records_aka_see     0.562378             aka
# records_asymmetric
# records_error
# records_matched          1.0  records_mached
# records_matched_ok  0.969618  records_mached
# records_see_aka     0.306101             see
# records_see_see     0.001753             see
# records_transitive  0.030382  records_mached
# see                      1.0             see
# see_fac             0.241585             see
# see_geo             0.924614             see
# see_matched         0.307854             see
# see_matched_ok      0.308906             see
# see_pai              0.27507             see
# vide
# vide_plus

# %% [markdown]
# ### Generate matching file and dataframe

# %%
matching_view_cols = ['match','nome-geografico','uc-entrada','uc-saida','name','nome-vide','lookup','nome-pai','vide_type','faculdade','match_type','match_error','match_obs']

matched_error = vide_plus[vide_plus['match_error']==True]
matched_error_index = matched_error.index.unique()

matched_index = match_records['records_matched']['data']
matched_ok_index = list(set(matched_index)-set(matched_error_index))

matched = vide_plus.loc[matched_index].sort_values(['sort_key','nome-geografico','uc-entrada'])[matching_view_cols]
nmatched = len(matched_index)
print("Number of matched records:",nmatched)
matched.to_csv('../inferences/cross-references/vide_matched.csv',sep=',',)
matched.head(40)
# Out:
# Number of matched records: 3818
#          match    nome-geografico  uc-entrada    uc-saida  \
# 179898  151044  Pinheiro de Ázere  0000-00-00  0000-00-00
# 151044  179898  Pinheiro de Ázere  1596-10-19  1620-07-11
# 151589  131748              Viana  0000-00-00  0000-00-00
# 131748  151589              Viana  1684-10-01  1687-10-01
# 250325  151588           Estremoz  0000-00-00  0000-00-00
# 151588  250325           Estremoz  1563-11-16  1577-10-11
# 181618  186611              Viseu  0000-00-00  0000-00-00
# 186611  181618              Viseu  1609-10-01  1624-10-30
# 186611  181618              Viseu  1609-10-01  1624-10-30
# 221796  164067              Elvas  0000-00-00  0000-00-00
# 164067  221796              Elvas  1621-00-00  1627-02-12
# 214147    None             Lisboa  0000-00-00  0000-00-00
# 169888    None             Lisboa  1585-10-15  1594-07-30
# 169890    None             Lisboa  1600-10-05  1611-06-05
# 203124  177343          Fronteira  0000-00-00  0000-00-00
# 177343  203124          Fronteira  1577-10-03  1585-11-23
# 187008  190253             Arruda  0000-00-00  0000-00-00
# 190253  187008             Arruda  1653-10-25  1659-10-24
# 184829  160532        Campo Maior  0000-00-00  0000-00-00
# 160532  184829        Campo Maior  1641-10-17  1648-05-14
# 244221  172641             Lisboa  1562-11-10  1570-07-03
# 172641  244221             Lisboa  1563-12-01  1568-06-30
# 223131  234243             Torrão  0000-00-00  0000-00-00
# 234243  223131             Torrão  1616-12-10  1622-07-05
# 234243  223131             Torrão  1616-12-10  1622-07-05
# 223831  231672           Estremoz  0000-00-00  0000-00-00
# 231672  223831           Estremoz  1654-10-13  1660-07-14
# 234683  201868              Moura  0000-00-00  0000-00-00
# 201868  234683              Moura  1592-10-16  1598-10-20
# 163159  143866             Lisboa  0000-00-00  0000-00-00
# 203124                Afonso Garcia          Pedro Garcia Tinoco       cut
# 177343         Afonso Garcia Tinoco          Pedro Garcia Tinoco       add
# 187008       Afonso Henriques Homem                          NaN       add
# 190253             Afonso Henriques                          NaN       cut
# 184829         Afonso Martins Fouto                          NaN       add
# 160532               Afonso Martins               Gaspar da Gama       cut
# 244221                 Afonso Nunes                          NaN       cut
# 172641        Afonso Nunes Ferreira                          NaN       add
# 223131            Afonso Pato Sousa                   André Pato       add
# 234243                  Afonso Pato                   André Pato       cut
# 234243                  Afonso Pato                   André Pato       cut
# 223831                Afonso Soares                          NaN       cut
# 231672         Afonso Soares Serrão                Diogo Pereira       add
# 234683                 Afonso Teles                          NaN       cut
# 201868         Afonso Teles Menezes                    Rui Teles       add
# 163159               Afonso Álvares                          NaN       cut
# 143866        Afonso Álvares Franco                          NaN       add
# 198999        Agostinho de Atouguia                          NaN       cut
# 148379  Agostinho de Atouguia Costa          António de Atouguia       add
# 164224          Agostinho do Avelar                          NaN       cut
# 148698   Agostinho do Avelar Freire                          NaN       add
# 148698   Agostinho do Avelar Freire                          NaN       add
# 244243            Agostinho Barbosa   Francisco Barbosa Ferreira       cut
# 150572   Agostinho Barbosa Ferreira   Francisco Barbosa Ferreira       add
# 150572   Agostinho Barbosa Ferreira   Francisco Barbosa Ferreira       add
# 244233    Agostinho Ferreira Rebelo                          NaN       add
#
#        faculdade match_type  match_error                    match_obs
# 179898       NaN    see-aka        False                          NaN
# 151044   Cânones    aka-see        False                          NaN
# 151589       NaN    see-aka        False                          NaN
# 131748   Cânones    aka-see        False                          NaN
# 250325       NaN    see-aka        False                          NaN
# 151588      Leis    aka-see        False                          NaN
# 181618      Leis    see-aka        False                          NaN
# 186611   Cânones    aka-see        False                          NaN
# 186611      Leis    aka-see        False                          NaN
# 221796       NaN    see-aka        False                          NaN
# 164067   Cânones    aka-see        False                          NaN
# 214147       NaN       None         True  E04-Ambiguity in match data
# 169888   Cânones       None         True  E04-Ambiguity in match data
# 169890   Cânones       None         True  E04-Ambiguity in match data
# 203124      Leis    see-aka        False                          NaN
# 177343      Leis    aka-see        False                          NaN
# 187008   Cânones    see-aka        False                          NaN
# 190253   Cânones    aka-see        False                          NaN
# 184829       NaN    see-aka        False                          NaN
# 160532      Leis    aka-see        False                          NaN
# 244221      Leis    aka-aka        False                          NaN
# 172641      Leis    aka-aka        False                          NaN
# 223131      Leis    see-aka        False                          NaN
# 234243      Leis    aka-see        False                          NaN
# 234243  Medicina    aka-see        False                          NaN
# 223831       NaN    see-aka        False                          NaN
# 231672  Medicina    aka-see        False                          NaN
# 234683       NaN    see-aka        False                          NaN
# 201868   Cânones    aka-see        False                          NaN
# 163159       NaN    see-aka        False                          NaN
# 143866   Cânones    aka-see        False                          NaN
# 198999       NaN    see-aka        False                          NaN
# 148379   Cânones    aka-see        False                          NaN
# 164224       NaN    see-aka        False                          NaN
# 148698   Cânones    aka-see        False                          NaN
# 148698      Leis    aka-see        False                          NaN
# 244243   Cânones    aka-aka        False                          NaN
# 134538            Agostinho Ferreira  Agostinho Francisco Ferreira       cut
# 179131   Agostinho Gonçalves Pereira             António Gonçalves       add
# 225541           Agostinho Gonçalves                                     cut
# 253938  Agostinho Loureiro de Aguiar                                     add
# 183928  Agostinho Manuel de Sequeira                                     rep
# 222335              Agostinho Manuel                                     cut
# 251007       Agostinho Monteiro Belo                                     add
# 185242            Agostinho Monteiro                                     cut
#
#                                  faculdade match_type  match_error match_obs
# 151044                             Cânones    aka-see        False
# 179898                                        see-aka        False
# 186611                             Cânones    aka-see        False
# 186611                                Leis    aka-see        False
# 181618                                Leis    see-aka        False
# 164067                             Cânones    aka-see        False
# 221796                                        see-aka        False
# 177343                                Leis    aka-see        False
# 203124                                Leis    see-aka        False
# 187008                             Cânones    see-aka        False
# 190253                             Cânones    aka-see        False
# 184829                                        see-aka        False
# 160532                                Leis    aka-see        False
# 172641                                Leis    aka-aka        False
# 244221                                Leis    aka-aka        False
# 223131                                Leis    see-aka        False
# 234243                                Leis    aka-see        False
# 234243                            Medicina    aka-see        False
# 231672                            Medicina    aka-see        False
# 223831                                        see-aka        False
# 201868                             Cânones    aka-see        False
# 234683                                        see-aka        False
# 151588                                Leis    aka-see        False
# 151589                                        see-aka        False
# 131748                             Cânones    aka-see        False
# 250325                                        see-aka        False
# 143866                             Cânones    aka-see        False
# 163159                                        see-aka        False
# 150572                             Cânones    aka-aka        False
# 150572                             Cânones    aka-aka        False
# 244243                             Cânones    aka-aka        False
# 244233                             Cânones    see-aka        False
# 134538                             Cânones    aka-see        False
# 179131                             Cânones    aka-see        False
# 225541                                        see-aka        False
# 253938                             Cânones    aka-see        False
# 183928  Cursos jurídicos (Cânones ou Leis)    aka-see        False
# 222335                                        see-aka        False
# 251007  Cursos jurídicos (Cânones ou Leis)    aka-see        False
# 185242                                        see-aka        False

# %% [markdown]
# ### Show diferences in matching results

# %%
match_info
# Out:
#                     data sequential random perc_vide_plus perc_matched_ok  \
# aka                 3062        NaN    NaN       0.349304             NaN
# aka_fac             3035        NaN    NaN       0.346224             NaN
# aka_geo             2973        NaN    NaN       0.339151             NaN
# aka_matched         1910       1913   1970            NaN             NaN
# aka_matched_ok      1940       1907   1897            NaN             NaN
# aka_pai             1619        NaN    NaN       0.184691             NaN
# matched_pairs       3818       3644   3804            NaN             NaN
# matched_pairs_ok    3665       3628   3614            NaN             NaN
# nodate              5763        NaN    NaN       0.657426             NaN
# nodate_novide        141        NaN    NaN       0.016085             NaN
# nodate_novide        141        NaN    NaN       0.016085             NaN
# records_aka_aka      188        200    216       0.021446        0.050783
# records_aka_see     1722       1713   1754       0.196441        0.465154
# records_asymmetric    74          0     76            NaN             NaN
# records_error        116         12    190            NaN             NaN
# records_matched     3818       3640   3804       0.435546             NaN
# records_matched_ok  3702       3628   3614       0.422313             1.0
# records_see_aka     1746       1713   1781       0.199179        0.471637
# records_see_see       10         14     24       0.001141        0.002701
# records_transitive   116         12    116       0.013233        0.031334
# see                 5704        NaN    NaN            NaN             NaN
# see_fac             1378        NaN    NaN            NaN             NaN
# see_geo             5274        NaN    NaN            NaN             NaN
# see_matched         1756       1727   1796            NaN             NaN
# see_matched_ok      1762       1721   1717            NaN             NaN
# see_pai             1569        NaN    NaN            NaN             NaN
# vide                8625        NaN    NaN       0.983915             NaN
# vide_plus           8766        NaN    NaN            1.0             NaN
#
#                    perc_type            type
# aka                      1.0             aka
# aka_fac             0.991182             aka
# aka_geo             0.970934             aka
# aka_matched         0.623775             aka
# aka_matched_ok      0.633573             aka
# aka_pai             0.528739             aka
# matched_pairs            1.0   matched_pairs
# matched_pairs_ok    0.959927   matched_pairs
# nodate                   NaN             NaN
# nodate_novide            NaN             NaN
# nodate_novide            NaN             NaN
# records_aka_aka     0.061398             aka
# records_aka_see     0.562378             aka
# records_asymmetric       NaN             NaN
# records_error            NaN             NaN
# records_matched          1.0  records_mached
# records_matched_ok  0.969618  records_mached
# records_see_aka     0.306101             see
# records_see_see     0.001753             see
# records_transitive  0.030382  records_mached
# see                      1.0             see
# see_fac             0.241585             see
# see_geo             0.924614             see
# see_matched         0.307854             see
# see_matched_ok      0.308906             see
# see_pai              0.27507             see
# vide                     NaN             NaN
# vide_plus                NaN             NaN

# %% [markdown]
# ####  Only matched in random mode
#
# The extra success of the random mode comes from a better tolerance to variations of geographic names.
#
# This is because the random mode uses a similarity factor to find students of with the same birth place while the sequential method uses sorting on geographic name and names to get the matches adjacent.
#
# Each methods manages to succeed in cases where the other fails, but random is more efficient.

# %%
matched_rand_index = match_records['records_matched_ok']['random']
matched_seq_index = match_records['records_matched_ok']['sequential']
matched_error_index = match_records['records_error']['data']

matched_rand_only = list(set(matched_rand_index)-set(matched_seq_index)-set(matched_error_index))
nmatched_rand_only = len(matched_rand_only)
print(f"Number of records matched only in random access mode (errors excluded): {nmatched_rand_only}")
print()
print("Sample:")
matched.loc[matched_rand_only].sort_values(['name','nome-geografico','uc-entrada',])[matching_view_cols].head(40)
# Out:
# Number of records matched only in random access mode (errors excluded): 68
#
# Sample:
#          match       nome-geografico  uc-entrada    uc-saida  \
# 183928  222335              Nogoselo  1756-10-01  1756-10-01
# 222335  183928              Nagoselo  0000-00-00  0000-00-00
# 148502  213090     Santiago do Cacém  1650-10-12  1658-03-30
# 148502  213090     Santiago do Cacém  1650-10-12  1658-03-30
# 213090  148502     Santiago de Cacém  0000-00-00  0000-00-00
# 178267  251037         Ilha Terceira  1567-10-01  1575-05-17
# 251037  178267      Ilha da Terceira  0000-00-00  0000-00-00
# 222372  140377      Várzae de Meruge  1728-10-01  1731-10-01
# 140377  222372      Várzea de Meruge  0000-00-00  0000-00-00
# 238571  202253                  Setã  1632-01-10  1659-11-08
# 202253  238571                 Sertã  0000-00-00  0000-00-00
# 144763  211813        Paradinha Nova  1733-10-01  1739-10-01
# 211813  144763         Parainha Nova  0000-00-00  0000-00-00
# 139658  214433              Mourilhe  1725-10-01  1732-10-01
# 139670  128053              Samadães  1656-10-15  1665-12-15
# 128053  139670              Samodães  0000-00-00  0000-00-00
# 214433  139658               Morilhe  0000-00-00  0000-00-00
# 144763                   António Vaz
# 211813        António Teixeira Alves
# 139658                    de Sampaio
# 139670                        Cabral
# 128053                       Fonseca
# 214433                       Fonseca
# 225941              Guerra de Macedo
# 181220                       Pereira
# 233079                          Neto
# 233079                          Neto
# 168893                       Pereira
# 150703                        Caldas
# 251990                    Figueiredo
# 251990                    Figueiredo
# 135191                     Fernandes
# 194625             Ferreira da Costa
# 201050                Francisco José
# 171296                       Correia
# 197094                      Nogueira
# 129133                       Barbosa
# 135244                      Carvalho
# 155250                        Rebelo
# 155250                        Rebelo
# 240038                     de Castro
# 191015                      Pessanha
# 181999                      Ferreira
# 246747                       Machado
# 241319              Pereira da Silva
# 228204                         Moura
#
#                                              lookup  \
# 183928                 Agostinho Manuel de Sequeira
# 222335                             Agostinho Manuel
# 148502                         André Ascenso Salema
# 148502                         André Ascenso Salema
# 213090                                André Ascenso
# 178267                         André Gomes Monteiro
# 251037                                  André Gomes
# 222372                  André de Sequeira Abranches
# 140377                            André de Sequeira
# 238571                         António Lopes Leitão
# 202253                                António Lopes
# 144763                                  António Vaz
# 211813                       António Teixeira Alves
# 139658                António da Fonseca de Sampaio
# 139670                    António da Fonseca Cabral
# 128053                           António da Fonseca
# 214433                           António da Fonseca
# 225941  António de Almeida Pereira Guerra de Macedo
# 181220                   António de Almeida Pereira
# 233079                           Diogo Pereira Neto
# 233079                           Diogo Pereira Neto
# 168893                                Diogo Pereira
# 150703                             Francisco Caldas
# 251990               Francisco Fernandes Figueiredo
# 251990               Francisco Fernandes Figueiredo
# 135191                          Francisco Fernandes
# 194625             Francisco José Ferreira da Costa
# 201050                               Francisco José
# 171296                   Francisco Nogueira Correia
# 197094                           Francisco Nogueira
# 129133                  Francisco de Caldas Barbosa
# 135244                       Gaspar Rebelo Carvalho
# 155250                                Gaspar Rebelo
# 155250                                Gaspar Rebelo
# 240038                     Jorge Pessanha de Castro
# 191015                               Jorge Pessanha
# 181999               José Bernardo Machado Ferreira
# 246747                        José Bernardo Machado
# 241319               José de Moura Pereira da Silva
# 228204                                José de Moura
#
#                            nome-pai vide_type  \
# 183928                          NaN       rep
# 222335                          NaN       cut
# 148502       Manuel Raposo Pessanha       add
# 148502       Manuel Raposo Pessanha       add
# 213090                          NaN       cut
# 178267                  António Vaz       add
# 251037                          NaN       cut
# 222372                          NaN       add
# 140377                          NaN       cut
# 238571                António André       add
# 202253                          NaN       cut
# 144763                          NaN       rep
# 211813                          NaN       rep
# 139658                          NaN       add
# 139670         Sebastião da Fonseca       add
# 128053  Sebastião da Fonseca Cabral       cut
# 214433                          NaN       cut
# 225941                          NaN       add
# 181220                          NaN       cut
# 233079            Francisco Martins       add
# 233079            Francisco Martins       add
# 168893                          NaN       cut
# 150703                          NaN       cut
# 251990                          NaN       add
# 251990                          NaN       add
# 135191             Marcos Fernandes       cut
# 194625           Manuel Pires Amada       add
# 201050                          NaN       cut
# 171296                          NaN       add
# 197094                          NaN       cut
# 129133                          NaN       add
# 135244                          NaN       add
# 155250                          NaN       cut
# 155250                          NaN       cut
# 240038                          NaN       add
# 191015                          NaN       cut
# 181999                          NaN       add
# 246747                          NaN       cut
# 241319                          NaN       add
# 228204                          NaN       cut
#
#                                  faculdade match_type  match_error match_obs
# 183928  Cursos jurídicos (Cânones ou Leis)    aka-see        False       NaN
# 222335                                 NaN    see-aka        False       NaN
# 148502                             Cânones    aka-see        False       NaN
# 148502                                Leis    aka-see        False       NaN
# 213090                                Leis    see-aka        False       NaN
# 178267                             Cânones    aka-see        False       NaN
# 251037                                 NaN    see-aka        False       NaN
# 222372                             Cânones    aka-see        False       NaN
# 140377                                 NaN    see-aka        False       NaN
# 238571                             Cânones    aka-see        False       NaN
# 202253                                 NaN    see-aka        False       NaN
# 144763                             Cânones    aka-see        False       NaN
# 211813                                 NaN    see-aka        False       NaN
# 139658                             Cânones    aka-see        False       NaN
# 139670                             Cânones    aka-see        False       NaN
# 128053                             Cânones    see-aka        False       NaN
# 214433                                 NaN    see-aka        False       NaN
# 225941                             Cânones    aka-see        False       NaN
# 181220                                 NaN    see-aka        False       NaN
# 233079                             Cânones    aka-see        False       NaN
# 233079                                Leis    aka-see        False       NaN
# 168893                                 NaN    see-aka        False       NaN
# 150703                             Cânones    see-aka        False       NaN
# 251990                                 NaN    see-aka        False       NaN
# 251990                                 NaN    see-aka        False       NaN
# 135191                             Cânones    aka-see        False       NaN
# 194625                             Cânones    aka-see        False       NaN
# 201050                                 NaN    see-aka        False       NaN
# 171296                             Cânones    aka-see        False       NaN
# 197094                                 NaN    see-aka        False       NaN
# 129133                             Cânones    aka-see        False       NaN
# 135244                                Leis    see-aka        False       NaN
# 155250                             Cânones    aka-see        False       NaN
# 155250                                Leis    aka-see        False       NaN
# 240038                             Cânones    aka-see        False       NaN
# 191015                                 NaN    see-aka        False       NaN
# 181999                                 NaN    see-aka        False       NaN
# 246747                             Cânones    aka-see        False       NaN
# 241319                             Cânones    aka-see        False       NaN
# 228204                                 NaN    see-aka        False       NaN

# %% [markdown]
# #### Only matched in sequential mode

# %% [markdown]
# A few cases sequential is more successful.

# %%
pd.set_option('display.max_rows',100)


matched_seq_only = list(set(matched_seq_index)-set(matched_rand_index)-set(matched_error_index))
nmatched_not_rand = len(matched_seq_only)
print(f"Number of records matched only in sequential mode (errors excluded): {nmatched_not_rand}")
print()
matched.loc[matched_seq_only].sort_values(['name','nome-geografico','uc-entrada',]).head(20)[matching_view_cols]
# Out:
# Number of records matched only in sequential mode (errors excluded): 14
#          match                   nome-geografico  uc-entrada    uc-saida  \
# 241634  250486                            Algoso  0000-00-00  0000-00-00
# 250486  241634                            Algozo  1656-10-15  1665-03-24
# 212564  151964                             Mouta  1613-03-23  1615-10-05
# 151964  212564                    Mouta ou Moita  0000-00-00  0000-00-00
# 188868  131782                    Azoia de Baixo  1748-10-01  1752-10-01
# 131782  188868                             Azoia  0000-00-00  0000-00-00
# 239722  242576                 São José de Godim  0000-00-00  0000-00-00
# 242576  239722                            Gondim  1762-10-01  1766-10-01
# 242576  239722                          São José  1762-10-01  1766-10-01
# 136003  143938                   Lobelhe do Mato  1642-10-20  1648-02-29
# 143938  136003                            Lobete  0000-00-00  0000-00-00
# 176853  145626                           Almeida  0000-00-00  0000-00-00
# 145626  176853                        Almeidinha  1649-10-20  1657-02-13
# 145626  176853                        Almeidinha  1649-10-20  1657-02-13
# 172863  213192  Arrifana de Santa Maria de Feira  1645-10-16  1654-05-29
# 213192  172863           Arrifana de Santa Maria  0000-00-00  0000-00-00
#
#                                      name                          nome-vide  \
# 241634                   António Pimentel                             Morais
# 250486            António Pimentel Morais                           Pimentel
# 212564                          Jorge Vaz                             Barros
# 151964                Jorge Vaz de Barros                                Vaz
# 188868                     José Henriques                           Figueira
# 131782            José Henriques Figueira                     José Henriques
# 239722        José Manuel Borges de Sousa  José Manuel Borges de Sousa Pinto
# 242576  José Manuel Borges de Sousa Pinto        José Manuel Borges de Sousa
# 242576  José Manuel Borges de Sousa Pinto        José Manuel Borges de Sousa
# 136003                     Manuel Cardoso                         de Almeida
# 143938          Manuel Cardoso de Almeida                            Cardoso
# 176853                      Manuel Osório                             Amaral
# 145626            Manuel Osório do Amaral                             Osório
# 145626            Manuel Osório do Amaral                             Osório
# 172863                  Salvador de Matos                             Mendes
# 213192           Salvador de Matos Mendes                              Matos
#
#                                    lookup                      nome-pai  \
# 241634            António Pimentel Morais                           NaN
# 250486                   António Pimentel                           NaN
# 212564                   Jorge Vaz Barros                    Manuel Vaz
# 151964                          Jorge Vaz                    Manuel Vaz
# 188868            José Henriques Figueira                           NaN
# 131782                     José Henriques                           NaN
# 239722  José Manuel Borges de Sousa Pinto                           NaN
# 242576        José Manuel Borges de Sousa                           NaN
# 242576        José Manuel Borges de Sousa                           NaN
# 136003          Manuel Cardoso de Almeida             Agostinho Cardoso
# 143938                     Manuel Cardoso                           NaN
# 176853               Manuel Osório Amaral                           NaN
# 145626                      Manuel Osório               Simão do Amaral
# 145626                      Manuel Osório               Simão do Amaral
# 172863           Salvador de Matos Mendes  Paulo de Almeida de Mesquita
# 213192                  Salvador de Matos                           NaN
#
#        vide_type faculdade match_type  match_error match_obs
# 241634       add   Cânones    see-aka        False       NaN
# 250486       cut      Leis    aka-see        False       NaN
# 212564       add  Teologia    aka-see        False       NaN
# 151964       cut  Teologia    see-aka        False       NaN
# 188868       add   Cânones    aka-see        False       NaN
# 131782       cut   Cânones    see-aka        False       NaN
# 239722       rep       NaN    see-aka        False       NaN
# 242576       cut      Leis    aka-see        False       NaN
# 242576       cut      Leis    aka-see        False       NaN
# 136003       add  Medicina    aka-see        False       NaN
# 143938       cut       NaN    see-aka        False       NaN
# 176853       add      Leis    see-aka        False       NaN
# 145626       cut   Cânones    aka-see        False       NaN
# 145626       cut      Leis    aka-see        False       NaN
# 172863       add   Cânones    aka-see        False       NaN
# 213192       cut       NaN    see-aka        False       NaN

# %% [markdown]
# #### Analyse Aka to Aka (see also) links.
#
# These are true duplicates. Some of them could be prevented with a check on dates, but this serves to assess the extend of duplicate records in the data.
#
# Analysis:
# * 150364 265272: strange because the two records are exactly the same except for the name and vide **and the date on instituta** One of the vide should be a "see" record.
# * 129553 191232: also strange: same father name, both records contain the same enrollment in "instituta" in 1601-10-14. the record 191232
#   has the faculdade "Medicina" and an enrollment date of 1613.01.12, while keeping the instituta date.
# * 207361 251998 This looks like a late addition to the "vide" scheme, a note on record 251998 states "Mudou o nome no ano de 1573 aos 03.06 - Atos e Graus 10, fl. 143, caderno 3º". To be in conformity 251988 should be a "see" records with no dates.
# * 190606 248991 the record 248991 should be a "See" it retains a single enrolment date  in 1588.10.01 which also exists in the paired record. With no dates and the redundant enrollment removed 248991 this would have been a normal match
# * 5 188413 193737: this is a true duplicate but the shorter record 188413 seems to contain redundant information except that the faculdade is
#   recorded as "Leis" while in 193737 is recorded as "Cânones". Note that except for the name of the faculdade 193737 always refers "Leis" in the various fields, including the degree.

# %%
vide_plus.columns
# Out:
# Index(['name', 'sex', 'nome-vide', 'nome-geografico', 'faculdade',
#        'faculdade.date', 'faculdade.obs', 'nome-pai', 'uc-entrada', 'uc-saida',
#        'uc-saida.date', 'uc-saida.obs', 'rec_type', 'loookup', 'vide_type',
#        'lookup', 'name_sp', 'lookup_sp', 'sort_key', 'match_error',
#        'match_obs', 'match', 'match_type'],
#       dtype='object')

# %%
from timelinknb.pandas import display_group_attributes

date_threshold = 15  # difference in years for flagging false duplicate.
show_only = 20

no_show=['código-de-referência','data-do-registo','url','faculdade.ano','naturalidade.ano',
         'matricula-faculdade.ano','nome-apelido','nome-primeiro','nome-geografico.ano',
         'grau.ano','matricula-outra.ano','nome-geografico','instituta.ano']

pairs = match_records['matched_pairs_ok']['data']
show_pairs = [(o,d,t) for o,d,t in pairs if t == 'aka-aka' and o<d]

aka_aka_same_date = []
aka_aka_far_apart = []
aka_aka_possible_see = []
for o,d,t in show_pairs:
    if o == '141854':
        pass
    # get the dates of entry to filter those that cannot be then same
    date_o = matched.loc[[o]]['uc-entrada'][0]
    date_d = matched.loc[[d]]['uc-entrada'][0]
    date_s_o = matched.loc[[o]]['uc-saida'][0]
    date_s_d = matched.loc[[d]]['uc-saida'][0]

    if date_o == date_s_o:
        aka_aka_possible_see.append(o)
        
    if date_d == date_s_d:
        aka_aka_possible_see.append(d)

    if date_o == date_d and date_s_o == date_s_d:
        # print("aka-aka pair with same date:",date_o,(o,d,t))
        aka_aka_same_date.append((o,d,t))
    else:
        year_o = int(date_o[:4])    
        year_d = int(date_d[:4])
        if max(year_o,year_d) - min(year_o,year_d) > date_threshold:
            # print(f"False aka-aka: records more than {date_threshold} years appart",(o,d,t),date_s_o,date_d)
            aka_aka_far_apart.append((o,d,t))

print(f"Number of aka-aka pairs with the same date:",len(aka_aka_same_date))
print(f"Number of aka-aka pairs more {date_threshold} years apart:",len(aka_aka_far_apart))
print(f"Number of possible false aka records (records with a single date, probably a see record)",len(aka_aka_possible_see))


print(f"aka-aka matches (show only {show_only}) of {len(show_pairs)}:")
i = 0
for o,d,t in show_pairs[:show_only]:
    i += 1
    print(i,o,d)
    if (o,d,t) in aka_aka_same_date:
        print("SAME DATES: Possible double registration of the same card")
    elif (o,d,t) in aka_aka_far_apart:
        print(f"FAR APART >{date_threshold} years: possible false match, records chronologically affar")
    if o in aka_aka_possible_see:
        print(f"{o} is a possible 'see' record")
    if d in aka_aka_possible_see:
        print(f"{d} is a possible 'see' record")
    
    display_group_attributes([o,d],
                             header_cols=['name','nome-vide','naturalidade','uc-entrada','uc-saida','faculdade','nome-pai'],
                             exclude_attributes=no_show,
                             sort_attributes=['date','type','value'],
                             cmap_name='Pastel1')
# Out:
# Number of aka-aka pairs with the same date: 5
# Number of aka-aka pairs more 15 years apart: 9
# Number of possible false aka records (records with a single date, probably a see record) 38
# aka-aka matches (show only 20) of 94:
# 1 143239 163231
# <style type="text/css">
# #T_f956a_row0_col0, #T_f956a_row0_col1, #T_f956a_row0_col2, #T_f956a_row0_col3, #T_f956a_row0_col4, #T_f956a_row0_col5, #T_f956a_row0_col6, #T_f956a_row0_col7 {
#   background-color: #fbb4ae;
# }
# #T_f956a_row1_col0, #T_f956a_row1_col1, #T_f956a_row1_col2, #T_f956a_row1_col3, #T_f956a_row1_col4, #T_f956a_row1_col5, #T_f956a_row1_col6, #T_f956a_row1_col7 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_f956a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f956a_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_f956a_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_f956a_level0_col2" class="col_heading level0 col2" >nome-vide</th>
#       <th id="T_f956a_level0_col3" class="col_heading level0 col3" >naturalidade</th>
#       <th id="T_f956a_level0_col4" class="col_heading level0 col4" >uc-entrada</th>
#       <th id="T_f956a_level0_col5" class="col_heading level0 col5" >uc-saida</th>
#       <th id="T_f956a_level0_col6" class="col_heading level0 col6" >faculdade</th>
#       <th id="T_f956a_level0_col7" class="col_heading level0 col7" >nome-pai</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f956a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f956a_row0_col0" class="data row0 col0" >143239</td>
#       <td id="T_f956a_row0_col1" class="data row0 col1" >Jerónimo de Almeida</td>
#       <td id="T_f956a_row0_col2" class="data row0 col2" >Ribeiro</td>
#       <td id="T_f956a_row0_col3" class="data row0 col3" >Ferreira</td>
#       <td id="T_f956a_row0_col4" class="data row0 col4" >1553-10-00</td>
#       <td id="T_f956a_row0_col5" class="data row0 col5" >1559-07-27</td>
#       <td id="T_f956a_row0_col6" class="data row0 col6" >Leis</td>
#       <td id="T_f956a_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f956a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f956a_row1_col0" class="data row1 col0" >163231</td>
#       <td id="T_f956a_row1_col1" class="data row1 col1" >Jerónimo de Almeida Ribeiro</td>
#       <td id="T_f956a_row1_col2" class="data row1 col2" >Almeida</td>
#       <td id="T_f956a_row1_col3" class="data row1 col3" >Ferreira</td>
#       <td id="T_f956a_row1_col4" class="data row1 col4" >1560-01-24</td>
#       <td id="T_f956a_row1_col5" class="data row1 col5" >1560-07-24</td>
#       <td id="T_f956a_row1_col6" class="data row1 col6" >Cânones</td>
#       <td id="T_f956a_row1_col7" class="data row1 col7" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_38d8c_row0_col0, #T_38d8c_row0_col1, #T_38d8c_row0_col2, #T_38d8c_row0_col3, #T_38d8c_row0_col4, #T_38d8c_row1_col0, #T_38d8c_row1_col1, #T_38d8c_row1_col2, #T_38d8c_row1_col3, #T_38d8c_row1_col4, #T_38d8c_row2_col0, #T_38d8c_row2_col1, #T_38d8c_row2_col2, #T_38d8c_row2_col3, #T_38d8c_row2_col4, #T_38d8c_row3_col0, #T_38d8c_row3_col1, #T_38d8c_row3_col2, #T_38d8c_row3_col3, #T_38d8c_row3_col4, #T_38d8c_row4_col0, #T_38d8c_row4_col1, #T_38d8c_row4_col2, #T_38d8c_row4_col3, #T_38d8c_row4_col4, #T_38d8c_row5_col0, #T_38d8c_row5_col1, #T_38d8c_row5_col2, #T_38d8c_row5_col3, #T_38d8c_row5_col4, #T_38d8c_row6_col0, #T_38d8c_row6_col1, #T_38d8c_row6_col2, #T_38d8c_row6_col3, #T_38d8c_row6_col4, #T_38d8c_row7_col0, #T_38d8c_row7_col1, #T_38d8c_row7_col2, #T_38d8c_row7_col3, #T_38d8c_row7_col4, #T_38d8c_row8_col0, #T_38d8c_row8_col1, #T_38d8c_row8_col2, #T_38d8c_row8_col3, #T_38d8c_row8_col4, #T_38d8c_row9_col0, #T_38d8c_row9_col1, #T_38d8c_row9_col2, #T_38d8c_row9_col3, #T_38d8c_row9_col4, #T_38d8c_row10_col0, #T_38d8c_row10_col1, #T_38d8c_row10_col2, #T_38d8c_row10_col3, #T_38d8c_row10_col4, #T_38d8c_row11_col0, #T_38d8c_row11_col1, #T_38d8c_row11_col2, #T_38d8c_row11_col3, #T_38d8c_row11_col4 {
#   background-color: #fbb4ae;
# }
# #T_38d8c_row12_col0, #T_38d8c_row12_col1, #T_38d8c_row12_col2, #T_38d8c_row12_col3, #T_38d8c_row12_col4, #T_38d8c_row13_col0, #T_38d8c_row13_col1, #T_38d8c_row13_col2, #T_38d8c_row13_col3, #T_38d8c_row13_col4, #T_38d8c_row14_col0, #T_38d8c_row14_col1, #T_38d8c_row14_col2, #T_38d8c_row14_col3, #T_38d8c_row14_col4, #T_38d8c_row15_col0, #T_38d8c_row15_col1, #T_38d8c_row15_col2, #T_38d8c_row15_col3, #T_38d8c_row15_col4, #T_38d8c_row16_col0, #T_38d8c_row16_col1, #T_38d8c_row16_col2, #T_38d8c_row16_col3, #T_38d8c_row16_col4, #T_38d8c_row17_col0, #T_38d8c_row17_col1, #T_38d8c_row17_col2, #T_38d8c_row17_col3, #T_38d8c_row17_col4, #T_38d8c_row18_col0, #T_38d8c_row18_col1, #T_38d8c_row18_col2, #T_38d8c_row18_col3, #T_38d8c_row18_col4, #T_38d8c_row19_col0, #T_38d8c_row19_col1, #T_38d8c_row19_col2, #T_38d8c_row19_col3, #T_38d8c_row19_col4, #T_38d8c_row20_col0, #T_38d8c_row20_col1, #T_38d8c_row20_col2, #T_38d8c_row20_col3, #T_38d8c_row20_col4, #T_38d8c_row21_col0, #T_38d8c_row21_col1, #T_38d8c_row21_col2, #T_38d8c_row21_col3, #T_38d8c_row21_col4, #T_38d8c_row22_col0, #T_38d8c_row22_col1, #T_38d8c_row22_col2, #T_38d8c_row22_col3, #T_38d8c_row22_col4, #T_38d8c_row23_col0, #T_38d8c_row23_col1, #T_38d8c_row23_col2, #T_38d8c_row23_col3, #T_38d8c_row23_col4 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_38d8c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38d8c_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_38d8c_level0_col1" class="col_heading level0 col1" >id</th>
#       <th id="T_38d8c_level0_col2" class="col_heading level0 col2" >type</th>
#       <th id="T_38d8c_level0_col3" class="col_heading level0 col3" >value</th>
#       <th id="T_38d8c_level0_col4" class="col_heading level0 col4" >attr_obs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38d8c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_38d8c_row0_col0" class="data row0 col0" >1553-00-00:1555-06-00</td>
#       <td id="T_38d8c_row0_col1" class="data row0 col1" >143239</td>
#       <td id="T_38d8c_row0_col2" class="data row0 col2" >instituta</td>
#       <td id="T_38d8c_row0_col3" class="data row0 col3" >1553-00-00:1555-06-00</td>
#       <td id="T_38d8c_row0_col4" class="data row0 col4" >curso: 1 curso de Instituta, 1 de Código desde Outubro de 1553 a Junho de 1555</td>
#     </tr>
#     <tr>
#       <th id="T_38d8c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_38d8c_row1_col0" class="data row1 col0" >1553-10-00</td>
#       <td id="T_38d8c_row1_col1" class="data row1 col1" >143239</td>
#       <td id="T_38d8c_row1_col2" class="data row1 col2" >faculdade</td>
#       <td id="T_38d8c_row1_col3" class="data row1 col3" >Leis</td>
#       <td id="T_38d8c_row1_col4" class="data row1 col4" >Leis</td>
#     </tr>
#     <tr>
#       <th id="T_38d8c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_38d8c_row2_col0" class="data row2 col0" >1553-10-00</td>
#       <td id="T_38d8c_row2_col1" class="data row2 col1" >143239</td>
#       <td id="T_38d8c_row2_col2" class="data row2 col2" >naturalidade</td>
#       <td id="T_38d8c_row2_col3" class="data row2 col3" >Ferreira</td>
#       <td id="T_38d8c_row2_col4" class="data row2 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_38d8c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_38d8c_row3_col0" class="data row3 col0" >1553-10-00</td>
#       <td id="T_38d8c_row3_col1" class="data row3 col1" >143239</td>
#       <td id="T_38d8c_row3_col2" class="data row3 col2" >nome</td>
#       <td id="T_38d8c_row3_col3" class="data row3 col3" >Jerónimo de Almeida</td>
#       <td id="T_38d8c_row3_col4" class="data row3 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_38d8c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_38d8c_row4_col0" class="data row4 col0" >1553-10-00</td>
#       <td id="T_38d8c_row4_col1" class="data row4 col1" >143239</td>
#       <td id="T_38d8c_row4_col2" class="data row4 col2" >nome</td>
#       <td id="T_38d8c_row4_col3" class="data row4 col3" >Jerónimo de Almeida Ribeiro</td>
#       <td id="T_38d8c_row4_col4" class="data row4 col4" >Jerónimo de Almeida, vide Ribeiro</td>
#     </tr>
#     <tr>
#       <th id="T_38d8c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_38d8c_row5_col0" class="data row5 col0" >1553-10-00</td>
#       <td id="T_38d8c_row5_col1" class="data row5 col1" >143239</td>
#       <td id="T_38d8c_row5_col2" class="data row5 col2" >nome-vide</td>
#       <td id="T_38d8c_row5_col3" class="data row5 col3" >Ribeiro</td>
#       <td id="T_38d8c_row5_col4" class="data row5 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_38d8c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_38d8c_row6_col0" class="data row6 col0" >1553-10-00</td>
#       <td id="T_38d8c_row6_col1" class="data row6 col1" >143239</td>
#       <td id="T_38d8c_row6_col2" class="data row6 col2" >uc-entrada</td>
#       <td id="T_38d8c_row6_col3" class="data row6 col3" >1553-10-00</td>
#       <td id="T_38d8c_row6_col4" class="data row6 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_38d8c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_38d8c_row7_col0" class="data row7 col0" >1553-10-00</td>
#       <td id="T_38d8c_row7_col1" class="data row7 col1" >143239</td>
#       <td id="T_38d8c_row7_col2" class="data row7 col2" >uc-entrada.ano</td>
#       <td id="T_38d8c_row7_col3" class="data row7 col3" >1553</td>
#       <td id="T_38d8c_row7_col4" class="data row7 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_38d8c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_38d8c_row8_col0" class="data row8 col0" >1559-07-27</td>
#       <td id="T_38d8c_row8_col1" class="data row8 col1" >143239</td>
#       <td id="T_38d8c_row8_col2" class="data row8 col2" >exame</td>
#       <td id="T_38d8c_row8_col3" class="data row8 col3" >Exame para Bacharel</td>
#       <td id="T_38d8c_row8_col4" class="data row8 col4" > 27.07.1559</td>
#     </tr>
#     <tr>
#       <th id="T_38d8c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_38d8c_row9_col0" class="data row9 col0" >1559-07-27</td>
#       <td id="T_38d8c_row9_col1" class="data row9 col1" >143239</td>
#       <td id="T_38d8c_row9_col2" class="data row9 col2" >grau</td>
#       <td id="T_38d8c_row9_col3" class="data row9 col3" >Bacharel em Leis</td>
#       <td id="T_38d8c_row9_col4" class="data row9 col4" >"1559/07/27"</td>
#     </tr>
#     <tr>
#       <th id="T_38d8c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_38d8c_row10_col0" class="data row10 col0" >1559-07-27</td>
#       <td id="T_38d8c_row10_col1" class="data row10 col1" >143239</td>
#       <td id="T_38d8c_row10_col2" class="data row10 col2"
# 2 129553 191232
# 129553 is a possible 'see' record
# <style type="text/css">
# #T_79650_row0_col0, #T_79650_row0_col1, #T_79650_row0_col2, #T_79650_row0_col3, #T_79650_row0_col4, #T_79650_row0_col5, #T_79650_row0_col6, #T_79650_row0_col7 {
#   background-color: #fbb4ae;
# }
# #T_79650_row1_col0, #T_79650_row1_col1, #T_79650_row1_col2, #T_79650_row1_col3, #T_79650_row1_col4, #T_79650_row1_col5, #T_79650_row1_col6, #T_79650_row1_col7 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_79650">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_79650_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_79650_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_79650_level0_col2" class="col_heading level0 col2" >nome-vide</th>
#       <th id="T_79650_level0_col3" class="col_heading level0 col3" >naturalidade</th>
#       <th id="T_79650_level0_col4" class="col_heading level0 col4" >uc-entrada</th>
#       <th id="T_79650_level0_col5" class="col_heading level0 col5" >uc-saida</th>
#       <th id="T_79650_level0_col6" class="col_heading level0 col6" >faculdade</th>
#       <th id="T_79650_level0_col7" class="col_heading level0 col7" >nome-pai</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79650_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_79650_row0_col0" class="data row0 col0" >191232</td>
#       <td id="T_79650_row0_col1" class="data row0 col1" >Manuel de Castro</td>
#       <td id="T_79650_row0_col2" class="data row0 col2" >Caldeira</td>
#       <td id="T_79650_row0_col3" class="data row0 col3" >Abrantes</td>
#       <td id="T_79650_row0_col4" class="data row0 col4" >1601-10-14</td>
#       <td id="T_79650_row0_col5" class="data row0 col5" >1613-01-12</td>
#       <td id="T_79650_row0_col6" class="data row0 col6" >Medicina</td>
#       <td id="T_79650_row0_col7" class="data row0 col7" >Lopo de Castro</td>
#     </tr>
#     <tr>
#       <th id="T_79650_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T
row5_col4" class="data row5 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_0ee53_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0ee53_row6_col0" class="data row6 col0" >1601-10-14</td>
#       <td id="T_0ee53_row6_col1" class="data row6 col1" >129553</td>
#       <td id="T_0ee53_row6_col2" class="data row6 col2" >nome</td>
#       <td id="T_0ee53_row6_col3" class="data row6 col3" >Manuel de Castro</td>
#       <td id="T_0ee53_row6_col4" class="data row6 col4" >Manuel de Castro Caldeira, vide Castro</td>
#     </tr>
#     <tr>
#       <th id="T_0ee53_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0ee53_row7_col0" class="data row7 col0" >1601-10-14</td>
#       <td id="T_0ee53_row7_col1" class="data row7 col1" >191232</td>
#       <td id="T_0ee53_row7_col2" class="data row7 col2" >nome</td>
#       <td id="T_0ee53_row7_col3" class="data row7 col3" >Manuel de Castro</td>
#       <td id="T_0ee53_row7_col4" class="data row7 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_0ee53_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0ee53_row8_col0" class="data row8 col0" >1601-10-14</td>
#       <td id="T_0ee53_row8_col1" class="data row8 col1" >129553</td>
#       <td id="T_0ee53_row8_col2" class="data row8 col2" >nome</td>
#       <td id="T_0ee53_row8_col3" class="data row8 col3" >Manuel de Castro Caldeira</td>
#       <td id="T_0ee53_row8_col4" class="data row8 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_0ee53_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0ee53_row9_col0" class="data row9 col0" >1601-10-14</td>
#       <td id="T_0ee53_row9_col1" class="data row9 col1" >191232</td>
#       <td id="T_0ee53_row9_col2" class="data row9 col2" >nome</td>
#       <td id="T_0ee53_row9_col3" class="data row9 col3" >Manuel de Castro Caldeira</td>
#       <td id="T_0ee53_row9_col4" class="data row9 col4" >Manuel de Castro, vide Caldeira</td>
#     </tr>
#     <tr>
#       <th id="T_0ee53_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0ee53_row10_col0" class="data row10 col0" >1601-10-14</td>
#       <td id="T_0ee53_row10_col1" class="data row10 col1" >129553</td>
#       <td id="T_0ee53_row10_col2" class="data row10 c
# 3 167251 231579
# 167251 is a possible 'see' record
# <style type="text/css">
# #T_9dac0_row0_col0, #T_9dac0_row0_col1, #T_9dac0_row0_col2, #T_9dac0_row0_col3, #T_9dac0_row0_col4, #T_9dac0_row0_col5, #T_9dac0_row0_col6, #T_9dac0_row0_col7 {
#   background-color: #fbb4ae;
# }
# #T_9dac0_row1_col0, #T_9dac0_row1_col1, #T_9dac0_row1_col2, #T_9dac0_row1_col3, #T_9dac0_row1_col4, #T_9dac0_row1_col5, #T_9dac0_row1_col6, #T_9dac0_row1_col7 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_9dac0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9dac0_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_9dac0_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_9dac0_level0_col2" class="col_heading level0 col2" >nome-vide</th>
#       <th id="T_9dac0_level0_col3" class="col_heading level0 col3" >naturalidade</th>
#       <th id="T_9dac0_level0_col4" class="col_heading level0 col4" >uc-entrada</th>
#       <th id="T_9dac0_level0_col5" class="col_heading level0 col5" >uc-saida</th>
#       <th id="T_9dac0_level0_col6" class="col_heading level0 col6" >faculdade</th>
#       <th id="T_9dac0_level0_col7" class="col_heading level0 col7" >nome-pai</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9dac0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_
row5_col4" class="data row5 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_99131_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_99131_row6_col0" class="data row6 col0" >1665-10-19</td>
#       <td id="T_99131_row6_col1" class="data row6 col1" >231579</td>
#       <td id="T_99131_row6_col2" class="data row6 col2" >naturalidade</td>
#       <td id="T_99131_row6_col3" class="data row6 col3" >Campo Maior</td>
#       <td id="T_99131_row6_col4" class="data row6 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_99131_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_99131_row7_col0" class="data row7 col0" >1665-10-19</td>
#       <td id="T_99131_row7_col1" class="data row7 col1" >167251</td>
#       <td id="T_99131_row7_col2" class="data row7 col2" >nome</td>
#       <td id="T_99131_row7_col3" class="data row7 col3" >Pedro Simões</td>
#       <td id="T_99131_row7_col4" class="data row7 col4" >Pedro Simões Esteves, vide Simões</td>
#     </tr>
#     <tr>
#       <th id="T_99131_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_99131_row8_col0" class="data row8 col0" >1665-10-19</td>
#       <td id="T_99131_row8_col1" class="data row8 col1" >231579</td>
#       <td id="T_99131_row8_col2" class="data row8 col2" >nome</td>
#       <td id="T_99131_row8_col3" class="data row8 col3" >Pedro Simões</td>
#       <td id="T_99131_row8_col4" class="data row8 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_99131_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_99131_row9_col0" class="data row9 col0" >1665-10-19</td>
#       <td id="T_99131_row9_col1" class="data row9 col1" >167251</td>
#       <td id="T_99131_row9_col2" class="data row9 col2" >nome</td>
#       <td id="T_99131_row9_col3" class="data row9 col3" >Pedro Simões Esteves</td>
#       <td id="T_99131_row9_col4" class="data row9 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_99131_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_99131_row10_col0" class="data row10 col0" >1665-10-19</td>
#       <td id="T_99131_row10_col1" class="data row10 col1" >231579</td>
#       <td id="T_99131_row10_col2" class="data row10 col2" >nome</td>
#       <td id="T_99131_row10_col3" class="data row10 col3" >Pedro Simões Esteves</td>
#       <td id="T_99131_row10_c
# 4 149046 216902
# <style type="text/css">
# #T_f1fff_row0_col0, #T_f1fff_row0_col1, #T_f1fff_row0_col2, #T_f1fff_row0_col3, #T_f1fff_row0_col4, #T_f1fff_row0_col5, #T_f1fff_row0_col6, #T_f1fff_row0_col7 {
#   background-color: #fbb4ae;
# }
# #T_f1fff_row1_col0, #T_f1fff_row1_col1, #T_f1fff_row1_col2, #T_f1fff_row1_col3, #T_f1fff_row1_col4, #T_f1fff_row1_col5, #T_f1fff_row1_col6, #T_f1fff_row1_col7 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_f1fff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f1fff_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_f1fff_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_f1fff_level0_col2" class="col_heading level0 col2" >nome-vide</th>
#       <th id="T_f1fff_level0_col3" class="col_heading level0 col3" >naturalidade</th>
#       <th id="T_f1fff_level0_col4" class="col_heading level0 col4" >uc-entrada</th>
#       <th id="T_f1fff_level0_col5" class="col_heading level0 col5" >uc-saida</th>
#       <th id="T_f1fff_level0_col6" class="col_heading level0 col6" >faculdade</th>
#       <th id="T_f1fff_level0_col7" class="col_heading level0 col7" >nome-pai</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f1fff_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f1fff_row0_col0" class="data row0 col0" >149046</td>
#       <td id="T_f1fff_row0_col1" class="data row0 col1" >Bernardo José de Azevedo</td>
#       <td id="T_f1fff_row0_col2" class="data row0 col2" >Vieira</td>
#       <td id="T_f1fff_row0_col3" class="data row0 col3" >Paredes</td>
#       <td id="T_f1fff_row0_col4" class="data row0 col4" >1725-10-01</td>
#       <td id="T_f1fff_row0_col5" class="data row0 col5" >1746-10-01</td>
#       <td id="T_f1fff_row0_col6" class="data row0 col6" >Cânones</td>
#       <td id="T_f1fff_row0_col7" class="data row0 col7" >José de Azevedo Vieira</td>
#     </tr>
#     <tr>
#       <th id="T_f1fff_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f1fff_row1_col0" class="data row1 col0" >216902</td>
#       <td id="T_f1fff_row1_col1" class="data row1 col1" >Bernardo José de Azevedo Vieira</td>
#       <td id="T_f1fff_row1_col2" class="data row1 col2" >Azevedo</td>
#       <td id="T_f1fff_row1_col3" class="data row1 col3" >Paredes</td>
#       <td id="T_f1fff_row1_col4" class="data row1 col4" >1726-10-01</td>
#       <td id="T_f1fff_row1_col5" class="data row1 col5" >1729-10-01</td>
#       <td id="T_f1fff_row1_col6" class="data row1 col6" >Cânones</td>
#       <td id="T_f1fff_row1_col7" class="data row1 col7" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_a6d6a_row0_col0, #T_a6d6a_row0_col1, #T_a6d6a_row0_col2, #T_a6d6a_row0_col3, #T_a6d6a_row0_col4, #T_a6d6a_row1_col0, #T_a6d6a_row1_col1, #T_a6d6a_row1_col2, #T_a6d6a_row1_col3, #T_a6d6a_row1_col4, #T_a6d6a_row2_col0, #T_a6d6a_row2_col1, #T_a6d6a_row2_col2, #T_a6d6a_row2_col3, #T_a6d6a_row2_col4, #T_a6d6a_row3_col0, #T_a6d6a_row3_col1, #T_a6d6a_row3_col2, #T_a6d6a_row3_col3, #T_a6d6a_row3_col4, #T_a6d6a_row4_col0, #T_a6d6a_row4_col1, #T_a6d6a_row4_col2, #T_a6d6a_row4_col3, #T_a6d6a_row4_col4, #T_a6d6a_row5_col0, #T_a6d6a_row5_col1, #T_a6d6a_row5_col2, #T_a6d6a_row5_col3, #T_a6d6a_row5_col4, #T_a6d6a_row6_col0, #T_a6d6a_row6_col1, #T_a6d6a_row6_col2, #T_a6d6a_row6_col3, #T_a6d6a_row6_col4, #T_a6d6a_row7_col0, #T_a6d6a_row7_col1, #T_a6d6a_row7_col2, #T_a6d6a_row7_col3, #T_a6d6a_row7_col4, #T_a6d6a_row8_col0, #T_a6d6a_row8_col1, #T_a6d6a_row8_col2, #T_a6d6a_row8_col3, #T_a6d6a_row8_col4, #T_a6d6a_row9_col0, #T_a6d6a_row9_col1, #T_a6d6a_row9_col2, #T_a6d6a_row9_col3, #T_a6d6a_row9_col4, #T_a6d6a_row10_col0, #T_a6d6a_row10_col1, #T_a6d6a_row10_col2, #T_a6d6a_row10_col3, #T_a6d6a_row10_col4, #T_a6d6a_row12_col0, #T_a6d6a_row12_col1, #T_a6d6a_row12_col2, #T_a6d6a_row12_col3, #T_a6d6a_row12_col4, #T_a6d6a_row20_col0, #T_a6d6a_row20_col1, #T_a6d6a_row20_col2, #T_a6d6a_row20_col3, #T_a6d6a_row20_col4, #T_a6d6a_row22_col0, #T_a6d6a_row22_col1, #T_a6d6a_row22_col2, #T_a6d6a_row22_col3,
_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a6d6a_row8_col0" class="data row8 col0" >1725-10-01</td>
#       <td id="T_a6d6a_row8_col1" class="data row8 col1" >149046</td>
#       <td id="T_a6d6a_row8_col2" class="data row8 col2" >padre</td>
#       <td id="T_a6d6a_row8_col3" class="data row8 col3" >sim</td>
#       <td id="T_a6d6a_row8_col4" class="data row8 col4" >padre</td>
#     </tr>
#     <tr>
#       <th id="T_a6d6a_level0_row9" class="row_heading level0 row9" >9</th>
#       <
# 5 163896 210366
# 163896 is a possible 'see' record
# <style type="text/css">
# #T_10425_row0_col0, #T_10425_row0_col1, #T_10425_row0_col2, #T_10425_row0_col3, #T_10425_row0_col4, #T_10425_row0_col5, #T_10425_row0_col6, #T_10425_row0_col7 {
#   background-color: #fbb4ae;
# }
# #T_10425_row1_col0, #T_10425_row1_col1, #T_10425_row1_col2, #T_10425_row1_col3, #T_10425_row1_col4, #T_10425_row1_col5, #T_10425_row1_col6, #T_10425_row1_col7 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_10425">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_10425_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_10425_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_10425_level0_col2" class="col_heading level0 col2" >nome-vide</th>
#       <th id="T_10425_level0_col3" class="col_heading level0 col3" >naturalidade</th>
#       <th id="T_10425_level0_col4" class="col_heading level0 col4" >uc-entrada</th>
#       <th id="T_10425_level0_col5" class="col_heading level0 col5" >uc-saida</th>
#       <th id="T_10425_level0_col6" class="col_heading level0 col6" >faculdade</th>
#       <th id="T_10425_level0_col7" class="col_heading level0 col7" >nome-pai</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10425_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_10425_row0_col0" class="data row0 col0" >210366</td>
#       <td id="T_10425_row0_col1" class="data row0 col1" >Joaquim José Ribeiro de Vasconcelos</td>
#       <td id="T_10425_row0_col2" class="data row0 col2" >Joaquim José Ribeiro</td>
#       <td id="T_10425_row0_col3" class="data row0 col3" >Baía, Brasil</td>
#       <td id="T_10425_row0_col4" class="data row0 col4" >1779-10-26</td>
#       <td id="T_10425_row0_col5" class="data row0 col5" >1781-10-05</td>
#       <td id="T_10425_row0_col6" class="data row0 col6" >Filosofia</td>
#       <td id="T_10425_row0_col7" class="data row0 col7" >João Ribeiro de Vasconcelos</td>
#     </tr>
#     <tr>
#       <th id="T_10425_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_10425_row1_col0" class="data row1 col0" >163896</td>
#       <td id="T_10425_row1_col1" class="data row1 col1" >Joaquim José Ribeiro</td>
#       <td id="T_10425_row1_col2" class="data row1 col2" >Vasconcelos</td>
#       <td id="T_10425_row1_col3" class="data row1 col3" >Baía</td>
#       <td id="T_10425_row1_col4" class="data row1 col4" >1781-11-05</td>
#       <td id="T_10425_row1_col5" class="data row1 col5" >1781-11-05</td>
#       <td id="T_10425_row1_col6" class="data row1 col6" >Matemática</td>
#       <td id="T_10425_row1_col7" class="data row1 col7" >João Ribeiro de Vasconcelos</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d9318_row0_col0, #T_d9318_row0_col1, #T_d9318_row0_col2, #T_d9318_row0_col3, #T_d9318_row0_col4, #T_d9318_row1_col0, #T_d9318_row1_col1, #T_d9318_row1_col2, #T_d9318_row1_col3, #T_d9318_row1_col4, #T_d9318_row2_col0, #T_d9318_row2_col1, #T_d9318_row2_col2, #T_d9318_row2_col3, #T_d9318_row2_col4, #T_d9318_row3_col0, #T_d9318_row3_col1, #T_d9318_row3_col2, #T_d9318_row3_col3, #T_d9318_row3_col4, #T_d9318_row4_col0, #T_d9318_row4_col1, #T_d9318_row4_col2, #T_d9318_row4_col3, #T_d9318_row4_col4, #T_d9318_row5_col0, #T_d9318_row5_col1, #T_d9318_row5_col2, #T_d9318_row5_col3, #T_d9318_row5_col4, #T_d9318_row6_col0, #T_d9318_row6_col1, #T_d9318_row6_col2, #T_d9318_row6_col3, #T_d9318_row6_col4, #T_d9318_row7_col0, #T_d9318_row7_col1, #T_d9318_row7_col2, #T_d9318_row7_col3, #T_d9318_row7_col4, #T_d9318_row8_col0, #T_d9318_row8_col1, #T_d9318_row8_col2, #T_d9318_row8_col3, #T_d9318_row8_col4, #T_d9318_row9_col0, #T_d9318_row9_col1, #T_d9318_row9_col2, #T_d9318_row9_col3, #T_d9318_row9_col4, #T_d9318_row10_col0, #T_d9318_row10_col1, #T_d9318_row10_col2, #T_d9318_row10_col3, #T_d9318_row10_col4, #T_d9318_row11_col0, #T_d9318_row11_col1, #T_d9318_row11_col2, #T_d9318_row11_col3, #T_d9318_row11_col4, #T_d9318_row12_col0, #T_d9318_row12_col1, #T_d9318_row12_col2, #T_d9318_row12_col3, #T_d9318_row12_col4, #T_d9318_row13_col0, #T_d9318_row13_col1, #T_d9318_row13_col2, #T_d9318_row13_col3, #T_d9318_row13_col4 {
#   background-color: #fbb4ae;
# }
# ...
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_e4bd3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e4bd3_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_e4bd3_level0_col1" class="col_heading level0 col1" >id</th>
#       <th id="T_e4bd3_level0_col2" class="col_heading level0 col2" >type</th>
#       <th id="T_e4bd3_level0_col3" class="col_heading level0 col3" >value</th>
#       <th id="T_e4bd3_level0_col4" class="col_heading level0 col4" >attr_obs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4bd3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e4bd3_row0_col0" class="data row0 col0" >1652-09-16</td>
#       <td id="T_e4bd3_row0_col1" class="data row0 col1" >199685</td>
#       <td id="T_e4bd3_row0_col2" class="data row0 col2" >faculdade</td>
#       <td id="T_e4bd3_row0_col3" class="data row0 col3" >Leis</td>
#       <td id="T_e4bd3_row0_col4" class="data row0 col4" >Leis</td>
#     </tr>
#     <tr>
#       <th id="T_e4bd3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e4bd3_row1_col0" class="data row1 col0" >1652-09-16</td>
#       <td id="T_e4bd3_row1_col1" class="data row1 col1" >199685</td>
#       <td id="T_e4bd3_row1_col2" class="data row1 col2" >matricula-faculdade</td>
#       <td id="T_e4bd3_row1_col3" class="data row1 col3" >Leis</td>
#       <td id="T_e4bd3_row1_col4" class="data row1 col4" >16.09.1652</td>
#     </tr>
#     <tr>
#       <th id="T_e4bd3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e4bd3_row2_col0" class="data row2 col0" >1652-09-16</td>
#       <td id="T_e4bd3_row2_col1" class="data row2 col1" >199685</td>
#       <td id="T_e4bd3_row2_col2" class="data row2 col2" >naturalidade</td>
#       <td id="T_e4bd3_row2_col3" class="data row2 col3" >Lisboa</td>
#       <td id="T_e4bd3_row2_col4" class="data row2 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e4bd3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e4bd3_row3_col0" class="data row3 col0" >1652-09-16</td>
#       <td id="T_e4bd3_row3_col1" class="data row3 col1" >199685</td>
#       <td id="T_e4bd3_row3_col2" class="data row3 col2" >nome</td>
#       <td id="T_e4bd3_row3_col3" class="data row3 col3" >Diogo Mendes</td>
#       <td id="T_e4bd3_row3_col4" class="data row3 col4" >Diogo Mendes Leão, vide Mendes</td>
#     </tr>
#     <tr>
#       <th id="T_e4bd3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e4bd3_row4_col0" class="data row4 col0" >1652-09-16</td>
#       <td id="T_e4bd3_row4_col1" class="data row4 col1" >199685</td>
#       <td id="T_e4bd3_row4_col2" class="data row4 col2" >nome</td>
#       <td id="T_e4bd3_row4_col3" class="data row4 col3" >Diogo Mendes Leão</td>
#       <td id="T_e4bd3_row4_col4" class="data row4 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e4bd3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e4bd3_row5_col0" class="data row5 col0" >1652-09-16</td>
#       <td id="T_e4bd3_row5_col1" class="data row5 col1" >199685</td>
#       <td id="T_e4bd3_row5_col2" class="data row5 col2" >nome-vide</td>
#       <td id="T_e4bd3_row5_col3" class="data row5 col3" >Mendes</td>
#       <td id="T_e4bd3_row5_col4" class="data row5 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e4bd3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e4bd3_row6_col0" class="data row6 col0" >1652-09-16</td>
#       <td id="T_e4bd3_row6_col1" class="data row6 col1" >199685</td>
#       <td id="T_e4bd3_row6_col2" class="data row6 col2" >uc-entrada</td>
#       <td id="T_e4bd3_row6_col3" class="data row6 col3" >1652-09-16</td>
#       <td id="T_e4bd3_row6_col4" class="data row6 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e4bd3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e4bd3_row7_col0" class="data row7 col0" >1652-09-16</td>
#       <td id="T_e4bd3_row7_col1" class="data row7 col1" >199685</td>
#       <td id="T_e4bd3_row7_col2" class="data row7 col2" >uc-entrada.ano</td>
#       <td id="T_e4bd3_row7_col3" class="data row7 col3" >1652</td>
#       <td id="T_e4bd3_row7_col4" class="data row7 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e4bd3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e4bd3_row8_col0" class="data row8 col0" >1653-10-15</td>
#       <td id="T_e4bd3_row8_col1" class="data row8 col1" >199685</td>
#       <td id="T_e4bd3_row8_col2" class="data row8 col2" >matricula-faculdade</td>
#       <td id="T_e4bd3_row8_col3" class="data row8 col3" >Leis</td>
#       <td id="T_e4bd3_row8_col4" class="data row8 col4" >15.10.1653</td>
#     </tr>
#     <tr>
#       <th id="T_e4bd3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e4bd3_row9_col0" class="data row9 col0" >1653-10-15</td>
#       <td id="T_e4bd3_row9_col1" class="data row9 col1" >199685</td>
#       <td id="T_e4bd3_row9_col2" class="data row9 col2" >uc-saida</td>
#       <td id="T_e4bd3_row9_col3" clas
# 20 160999 214635
# FAR APART >15 years: possible false match, records chronologically affar
# <style type="text/css">
# #T_006e4_row0_col0, #T_006e4_row0_col1, #T_006e4_row0_col2, #T_006e4_row0_col3, #T_006e4_row0_col4, #T_006e4_row0_col5, #T_006e4_row0_col6, #T_006e4_row0_col7 {
#   background-color: #fbb4ae;
# }
# #T_006e4_row1_col0, #T_006e4_row1_col1, #T_006e4_row1_col2, #T_006e4_row1_col3, #T_006e4_row1_col4, #T_006e4_row1_col5, #T_006e4_row1_col6, #T_006e4_row1_col7 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_006e4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_006e4_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_006e4_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_006e4_level0_col2" class="col_heading level0 col2" >nome-vide</th>
#       <th id="T_006e4_level0_col3" class="col_heading level0 col3" >naturalidade</th>
#       <th id="T_006e4_level0_col4" class="col_heading level0 col4" >uc-entrada</th>
#       <th id="T_006e4_level0_col5" class="col_heading level0 col5" >uc-saida</th>
#       <th id="T_006e4_level0_col6" class="col_heading level0 col6" >faculdade</th>
#       <th id="T_006e4_level0_col7" class="col_heading level0 col7" >nome-pai</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_006e4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_006e4_row0_col0" class="data row0 col0" >214635</td>
#       <td id="T_006e4_row0_col1" class="data row0 col1" >Pedro Velho</td>
#       <td id="T_006e4_row0_col2" class="data row0 col2" >Fragoso</td>
#       <td id="T_006e4_row0_col3" class="data row0 col3" >Vila Nova de Portimão</td>
#       <td id="T_006e4_row0_col4" class="data row0 col4" >1608-10-01</td>
#       <td id="T_006e4_row0_col5" class="data row0 col5" >1617-07-23</td>
#       <td id="T_006e4_row0_col6" class="data row0 col6" >Cânones</td>
#       <td id="T_006e4_row0_col7" class="data row0 col7" >Francisco Velho</td>
#     </tr>
#     <tr>
#       <th id="T_006e4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_006e4_row1_col0" class="data row1 col0" >160999</td>
#       <td id="T_006e4_row1_col1" class="data row1 col1" >Pedro Velho Fragoso</td>
#       <td id="T_006e4_row1_col2" class="data row1 col2" >Velho</td>
#       <td id="T_006e4_row1_col3" class="data row1 col3" >Vila Nova de Portimão</td>
#       <td id="T_006e4_row1_col4" class="data row1 col4" >1626-05-12</td>
#       <td id="T_006e4_row1_col5" class="data row1 col5" >1636-11-05</td>
#       <td id="T_006e4_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_006e4_row1_col7" class="data row1 col7" >Francisco Velho</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_096c4_row0_col0, #T_096c4_row0_col1, #T_096c4_row0_col2, #T_096c4_row0_col3, #T_096c4_row0_col4, #T_096c4_row1_col0, #T_096c4_row1_col1, #T_096c4_row1_col2, #T_096c4_row1_col3, #T_096c4_row1_col4, #T_096c4_row2_col0, #T_096c4_row2_col1, #T_096c4_row2_col2, #T_096c4_row2_col3, #T_096c4_row2_col4, #T_096c4_row3_col0, #T_096c4_row3_col1, #T_096c4_row3_col2, #T_096c4_row3_col3, #T_096c4_row3_col4, #T_096c4_row4_col0, #T_096c4_row4_col1, #T_096c4_row4_col2, #T_096c4_row4_col3, #T_096c4_row4_col4, #T_096c4_row5_col0, #T_096c4_row5_col1, #T_096c4_row5_col2, #T_096c4_row5_col3, #T_096c4_row5_col4, #T_096c4_row6_col0, #T_096c4_row6_col1, #T_096c4_row6_col2, #T_096c4_row6_col3, #T_096c4_row6_col4, #T_096c4_row7_col0, #T_096c4_row7_col1, #T_096c4_row7_col2, #T_096c4_row7_col3, #T_096c4_row7_col4, #T_096c4_row8_col0, #T_096c4_row8_col1, #T_096c4_row8_col2, #T_096c4_row8_col3, #T_096c4_row8_col4, #T_096c4_row9_col0, #T_096c4_row9_col1, #T_096c4_row9_col2, #T_096c4_row9_col3, #T_096c4_row9_col4, #T_096c4_row10_col0, #T_096c4_row10_col1, #T_096c4_row10_col2, #T_096c4_row10_col3, #T_096c4_row10_col4, #T_096c4_row11_col0, #T_096c4_row11_col1, #T_096c4_row11_col2, #T_096c4_row11_col3, #T_096c4_row11_col4, #T_096c4_row12_col0, #T_096c4_row12_col1, #T_096c4_row12_col2, #T_096c4_row12_col3, #T_096c4_row12_col4, #T_096c4_row13_col0, #T_096c4_row13_col1, #T_096c4_row13_col2, #T_096c4_row13_col3, #T_096c4_row13_col4, #T_096c4_row14_col0, #T_096c4_row14_col1, #T_096c4_row14_col2, #T_096c4_row14_col3, #T_096c4_row14_col4,
col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_096c4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_096c4_row3_col0" class="data row3 col0" >1608-10-01</td>
#       <td id="T_096c4_row3_col1" class="data row3 col1" >214635</td>
#       <td id="T_096c4_row3_col2" class="data row3 col2" >nome</td>
#       <td id="T_096c4_row3_col3" class="data row3 col3" >Pedro Velho</td>
#       <td id="T_096c4_row3_col4" class="data row3 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_096c4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_096c4_row4_col0" class="data row4 col0" >1608-10-01</td>
#       <td id="T_096c4_row4_col1" class="data row4 col1" >214635</td>
#       <td id="T_096c4_row4_col2" class="data row4 col2" >nome</td>
#       <td id="T_096c4_row4_col3" class="data row4 col3" >Pedro Velho Fragoso</td>
#       <td id="T_096c4_row4_col4" class="data row4 col4" >Pedro Velho, vide Fragoso</td>
#     </tr>
#     <tr>
#       <th id="T_096c4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_096c4_row5_col0" class="data row5 col0" >1608-10-01</td>
#       <td id="T_096c4_row5_col1" class="data row5 col1" >214635</td>
#       <td id="T_096c4_row5_col2" class="data row5 col2" >nome-pai</td>
#       <td id="T_096c4_row5_col3" class="data row5 col3" >Francisco Velho</td>
#       <td id="T_096c4_row5_col4" class="data row5 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_096c4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_096c4_row6_col0" class="data row6 col0" >1608-10-01</td>
#       <td id="T_096c4_row6_col1" class="data row6 col1" >214635</td>
#       <td id="T_096c4_row6_col2" class="data row6 col2" >nome-vide</td>
#       <td id="T_096c4_row6_col3" class="data row6 col3" >Fragoso</td>
#       <td id="T_096c4_row6_col4" class="data row6 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_096c4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_096c4_row7_col0" class="data row7 col0" >1608-10-01</td>
#       <td id="T_096c4_row7_col1" class="data row7 col1" >214635</td>
#       <td id="T_096c4_row7_col2" class="data row7 col2" >uc-entrada</td>
#       <td id="T_096c4_row7_col3" class="data row7 col3" >1608-10-01</td>
#       <td id="T_096c4_row7_col4" class="data row7 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_096c4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_096c4_row8_col0" class="data row8 col0" >1608-10-01</td>
#       <td id="T_096c4_row8_col1" class="data row8 col1" >214635</td>
#       <td id="T_096c4_row8_col2" class="data row8 col2" >uc-entrada.ano</td>
#       <td id="T_096c4_row8_col3" class="data row8 col3" >1608</td>
#       <td id="T_096c4_row8_col4" class="data row8 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_096c4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_096c4_row9_col0" class="data row9 col0" >1609-10-06</td>
#       <td id="T_096c4_row9_col1" class="data row9 col

# %% [markdown]
# #### Types of transformations in matched records

# %%
vide_types_matches = matched.groupby('vide_type').count()[['name']]
vide_types_matches['perc'] = vide_types_matches['name']/ vide_types_matches['name'].sum()
vide_types_matches
# Out:
#            name      perc
# vide_type
# add        1897  0.460213
# cut        1899  0.460699
# novid        26  0.006308
# rep         294  0.071325
# repap         6  0.001456

# %%
match_info.fillna("")
# Out:
#                     data sequential random perc_vide_plus perc_matched_ok  \
# aka                 3062                         0.349304
# aka_fac             3035                         0.346224
# aka_geo             2973                         0.339151
# aka_matched         1910       1913   1970
# aka_matched_ok      1940       1907   1897
# aka_pai             1619                         0.184691
# matched_pairs       3818       3644   3804
# matched_pairs_ok    3665       3628   3614
# nodate              5763                         0.657426
# nodate_novide        141                         0.016085
# nodate_novide        141                         0.016085
# records_aka_aka      188        200    216       0.021446        0.050783
# records_aka_see     1722       1713   1754       0.196441        0.465154
# records_asymmetric    74          0     76
# records_error        116         12    190
# records_matched     3818       3640   3804       0.435546
# records_matched_ok  3702       3628   3614       0.422313             1.0
# records_see_aka     1746       1713   1781       0.199179        0.471637
# records_see_see       10         14     24       0.001141        0.002701
# records_transitive   116         12    116       0.013233        0.031334
# see                 5704
# see_fac             1378
# see_geo             5274
# see_matched         1756       1727   1796
# see_matched_ok      1762       1721   1717
# see_pai             1569
# vide                8625                         0.983915
# vide_plus           8766                              1.0
#
#                    perc_type            type
# aka                      1.0             aka
# aka_fac             0.991182             aka
# aka_geo             0.970934             aka
# aka_matched         0.623775             aka
# aka_matched_ok      0.633573             aka
# aka_pai             0.528739             aka
# matched_pairs            1.0   matched_pairs
# matched_pairs_ok    0.959927   matched_pairs
# nodate
# nodate_novide
# nodate_novide
# records_aka_aka     0.061398             aka
# records_aka_see     0.562378             aka
# records_asymmetric
# records_error
# records_matched          1.0  records_mached
# records_matched_ok  0.969618  records_mached
# records_see_aka     0.306101             see
# records_see_see     0.001753             see
# records_transitive  0.030382  records_mached
# see                      1.0             see
# see_fac             0.241585             see
# see_geo             0.924614             see
# see_matched         0.307854             see
# see_matched_ok      0.308906             see
# see_pai              0.27507             see
# vide
# vide_plus

# %% [markdown]
# ### Analysis of non matched records

# %%
pd.set_option('display.max_rows',250)
matched_index = match_records['records_matched']['data']
non_matched_index = set(vide_plus.index.unique())-set(matched_index)
vide_non_matched = vide_plus.loc[list(non_matched_index)].sort_values(['sort_key','nome-geografico'])[['nome-geografico','match','name','nome-vide','vide_type','lookup','faculdade','nome-pai','uc-entrada','match_error','match_obs']]
vide_non_matched.to_csv('../inferences/cross-references/vide_non_matched.csv',sep=',')

# %%
vide_types_non_matches = vide_non_matched.groupby('vide_type').count()[['name']]
vide_types_non_matches['perc'] = vide_types_non_matches['name']/ vide_types_non_matches['name'].sum()
vide_types_non_matches
# Out:
#            name      perc
# vide_type
# add        2160  0.406321
# cut        2227  0.418924
# novid       126  0.023702
# rep         763  0.143529
# rep+         20  0.003762
# repap        20  0.003762

# %% [markdown]
# ### Sample of non-matched records

# %%
vide_non_matched.head(31)
# Out:
#             nome-geografico match  \
# 220890           Portalegre  None
# 271719              Abreiro  None
# 271719            Mirandela  None
# 182548                 Eiró  None
# 285686   Oliveira de Frades  None
# 285686             Pinheiro  None
# 286149   Amoreira da Gandra  None
# 226700               Marvão  None
# 226683               Marvão  None
# 273326               Lisboa  None
# 230176                Arcos  None
# 230176               Aveiro  None
# 250994                Arcos  None
# 250994               Aveiro  None
# 282429             ***NA***  None
# 180061            Salgueiro  None
# 180742            Salgueiro  None
# 296930              Almarge  None
# 225520               Lisboa  None
# 147465             Trancoso  None
# 251547                 Baía  None
# 225529               Monção  None
# 129050                Elvas  None
# 221241                Elvas  None
# 271719                                   Abel de Mendonça
# 271719                                   Abel de Mendonça
# 182548          José Joaquim Xavier Teixeira de Magalhães
# 285686                          Abílio Ribeiro de Almeida
# 285686                          Abílio Ribeiro de Almeida
# 286149                       Adelino Pinto Tavares Ferrão
# 226700                                Adolfo António Rôlo
# 226683                        Adolfo Augusto Zuzarte Rôlo
# 273326                        Adriano Ernesto de Castilho
# 230176       Adriano Joaquim Lopes Mariz e Silva Monteiro
# 230176       Adriano Joaquim Lopes Mariz e Silva Monteiro
# 250994               Tomás Joaquim Lopes de Maris e Silva
# 250994               Tomás Joaquim Lopes de Maris e Silva
# 282429                    Adriano Osório Pereira Cerenato
# 180061                      Adriano Osório Pereira Guerra
# 180742                      João António Pereira Cerenato
# 296930        Adriano Sisnando Brotero Quintino de Avelar
# 225520                               Adrião Pereira Gomes
# 147465                           Afonso de Araújo Tavares
# 251547                             Afonso Luís da Fonseca
# 225529                             Afonso Pereira Pimenta
# 129050                                   Afonso Rodrigues
# 221241                                Afonso Vaz Sardinha
# 235544                             Afonso Soares de Lemos
# 225535                                       Afonso de Sá
# 148819                                    Afonso Teixeira
# 214149                                    Afonso Teixeira
# 199294                 Afonso Teixeira Mendonça e Azevedo
# 199294                 Afonso Teixeira Mendonça e Azevedo
# 316331  Agostinho António de Sousa Brito Resende Souto...
#
#                                  faculdade  \
# 220890                                 NaN
# 271719                                 NaN
# 271719                                 NaN
# 182548  Cursos jurídicos (Cânones ou Leis)
# 285686  Cursos jurídicos (Cânones ou Leis)
# 285686  Cursos jurídicos (Cânones ou Leis)
# 286149                                 NaN
# 226700                            Medicina
# 226683                                 NaN
# 273326                                 NaN
# 230176  Cursos jurídicos (Cânones ou Leis)
# 230176  Cursos jurídicos (Cânones ou Leis)
# 250994  Cursos jurídicos (Cânones ou Leis)
# 250994  Cursos jurídicos (Cânones ou Leis)
# 282429                                 NaN
# 180061  Cursos jurídicos (Cânones ou Leis)
# 180742                                Leis
# 296930                                 NaN
# 225520                             Cânones
# 147465                                 NaN
# 251547                                 NaN
# 225529                                 NaN
# 129050                                Leis
# 221241                             Cânones
# 235544                                 NaN
# 225535                             Cânones
# 148819                                 NaN
# 214149                                Leis
# 199294                             Cânones
# 199294                                Leis
# 316331                                 NaN
#
#                                        nome-pai  uc-entrada  match_error  \
# 220890                                      NaN  0000-00-00        False
# 271719                                      NaN  0000-00-00        False
# 271719                                      NaN  0000-00-00        False
# 182548                                      NaN  0000-00-00        False
# 285686  António de Almeida Silva Campos de Melo  0000-00-00        False
# 285686  António de Almeida Silva Campos de Melo  0000-00-00        False
# 286149                                      NaN  0000-00-00        False
# 226700                                      NaN  1871-06-06        False
# 226683                                      NaN  0000-00-00        False
# 273326                                      NaN  0000-00-00        False
# 230176                                      NaN  0000-00-00        False
# 230176                                      NaN  0000-00-00        False
# 250994                                      NaN  1794-10-14        False
# 250994                                      NaN  1794-10-14        False
# 282429                                Salgueira  0000-00-00        False
# 180061                                      NaN  1800-10-31        False
# 180742                                      NaN  1799-10-07        False
# 296930                                      NaN  0000-00-00        False
# 225520                              Adrião Dias  0000-00-00        False
# 147465                                      NaN  0000-00-00        False
# 251547                                      NaN  0000-00-00        False
# 225529                                      NaN  0000-00-00        False
# 129050                                      NaN  1657-11-02        False
# 221241                        Gonçalo Rodrigues  1706-10-01        False
# 235544                     António Pinto Soares  0000-00-00        False
# 225535                                      NaN  0000-00-00        False
# 148819                                      NaN  0000-00-00        False
# 214149                                      NaN  0000-00-00        False
# 199294                                      NaN  1650-11-08        False
# 199294                                      NaN  1650-11-08        False
# 316331                                      NaN  0000-00-00        False
#
#        match_obs
# 220890       NaN
# 271719       NaN
# 271719       NaN
# 182548       NaN
# 285686       NaN
# 285686       NaN
# 286149       NaN
# 226700       NaN
# 226683       NaN
# 273326       NaN
# 230176       NaN
# 230176       NaN
# 250994       NaN
# 250994       NaN
# 282429       NaN
# 180061       NaN
# 180742       NaN
# 296930       NaN
# 225520       NaN
# 147465       NaN
# 251547       NaN
# 225529       NaN
# 129050       NaN
# 221241       NaN
# 235544       NaN
# 225535       NaN
# 148819       NaN
# 214149       NaN
# 199294       NaN
# 199294       NaN
# 316331       NaN

# %% [markdown]
# Analysis:
# 1. 220890	Portalegre	"Pedro Rodrigues, vide; Abreu" links with 140806 __problem in vide expression__
# 2. 271719	Abreiro/Mirandela	Abel de Mendonça Machado de Araújo	Abel de Mendonça links with 286147 __no back vide expression__
# 3. 182548	Eiró	Abel Xavier Teixeira de Magalhães	José Joaquim Xavier Teixeira de Magalhães links with 182950  __no back vide expression__
# 4. 285686	Oliveira de Frades	Abílio Ribeiro de Almeida Campos de Melo	Abílio Ribeiro de Almeida links with 142075 __no back vide expression__
# 5. 286149	Amoreira da Gandra	Adelino Pinto Tavares Ferrão de Mendonça	Ferrão links with 248088 __no back vide expression__ and __typo in geo name__
# 6. 273326	Lisboa	Adriano Ernesto de Castilho Barreto	Castilho links with 189993 __no back vide expression__
# 7. 230176	Arcos	Tomás Joaquim Lopes de Mariz e Silva	Adriano Joaquim Lopes Mariz e Silva Monteiro links with 250994 __variation in the vide name (Maris/Mariz)__
# 8. 282429	NaN	Adriano Osório Pereira Gouveia	Adriano Osório Pereira Cerenato	rep	Adriano Osório Pereira Cerenato	links with 291196 __no back vide expression__
# 9. 296930	Almarge	Adriano Sisnando Brotero de Avelar Quintino	Adriano Sisnando Brotero Quintino de Avelar	rep	Adriano Sisnando Brotero Quintino de Avelar links with 133134 __no back vide expression__
# 10. 225520	Lisboa	Adrião Pereira	Gomes	add	Adrião Pereira Gomes	Cânones, links with 178240 __no back vide expression__
# 11. 147465	Trancoso	Afonso Tavares de Araújo	Afonso de Araújo Tavares	rep	Afonso de Araújo Tavares links with 197047 __no back vide expression__
# 12. 169888	Lisboa	Afonso Furtado	Mendonça	add	Afonso Furtado Mendonça link with 214147 (see) or 169890__ __ambiguity__
# 13. 251547	Baía	Afonso Luís	da Fonseca	add	Afonso Luís da Fonseca	links with 139362 __no back vide expression__
# 14. 225529	Monção	Afonso Pereira	Pimenta	add	Afonso Pereira Pimenta	 links with 241162 __no back vide expression__
# 15. 129050	Elvas	Afonso Rodrigues Caldas	Rodrigues	cut	Afonso Rodrigues __no link found__
# 16. 221241	Elvas	Afonso Sardinha	Afonso Vaz Sardinha	rep	Afonso Vaz Sardinha	Cânones see link missing	__no link found__
# 17. 235544	Elvas	Afonso Soares da Mota	Afonso Soares de Lemos	rep	Afonso Soares de Lemos	link 211794 	__no back vide expression__
# 18. 225535	Aldeia Nova do Cabo	Afonso de Sá Pereira	Sá	cut	Afonso de Sá links with 211378 __no back vide expression__
# 19. 199294	Vila Real	Afonso Teixeira	   Mendonça e Azevedo	add	Afonso Teixeira Mendonça e Azevedo	Cânones	 links with 148819/See  214149/see __ambiguity__
# 20. 316331	Quinta do Alqueidão	Agostinho António de Sousa Brito Resende	Soutomaior	add	Agostinho António de Sousa Brito Resende Souto...
# 	link to 224178 	__no back vide expression_ NO match on geoname Alqueidão, quinta do Alqueidão__
# 21. 234238 Lisboa	Agostinho Armando de Vasconcelos e Sousa	Agostinho Armando Vasconcelos	rep	Agostinho Armando Vasconcelos
#         Links to 148028 __fail lookup not matching linked record name: both lookup the same though__

# %% [markdown]
# ### Aka Records non matched
#
# There is an inbalance of "see" and "aka" numbers, so a high number of unmatched "see"  is expected.
#
# Aka records should be more easily matched with corresponding see. That is the case in fact with around 55% of aka records matched
#
# Let's see the reason why Aka records do not find a matching "see".

# %%
aka_see_not_matched_index = vide_non_matched[vide_non_matched['uc-entrada']!='0000-00-00'].index.unique()
print("Number of aka records not matched:", {len(aka_see_not_matched_index)})
print("Partial list, change head parameter for more:")

vide_non_matched.loc[aka_see_not_matched_index].head(20)
# Out:
# Number of aka records not matched: {1053}
# Partial list, change head parameter for more:
#           nome-geografico match                                       name  \
# 226700             Marvão  None                        Adolfo Augusto Rôlo
# 250994              Arcos  None  Adriano Joaquim de Mariz e Silva Monteiro
# 250994             Aveiro  None  Adriano Joaquim de Mariz e Silva Monteiro
# 180061          Salgueiro  None        João António Osório Pereira Gouveia
# 180742          Salgueiro  None              Adriano Osório Pereira Guerra
# 129050              Elvas  None                    Afonso Rodrigues Caldas
# 221241              Elvas  None                            Afonso Sardinha
# 199294          Vila Real  None                            Afonso Teixeira
# 199294          Vila Real  None                            Afonso Teixeira
# 187458        Santa Olaia  None                          Agostinho Brandão
# 152599             Lisboa  None                 Agostinho José de Carvalho
# 149805             Lisboa  None                      Aires Correia Baharém
# 247737    Condeixa-a-Nova  None                    Aires Duarte de Miranda
# 224211            Covilhã  None         Aires Francisco de Proneça e Silva
# 192844          Ovfmatsen  None                            Alberto Chremer
# 298044            Coimbra  None                     Alberto de Moura Pinto
# 168566             Lisboa  None                       Alberto de Negreiros
# 234289           Celorico  None                 Alexandre Batista de Sousa
# 150110  Celorico de Basto  None                          Alexandre Batista
# 152672           Amarante  None               Alexandre Duarte de Carvalho
#
#                                                nome-vide vide_type  \
# 226700                               Adolfo António Rôlo       rep
# 250994              Tomás Joaquim Lopes de Maris e Silva      rep+
# 250994              Tomás Joaquim Lopes de Maris e Silva      rep+
# 180061                     Adriano Osório Pereira Guerra      rep+
# 180742                     João António Pereira Cerenato      rep+
# 129050                                         Rodrigues       cut
# 221241                               Afonso Vaz Sardinha       rep
# 199294                                Mendonça e Azevedo       add
# 199294                                Mendonça e Azevedo       add
# 187458                                             Pinto       add
# 152599  Agostinho José de Figueiredo Carvalho e Oliveira       rep
# 149805                                           Correia       cut
# 247737                             José Aires de Miranda       rep
# 224211                                           Proença       add
# 192844                                           Cremert       add
# 298044                                   Alberto Marques       rep
# 168566                                          Ferreira       add
# 234289                                           Batista       cut
# 150110                                             Sousa       add
# 152672                                            Duarte       cut
#
#                                                   lookup  \
# 226700                               Adolfo António Rôlo
# 250994              Tomás Joaquim Lopes de Maris e Silva
# 250994              Tomás Joaquim Lopes de Maris e Silva
# 180061                     Adriano Osório Pereira Guerra
# 180742                     João António Pereira Cerenato
# 129050                                  Afonso Rodrigues
# 221241                               Afonso Vaz Sardinha
# 199294                Afonso Teixeira Mendonça e Azevedo
# 199294                Afonso Teixeira Mendonça e Azevedo
# 187458                           Agostinho Brandão Pinto
# 152599  Agostinho José de Figueiredo Carvalho e Oliveira
# 149805                                     Aires Correia
# 247737                             José Aires de Miranda
# 224211        Aires Francisco de Proneça e Silva Proença
# 192844                           Alberto Chremer Cremert
# 298044                                   Alberto Marques
# 168566                     Alberto de Negreiros Ferreira
# 234289                                 Alexandre Batista
# 150110                           Alexandre Batista Sousa
# 152672                                  Alexandre Duarte
#
#                                  faculdade                   nome-pai  \
# 226700                            Medicina                        NaN
# 250994  Cursos jurídicos (Cânones ou Leis)                        NaN
# 250994  Cursos jurídicos (Cânones ou Leis)                        NaN
# 180061  Cursos jurídicos (Cânones ou Leis)                        NaN
# 180742                                Leis                        NaN
# 129050                                Leis                        NaN
# 221241                             Cânones          Gonçalo Rodrigues
# 199294                             Cânones                        NaN
# 199294                                Leis                        NaN
# 187458  Cursos jurídicos (Cânones ou Leis)                        NaN
# 152599                                Leis                        NaN
# 149805                            Teologia  Manuel Correia de Menezes
# 247737                             Cânones         Custódio Gonçalves
# 224211                             Cânones                        NaN
# 192844                             Cânones                        NaN
# 298044                             Direito              Pai incognito
# 168566                             Cânones                        NaN
# 234289                            Medicina    Manuel Batista de Sousa
# 150110                            Medicina    Manuel Batista de Sousa
# 152672                             Cânones                        NaN
#
#         uc-entrada  match_error match_obs
# 226700  1871-06-06        False       NaN
# 250994  1794-10-14        False       NaN
# 250994  1794-10-14        False       NaN
# 180061  1800-10-31        False       NaN
# 180742  1799-10-07        False       NaN
# 129050  1657-11-02        False       NaN
# 221241  1706-10-01        False       NaN
# 199294  1650-11-08        False       NaN
# 199294  1650-11-08        False       NaN
# 187458  1688-01-21        False       NaN
# 152599  1791-10-27        False       NaN
# 149805  1594-10-18        False       NaN
# 247737  1736-10-01        False       NaN
# 224211  1719-10-01        False       NaN
# 192844  1726-10-01        False       NaN
# 298044  1902-06-10        False       NaN
# 168566  1702-10-01        False       NaN
# 234289  1690-10-01        False       NaN
# 150110  1690-10-01        False       NaN
# 152672  1710-10-01        False       NaN

# %% [markdown]
# ##### Analysis
#
# 1. 226700 Marvão Adolfo Augusto Rôlo, vide Adolfo António Rôlo matches 226683 Adolfo António Rôlo, vide Adolfo Augusto Zuzarte Rôlo __back vide does not match__
# 2. 250994 Arcos	Tomás Joaquim Lopes de Mariz e Silva vide Adriano Joaquim Lopes Mariz e Silva Monteiro links with  230176 __variation in the vide name (Maris/Mariz)__
# 3. 180061	Salgueiro	_João António Osório Pereira Gouveia_, vide Adriano Osório Pereira Guerra	rep+	Adriano Osório Pereira Guerra	Direito (Cânones ou Leis) 1800-10-31	__variation in the vide name__
#   * 180742	Salgueiro   Adriano Osório Pereira Guerra, vide _João António Pereira Cerenato_	Leis 1799-10-07
#   * Other possible matches 291196, 191903 complex case
# 4. 129050	Elvas	Afonso Rodrigues Caldas	vide Rodrigues	cut	Afonso Rodrigues	Leis	NaN	1657-11-02	__see record not found manualy__
# 5. 221241	Elvas	Afonso Sardinha	vide Afonso Vaz Sardinha	rep	Afonso Vaz Sardinha	Cânones	Gonçalo Rodrigues	1706-10-01	__see record not found manualy__
# 6. 199294	Vila Real	Afonso Teixeira	vide Mendonça e Azevedo	add	Afonso Teixeira Mendonça e Azevedo	Cânones	1650-11-08
#   * links with see record 214149 Afonso Teixeira de Mendonça, vide Teixeira  __vide in aka record does not match name in see record__
#   * links also with 148819 Afonso Teixeira de Azevedo, vide Teixeira __vide in aka record does not match name in see record__
#   * so the vide expression in 199924 should be __vide Mendonça e vide Azevedo__ to link with Afonso Teixeira de Mendonça and Afonso Teixeira de Azevedo
# 7. 187458	Santa Olaia	Agostinho Brandão	vide Pinto	add	Agostinho Brandão Pinto	Direito (Cânones ou Leis)	NaN	1688-01-21	__matching record is aka, not see__
#   * links with 245344 which is not a see record nor a vide record. __187458 and 245344 are dupicates__ __matching record is aka, not see__
# 8.  152599	Lisboa	Agostinho José de Carvalho vide	Agostinho José de Figueiredo Carvalho e Oliveira	Leis	1791-10-27
#    *  links with 174123 Agostinho José de Figueiredo Carvalho e Oliveira, but it is not a see record. __152599 and 174213 are duplicates__ __matching record is aka, not see__
# 9. 149805	Lisboa Aires Correia Baharém vide	Correia	cut	Aires Correia	Teologia	pai Manuel Correia de Menezes	1594-10-18
#   * links with see record 196492 slight variation in the vide expression __variation in the vide name (Baharém/Baharem)__
#
#
# 10. 192844	Ovfmatsen	Alberto Chremer	vide Cremert	add	Alberto Chremer Cremert	Cânones
#    *  links with 207263 Alberto Cremert no vide expression __matching record is aka, not see__ __duplicate__

# %% [markdown]
# ### Matched records
#
# Sucessive lines are matches. Sometime more than one line per record when there is more than one geographic name or faculty.

# %%
vide_plus.loc[matched_index].sort_values(['nome-geografico','sort_key','uc-entrada'])[['uc-entrada','nome-geografico','name','lookup','nome-pai','faculdade','faculdade.obs','match_obs']].head(30)
# Out:
#         uc-entrada     nome-geografico                                name  \
# 202622  0000-00-00          Constância            Fernão de Álvares Temudo
# 144388  1573-11-13          Constância                   Fernão de Álvares
# 146869                  António Figueiredo                          NaN
#
#                                  faculdade       faculdade.obs match_obs
# 202622                                 NaN                 NaN       NaN
# 144388                             Cânones             Cânones       NaN
# 171438                                Leis                Leis       NaN
# 213495                                Leis                Leis       NaN
# 214577                                 NaN                 NaN       NaN
# 143676                             Cânones             Cânones       NaN
# 203159                                 NaN                 NaN       NaN
# 176277                             Cânones             Cânones       NaN
# 243351                             Cânones             Cânones       NaN
# 165844                             Cânones           . Cânones       NaN
# 146909                                 NaN                 NaN       NaN
# 251620                             Cânones             Cânones       NaN
# 251990                                 NaN                 NaN       NaN
# 187661                                Leis                Leis       NaN
# 187658                                Leis                Leis       NaN
# 247274                             Cânones             Cânones       NaN
# 144513                             Cânones             Cânones       NaN
# 233523                                 NaN                 NaN       NaN
# 147478  Cursos jurídicos (Cânones ou Leis)  Faculdade inferida       NaN
# 167316                                 NaN                 NaN       NaN
# 147265                            Teologia            Teologia       NaN
# 249475                                 NaN                 NaN       NaN
# 163593                            Teologia            Teologia       NaN
# 217035                                 NaN                 NaN       NaN
# 217030                            Teologia            Teologia       NaN
# 223442                                 NaN                 NaN       NaN
# 233837                                Leis                Leis       NaN
# 218229                                 NaN                 NaN       NaN
# 218205                            Teologia            Teologia       NaN
# 146869                                 NaN                 NaN       NaN

# %% [markdown]
# # Save current stats on cross reference processing
#
# This allows later in "git" see how the situation evolves.

# %%
# save status to file
fname = '../inferences/cross-references/015-remissivas_info.txt'

with open(fname,'w+') as f:
    print(f"Cross references, current stats: {current_time}",file=f)
    print(file=f)

    vide_plus.info(buf=f)

    print(match_info.fillna(""), file=f)

# %% [markdown]
# ### Focus on specific records
#
# Use this to check specific records.
#
#
# Define a column and a pattern to search for. Pattern is a _regular expression_.
# For more information on the patterns and alternative searches see https://pandas.pydata.org/docs/reference/api/pandas.Series.str.contains.html
#
# Examples:
#
# * column='nome', pattern='André': 'André' anywhere in column 'name' (will also get 166395 Manuel André Ribeiro)
# * column='nome', pattern='André$': names ending in 'André' (e.g. 146664 Manuel André )
# * column='nome', pattern='^André': names starting with 'André'
# * column='nome', pattern='André|Joaquim': names containing either 'André' or 'Joaquim'
# * column='naturalidade', pattern='Alcácer|Alcacer':  naturalidade contains either 'Alcácer' or 'Alcacer'

# %%
import pandas as pd
column = 'name'
pattern = '^Estevão'
pd.set_option('display.max_rows',1000)
#                                      na=False prevents errors column is missing
vide_selection = vide_plus[vide_plus[column].str.contains(pattern,na=False)]
vide_selection.sort_values([column]).head(10)
# Out:
#                                           name sex  \
# 200659                 Estevão Afonso da Costa   m
# 276913                 Estevão Anacleto Duarte   m
# 236147  Estevão Barreto de Magalhães e Menezes   m
# 129044                         Estevão Caetano   m
# 134106        Estevão Caetano de Araújo Rangel   m
# 133510                         Estevão Cardoso   m
# 230444             Estevão Cardoso da Silveira   m
# 152876                            Estevão Dias   m
# 233458                    Estevão Dias Pereira   m
# 293823                     Estevão Falcão Cota   m
#
#                              nome-vide nome-geografico  \
# 200659                          Afonso        Bragança
# 276913                Estevão Anacleto     Vila Viçosa
# 230444           Estevão Cardoso-Estevão Cardoso Silveira       False
# 152876                  Estevão Dias-Estevão Dias Pereira       False
# 233458                  Estevão Dias-Estevão Dias Pereira       False
# 293823    Estevão Falcão Cota-Estevão Falcão Cota Menezes       False
#
#        match_obs   match  match_type
# 200659       NaN    None        None
# 276913       NaN    None        None
# 236147       NaN  236150     see-aka
# 129044       NaN    None        None
# 134106       NaN    None        None
# 133510       NaN  230444     aka-see
# 230444       NaN  133510     see-aka
# 152876       NaN  233458     see-aka
# 233458       NaN  152876     aka-see
# 293823       NaN    None        None
#
# [10 rows x 23 columns]

# %% [markdown]
# ## Sorted lists

# %%
vide_selection[['nome-geografico','match','match_type','match_obs','name','nome-vide','faculdade','uc-entrada','uc-saida']].sort_values(['nome-geografico','name','uc-entrada']).head(20)
# Out:
#           nome-geografico   match match_type match_obs  \
# 293823           ***NA***    None       None       NaN
# 285795           ***NA***    None       None       NaN
# 173368           Abrantes    None       None       NaN
# 149184  Arrifana de Sousa    None       None       NaN
# 206520               Beco    None       None       NaN
# 233530               Beja    None       None       NaN
# 236147              Braga  236150    see-aka       NaN
# 236150              Braga  236147    aka-see       NaN
# 200659           Bragança    None       None       NaN
# 309989             Brasil    None       None       NaN
# 286832             Brasil    None       None       NaN
# 198947             Brasil    None       None       NaN
# 152876            Cascais  233458    see-aka       NaN
# 233458            Cascais  152876    aka-see       NaN
# 291887           Chamusca    None       None       NaN
# 246486               Faro  237320    aka-see       NaN
# 237320               Faro  246486    see-aka       NaN
# 160826             Guarda    None       None       NaN
# 181801          Guimarães  248592    aka-see       NaN
# 181801          Guimarães  248592    aka-see       NaN
#
#                                           name  \
# 293823                     Estevão Falcão Cota
# 285795                 Estevão Machado de Melo
# 173368                    Estevão Lopes Galvão
# 149184            Estevão de Freitas e Azevedo
# 206520                          Estevão Mendes
# 233530                   Estevão Lopes Pereira
# 236147  Estevão Barreto de Magalhães e Menezes
# 236150          Estevão de Magalhães e Menezes
# 200659                 Estevão Afonso da Costa
# 309989    Estevão Mauricio de Velasco e Tavora
# 286832      Estevão Maurício de Velasco Molina
# 198947    Estevão Maurício de Velasco e Távora
# 152876                            Estevão Dias
# 233458                    Estevão Dias Pereira
# 291887                   Estevão de Contreiras
# 246486                           Estevão Pinto
# 237320                  Estevão Pinto de Sousa
# 160826                         Estevão Fragoso
# 181801                         Estevão Machado
# 181801                         Estevão Machado
#
#                                      nome-vide faculdade  uc-entrada  \
# 293823                                 Menezes       NaN  0000-00-00
# 285795                                  Castro       NaN  0000-00-00
# 173368                                   Lopes       NaN  0000-00-00
# 149184                                 Freitas       NaN  0000-00-00
# 206520                             Vasconcelos   Cânones  0000-00-00
# 233530                                   Lopes       NaN  0000-00-00
# 236147          Estevão de Magalhães e Menezes       NaN  0000-00-00
# 236150  Estevão Barreto de Magalhães e Menezes   Cânones  1738-10-01
# 200659                                  Afonso   Cânones  1664-10-15
# 309989      Estevão Mauricio de Velasco Molina   Cânones  0000-00-00
# 286832    Estevão Maurício de Velasco e Távora   Cânones  1761-11-05
# 198947                                 Velasco       NaN  0000-00-00
# 152876                                 Pereira       NaN  0000-00-00
# 233458                                    Dias   Cânones  1619-10-24
# 291887                                 Almeida      Leis  0000-00-00
# 246486                                   Sousa      Leis  1614-10-08
# 237320                                   Pinto      Leis  0000-00-00
# 160826                                 Ribeiro       NaN  0000-00-00
# 181801                              de Miranda   Cânones  1619-10-19
# 181801                              de Miranda      Leis  1619-10-19
#
#           uc-saida
# 293823  0000-00-00
# 285795  0000-00-00
# 173368  0000-00-00
# 149184  0000-00-00
# 206520  0000-00-00
# 233530  0000-00-00
# 236147  0000-00-00
# 236150  1740-10-01
# 200659  1671-07-03
# 309989  0000-00-00
# 286832  1761-11-05
# 198947  0000-00-00
# 152876  0000-00-00
# 233458  1623-10-03
# 291887  0000-00-00
# 246486  1622-06-08
# 237320  0000-00-00
# 160826  0000-00-00
# 181801  1637-10-15
# 181801  1637-10-15

# %% [markdown]
# ### Examine individual records

# %%
from timelinknb import pperson,Session
pd.set_option('display.max_rows',250)

with Session() as session:
    session.begin()
    pperson(219458)
# Out:
# n$Estevão José dos Santos/m/id=219458/obs="""
#
#             Id: 219458
#             Código de referência: PT/AUC/ELU/UC-AUC/B/001-001/S/003081
#
#             Nome        : Estevão José dos Santos, vide Estevão José
#             Data inicial: 0000-00-00
#             Data final  : 0000-00-00
#             Filiação:
#             Naturalidade: Lisboa
#             Faculdade:
#
#             Matrícula(s):
#
#             Instituta:
#         """
#   atr$código-de-referência/"PT/AUC/ELU/UC-AUC/B/001-001/S/003081"/2020-12-30
#   atr$data-do-registo/2020-12-30/2020-12-30
#   atr$url/"https://pesquisa.auc.uc.pt/details?id=219458"/2020-12-30
#   ls$uc-entrada/0000-00-00/0000-00-00
#   ls$uc-saida/0000-00-00/0000-00-00
#   ls$nome-vide/Estevão José/0000-00-00
#   ls$nome/Estevão José/0000-00-00/obs=Estevão José dos Santos, vide Estevão José
#   ls$nome/Estevão José dos Santos/0000-00-00
#   ls$nome-primeiro/Estevão/0000-00-00
#   ls$nome-apelido/José dos Santos/0000-00-00
#   ls$nome-apelido/Santos/0000-00-00
#   ls$nome-geografico/Lisboa/0000-00-00
#   ls$naturalidade/Lisboa/0000-00-00
#   ls$naturalidade.ano/Lisboa.0000/0000-00-00
#   rel$function-in-act/n/alunos-S-00008/20220405

# %% [markdown]
# ### Examine groups of records in a single chrological table

# %%
from timelinknb import Session
from timelinknb.pandas import group_attributes

pd.set_option('display.max_rows',250)

with Session() as session:
    session.begin()
    ga = group_attributes(['215193','182145'],person_info=False,exclude_attributes=['pobs'])

ga.sort_values(['date','type','value'], inplace=True)
ga[['date','type','value','attr_obs']]
# Out:
#               date                     type  \
# id
# 182145  1604-10-11                faculdade
# 182145  1604-10-11                faculdade
# 215193  1604-10-11                faculdade
# 182145  1604-10-11       faculdade-original
# 182145  1604-10-11            faculdade.ano
# 182145  1604-10-11            faculdade.ano
# 215193  1604-10-11            faculdade.ano
# 182145  1604-10-11                instituta
# 215193  1604-10-11                instituta
# 182145  1604-10-11            instituta.ano
# 215193  1604-10-11            instituta.ano
