# %% [markdown]
# > First time use: follow instructions in the README.md file in this directory.

# %% [markdown]
# **[PT]** Português
#
# ---
#
# **[EN]** English

# %% [markdown]
# # Georeferenciação com GeoNames
#
#
# Identificação e geolocalização de topónimos com GeoNames.
#
# Este bloco de notas utiliza informação disponibilizada por GeoNames em
# http://www.geonames.org segundo a licença [Creative Commons Attribution 4.0](https://creativecommons.org/licenses/by/4.0/)
#
# ---
#
# # Georeferencing place names with GeoNames
#
# Identification and geocoding of place names with GeoNames.
#
# This notebook uses information made availabe be GeoNames
# http://www.geonames.org under a [Creative Commons Attribution 4.0 License](https://creativecommons.org/licenses/by/4.0/)

# %% [markdown]
# ## Ligação à base de dados local
#
# Para inicializar a base de dados
# local ver [000-database-setup](000-database-setup.ipynb)
#
# ---
#
# ## Setup local database access
#
# To initialize the local database see [000-database-setup](000-database-setup.ipynb)

# %%
from timelink.api.database import TimelinkDatabase
from ucalumni.config import default_db_url

print(f"Creating TimelinkDatabase instance from {default_db_url}")
db = TimelinkDatabase(db_url=default_db_url)
# Out:
# Creating TimelinkDatabase instance from sqlite:///../database/sqlite3/fauc.db?check_same_thread=False

# %% [markdown]
# ## Lista de lugares diferentes e número de ocorrências
#
# ---
#
# ## List of different places with number of occurrences

# %%
from timelink.pandas import attribute_values

attribute = 'naturalidade'
period = ('1500-00-00','1990-00-00')

places = attribute_values(attribute,dates_between=period, db=db)
places['place_name'] = places.index.values
places.reset_index()
places.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11499 entries, Lisboa to Óvoa, Viseu
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   count       11499 non-null  int64
#  1   date_min    11499 non-null  object
#  2   date_max    11499 non-null  object
#  3   place_name  11499 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 449.2+ KB

# %% [markdown]
# ### Lugares principais
#
# ---
#
# ### Main locations

# %%
places.sort_values('count', ascending=False).head(10)
# Out:
#            count    date_min    date_max place_name
# value
# Lisboa      8784  1537-02-12  1916-07-19     Lisboa
# Coimbra     5526  1537-00-00  1915-10-12    Coimbra
# Porto       3391  1537-05-30  1917-10-22      Porto
# Braga       1608  1540-01-21  1914-07-24      Braga
# Évora       1072  1537-11-22  1910-10-10      Évora
# Viseu        986  1537-00-00  1912-07-03      Viseu
# Guimarães    980  1537-12-18  1912-07-18  Guimarães
# Lamego       972  1537-00-00  1909-10-05     Lamego
# Aveiro       790  1538-04-21  1913-10-13     Aveiro
# Vila Real    765  1537-03-07  1909-11-09  Vila Real

# %% [markdown]
# ### Lugares só com uma ocorrência
# ---
#
# ### Locations with just one occurrence

# %%
places[places['count'] == 1].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7554 entries, - Lisboa to Óvoa, Viseu
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   count       7554 non-null   int64
#  1   date_min    7554 non-null   object
#  2   date_max    7554 non-null   object
#  3   place_name  7554 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 295.1+ KB

# %%
places[places['count']==1].head(10)
# Out:
#                      count    date_min    date_max           place_name
# value
# - Lisboa                 1  1658-10-02  1658-10-02             - Lisboa
# - Vila Franca            1  1658-10-01  1658-10-01        - Vila Franca
# -Lisboa                  1  1723-10-01  1723-10-01              -Lisboa
# A de Barros, Caria       1  1765-10-01  1765-10-01   A de Barros, Caria
# A de Barros, Lamego      1  1624-10-10  1624-10-10  A de Barros, Lamego
# A dos Francos            1  1745-10-01  1745-10-01        A dos Francos
# ALgaça, Poiares          1  1751-10-01  1751-10-01      ALgaça, Poiares
# AZagães                  1  1749-10-01  1749-10-01              AZagães
# Abade                    1  1747-12-14  1747-12-14                Abade
# Abade de São Romão       1  1540-01-10  1540-01-10   Abade de São Romão

# %% [markdown]
# ## Geonames
# >The GeoNames geographical database covers all countries and contains over eleven million placenames that are available for download free of charge.
#
# * http://www.geonames.org
# * Dowloads em http://download.geonames.org/export/dump/
#
# Description of available files in [readme.txt](../extras/gecoding/geonames/readme.txt)
#
# To use this notebook you need the following files from geonames:
#
# * one or more "XX.ZIP" for the countries of interest
# * the file "featureCodes.txt" to
# To import geocode data download the files needed from the link above
# into directory `../extras/geocoding/geonames/` (to use another directory
# change the variable `path_to_geonames` in the cell bellow  ).

# %%
# Collect geonames files
from pathlib import Path
from os.path import exists
path_to_geonames = '../extras/geocoding/geonames'

files = list(Path(path_to_geonames).rglob("[A-Z][A-Z].txt"))
[file.name for file in sorted(files)]
# Out:
# ['AO.txt',
#  'BR.txt',
#  'CV.txt',
#  'ES.txt',
#  'GW.txt',
#  'IE.txt',
#  'MZ.txt',
#  'PT.txt',
#  'ST.txt',
#  'TL.txt']

# %%
# from readme.txt
read_me = """
geonameid         : integer id of record in geonames database
name              : name of geographical point (utf8) varchar(200)
asciiname         : name of geographical point in plain ascii characters, varchar(200)
alternatenames    : alternatenames, comma separated, ascii names automatically transliterated, convenience attribute from alternatename table, varchar(10000)
latitude          : latitude in decimal degrees (wgs84)
longitude         : longitude in decimal degrees (wgs84)
feature class     : see d, char(1)
feature code      : see http://www.geonames.org/export/codes.html, varchar(10)
country code      : ISO-3166 2-letter country code, 2 characters
cc2               : alternate country codes, comma separated, ISO-3166 2-letter country code, 200 characters
admin1 code       : fipscode (subject to change to iso code), see exceptions below, see file admin1Codes.txt for display names of this code; varchar(20)
admin2 code       : code for the second administrative division, a county in the US, see file admin2Codes.txt; varchar(80)
admin3 code       : code for third level administrative division, varchar(20)
admin4 code       : code for fourth level administrative division, varchar(20)
population        : bigint (8 byte int)
elevation         : in meters, integer
dem               : digital elevation model, srtm3 or gtopo30, average elevation of 3''x3'' (ca 90mx90m) or 30''x30'' (ca 900mx900m) area in meters, integer. srtm processed by cgiar/ciat.
timezone          : the iana timezone id (see file timeZone.txt) varchar(40)
modification date : date of last modification in yyyy-MM-dd format
"""

# %%
lines = read_me.splitlines()
fields = [f.split(':')[0].strip().replace(' ','_') for f in lines if f != '']
fields
# Out:
# ['geonameid',
#  'name',
#  'asciiname',
#  'alternatenames',
#  'latitude',
#  'longitude',
#  'feature_class',
#  'feature_code',
#  'country_code',
#  'cc2',
#  'admin1_code',
#  'admin2_code',
#  'admin3_code',
#  'admin4_code',
#  'population',
#  'elevation',
#  'dem',
#  'timezone',
#  'modification_date']

# %% [markdown]
# ### Converter informação para Pandas DataFrame

# %%
 dtypes = {
    'geonameid':str,
    'admin1_code':str,
    'admin2_code':str,
    'admin3_code':str,
    'admin4_code':str,
 }

# %%
import pandas as pd

geonames_df = None
for file in [f for f in files if 'alternatenames' not in str(f.parent)] :
    print("Reading from ",file.name)
    df = pd.read_csv(file,sep='\t',names=fields,dtype=dtypes,header=0, low_memory=False, index_col='geonameid')
    if geonames_df is None:
        geonames_df = df.copy()
    else:
        geonames_df = pd.concat([geonames_df,df],axis=0)
geonames_df.info()
# Out:
# Reading from  MZ.txt
# Reading from  TL.txt
# Reading from  ST.txt
# Reading from  PT.txt
# Reading from  GW.txt
# Reading from  AO.txt
# Reading from  BR.txt
# Reading from  CV.txt
# Reading from  ES.txt
# Reading from  IE.txt
# <class 'pandas.core.frame.DataFrame'>
# Index: 419185 entries, 345948 to 12493118
# Data columns (total 18 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   name               419184 non-null  object
#  1   asciiname          419182 non-null  object
#  2   alternatenames     145930 non-null  object
#  3   latitude           419185 non-null  float64
#  4   longitude          419185 non-null  float64
#  5   feature_class      419185 non-null  object
#  6   feature_code       419161 non-null  object
#  7   country_code       419185 non-null  object
#  8   cc2                25133 non-null   object
#  9   admin1_code        418343 non-null  object
#  10  admin2_code        230887 non-null  object
#  11  admin3_code        122463 non-null  object
#  12  admin4_code        3367 non-null    object
#  13  population         419185 non-null  int64
#  14  elevation          11182 non-null   float64
#  15  dem                419185 non-null  int64
#  16  timezone           419126 non-null  object
#  17  modification_date  419185 non-null  object
# dtypes: float64(3), int64(2), object(13)
# memory usage: 60.8+ MB

# %% [markdown]
# Get the admin level 5 codes which are in separate file

# %%
admin_code5_exists = False
admin_code5_file = '../extras/geocoding/geonames/adminCode5.txt'
if exists(admin_code5_file):
    admin_code5_exists = True
    geonames_ac5  = pd.read_csv(admin_code5_file,sep='\t',names=['geonameid','admin5_code'],header=None, dtype={'geonameid':'str','admin5_code':'str'},index_col='geonameid')
    geonames_df = pd.merge(geonames_df, geonames_ac5, how='left',on='geonameid')
geonames_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 419185 entries, 345948 to 12493118
# Data columns (total 19 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   name               419184 non-null  object
#  1   asciiname          419182 non-null  object
#  2   alternatenames     145930 non-null  object
#  3   latitude           419185 non-null  float64
#  4   longitude          419185 non-null  float64
#  5   feature_class      419185 non-null  object
#  6   feature_code       419161 non-null  object
#  7   country_code       419185 non-null  object
#  8   cc2                25133 non-null   object
#  9   admin1_code        418343 non-null  object
#  10  admin2_code        230887 non-null  object
#  11  admin3_code        122463 non-null  object
#  12  admin4_code        3367 non-null    object
#  13  population         419185 non-null  int64
#  14  elevation          11182 non-null   float64
#  15  dem                419185 non-null  int64
#  16  timezone           419126 non-null  object
#  17  modification_date  419185 non-null  object
#  18  admin5_code        1 non-null       object
# dtypes: float64(3), int64(2), object(14)
# memory usage: 64.0+ MB

# %% [markdown]
# Manter apenas topónimos povoados
#
# ---
#
# Keep only populated places

# %%
geonames_df = geonames_df[geonames_df.population>0]
geonames_df.reset_index(inplace=True)
geonames_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30700 entries, 0 to 30699
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   geonameid          30700 non-null  object
#  1   name               30700 non-null  object
#  2   asciiname          30700 non-null  object
#  3   alternatenames     19274 non-null  object
#  4   latitude           30700 non-null  float64
#  5   longitude          30700 non-null  float64
#  6   feature_class      30700 non-null  object
#  7   feature_code       30700 non-null  object
#  8   country_code       30700 non-null  object
#  9   cc2                229 non-null    object
#  10  admin1_code        30697 non-null  object
#  11  admin2_code        29828 non-null  object
#  12  admin3_code        21253 non-null  object
#  13  admin4_code        153 non-null    object
#  14  population         30700 non-null  int64
#  15  elevation          403 non-null    float64
#  16  dem                30700 non-null  int64
#  17  timezone           30697 non-null  object
#  18  modification_date  30700 non-null  object
#  19  admin5_code        0 non-null      object
# dtypes: float64(3), int64(2), object(15)
# memory usage: 4.7+ MB

# %%
geonames_df[geonames_df.country_code == 'PT'].sample(10)
# Out:
#      geonameid                name           asciiname  \
# 2276   8011565            Remondes            Remondes
# 1597   8010886          Vila Ruiva          Vila Ruiva
# 2245   8011534           Fradizela           Fradizela
# 4858   8014148     Além da Ribeira     Alem da Ribeira
# 3390   8012679              Viariz              Viariz
# 2080   8011369  Portela das Cabras  Portela das Cabras
# 4862   8014152     Juncal do Campo     Juncal do Campo
# 1005   3372952               Lajes               Lajes
# 726    2737437    Montemor-o-Velho    Montemor-o-Velho
# 687    2736337            Perelhal            Perelhal
#
#                                          alternatenames  latitude  longitude  \
# 2276                                                NaN  41.38923   -6.78475
# 1597                                                NaN  38.25530   -7.93251
# 2245                                                NaN  41.65509   -7.18071
# 4858                                                NaN  39.66852   -8.40842
# 3390                                                NaN  41.17084   -7.97808
# 2080                                                NaN  41.66997   -8.49914
# 4862                                                NaN  39.90892   -7.60114
# 1005                            Lagens,Lajens,Lajes,TER  38.76352  -27.10336
# 726   Montemor-o-Vel'ju,Montemor-o-Velho,Montemor-u-...  40.17287   -8.68616
# 687                                   Parelhal,Perelhal  41.53075   -8.68982
#
#      feature_class feature_code country_code  cc2 admin1_code admin2_code  \
# 2276             A         ADM3           PT  NaN          05        0408
# 1597             A         ADM3           PT  NaN          03        0207
# 2245             A         ADM3           PT  NaN          05        0407
# 4858             A         ADM3           PT  NaN          18        1418
# 3390             A         ADM3           PT  NaN          17        1302
# 2080             A         ADM3           PT  NaN          04        0313
# 4862             A         ADM3           PT  NaN          06        0502
# 1005             P          PPL           PT  NaN          23        4302
# 726              P        PPLA2           PT  NaN          07        0610
# 687              P          PPL           PT  NaN          04        0302
#
#      admin3_code admin4_code  population  elevation  dem         timezone  \
# 2276      040814         NaN         212        NaN  551    Europe/Lisbon
# 1597      020704         NaN         467        NaN  197    Europe/Lisbon
# 2245      040714         NaN         234        NaN  342    Europe/Lisbon
# 4858      141816         NaN         764        NaN  123    Europe/Lisbon
# 3390      130220         NaN         520        NaN  787    Europe/Lisbon
# 2080      031338         NaN         278        NaN  269    Europe/Lisbon
# 4862      050210         NaN         355        NaN  261    Europe/Lisbon
# 1005      430206         NaN        3744        NaN   67  Atlantic/Azores
# 726       061007         NaN        3154        NaN   20    Europe/Lisbon
# 687       030260         NaN        1749        NaN   61    Europe/Lisbon
#
#      modification_date admin5_code
# 2276        2019-07-24         NaN
# 1597        2019-07-24         NaN
# 2245        2019-07-24         NaN
# 4858        2019-07-24         NaN
# 3390        2019-07-24         NaN
# 2080        2019-07-24         NaN
# 4862        2019-07-24         NaN
# 1005        2018-03-15         NaN
# 726         2014-04-06         NaN
# 687         2018-06-21         NaN

# %% [markdown]
# ### Get extra information (example)

# %% [markdown]
# #### Get feature codes

# %%
from os.path import exists

fcodes_exist = False
features_codes_file = '../extras/geocoding/geonames/featureCodes_en.txt'
if exists(features_codes_file):
    fcodes_exist = True
    geonames_fc  = pd.read_csv(features_codes_file,sep='\t',names=['fcode','fname','fdesc'],index_col='fcode', header=0)

# %%
geonames_fc.head()
# Out:
#                                                    fname  \
# fcode
# A.ADM1H   historical first-order administrative division
# A.ADM2              second-order administrative division
# A.ADM2H  historical second-order administrative division
# A.ADM3               third-order administrative division
# A.ADM3H   historical third-order administrative division
#
#                                                      fdesc
# fcode
# A.ADM1H       a former first-order administrative division
# A.ADM2   a subdivision of a first-order administrative ...
# A.ADM2H      a former second-order administrative division
# A.ADM3   a subdivision of a second-order administrative...
# A.ADM3H       a former third-order administrative division

# %% [markdown]
# #### Get admin codes

# %%
from os.path import exists

admin_code1_exists = False
admin_code1_file = '../extras/geocoding/geonames/admin1CodesASCII.txt'
if exists(admin_code1_file):
    admin_code1_exists = True
    geonames_ac1  = pd.read_csv(admin_code1_file,sep='\t',names=['acode1','ac1_name','ac1_name_ascii','geonames_id'],dtype={'geonames_id':'str'},index_col='geonames_id', header=0)

admin_code2_exists = False
admin_code2_file = '../extras/geocoding/geonames/admin2Codes.txt'
if exists(admin_code2_file):
    admin_code2_exists = True
    geonames_ac2  = pd.read_csv(admin_code1_file,sep='\t',names=['acode2','ac2_name','ac2_name_ascii','geonames_id'],dtype={'geonames_id':'str'},index_col='geonames_id', header=0)

# %%
geonames_ac1.head()
# Out:
#             acode1          ac1_name    ac1_name_ascii
# geonames_id
# 3039676      AD.05            Ordino            Ordino
# 3040131      AD.04        La Massana        La Massana
# 3040684      AD.03            Encamp            Encamp
# 3041203      AD.02           Canillo           Canillo
# 3041566      AD.07  Andorra la Vella  Andorra la Vella

# %%
geonames_ac1.loc[geonames_ac1.ac1_name == 'Coimbra']
# Out:
#             acode1 ac1_name ac1_name_ascii
# geonames_id
# 2740636      PT.07  Coimbra        Coimbra

# %%
geonames_ac1.loc['2740636']
# Out:
# acode1              PT.07
# ac1_name          Coimbra
# ac1_name_ascii    Coimbra
# Name: 2740636, dtype: object

# %%
place = 'Coimbra'
result = geonames_df[geonames_df.name == place]
for i,row in result.iterrows():
    name = row['name']
    fcode = f"{row.feature_class}.{row.feature_code}"
    if fcodes_exist:
        fcode_desc = geonames_fc.loc[fcode].fname
    else:
        fcodes = 'NA'

    admin_code = None
    for acode_column in ['admin4_code','admin3_code','admin2_code','admin1_code']:
        if type(row[acode_column]) is str:
            admin_code = row[acode_column]
            break
    if admin_code is None:
        admin_code = '(NA)'
    print(f" {row.country_code} {row.geonameid} {name} {fcode} {fcode_desc} {admin_code}")
    print(f"      {row.alternatenames}")
result
# Out:
#  PT 2740637 Coimbra P.PPLA seat of a first-order administrative division 060325
#       CBP,Coimbra,Coímbra,Coïmbra,Koimbra,Koimbro,Koimpra,Koímbra,ke ying bu la,koinbura,Κόιμπρα,Коимбра,コインブラ,科英布拉
#  PT 8010483 Coimbra A.ADM2 second-order administrative division 0603
#       Coimbra,Coimbra Municipality,Coinvra,Conimbriga,Coímbra,Coïmbra,Gorad Kaimbra,Koimbra,Koimbro,Koimpra,Koímbra,ke ying bu la,ko xim bra,ko'imabra,koimbeula,koinbura,kwymbra,kwyymbra,qlmryt,qwymbrh,Κοΐμπρα,Горад Каімбра,Коимбра,Коїмбра,קוימברה,قلمرية,کوئیمبرا,کویمبرا,কোইমব্রা,โกอิมบรา,კოიმბრა,コインブラ,科英布拉,코임브라
#  BR 6321278 Coimbra A.ADM2 second-order administrative division 3116704
#       nan
#       geonameid     name asciiname  \
# 859     2740637  Coimbra   Coimbra
# 1195    8010483  Coimbra   Coimbra
# 10237   6321278  Coimbra   Coimbra
#
#                                           alternatenames  latitude  longitude  \
# 859    CBP,Coimbra,Coímbra,Coïmbra,Koimbra,Koimbro,Ko...  40.20564   -8.41955
# 1195   Coimbra,Coimbra Municipality,Coinvra,Conimbrig...  40.21026   -8.42683
# 10237                                                NaN -20.84494  -42.79834
#
#       feature_class feature_code country_code  cc2 admin1_code admin2_code  \
# 859               P         PPLA           PT  NaN          07        0603
# 1195              A         ADM2           PT  NaN          07        0603
# 10237             A         ADM2           BR  NaN          15     3116704
#
#       admin3_code admin4_code  population  elevation  dem           timezone  \
# 859        060325         NaN      106582        NaN   98      Europe/Lisbon
# 1195          NaN         NaN      143396        NaN   88      Europe/Lisbon
# 10237         NaN         NaN        7054        NaN  740  America/Sao_Paulo
#
#       modification_date admin5_code
# 859          2019-02-26         NaN
# 1195         2020-02-07         NaN
# 10237        2015-07-20         NaN

# %% [markdown]
# ### Cruzar com topónimos da base local

# %%
# !pip install recordlinkage
# Out:
# .bash_profile RUN!
# Requirement already satisfied: recordlinkage in /Users/jrc/develop/fauc1537-1919/.venv/lib/python3.11/site-packages (0.16)
# Requirement already satisfied: jellyfish>=1 in /Users/jrc/develop/fauc1537-1919/.venv/lib/python3.11/site-packages (from recordlinkage) (1.1.0)
# Requirement already satisfied: numpy>=1.13 in /Users/jrc/develop/fauc1537-1919/.venv/lib/python3.11/site-packages (from recordlinkage) (2.1.3)
# Requirement already satisfied: pandas<3,>=1 in /Users/jrc/develop/fauc1537-1919/.venv/lib/python3.11/site-packages (from recordlinkage) (2.2.3)
# Requirement already satisfied: scipy>=1 in /Users/jrc/develop/fauc1537-1919/.venv/lib/python3.11/site-packages (from recordlinkage) (1.14.1)
# Requirement already satisfied: scikit-learn>=1 in /Users/jrc/develop/fauc1537-1919/.venv/lib/python3.11/site-packages (from recordlinkage) (1.5.2)
# Requirement already satisfied: joblib in /Users/jrc/develop/fauc1537-1919/.venv/lib/python3.11/site-packages (from recordlinkage) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jrc/develop/fauc1537-1919/.venv/lib/python3.11/site-packages (from pandas<3,>=1->recordlinkage) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/jrc/develop/fauc1537-1919/.venv/lib/python3.11/site-packages (from pandas<3,>=1->recordlinkage) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/jrc/develop/fauc1537-1919/.venv/lib/python3.11/site-packages (from pandas<3,>=1->recordlinkage) (2024.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/jrc/develop/fauc1537-1919/.venv/lib/python3.11/site-packages (from scikit-learn>=1->recordlinkage) (3.5.0)
# Requirement already satisfied: six>=1.5 in /Users/jrc/develop/fauc1537-1919/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1->recordlinkage) (1.16.0)

# %%
import recordlinkage
from recordlinkage.preprocessing import clean

indexer = recordlinkage.index.SortedNeighbourhood('place_name','name',window=11)
candidates = indexer.index(places,geonames_df)
print(len(candidates))
# Out:
# 88187

# %%
compare = recordlinkage.Compare()
compare.string('place_name','name',
    # ['jaro', 'jarowinkler', 'levenshtein', 'damerau_levenshtein', 'qgram', 'cosine', 'smith_waterman', 'lcs'].
    method='damerau_levenshtein',
    threshold=0.90,
    label='score')
compare.exact('place_name','name',
    label='equal')
features = compare.compute(candidates,places,geonames_df)
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 88187 entries, ('Porto', np.int64(8560)) to ('Óvoa, Viseu', np.int64(11379))
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   score   88187 non-null  float64
#  1   equal   88187 non-null  int64
# dtypes: float64(1), int64(1)
# memory usage: 2.7+ MB

# %%
features.sum(axis=1).value_counts().sort_index(ascending=False)
# Out:
# 2.0     4052
# 1.0      428
# 0.0    83707
# Name: count, dtype: int64

# %%
potential_matches = features[features.sum(axis=1) >0 ].reset_index()

potential_matches['place_name']=potential_matches['value']
potential_matches.drop('value',axis=1, inplace=True)
potential_matches['geoname']=geonames_df.loc[potential_matches['level_1']]['name'].values
potential_matches['country']=geonames_df.loc[potential_matches['level_1']]['country_code'].values
potential_matches['pop']=geonames_df.loc[potential_matches['level_1']]['population'].values
potential_matches['geoname_id']=geonames_df.loc[potential_matches['level_1']]['geonameid'].values
potential_matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4480 entries, 0 to 4479
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   level_1     4480 non-null   int64
#  1   score       4480 non-null   float64
#  2   equal       4480 non-null   int64
#  3   place_name  4480 non-null   object
#  4   geoname     4480 non-null   object
#  5   country     4480 non-null   object
#  6   pop         4480 non-null   int64
#  7   geoname_id  4480 non-null   object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 280.1+ KB

# %%
potential_matches.sort_values(['place_name','geoname','country','pop'],
                                        ascending=[True,True,True,False],
                                        inplace=True)
potential_matches.sample(10)
# Out:
#       level_1  score  equal           place_name              geoname country  \
# 13       5003    1.0      0    Pinheiro de Azere    Pinheiro de Ázere      PT
# 3317     3737    1.0      1              Fráguas              Fráguas      PT
# 3379     3079    1.0      1             Marrazes             Marrazes      PT
# 2785     4256    1.0      1               Pinhão               Pinhão      PT
# 3943     1398    1.0      1             Nordeste             Nordeste      PT
# 1848      312    1.0      1            Monchique            Monchique      PT
# 2326     5121    1.0      1  Santa Cruz da Trapa  Santa Cruz da Trapa      PT
# 2829      178    1.0      1               Seixal               Seixal      PT
# 463      2185    1.0      1              Poiares              Poiares      PT
# 3071     2423    1.0      1         Penha Garcia         Penha Garcia      PT
#
#         pop geoname_id
# 13      937    8014293
# 3317    905    8013027
# 3379  22528    8012368
# 2785    648    8013546
# 3943   4937    8010686
# 1848   5421    2266268
# 2326   1313    8014411
# 2829    656    2263117
# 463     411    8011474
# 3071    748    8011712

# %%
potential_matches.drop_duplicates(subset=['place_name','geoname','country'], keep='first',inplace=True)
potential_matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2706 entries, 3560 to 3172
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   level_1     2706 non-null   int64
#  1   score       2706 non-null   float64
#  2   equal       2706 non-null   int64
#  3   place_name  2706 non-null   object
#  4   geoname     2706 non-null   object
#  5   country     2706 non-null   object
#  6   pop         2706 non-null   int64
#  7   geoname_id  2706 non-null   object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 190.3+ KB

# %%
potential_matches.sample(10)
# Out:
#       level_1  score  equal             place_name                geoname  \
# 1943     1540    1.0      1                  Arada                  Arada
# 3445     4622    1.0      1                  Pinho                  Pinho
# 1381     5003    1.0      1      Pinheiro de Ázere      Pinheiro de Ázere
# 1075     4105    1.0      1                Outeiro                Outeiro
# 3763    14803    1.0      1                Escobar                Escobar
# 2648     4564    1.0      1             Vilar Seco             Vilar Seco
# 3034     4100    1.0      1                Meixedo                Meixedo
# 138      4962    1.0      0  Cernache de Bonjardim  Cernache do Bonjardim
# 3570     3392    1.0      1                 Airães                 Airães
# 3286     4594    1.0      1               Cárquere               Cárquere
#
#      country   pop geoname_id
# 1943      PT  3318    8010829
# 3445      PT   777    8013912
# 1381      PT   937    8014293
# 1075      PT  1234    8013395
# 3763      ES   386    2517948
# 2648      PT   745    8013854
# 3034      PT   467    8013390
# 138       PT  3052    8014252
# 3570      PT  2486    8012681
# 3286      PT   854    8013884

# %% [markdown]
# #### Verificar inferências

# %%
potential_matches[potential_matches.equal == 0]
# Out:
#       level_1  score  equal                place_name  \
# 4387     3749    1.0      0               Abituteiras
# 144       957    1.0      0          Aboim da Nobrega
# 4388      957    1.0      0          Aboim de Nóbrega
# 94        948    1.0      0        Albergaria-a Velha
# 4416     1126    1.0      0        Albergaria-a-Velha
# ...       ...    ...    ...                       ...
# 165       546    1.0      0          Vilar do Paraiso
# 4379     3935    1.0      0                Vilarelhos
# 4360     5443    1.0      0  Vilarinho da Castanheiro
# 4294     4809    1.0      0          Várzea de Moruge
# 4477      952    1.0      0              Águas Santos
#
#                        geoname country    pop geoname_id
# 4387               Abitureiras      PT    972    8013039
# 144           Aboim da Nóbrega      PT    987    2743436
# 4388          Aboim da Nóbrega      PT    987    2743436
# 94          Albergaria-a-Velha      PT   7974    2743233
# 4416        Albergaria-A-Velha      PT  25252    8010414
# ...                        ...     ...    ...        ...
# 165           Vilar do Paraíso      PT  14727    2732444
# 4379                 Vilarelho      PT   1125    8013225
# 4360  Vilarinho da Castanheira      PT    415    8014733
# 4294          Várzea de Meruge      PT    249    8014099
# 4477              Águas Santas      PT  27686    2743304
#
# [295 rows x 8 columns]

# %%
potential_matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2706 entries, 3560 to 3172
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   level_1     2706 non-null   int64
#  1   score       2706 non-null   float64
#  2   equal       2706 non-null   int64
#  3   place_name  2706 non-null   object
#  4   geoname     2706 non-null   object
#  5   country     2706 non-null   object
#  6   pop         2706 non-null   int64
#  7   geoname_id  2706 non-null   object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 190.3+ KB

# %% [markdown]
# Check how many not found we can match

# %%
from os.path import exists

not_found_file = '../inferences/places/osm_not_found.csv'

not_found_df: pd.DataFrame = None

if exists(not_found_file):
    not_found_df = pd.read_csv(not_found_file)
    not_found = list(not_found_df['not_found'])
else:
    not_found = []
    not_found_df = pd.DataFrame(columns=['not_found'])
not_found_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4539 entries, 0 to 4538
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   not_found  4538 non-null   object
# dtypes: object(1)
# memory usage: 35.6+ KB

# %%
nfs = not_found_df['not_found'].values
not_found_but_in_topo = potential_matches[potential_matches['place_name'].isin(nfs)].sort_values(['place_name','geoname'])
not_found_but_in_topo[not_found_but_in_topo['place_name'] != not_found_but_in_topo['geoname']]
# Out:
#       level_1  score  equal                   place_name  \
# 4307     5404    1.0      0    Aldeia Galega de Merciana
# 9        4989    1.0      0         Aldeia Nossa do Cabo
# 4428      517    1.0      0               Aldeia do Rato
# 56       4880    1.0      0             Almarge do Bispo
# 4452     3658    1.0      0                    Alvarelos
# 31       5536    1.0      0           Alvarções do Corgo
# 101      4033    1.0      0                   Bertiandes
# 87       5436    1.0      0            Borba da Montanha
# 104     10974    1.0      0        Campos dos Goitacases
# 4395     2192    1.0      0                   Carrapatos
# 4454      868    1.0      0         Carrazedo de Ansiães
# 4430     1174    1.0      0         Carrazedo de Ansiães
# 177      5184    1.0      0          Castelões de Cepada
# 181      1386    1.0      0               Câmara de Lobo
# 36       5270    1.0      0          Ferreiro de Tendais
# 131      5270    1.0      0         Ferreiros de Tendaes
# 4475     9910    1.0      0                   Maragugipe
# 38       4553    1.0      0                   Marmaleira
# 4335     5616    1.0      0                Pico de Pedra
# 4462     5301    1.0      0               Porto de Carne
# 4476      237    1.0      0               Proneça-a-Nova
# 28        662    1.0      0             Refoios de Basto
# 15       1220    1.0      0         Reguengo de Monsaraz
# 55       5506    1.0      0                 Seixo de Côa
# 4353     5534    1.0      0        São Cristovão do Muro
# 113     11538    1.0      0        São Lourenço da Beira
# 208      5128    1.0      0  São Lourenço de Riba Pinhão
# 93       5614    1.0      0       São Martinho da Gandra
# 4354     5334    1.0      0          São Tomé de Covelos
# 4413     5334    1.0      0          São Tomé de Cuvelas
# 115      4777    1.0      0           Vila Boa de Luires
#
#                          geoname country     pop geoname_id
# 4307   Aldeia Galega da Merceana      PT    2079    8014694
# 9            Aldeia Nova do Cabo      PT     600    8014279
# 4428              Aldeia do Mato      PT     441    2272084
# 56             Almargem do Bispo      PT    8983    8014170
# 4452                  Alvarelhos      PT    3151    8012948
# 31             Alvações do Corgo      PT     477    8014826
# 101                   Bertiandos      PT     414    8013323
# 87             Borba de Montanha      PT    1294    8014726
# 104        Campos dos Goytacazes      BR  463545    6322015
# 4395                  Carrapatas      PT     197    8011481
# 4454        Carrazeda de Anciães      PT    6373    2741431
# 4430        Carrazeda de Ansiães      PT    6373    8010462
# 177          Castelões de Cepeda      PT    8755    8014474
# 181              Câmara de Lobos      PT   35666    8010674
# 36          Ferreiros de Tendais      PT     695    8014560
# 131         Ferreiros de Tendais      PT     695    8014560
# 4475                  Maragogipe      BR   44793    6320951
# 38                    Marmeleira      PT     503    8013843
# 4335               Pico da Pedra      PT    2909    8014906
# 4462              Porto da Carne      PT     385    8014591
# 4476              Proença-a-Nova      PT    4590    2264314
# 28              Refojos de Basto      PT    5037    2735340
# 15         Reguengos de Monsaraz      PT   10828    8010508
# 55                  Seixo do Côa      PT     171    8014796
# 4353      São Cristovão do Douro      PT     160    8014824
# 113        São Lourenço da Serra      BR   13985    6322579
# 208   São Lourenço de Ribapinhão      PT     407    8014418
# 93       São Martinho da Gândara      PT    1985    8014904
# 4354         São Tomé de Covelas      PT     576    8014624
# 4413         São Tomé de Covelas      PT     576    8014624
# 115           Vila Boa de Quires      PT    3394    8014067
