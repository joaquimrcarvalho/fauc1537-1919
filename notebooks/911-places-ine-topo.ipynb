# %% [markdown]
# > First time use: follow instructions in the README.md file in this directory.

# %% [markdown]
# '*[PT]** Português
#
# ---
#
# **[EN]** English

# %% [markdown]
# # Instituto Nacional de Estatística / Instituto Hidrográfico
# * https://snig.dgterritorio.gov.pt/rndg/srv/por/catalog.search#/metadata/3ec40a92-b050-4c47-bede-a2976debb8c7
# *
#
# ## Toponímia de Portugal Continental
# * Dados abertos
# * Instituto Hidrográfico
#
# * Data de Referência (Publicação): 07-12-2017
# * Tema(s): Planeamento e Cadastro
# * Cobertura: {"Portugal Continental":"Portugal Continental","Local":"Local"}
# * Conjunto de dados Geográficos
#
#
# * Acesso público sem restrições
# * acesso e uso sem condições
#
# * https://inspire.ine.pt/geoserver/gn/wfs?REQUEST=GetCapabilities&service=wfs&version=2.0.0
# * https://inspire.ine.pt/geoserver/gn/wms?service=wms&version=1.3.0&request=GetCapabilities
#
# Ver/See:
# * https://docs.geoserver.org/stable/en/user/services/wfs/reference.html#wfs-getfeature
# * https://www.quadratic.be/en/programmatically-interact-with-geoserver-in-python/

# %% [markdown]
# Install packages to access INE server and transform coordinates

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (2.28.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (from requests) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (from requests) (2022.6.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (from requests) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (from requests) (3.3)

# %% [markdown]
# To convert coordinates to latitude longitude the proj library is needed.
#
# First install proj library. See: https://proj.org/install.html
#
# Then install pyproj in the next cell

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (2.28.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (from requests) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (from requests) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (from requests) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (from requests) (3.3)

# %%
# !pip install pyproj  # NOTE separateinstall of proj library needed see https://proj.org/install.html#install
# Out:
# Requirement already satisfied: pyproj in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (3.3.1)
# Requirement already satisfied: certifi in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (from pyproj) (2022.6.15)

# %% [markdown]
# # Toponímia de Portugal Continental

# %% [markdown]
# Teste do servço WFS do INE

# %%
import requests
import json

n = 1
resp = requests.get(
                'https://inspire.ine.pt/geoserver/gn/wfs',
                params = {'request':'GetFeature',
                            'service':'wfs',
                            'version':'2.0.0',
                            'typeNames':'gn:NamedPlace',
                            'count':n,
                            'outputFormat':'json',
                            'exceptions':'application/json',
                            }
                )
print("URL:",resp.url)
resp_dict = json.loads(resp.content)
results = resp_dict.get('features',resp_dict.get('exceptions',[resp_dict]))
print(json.dumps(results[0], indent=2))
# Out:
# URL: https://inspire.ine.pt/geoserver/gn/wfs?request=GetFeature&service=wfs&version=2.0.0&typeNames=gn%3ANamedPlace&count=1&outputFormat=json&exceptions=application%2Fjson
# {
#   "type": "Feature",
#   "id": "PT.GN.1",
#   "geometry": {
#     "type": "MultiPoint",
#     "coordinates": [
#       [
#         -52673.206,
#         190575.27
#       ]
#     ]
#   },
#   "properties": {
#     "leastDetailedViewingResolution": {
#       "MD_Resolution": {
#         "equivalentScale": {
#           "MD_RepresentativeFraction": {
#             "denominator": {
#               "Integer": 144447
#             }
#           }
#         }
#       }
#     },
#     "localType": {},
#     "mostDetailedViewingResolution": {
#       "MD_Resolution": {
#         "equivalentScale": {
#           "MD_RepresentativeFraction": {
#             "denominator": {
#               "Integer": 0
#             }
#           }
#         }
#       }
#     },
#     "name": {
#       "GeographicalName": {
#         "spelling": {
#           "SpellingOfName": {
#             "text": "P\u00d3VOA DE VARZIM",
#             "script": "Latn"
#           }
#         },
#         "language": "Por",
#         "pronunciation": {},
#         "sourceOfName": "CIGEOE",
#         "grammaticalGender": {},
#         "grammaticalNumber": {},
#         "nameStatus": {},
#         "nativeness": {}
#       }
#     },
#     "beginLifespanVersion": {
#       "simpleContent": "2015-04-14T00:00:00Z"
#     },
#     "type": {},
#     "inspireId": {
#       "Identifier": {
#         "versionId": "2015",
#         "localId": "4537",
#         "namespace": "http://id.igeo.pt/so/GN/NamedPlaced"
#       }
#     }
#   }
# }

# %% [markdown]
# Verificar se temos dados em cache.

# %%
from os.path import exists

import requests
import json
import pandas as pd
from pyproj import Transformer

cache_file = '../extras/geocoding/INE/ine_toponimia_clipped.csv'
if exists(cache_file):  # using data clipped to Portuguese border (in QGIS)
    cache_exists = True
    print("Locally cached clipped data found")
else:                  # no clipped version, use the original data 
    cache_file = '../extras/geocoding/INE/ine_toponimia.csv'
    if exists(cache_file):
        cache_exists = True
        print("Local cache data found")
    else:
        cache_exists = False
    
if not cache_exists:
    n=40000  #  as of june 2022 there are around 37k featues
    id='*'
    #  This could be done with geopandas by it is hard to install
    resp = requests.get(
                    'https://inspire.ine.pt/geoserver/gn/wfs',
                    params = {'request':'GetFeature',
                                # 'featureID':id,
                                'service':'wfs',
                                'version':'2.0.0',
                                'typeNames':'gn:NamedPlace',
                                'count':n,
                                # 'propertyName':'gn:*',
                                'outputFormat':'json',
                                'exceptions':'application/json',
                                }
                    )

    resp_dict = json.loads(resp.content)
    results = resp_dict.get('features',resp_dict.get('exceptions',[resp_dict]))
    # print(json.dumps(results[49], indent=2))
    tuples = []
    for f in results:
        id = f['id']
        name = f['properties']['name']['GeographicalName']['spelling']['SpellingOfName']['text']
        source = f['properties']['name']['GeographicalName']['sourceOfName']

        if f['geometry'].get('coordinates',None) is not None:
            coord = tuple(f['geometry']['coordinates'][0])
            x = coord[0]
            y = coord[1]
            # the coordinates from INE are projected, we convert to lat, long
            transformer = Transformer.from_crs('epsg:3763','epsg:4326')
            lat,long = transformer.transform(x,y)
        else:
            lat,long = None, None
        try:
            local_id = f['properties']['relatedSpatialObject']['Identifier']['localId']
        except(KeyError):
            local_id = None
        try:
            inspire_id = f['properties']['inspireId']['Identifier']['localId']
        except(KeyError):
            inspire_id = None
        try:
            local_type = f['properties']['localType']
            if len(local_type) > 0:
                local_type = str(local_type)
        except(KeyError):
            local_type = None
        try:
            inspire_type = f['properties']['type']
            if len(inspire_type) > 0:
                inspire_type = str(inspire_type)
        except(KeyError):
            inspire_type = None
        tuples = tuples + [(id, name, lat, long, source, local_type, inspire_type,local_id, inspire_id)]
        ine_df = pd.DataFrame(tuples, columns=['id','name','latitude','longitude','origin', 'local_type','inspire_type','local_id','inspire_id'])
        ine_df.to_csv(cache_file,index=False)
    print("Data loaded from INE server and saved to "+cache_file)
else:
    ine_df = pd.read_csv(cache_file, dtype={'inspire_id':'str'})
    print("Data loaded from local cache")
# Out:
# Locally cached clipped data found
# Data loaded from local cache

# %% [markdown]
# Número de registos: 37.215 (Junho 2022).
# Clipped: 36537

# %%
ine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36357 entries, 0 to 36356
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          36357 non-null  object
#  1   name        36357 non-null  object
#  2   latitude    36357 non-null  float64
#  3   longitude   36357 non-null  float64
#  4   origin      36357 non-null  object
#  5   local_id    32507 non-null  object
#  6   inspire_id  29322 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 1.9+ MB

# %% [markdown]
# Exemplos

# %%
ine_df.sample(5)
# Out:
#                  id          name   latitude  longitude  origin  \
# 16072   PT.GN.99049        Vascos  39.998796  -8.678775     INE
# 763      PT.GN.1216         Aboim  41.326167  -8.069046  CIGEOE
# 7534    PT.GN.90511        Sermil  41.625851  -8.493005     INE
# 34046  PT.GN.117025  Bouças Novas  41.261213  -8.438940     DGT
# 29078  PT.GN.112056        Formal  40.872601  -8.531016     INE
#
#                          local_id       inspire_id
# 16072                      016458  BGRI2011_016458
# 763                           NaN             5752
# 7534                       004618  BGRI2011_004618
# 34046  CDG200k_populatedPlace4914              NaN
# 29078                      035725  BGRI2011_035725

# %% [markdown]
# Os registos provêm de diferentes origens e por isso contêm duplicações
# (analisadas abaixo)
#
# * CIGEOE: Centro de Informação Geográfica e Espacial do Exército (4539)
#   * Usa abreviaturas:
#     * C.ça = Cabeça
# * DGT: Direção Geral do Território, corresponde aos dados da carta 200k disponíveis também em separado (7054)
# * IH: Instituto Hidrográfico, inclui "features" submarinas no Atlântico (149)
# * INE: Toponímia do censo de 2011 (25.473)
#   * O lugar consiste numa delimitação territorial, definida no âmbito das operações censitárias, que corresponde a um aglomerado populacional com dez ou mais alojamentos destinados à habitação de pessoas e com uma designação própria, independentemente de pertencer a uma ou mais freguesias. No âmbito dos Censos de 2011, foram recenseados cerca de 26 mil lugares no território nacional". https://www.ine.pt/xportal/xmain?xpid=INE&xpgid=ine_cont_inst&INST=6251013&xlang=pt

# %% [markdown]
# ### Uniformização

# %%
abrev = {
  'V.Nova':'Vila Nova',
  'V.N.a': 'Nova',
  'V.NẂ': 'Nova',
  'V.Nª': 'Nova',
  'Rib.a':'Ribeira',
  'Sr.Ẃ':'Senhora',
  'Sr.a':'Senhora',
  'C.ça':'Cabeça',
  'S.ta':'Santa',
  'S.to':'Santo',
  'Sto.':'Santo',
  'M.te':'Monte',
  'F.te':'Fonte',
  'P.te':'Ponte',
  'Q.ta':'Quinta',
  'Srª':'Senhora',
  'N.Ẃ':'Nova',
  'V.e':'Vale',
  'C.':'Casal',
  'N.':'Nossa',
  'S.':'São',
  'V.':'Vila',
  " Dos ":" dos ",
  " Das ":" das ",
  " Do ":" do ",
  " Da ":" da ",
  " De ":" de "

}

# %%
def unabrev(abrev,name):
    """Replace abreviations in string
    
    Args:
        abrev: dict with {abrev:expansion,...}
        name: string to return
    """

    nname = name
    if nname.isupper():
        nname = nname.title()
    for k,v in abrev.items():
        nname = nname.replace(k,v+' ')
    while "  " in nname:
        nname = nname.replace("  "," ")
    return nname

unabrev(abrev,"V.e de N. Sr.a da Anunciação em Rib.a do M.te da Q.ta do C. Novo junto ao F.te da P.te")
# Out:
# 'Vila Nova de Famalicão'

# %%
ine_df['nname'] =ine_df['name'].apply(lambda name: unabrev(abrev, name))

# %%
ine_df[ine_df['name'] != ine_df['nname']].head(15)
# Out:
#           id                  name   latitude  longitude  origin local_id  \
# 0    PT.GN.1       PÓVOA DE VARZIM  41.382737  -8.762818  CIGEOE      NaN
# 1    PT.GN.2  V. NOVA DE FAMALICÃO  41.407390  -8.520490  CIGEOE      NaN
# 2    PT.GN.3             GUIMARÃES  41.445545  -8.295324  CIGEOE      NaN
# 3    PT.GN.4                  FAFE  41.453953  -8.166989  CIGEOE      NaN
# 4    PT.GN.5              BARCELOS  41.534155  -8.617465  CIGEOE      NaN
# 5    PT.GN.6             ESPOSENDE  41.532128  -8.776059  CIGEOE      NaN
# 6    PT.GN.7                CHAVES  41.742417  -7.470780  CIGEOE      NaN
# 7    PT.GN.8         VILA DO CONDE  41.354690  -8.743017  CIGEOE      NaN
# 8    PT.GN.9           SANTO TIRSO  41.342612  -8.476255  CIGEOE      NaN
# 9   PT.GN.10            FELGUEIRAS  41.367026  -8.198653  CIGEOE      NaN
# 10  PT.GN.11              AMARANTE  41.272444  -8.079151  CIGEOE      NaN
# 11  PT.GN.12                  MAIA  41.233974  -8.622446  CIGEOE      NaN
# 12  PT.GN.13    MARCO DE CANAVESES  41.182851  -8.150284  CIGEOE      NaN
# 13  PT.GN.14               PAREDES  41.204838  -8.328719  CIGEOE      NaN
# 14  PT.GN.15     PAÇOS DE FERREIRA  41.275932  -8.377505  CIGEOE      NaN
#
#    inspire_id                   nname
# 0        4537         Póvoa de Varzim
# 1        4538  Vila Nova de Famalicão
# 2        4539               Guimarães
# 3        4540                    Fafe
# 4        4541                Barcelos
# 5        4542               Esposende
# 6        4543                  Chaves
# 7        4544           Vila do Conde
# 8        4545             Santo Tirso
# 9        4546              Felgueiras
# 10       4547                Amarante
# 11       4548                    Maia
# 12       4549      Marco de Canaveses
# 13       4550                 Paredes
# 14       4551       Paços de Ferreira

# %%
ine_df.groupby('origin').count()
# Out:
#            id   name  latitude  longitude  local_id  inspire_id  nname
# origin
# CIGEOE   3850   3850      3850       3850         0        3850   3850
# DGT      7035   7035      7035       7035      7035           0   7035
# INE     25472  25472     25472      25472     25472       25472  25472

# %% [markdown]
# ## Ficheiro síntese do Censo de 2011
#
# Inclui contagens de edifícios, famílias e pessoas com vários níveis de desagregação. Para os detalhes ver o ficheiro com a informação de síntese [extras/geocoding/INE/portugal2011/C2011_FSINTESE_VARIAVEIS.csv](../extras/geocoding/INE/portugal2011/C2011_FSINTESE_VARIAVEIS.csv).
#
# Não parece conter toponímia abaixo da freguesia.

# %%
brigi11_pt_file = '../extras/geocoding/INE/portugal2011/BGRI11_PT.csv'
brigi11_df = pd.read_csv(brigi11_pt_file, sep=';', dtype={'GEO_COD':'str'}, encoding='iso-8859-1')
brigi11_df['GEO_COD']=brigi11_df['GEO_COD'].str.strip("'") # geo_doc contains a single non closed quote

# %%
keep =['ANO', 'GEO_COD', 'GEO_COD_DSG', 'NIVEL', 'NIVEL_DSG','N_INDIVIDUOS_RESIDENT','N_NUCLEOS_FAMILIARES']
drop = [c for c in brigi11_df.columns if c not in keep ] # don't need most cols
brigi11_df.drop(drop,axis=1, inplace=True)
brigi11_df.sample(5)
# Out:
#          ANO      GEO_COD GEO_COD_DSG  NIVEL  NIVEL_DSG  N_NUCLEOS_FAMILIARES  \
# 210100  2011  14010500215                  8  Subsecção                     2
# 209107  2011  13180100428                  8  Subsecção                     2
# 67325   2011  03124700302                  8  Subsecção                     5
# 144737  2011  10130200216                  8  Subsecção                     1
# 233666  2011  15080401803                  8  Subsecção                    11
#
#         N_INDIVIDUOS_RESIDENT
# 210100                      6
# 209107                      7
# 67325                      18
# 144737                      4
# 233666                     35

# %% [markdown]
# #### Sobre a organização espacial subjacente aos censos
#
# "Geografia dos Censos
#
#
# A preparação e a execução de um recenseamento geral da população e habitação exigem a referenciação geográfica da informação com base em unidades territoriais de pequena dimensão. Com esse intuito, o Instituto Nacional de Estatística desenvolveu um sistema de referenciação geográfica que, contendo a delimitação administrativa, divide as freguesias em pequenas áreas estatísticas – __secções__ e __subsecções__ estatísticas. Este sistema é integrado em formato digital na Base Geográfica de Referenciação de Informação (BGRI) que constitui uma infraestrutura fundamental de suporte às operações censitárias e, simultaneamente, um instrumento para a difusão de informação censitária.
#
# Por __secção estatística__, entende-se a _unidade territorial correspondente a uma área contínua de uma única freguesia com cerca de 300 alojamentos destinados à habitação_. Por __subsecção estatística__, entende-se a _unidade territorial que identifica a mais pequena área homogénea de construção ou não, existente dentro da secção estatística_. Corresponde ao quarteirão nas áreas urbanas, ao lugar ou parte de um lugar nas áreas rurais, ou a áreas residuais que podem ou não conter alojamentos (isolados).
#
# Em 2011, o território nacional estava dividido em cerca de 18 mil secções estatísticas e cerca de 266 mil subsecções estatísticas."
# https://www.ine.pt/xportal/xmain?xpid=INE&xpgid=ine_cont_inst&INST=6251013&xlang=pt

# %%
brigi11_df.groupby(['NIVEL','NIVEL_DSG']).count()
# Out:
#                          ANO  GEO_COD  GEO_COD_DSG  N_NUCLEOS_FAMILIARES  \
# NIVEL NIVEL_DSG
# 1     Total Nacional       1        1            1                     1
# 2     NUT1                 3        3            3                     3
# 3     NUT2                 7        7            7                     7
# 4     NUT3                30       30           30                    30
# 5     Municipio          308      308          308                   308
# 6     Freguesia         4260     4260         4260                  4260
# 7     Secção           18074    18074        18074                 18074
# 8     Subsecção       265955   265955       265955                265955
#
#                       N_INDIVIDUOS_RESIDENT
# NIVEL NIVEL_DSG
# 1     Total Nacional                      1
# 2     NUT1                                3
# 3     NUT2                                7
# 4     NUT3                               30
# 5     Municipio                         308
# 6     Freguesia                        4260
# 7     Secção                          18074
# 8     Subsecção                      265955

# %% [markdown]
# Infelizmente os níveis inferiores não têm nome do topónimo
# e não contêm um identificador comum com a informação de toponímia.
#
# É contudo possível ligar com o ficheiro de toponímia através de
# informação nas Shapefiles do Censo 2011, como se verá adiante.

# %% [markdown]
# Até ao nível de freguesia os ficheiros do censo ainda contêm o nome do lugar (frequesia)

# %%
brigi11_df[brigi11_df.NIVEL == 6].sample(5)
# Out:
#        ANO GEO_COD                       GEO_COD_DSG  NIVEL  NIVEL_DSG  \
# 3647  2011  160711                           Cabaços      6  Freguesia
# 3057  2011  131120                           Novelas      6  Freguesia
# 732   2011  030252                             Moure      6  Freguesia
# 2133  2011  090622                             Vinhó      6  Freguesia
# 2001  2011  081404  Santa Catarina da Fonte do Bispo      6  Freguesia
#
#       N_NUCLEOS_FAMILIARES  N_INDIVIDUOS_RESIDENT
# 3647                   204                    671
# 3057                   554                   1794
# 732                    282                    925
# 2133                   181                    578
# 2001                   584                   1809

# %% [markdown]
# Para os níveis abaixo da frequesia não existe topónimo (GEO_COD_DSG)

# %%
brigi11_df[brigi11_df.NIVEL > 6].sample(5)
# Out:
#          ANO      GEO_COD GEO_COD_DSG  NIVEL  NIVEL_DSG  N_NUCLEOS_FAMILIARES  \
# 100451  2011  06161400510                  8  Subsecção                     3
# 35098   2011  01131700311                  8  Subsecção                     1
# 115588  2011  08100200104                  8  Subsecção                     7
# 128160  2011  09110500109                  8  Subsecção                     1
# 140016  2011  10091100221                  8  Subsecção                     0
#
#         N_INDIVIDUOS_RESIDENT
# 100451                     13
# 35098                       4
# 115588                     23
# 128160                      4
# 140016                      1

# %% [markdown]
# ## Categorias administrativas do Censo de 2011
#
# Códigos das freguesias, concelhos e distritos.
# Existe um ficheiro disponível em http://mapas.ine.pt/download/files/2011/tabela/
# http://mapas.ine.pt/download/files/2011/tabela/categorias.xlsx
#
# Contudo esse ficheiro tem as categorias atuais e por
# isso não corresponde aos códigos presentes nos dados do censo.
#
# O ficheiro correspondente às categorias administrativas de 2011
# consegue-se obter no site do INE em https://smi.ine.pt/Categoria/Exportacao?tipo=0
# pesquisando pelo documento V00017 - Código da divisão administrativa (distritos/municípios/freguesias)
# e pedindo a versão de 2011.

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (3.0.10)
# Requirement already satisfied: et-xmlfile in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (from openpyxl) (1.1.0)

# %%
cat2011_file = '../extras/geocoding/INE/categorias2011.xlsx'
cat2011_df = pd.read_excel(cat2011_file,skiprows=13, usecols=[1,2,3], dtype={'Código':'str'})
cat2011_df.head(10)
# Out:
#    Nível  Código            Designação
# 0      1      01                Aveiro
# 1      2    0101                Águeda
# 2      3  010101                Agadão
# 3      3  010102       Aguada de Baixo
# 4      3  010103        Aguada de Cima
# 5      3  010104                Águeda
# 6      3  010105                 Barrô
# 7      3  010106     Belazaima do Chão
# 8      3  010107  Castanheira do Vouga
# 9      3  010108              Espinhel

# %% [markdown]
# Para cada categoria inserir os códigos e designações das categorias
# de nível superior em que estão inseridas e produzir uma descrição
# estuturada "frequesia,concelho, distrito". Nessa descrição
# estruturada simplifica-se a fórmula "União de freguesias..."
# (embora não existam nos dados de 2011, fica para o futuro)

# %%
cat2011_df['N1_CODE'] = None
cat2011_df['N2_CODE'] = None
cat2011_df['N3_CODE'] = None
cat2011_df['N1_DSG'] = None
cat2011_df['N2_DSG'] = None
cat2011_df['N3_DSG'] = None
cat2011_df['COD_DSG'] = None # this serves as a contextualized identifier 

for i,row in cat2011_df.sort_values('Código').iterrows():
    if row['Nível'] == 1:
        n1_code = row['Código']
        n1_dsg = row['Designação']
        cat2011_df.loc[i,'N1_CODE'] = n1_code
        cat2011_df.loc[i,'N1_DSG'] = n1_dsg
        cat2011_df.loc[i,'COD_DSG'] = n1_dsg
        cat2011_df.loc[i,'COD_UPPER_LEVEL'] = None

    elif  row['Nível'] == 2:
        n2_code = row['Código']
        n2_dsg = row['Designação']
        cat2011_df.loc[i,'N1_CODE'] = n1_code
        cat2011_df.loc[i,'N2_CODE'] = n2_code
        cat2011_df.loc[i,'N1_DSG'] = n1_dsg
        cat2011_df.loc[i,'N2_DSG'] = n2_dsg
        cat2011_df.loc[i,'COD_DSG'] = n2_dsg+ ', '+n1_dsg
        cat2011_df.loc[i,'COD_UPPER_LEVEL'] = n1_code
    elif  row['Nível'] == 3:
        n3_code = row['Código']
        n3_dsg = row['Designação'].removeprefix('União das freguesias de ').replace(", "," e ")
        cat2011_df.loc[i,'N1_CODE'] = n1_code
        cat2011_df.loc[i,'N2_CODE'] = n2_code
        cat2011_df.loc[i,'N3_CODE'] = n3_code
        cat2011_df.loc[i,'N1_DSG'] = n1_dsg
        cat2011_df.loc[i,'N2_DSG'] = n2_dsg
        cat2011_df.loc[i,'N3_DSG'] = n3_dsg
        cat2011_df.loc[i,'COD_DSG'] = n3_dsg + ', '+n2_dsg+ ', '+n1_dsg
        cat2011_df.loc[i,'COD_UPPER_LEVEL'] = n2_code

cat2011_df.sort_values('Código').head(15)
# Out:
#     Nível  Código            Designação N1_CODE N2_CODE N3_CODE  N1_DSG  \
# 0       1      01                Aveiro      01    None    None  Aveiro
# 1       2    0101                Águeda      01    0101    None  Aveiro
# 2       3  010101                Agadão      01    0101  010101  Aveiro
# 3       3  010102       Aguada de Baixo      01    0101  010102  Aveiro
# 4       3  010103        Aguada de Cima      01    0101  010103  Aveiro
# 5       3  010104                Águeda      01    0101  010104  Aveiro
# 6       3  010105                 Barrô      01    0101  010105  Aveiro
# 7       3  010106     Belazaima do Chão      01    0101  010106  Aveiro
# 8       3  010107  Castanheira do Vouga      01    0101  010107  Aveiro
# 9       3  010108              Espinhel      01    0101  010108  Aveiro
# 10      3  010109           Fermentelos      01    0101  010109  Aveiro
# 11      3  010110        Lamas do Vouga      01    0101  010110  Aveiro
# 12      3  010111    Macieira de Alcoba      01    0101  010111  Aveiro
# 13      3  010112    Macinhata do Vouga      01    0101  010112  Aveiro
# 14      3  010113        Óis da Ribeira      01    0101  010113  Aveiro
#
#     N2_DSG                N3_DSG                               COD_DSG  \
# 0     None                  None                                Aveiro
# 1   Águeda                  None                        Águeda, Aveiro
# 2   Águeda                Agadão                Agadão, Águeda, Aveiro
# 3   Águeda       Aguada de Baixo       Aguada de Baixo, Águeda, Aveiro
# 4   Águeda        Aguada de Cima        Aguada de Cima, Águeda, Aveiro
# 5   Águeda                Águeda                Águeda, Águeda, Aveiro
# 6   Águeda                 Barrô                 Barrô, Águeda, Aveiro
# 7   Águeda     Belazaima do Chão     Belazaima do Chão, Águeda, Aveiro
# 8   Águeda  Castanheira do Vouga  Castanheira do Vouga, Águeda, Aveiro
# 9   Águeda              Espinhel              Espinhel, Águeda, Aveiro
# 10  Águeda           Fermentelos           Fermentelos, Águeda, Aveiro
# 11  Águeda        Lamas do Vouga        Lamas do Vouga, Águeda, Aveiro
# 12  Águeda    Macieira de Alcoba    Macieira de Alcoba, Águeda, Aveiro
# 13  Águeda    Macinhata do Vouga    Macinhata do Vouga, Águeda, Aveiro
# 14  Águeda        Óis da Ribeira        Óis da Ribeira, Águeda, Aveiro
#
#    COD_UPPER_LEVEL
# 0              NaN
# 1               01
# 2             0101
# 3             0101
# 4             0101
# 5             0101
# 6             0101
# 7             0101
# 8             0101
# 9             0101
# 10            0101
# 11            0101
# 12            0101
# 13            0101
# 14            0101

# %%
cat2011_file_out = '../extras/geocoding/INE/categorias2011.csv'
cat2011_df.to_csv(cat2011_file_out, index=None)

# %% [markdown]
# ## Censos 2011 Principais dados alfanuméricos e geográficos
#
# Contém dados e mapas do censo de 2011. A informação toponímica é a mesma da "Toponímia de Portugal Continental"
# mas contém a estrutura administrativa e num ficheiro separado os
# totais dos resultados do censo (edifícios, famílias e pessoas)
#
# * http://mapas.ine.pt/download/files/
#
# Este bloco de notas assume que o ficheiro em http://mapas.ine.pt/download/files/2011/portugal2011.zip
# foi transferido e descomprimido na directoria `extras/geocoding/INE/portugal2011`

# %%
# !pip install dbf
# Out:
# Requirement already satisfied: dbf in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (0.99.2)
# Requirement already satisfied: aenum in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (from dbf) (3.1.11)

# %%
from os.path import exists
import pandas as pd
import dbf

c2011_dbf = '../extras/geocoding/INE/portugal2011/CONTINENTE/BGRI11_CONT.dbf'
c2011_cache = '../extras/geocoding/INE/portugal2011/CONTINENTE/BGRI11_CONT.csv'

if exists(c2011_cache):
    cache_exists = True
    print("Local cache data found")
    c2011_df = pd.read_csv(c2011_cache, dtype= {
                'OBJECTID':'str',
                'DTMN11':'str',
                'FR11':'str',
                'SEC11':'str',
                'SS11':'str',
                'BGRI11':'str',
                'LUG11':'str',
                })
else:
    cache_exists = False
    with dbf.Table(c2011_dbf) as table:
        dbf.export(table,c2011_cache)
    c2011_df = pd.read_csv(c2011_cache, 
               dtype={
                'OBJECTID':'str',
                'DTMN11':'str',
                'FR11':'str',
                'SEC11':'str',
                'SS11':'str',
                'BGRI11':'str',
                'LUG11':'str',
                },
                encoding='iso-8859-1')
    c2011_df.to_csv(c2011_cache, index=False)
c2011_df.info()
# Out:
# Local cache data found
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255844 entries, 0 to 255843
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   OBJECTID    255844 non-null  object
#  1   DTMN11      255844 non-null  object
#  2   FR11        255844 non-null  object
#  3   SEC11       255844 non-null  object
#  4   SS11        255844 non-null  object
#  5   BGRI11      255844 non-null  object
#  6   LUG11       255844 non-null  object
#  7   LUG11DESIG  255844 non-null  object
# dtypes: object(8)
# memory usage: 15.6+ MB

# %%
c2011_df.sample(5)
# Out:
#        OBJECTID DTMN11 FR11 SEC11   SS11       BGRI11   LUG11  \
# 210586   211666   1809   03   003  07     18090300307  018508
# 175878   170432   1101   16   001  22     11011600122  021308
# 231490   236911   1803   11   001  13     18031100113  018277
# 128275   122064   0808   08   018  11     08080801811  026230
# 74421     72107   0312   46   001  04     03124600104  007042
#
#                                                LUG11DESIG
# 210586  Nelas                                         ...
# 175878  Mato                                          ...
# 231490  Eido                                          ...
# 128275  Loulé                                         ...
# 74421   Melhe                                         ...

# %% [markdown]
# ### Criação dos códigos administrativos compostos.
#
# Os ficheiros do censo contém o código do concelho (__DTMN11__) e o número
# da freguesia (__FR11__) dentro do concelho.
#
# Para obter o código completo da freguesia compatível com o ficheiro "categorias2011.xls"
# é necessário concatenar os dois.
#
# Aproveitamos e produzimos códigos qualificados das secções e dos lugares.
#
# Não esquecer a definição de "Lugar" que corresponde ao _name place_ INSPIRE:
#
# "Lugares
#
# O lugar consiste numa delimitação territorial, definida no âmbito das operações censitárias, que corresponde a um aglomerado populacional com dez ou mais alojamentos destinados à habitação de pessoas e com uma designação própria, independentemente de pertencer a uma ou mais freguesias. No âmbito dos Censos de 2011, foram recenseados cerca de 26 mil lugares no território nacional"
#
# https://www.ine.pt/xportal/xmain?xpid=INE&xpgid=ine_cont_inst&INST=6251013&xlang=pt

# %%
c2011_df['FR11ADMIN'] = c2011_df['DTMN11'].astype(str)+c2011_df['FR11'] 
c2011_df['SEC11ADMIN'] = c2011_df['DTMN11'].astype(str)+c2011_df['FR11']+c2011_df['SEC11']
c2011_df['LUG11ADMIN'] = c2011_df['LUG11'].astype(str)+'-'+c2011_df['FR11ADMIN']

# %%
c2011_df.head()
# Out:
#   OBJECTID DTMN11 FR11 SEC11   SS11       BGRI11   LUG11  \
# 0      548   0407   02   001  04     04070200104  013810
# 1      549   0407   02   001  06     04070200106  013810
# 2      550   0407   02   001  01     04070200101  013811
# 3      551   0407   02   001  02     04070200102  013811
# 4      552   0407   29   001  03     04072900103  013866
#
#                                           LUG11DESIG FR11ADMIN SEC11ADMIN  \
# 0  Abreiro                                       ...    040702  040702001
# 1  Abreiro                                       ...    040702  040702001
# 2  Milhais                                       ...    040702  040702001
# 3  Milhais                                       ...    040702  040702001
# 4  Pai Torto                                     ...    040729  040729001
#
#       LUG11ADMIN
# 0  013810-040702
# 1  013810-040702
# 2  013811-040702
# 3  013811-040702
# 4  013866-040729

# %% [markdown]
# O código composto __FR11ADMIN__ adicionado acima ao ficheiro do censo de 2011
# é o mesmo que __N3_CODE__ do ficheiro de categorias, quando Nível == 3 (freguesia)
#
# Atenção: é preciso usar o ficheiro de categorias em vigor em 2011 e não o que acompanha os
# mapas do Censo.
#
# Retirando as freguesisas do Censo de 2011 e cruzando com as
# categorias de 2011 (FR11ADMIN == N3_CODE) deve-se obter uma correspondência
# perfeita.

# %%
c2011_fregs = c2011_df.sort_values('FR11ADMIN').drop_duplicates(subset='FR11ADMIN',keep='first')[['FR11ADMIN','DTMN11']]
c2011_fregs = c2011_fregs.merge(cat2011_df,how='left', left_on='FR11ADMIN', right_on='N3_CODE')
c2011_fregs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4050 entries, 0 to 4049
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   FR11ADMIN   4050 non-null   object
#  1   DTMN11      4050 non-null   object
#  2   Nível       4050 non-null   int64
#  3   Código      4050 non-null   object
#  4   Designação  4050 non-null   object
#  5   N1_CODE     4050 non-null   object
#  6   N2_CODE     4050 non-null   object
#  7   N3_CODE     4050 non-null   object
#  8   N1_DSG      4050 non-null   object
#  9   N2_DSG      4050 non-null   object
#  10  N3_DSG      4050 non-null   object
#  11  COD_DSG     4050 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 411.3+ KB

# %%
c2011_fregs.sample(10)
# Out:
#      FR11ADMIN DTMN11  Nível  Código          Designação N1_CODE N2_CODE  \
# 3245    160504   1605      3  160504          Cossourado      16    1605
# 3016    142002   1420      3  142002   Praia do Ribatejo      14    1420
# 4003    182207   1822      3  182207  Vila Nova de Paiva      18    1822
# 3935    181809   1818      3  181809           Freixinho      18    1818
# 561     030725   0307      3  030725            Ribeiros      03    0307
# 2759    131407   1314      3  131407            Carreira      13    1314
# 1564    070908   0709      3  070908           Vera Cruz      07    0709
# 2912    141102   1411      3  141102              Areias      14    1411
# 1202    050420   0504      3  050420                Orca      05    0504
# 636     030868   0308      3  030868            Silvares      03    0308
#
#      N3_CODE            N1_DSG                  N2_DSG              N3_DSG  \
# 3245  160504  Viana do Castelo        Paredes de Coura          Cossourado
# 3016  142002          Santarém  Vila Nova da Barquinha   Praia do Ribatejo
# 4003  182207             Viseu      Vila Nova de Paiva  Vila Nova de Paiva
# 3935  181809             Viseu             Sernancelhe           Freixinho
# 561   030725             Braga                    Fafe            Ribeiros
# 2759  131407             Porto             Santo Tirso            Carreira
# 1564  070908             Évora                  Portel           Vera Cruz
# 2912  141102          Santarém      Ferreira do Zêzere              Areias
# 1202  050420    Castelo Branco                  Fundão                Orca
# 636   030868             Braga               Guimarães            Silvares
#
#                                                 COD_DSG
# 3245     Cossourado, Paredes de Coura, Viana do Castelo
# 3016  Praia do Ribatejo, Vila Nova da Barquinha, San...
# 4003      Vila Nova de Paiva, Vila Nova de Paiva, Viseu
# 3935                      Freixinho, Sernancelhe, Viseu
# 561                               Ribeiros, Fafe, Braga
# 2759                       Carreira, Santo Tirso, Porto
# 1564                           Vera Cruz, Portel, Évora
# 2912               Areias, Ferreira do Zêzere, Santarém
# 1202                       Orca, Fundão, Castelo Branco
# 636                          Silvares, Guimarães, Braga

# %% [markdown]
# ### Merge de Toponímia do INE com a shape file do Censo 2011 para obter os códigos administrativos dos topónimos

# %% [markdown]
# Podemos cruzar a shapefile do Censo para a informação de toponímia do INE
# usando os campos LUG11 e local_id ou alternativamente inspire_id.
#
# ine.inspire_id == 'BRGRI2011_'+c2011.LUG11
#
# ou
#
# ine.local_id = c2011.LUG11
#
# Renomeamos as colinas para mais clareza.

# %%
ine_2011_df = ine_df.merge(c2011_df.sort_values('LUG11').drop_duplicates(subset='LUG11',keep='first'),how='left', left_on='local_id', right_on='LUG11')
ine_2011_df.drop(['OBJECTID','FR11','SEC11','SS11','LUG11','LUG11DESIG'], axis=1, inplace=True)
ine_2011_df.rename(columns={'DTMN11':'concelho_cod','FR11ADMIN':'freg_cod','SEC11ADMIN':'sec_cod','LUG11ADMIN':'lug_cod'}, inplace=True)

# %%
ine_2011_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36357 entries, 0 to 36356
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            36357 non-null  object
#  1   name          36357 non-null  object
#  2   latitude      36357 non-null  float64
#  3   longitude     36357 non-null  float64
#  4   origin        36357 non-null  object
#  5   local_id      32507 non-null  object
#  6   inspire_id    29322 non-null  object
#  7   nname         36357 non-null  object
#  8   concelho_cod  25472 non-null  object
#  9   BGRI11        25472 non-null  object
#  10  freg_cod      25472 non-null  object
#  11  sec_cod       25472 non-null  object
#  12  lug_cod       25472 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 3.9+ MB

# %% [markdown]
# Temos a correspondência entre lugar e freguesia (freg_cod) nos
# topónimos cuja fonte é o INE.

# %%
ine_2011_df.sample(10)[['origin','name','local_id','freg_cod']]
# Out:
#        origin              name                    local_id freg_cod
# 2386   CIGEOE     São Cristóvão                         NaN      NaN
# 7608      INE     Fundo de Vila                      004731   031352
# 29155     INE       Monte Lemos                      035810   080703
# 26009     INE  Sarnadas de Cima                      030660   050601
# 3185   CIGEOE           Alqueve                         NaN      NaN
# 34334     DGT          Cartomil  CDG200k_populatedPlace5223      NaN
# 34787     DGT               Chã  CDG200k_populatedPlace5176      NaN
# 19728     INE        Souropires                      020478   091024
# 7175      INE            Bairro                      004206   031017
# 10581     INE           Regadas                      009534   130506

# %% [markdown]
# ### Merge das categorias de 2011 com o ficheiro de toponímia
#
# O campo freg_cod (FRE11) permite obter o contexto administrativo por extenso

# %%
ine_2011_cat_df = ine_2011_df.merge(cat2011_df.dropna(subset=['N3_CODE']),how='left',left_on='freg_cod',right_on='N3_CODE')
ine_2011_cat_df.drop(['BGRI11','Nível','Código','Designação','N2_CODE','N3_CODE'], axis=1, inplace=True)
ine_2011_cat_df.rename(columns={'N1_CODE':'distrito_cod','N1_DSG':'distrito_dsg','N2_DSG':'concelho_dsg','N3_DSG':'freg_dsg','COD_DSG':'admin_dsg'}, inplace=True)
ine_2011_cat_df['name_dsg'] = ine_2011_cat_df['nname'].astype(str)+', '+ine_2011_cat_df['admin_dsg']
ine_2011_cat_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36357 entries, 0 to 36356
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               36357 non-null  object
#  1   name             36357 non-null  object
#  2   latitude         36357 non-null  float64
#  3   longitude        36357 non-null  float64
#  4   origin           36357 non-null  object
#  5   local_id         32507 non-null  object
#  6   inspire_id       29322 non-null  object
#  7   nname            36357 non-null  object
#  8   concelho_cod     25472 non-null  object
#  9   freg_cod         25472 non-null  object
#  10  sec_cod          25472 non-null  object
#  11  lug_cod          25472 non-null  object
#  12  distrito_cod     25472 non-null  object
#  13  distrito_dsg     25472 non-null  object
#  14  concelho_dsg     25472 non-null  object
#  15  freg_dsg         25472 non-null  object
#  16  admin_dsg        25472 non-null  object
#  17  COD_UPPER_LEVEL  25472 non-null  object
#  18  name_dsg         25472 non-null  object
# dtypes: float64(2), object(17)
# 22683                              0                       4
# 22684                              0                       9
# 22685                              1                       6
# 22686                              0                       0
# 22687                              0                       2
#
#        N_IND_RESID_PENS_REFORM  N_IND_RESID_SEM_ACT_ECON  \
# 22683                        3                         3
# 22684                        5                        10
# 22685                        7                         9
# 22686                        4                         4
# 22687                        5                        10
#
#        N_IND_RESID_EMPREG_SECT_PRIM  N_IND_RESID_EMPREG_SECT_SEQ  \
# 22683                             0                            3
# 22684                             0                            6
# 22685                             0                            2
# 22686                             0                            0
# 22687                             1                            0
#
#        N_IND_RESID_EMPREG_SECT_TERC  N_IND_RESID_ESTUD_MUN_RESID  \
# 22683                             1                            2
# 22684                             3                            0
# 22685                             4                            2
# 22686                             0                            0
# 22687                             1                            4
#
#        N_IND_RESID_TRAB_MUN_RESID  Unnamed: 127
# 22683                           3           NaN
# 22684                           5           NaN
# 22685                           6           NaN
# 22686                           0           NaN
# 22687                           2           NaN
#
# [5 rows x 128 columns]

# %% [markdown]
# Primeiro cruzamos com os mapas do censo de 2011 para obter o contexto administrativo.

# %%
bgrilug11_df = brigi11_df.merge(c2011_df.sort_values('BGRI11').drop_duplicates(subset='BGRI11',keep='first'),how='left', left_on='GEO_COD', right_on='BGRI11')
bgrilug11_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 288638 entries, 0 to 288637
# Columns: 139 entries, ANO to LUG11ADMIN
# dtypes: float64(1), int64(124), object(14)
# memory usage: 308.3+ MB

# %%
bgrilug11_df[bgrilug11_df.NIVEL > 7].head()
# Out:
#         ANO      GEO_COD GEO_COD_DSG  NIVEL  NIVEL_DSG  N_NUCLEOS_FAMILIARES  \
# 22683  2011  01010100101                  8  Subsecção                     2
# 22684  2011  01010100102                  8  Subsecção                     7
# 22685  2011  01010100103                  8  Subsecção                     6
# 22686  2011  01010100104                  8  Subsecção                     2
# 22687  2011  01010100105                  8  Subsecção                     4
#
#        N_INDIVIDUOS_RESIDENT OBJECTID DTMN11 FR11 SEC11   SS11       BGRI11  \
# 22683                      9        0   0101   01   001  01     01010100101
# 22684                     19        0   0101   01   001  02     01010100102
# 22685                     18        0   0101   01   001  03     01010100103
# 22686                      4        0   0101   01   001  04     01010100104
# 22687                     15        0   0101   01   001  05     01010100105
#
#         LUG11                                         LUG11DESIG FR11ADMIN  \
# 22683  014420  Alcafaz                                       ...    010101
# 22684  014420  Alcafaz                                       ...    010101
# 22685  014421  Caselho                                       ...    010101
# 22686  014421  Caselho                                       ...    010101
# 22687  014421  Caselho                                       ...    010101
#
#       SEC11ADMIN     LUG11ADMIN
# 22683  010101001  014420-010101
# 22684  010101001  014420-010101
# 22685  010101001  014421-010101
# 22686  010101001  014421-010101
# 22687  010101001  014421-010101

# %% [markdown]
# Agregamos os dados ao nível do lugar. Só retemos os número de núcleos familiares e número de indivíduos.

# %%
lug11_pop = bgrilug11_df.groupby('LUG11').agg(nucleos_familiares = ('N_NUCLEOS_FAMILIARES','sum'),residentes = ('N_INDIVIDUOS_RESIDENT','sum')).reset_index()
lug11_pop.nucleos_familiares = lug11_pop.nucleos_familiares.astype(int)
lug11_pop.residentes = lug11_pop.residentes.astype(int)
lug11_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25474 entries, 0 to 25473
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   LUG11               25474 non-null  object
#  1   nucleos_familiares  25474 non-null  int64
#  2   residentes          25474 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 597.2+ KB

# %%
lug11_pop.sample(10)
# Out:
#         LUG11  nucleos_familiares  residentes
# 17845  022779                 203         629
# 20885  026374                  76         233
# 2787   003396                  28          98
# 4202   005405                  44         143
# 17363  022110                  10          29
# 1375   001640                  21          70
# 24072  034186                  74         221
# 19220  024367                 260         833
# 11705  015892                  22          61
# 4485   005821                  10          25

# %% [markdown]
# Copiamos os dados demográfico para a
# lista de topónimos.
#
# O resultado é uma lista de topónimos
# com contexto administrativo e
# resultados censo de 2011.

# %%
ine_2011_pop = ine_2011_cat_df.merge(lug11_pop, how='left', left_on='local_id', right_on='LUG11')
ine_2011_pop.drop(['LUG11'], axis=1, inplace=True)
ine_2011_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36357 entries, 0 to 36356
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  36357 non-null  object
#  1   name                36357 non-null  object
#  2   latitude            36357 non-null  float64
#  3   longitude           36357 non-null  float64
#  4   origin              36357 non-null  object
#  5   local_id            32507 non-null  object
#  6   inspire_id          29322 non-null  object
#  7   nname               36357 non-null  object
#  8   concelho_cod        25472 non-null  object
#  9   freg_cod            25472 non-null  object
#  10  sec_cod             25472 non-null  object
#  11  lug_cod             25472 non-null  object
#  12  distrito_cod        25472 non-null  object
#  13  distrito_dsg        25472 non-null  object
#  14  concelho_dsg        25472 non-null  object
#  15  freg_dsg            25472 non-null  object
#  16  admin_dsg           25472 non-null  object
#  17  COD_UPPER_LEVEL     25472 non-null  object
#  18  name_dsg            25472 non-null  object
#  19  nucleos_familiares  25472 non-null  float64
#  20  residentes          25472 non-null  float64
# dtypes: float64(4), object(17)
# memory usage: 6.1+ MB

# %% [markdown]
# ## Exemplos dos dados consolidados
#
# Toponímia, coordenadas, contexto administrativo, demografia dos censos.

# %% [markdown]
# ##### Lisboa

# %%
ine_2011_pop[ine_2011_pop.inspire_id =='BGRI2011_022406']
# Out:
#                  id    name   latitude  longitude origin local_id  \
# 21432  PT.GN.104409  Lisboa  38.741645  -9.157559    INE   022406
#
#             inspire_id   nname concelho_cod freg_cod  ...        lug_cod  \
# 21432  BGRI2011_022406  Lisboa         1106   110643  ...  022406-110643
#
#       distrito_cod distrito_dsg concelho_dsg          freg_dsg  \
# 21432           11       Lisboa       Lisboa  São João de Deus
#
#                               admin_dsg COD_UPPER_LEVEL  \
# 21432  São João de Deus, Lisboa, Lisboa            1106
#
#                                        name_dsg nucleos_familiares  residentes
# 21432  Lisboa, São João de Deus, Lisboa, Lisboa           154519.0    547733.0
#
# [1 rows x 21 columns]

# %% [markdown]
# ##### Soure

# %%
import pandas as pd
pd.set_option('display.max_rows',200)

ine_2011_pop[ine_2011_pop.concelho_cod == '0615'][['id','name','longitude','latitude','nucleos_familiares','residentes','name_dsg','inspire_id']].sort_values('residentes', ascending=False)
# Out:
#                  id                      name  longitude   latitude  \
# 15790   PT.GN.98767                     Soure  -8.628098  40.059784
# concelho_cod                                                 0615
# freg_cod                                                   061509
# sec_cod                                                 061509005
# lug_cod                                             035183-061509
# distrito_cod                                                   06
# distrito_dsg                                              Coimbra
# concelho_dsg                                                Soure
# freg_dsg                                                    Soure
# admin_dsg                                   Soure, Soure, Coimbra
# COD_UPPER_LEVEL                                              0615
# name_dsg              Prazo dos Estudantes, Soure, Soure, Coimbra
# nucleos_familiares                                           15.0
# residentes                                                   51.0
# Name: 28719, dtype: object

# %% [markdown]
# Informação no Censo de 2011, subsecção

# %%
c2011_df[c2011_df.LUG11.isin(ine_df[ine_df.name == name]['local_id'])].sort_values('BGRI11')
# Out:
#       OBJECTID DTMN11 FR11 SEC11   SS11       BGRI11   LUG11  \
# 18814    29717   0615   09   005  05     06150900505  035183
# 17727    29408   0615   09   005  06     06150900506  035183
#
#                                               LUG11DESIG FR11ADMIN SEC11ADMIN  \
# 18814  Prazo dos Estudantes                          ...    061509  061509005
# 17727  Prazo dos Estudantes                          ...    061509  061509005
#
#           LUG11ADMIN
# 18814  035183-061509
# 17727  035183-061509

# %% [markdown]
# Dados do Censo, do ficheiro de síntese

# %%
geo_codes = c2011_df[c2011_df.LUG11.isin(ine_df[ine_df.name == name]['local_id'])]['BGRI11']
print(geo_codes)
bgrilug11_df[bgrilug11_df.GEO_COD.isin(geo_codes)]
# Out:
# 17727    06150900506
# 18814    06150900505
# Name: BGRI11, dtype: object
#         ANO      GEO_COD GEO_COD_DSG  NIVEL  NIVEL_DSG  N_EDIFICIOS_CLASSICOS  \
# 99320  2011  06150900505                  8  Subsecção                      9
# 99321  2011  06150900506                  8  Subsecção                      9
#
#        N_EDIFICIOS_CLASSICOS_1OU2  N_EDIFICIOS_CLASSICOS_ISOLADOS   \
# 99320                           9                                8
# 99321                           9                                7
#
#        N_EDIFICIOS_CLASSICOS_GEMIN  N_EDIFICIOS_CLASSICOS_EMBANDA  ...  \
# 99320                            1                              0  ...
# 99321                            2                              0  ...
#
#        DTMN11  FR11  SEC11   SS11       BGRI11   LUG11  \
# 99320    0615    09    005  05     06150900505  035183
# 99321    0615    09    005  06     06150900506  035183
#
#                                               LUG11DESIG  FR11ADMIN  \
# 99320  Prazo dos Estudantes                          ...     061509
# 99321  Prazo dos Estudantes                          ...     061509
#
#        SEC11ADMIN     LUG11ADMIN
# 99320   061509005  035183-061509
# 99321   061509005  035183-061509
#
# [2 rows x 139 columns]

# %% [markdown]
# Ficheiro de toponímia consolidado, acesso por nome geográfico

# %%
ine_2011_pop[ine_2011_pop.name == name]
# Out:
#                  id                  name   latitude  longitude origin  \
# 28719  PT.GN.111697  Prazo dos Estudantes  40.053108  -8.614399    INE
#
#       local_id       inspire_id                 nname concelho_cod freg_cod  \
# 28719   035183  BGRI2011_035183  Prazo dos Estudantes         0615   061509
#
#        ...        lug_cod distrito_cod distrito_dsg concelho_dsg freg_dsg  \
# 28719  ...  035183-061509           06      Coimbra        Soure    Soure
#
#                    admin_dsg COD_UPPER_LEVEL  \
# 28719  Soure, Soure, Coimbra            0615
#
#                                           name_dsg nucleos_familiares  \
# 28719  Prazo dos Estudantes, Soure, Soure, Coimbra               15.0
#
#        residentes
# 28719        51.0
#
# [1 rows x 21 columns]

# %% [markdown]
# Dados da secção estatística que inclui o topónimo.

# %%
brigi11_df[brigi11_df.GEO_COD == '061509005']
# Out:
#        ANO    GEO_COD GEO_COD_DSG  NIVEL NIVEL_DSG  N_EDIFICIOS_CLASSICOS  \
# 8821  2011  061509005                  7    Secção                    411
#
#       N_EDIFICIOS_CLASSICOS_1OU2  N_EDIFICIOS_CLASSICOS_ISOLADOS   \
# 8821                         406                              316
#
#       N_EDIFICIOS_CLASSICOS_GEMIN  N_EDIFICIOS_CLASSICOS_EMBANDA  ...  \
# 8821                           69                             21  ...
#
#       N_IND_RESID_DESEMP_PROC_EMPRG  N_IND_RESID_EMPREGADOS  \
# 8821                             33                     285
#
#       N_IND_RESID_PENS_REFORM  N_IND_RESID_SEM_ACT_ECON  \
# 8821                      218                       343
#
#       N_IND_RESID_EMPREG_SECT_PRIM  N_IND_RESID_EMPREG_SECT_SEQ  \
# 8821                             6                           56
#
#       N_IND_RESID_EMPREG_SECT_TERC  N_IND_RESID_ESTUD_MUN_RESID  \
# 8821                           223                           92
#
#       N_IND_RESID_TRAB_MUN_RESID  Unnamed: 127
# 8821                         157           NaN
#
# [1 rows x 128 columns]

# %%
bgrilug11_df[bgrilug11_df.SEC11ADMIN == '061509005']
# Out:
#         ANO      GEO_COD GEO_COD_DSG  NIVEL  NIVEL_DSG  N_EDIFICIOS_CLASSICOS  \
# 99316  2011  06150900501                  8  Subsecção                     11
# 99317  2011  06150900502                  8  Subsecção                     14
# 99318  2011  06150900503                  8  Subsecção                      6
# 99319  2011  06150900504                  8  Subsecção                      2
# 99320  2011  06150900505                  8  Subsecção                      9
# 99321  2011  06150900506                  8  Subsecção                      9
# 99322  2011  06150900507                  8  Subsecção                      3
# 99323  2011  06150900508                  8  Subsecção                      4
# 99324  2011  06150900509                  8  Subsecção                      6
# 99325  2011  06150900510                  8  Subsecção                      2
# 99326  2011  06150900511                  8  Subsecção                     49
# 99327  2011  06150900512                  8  Subsecção                     15
# 99328  2011  06150900513                  8  Subsecção                     13
# 99329  2011  06150900514                  8  Subsecção                     16
# 99330  2011  06150900515                  8  Subsecção                      8
# 99331  2011  06150900516                  8  Subsecção                      6
# 99332  2011  06150900517                  8  Subsecção                     33
# 99333  2011  06150900518                  8  Subsecção                     21
# 99334  2011  06150900519                  8  Subsecção                     26
# 99335  2011  06150900520                  8  Subsecção                     11
# 99336  2011  06150900521                  8  Subsecção                      7
# 99337  2011  06150900522                  8  Subsecção                     23
# 99338  2011  06150900523                  8  Subsecção                     15
# 99339  2011  06150900524                  8  Subsecção                     16
# 99340  2011  06150900525                  8  Subsecção                     13
# 99341  2011  06150900526                  8  Subsecção                     16
# 99342  2011  06150900527                  8  Subsecção                      7
# 99343  2011  06150900528                  8  Subsecção                     13
# 99344  2011  06150900529                  8  Subsecção                     37
#
#        N_EDIFICIOS_CLASSICOS_1OU2  N_EDIFICIOS_CLASSICOS_ISOLADOS   \
# 99316                          10                               10
# 99317                          14                               11
# 99318                           5                                3
# 99319                           2                                2
# 99320                           9                                8
# 99321                           9                                7
# 99322                           3                                3
# 99323                           4                                4
# 99324                           6                                6
# 99325                           2                                2
# 99326                          49                               18
# 99327                          15                               12
# 99328                          13                               12
# 99329                          16                               12
# 99330                           8                                7
# 99331                           6                                6
# 99332                          33                               28
# 99333                          21                               13
# 99334                          26                               19
# 99335                          11                               10
# 99336                           7                                6
# 99337                          23                               18
# 99338                          15                               15
# 99339                          16                               11
# 99340                          13                               12
# 99341                          16                               14
# 99342                           7                                7
# 99343                          13                               10
# 99344                          34                               30
#
#        N_EDIFICIOS_CLASSICOS_GEMIN  N_EDIFICIOS_CLASSICOS_EMBANDA  ...  \
# 99316                            0                              0  ...
# 99317                            2                              1  ...
# 99318                            2                              0  ...
# 99319                            0                              0  ...
# 99320                            1                              0  ...
# 99321                            2                              0  ...
# 99322                            0                              0  ...
# 99323                            0                              0  ...
# 99324                            0                              0  ...
# 99325                            0                              0  ...
# 99326                           15                             16  ...
# 99327                            2                              1  ...
# 99328                            1                              0  ...
# 99329                            4                              0  ...
# 99330                            1                              0  ...
# 99331                            0                              0  ...
# 99332                            5                              0  ...
# 99333                            8                              0  ...
# 99334                            7                              0  ...
# 99335                            1                              0  ...
# 99336                            1                              0  ...
# 99337                            5                              0  ...
# 99338                            0                              0  ...
# 99339                            5                              0  ...
# 99340                            1                              0  ...
# 99341                            2                              0  ...
# 99342                            0                              0  ...
# 99343                            1                              2  ...
# 99344                            3                              1  ...
#
#        DTMN11  FR11  SEC11   SS11       BGRI11   LUG11  \
# 99316    0615    09    005  01     06150900501  016156
# 99317    0615    09    005  02     06150900502  016156
# 99318    0615    09    005  03     06150900503  016146
# 99319    0615    09    005  04     06150900504  016146
# 99320    0615    09    005  05     06150900505  035183
# 99321    0615    09    005  06     06150900506  035183
# 99322    0615    09    005  07     06150900507  016143
# 99323    0615    09    005  08     06150900508  016143
# 99324    0615    09    005  09     06150900509  016143
# 99325    0615    09    005  10     06150900510  016143
# 99326    0615    09    005  11     06150900511  016137
# 99327    0615    09    005  12     06150900512  016137
# 99328    0615    09    005  13     06150900513  035185
# 99329    0615    09    005  14     06150900514  035185
# 99330    0615    09    005  15     06150900515  035185
# 99331    0615    09    005  16     06150900516  035185
# 99332    0615    09    005  17     06150900517  016121
# 99333    0615    09    005  18     06150900518  016121
# 99334    0615    09    005  19     06150900519  016121
# 99335    0615    09    005  20     06150900520  016121
# 99336    0615    09    005  21     06150900521  016121
# 99337    0615    09    005  22     06150900522  016121
# 99338    0615    09    005  23     06150900523  016121
# 99339    0615    09    005  24     06150900524  016121
# 99340    0615    09    005  25     06150900525  035979
# 99341    0615    09    005  26     06150900526  035979
# 99342    0615    09    005  27     06150900527  016161
# 99343    0615    09    005  28     06150900528  016161
# 99344    0615    09    005  29     06150900529  999999
#
#                                               LUG11DESIG  FR11ADMIN  \
# 99316  Novos                                         ...     061509
# 99317  Novos                                         ...     061509
# 99318  Soure                                         ...     061509
# 99319  Soure                                         ...     061509
# 99320  Prazo dos Estudantes                          ...     061509
# 99321  Prazo dos Estudantes                          ...     061509
# 99322  Quinta de S. Mateus                           ...     061509
# 99323  Quinta de S. Mateus                           ...     061509
# 99324  Quinta de S. Mateus                           ...     061509
# 99325  Quinta de S. Mateus                           ...     061509
# 99326  Paleão                                        ...     061509
# 99327  Paleão                                        ...     061509
# 99328  Casal dos Feijões                             ...     061509
# 99329  Casal dos Feijões                             ...     061509
# 99330  Casal dos Feijões                             ...     061509
# 99331  Casal dos Feijões                             ...     061509
# 99332  Casal do Barril                               ...     061509
# 99333  Casal do Barril                               ...     061509
# 99334  Casal do Barril                               ...     061509
# 99335  Casal do Barril                               ...     061509
# 99336  Casal do Barril                               ...     061509
# 99337  Casal do Barril                               ...     061509
# 99338  Casal do Barril                               ...     061509
# 99339  Casal do Barril                               ...     061509
# 99340  Meãs                                          ...     061509
# 99341  Meãs                                          ...     061509
# 99342  Marco do Sul                                  ...     061509
# 99343  Marco do Sul                                  ...     061509
# 99344  Residual                                      ...     061509
#
#        SEC11ADMIN     LUG11ADMIN
# 99316   061509005  016156-061509
# 99317   061509005  016156-061509
# 99318   061509005  016146-061509
# 99319   061509005  016146-061509
# 99320   061509005  035183-061509
# 99321   061509005  035183-061509
# 99322   061509005  016143-061509
# 99323   061509005  016143-061509
# 99324   061509005  016143-061509
# 99325   061509005  016143-061509
# 99326   061509005  016137-061509
# 99327   061509005  016137-061509
# 99328   061509005  035185-061509
# 99329   061509005  035185-061509
# 99330   061509005  035185-061509
# 99331   061509005  035185-061509
# 99332   061509005  016121-061509
# 99333   061509005  016121-061509
# 99334   061509005  016121-061509
# 99335   061509005  016121-061509
# 99336   061509005  016121-061509
# 99337   061509005  016121-061509
# 99338   061509005  016121-061509
# 99339   061509005  016121-061509
# 99340   061509005  035979-061509
# 99341   061509005  035979-061509
# 99342   061509005  016161-061509
# 99343   061509005  016161-061509
# 99344   061509005  999999-061509
#
# [29 rows x 139 columns]

# %% [markdown]
# ## Exportar os dados consolidados

# %%
ine_2011_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36357 entries, 0 to 36356
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  36357 non-null  object
#  1   name                36357 non-null  object
#  2   latitude            36357 non-null  float64
#  3   longitude           36357 non-null  float64
#  4   origin              36357 non-null  object
#  5   local_id            32507 non-null  object
#  6   inspire_id          29322 non-null  object
#  7   nname               36357 non-null  object
#  8   concelho_cod        25472 non-null  object
#  9   freg_cod            25472 non-null  object
#  10  sec_cod             25472 non-null  object
#  11  lug_cod             25472 non-null  object
#  12  distrito_cod        25472 non-null  object
#  13  distrito_dsg        25472 non-null  object
#  14  concelho_dsg        25472 non-null  object
#  15  freg_dsg            25472 non-null  object
#  16  admin_dsg           25472 non-null  object
#  17  COD_UPPER_LEVEL     25472 non-null  object
#  18  name_dsg            25472 non-null  object
#  19  nucleos_familiares  25472 non-null  float64
#  20  residentes          25472 non-null  float64
# dtypes: float64(4), object(17)
# memory usage: 6.1+ MB

# %%
ine_topo_file = cache_file
ine_2011_pop.to_csv(ine_topo_file, index=False)
print("Exporting to", cache_file)
# Out:
# Exporting to ../extras/geocoding/INE/ine_toponimia_clipped.csv

# %% [markdown]
# ## Análise do ficheiro consolidado

# %%
! pip install folium
# Out:
# Requirement already satisfied: folium in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (0.12.1.post1)
# Requirement already satisfied: requests in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (from folium) (2.28.0)
# Requirement already satisfied: branca>=0.3.0 in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (from folium) (0.5.0)
# Requirement already satisfied: numpy in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (from folium) (1.23.0)
# Requirement already satisfied: jinja2>=2.9 in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (from folium) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (from requests->folium) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (from requests->folium) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (from requests->folium) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (from requests->folium) (2022.6.15)

# %% [markdown]
# ### Análise dos identificadores

# %%
cigoe_df = ine_2011_pop[ine_2011_pop.origin=='CIGEOE']
dgt_df = ine_2011_pop[ine_2011_pop.origin=='DGT']
ine_ine_df = ine_2011_pop[ine_2011_pop.origin=='INE']

cigoe_names = cigoe_df['name'].str.lower()
dgt_names = dgt_df['name'].str.lower()
ine_ine_names = ine_ine_df['name'].str.lower()

print("Number of names in cigoe:",len(cigoe_names))
print("Number of names in dgt:",len(dgt_names))
print("Number of names in ine:",len(ine_ine_names))
# Out:
# Number of names in cigoe: 3850
# Number of names in dgt: 7035
# Number of names in ine: 25472

# %% [markdown]
# ### Topo-homonomia

# %%
ine_2011_pop.groupby('name').agg(count=('name','count')).reset_index().sort_values('count', ascending=False).head(15)
# Out:
#               name  count
# 6824        Igreja    349
# 9074       Outeiro    291
# 8335         Monte    160
# 10227      Portela    135
# 12756        Souto    126
# 3003     Carvalhal    115
# 1947      Boavista    105
# 371         Aldeia    104
# 9487          Paço     91
# 3274         Casal     90
# 4651         Costa     90
# 9970      Pinheiro     85
# 383    Aldeia Nova     82
# 13390        Torre     79
# 1176       Assento     77

# %% [markdown]
# ### Sobreposição das fontes de dados

# %%
common_dgt_cigoe = list(set(cigoe_names).intersection(set(dgt_names)))
common_ine_cigoe = list(set(cigoe_names).intersection(set(ine_ine_names)))
common_ine_cigoe_dgt = list(set(cigoe_names).intersection(set(ine_ine_names)).intersection(set(dgt_names)))
print("Common names cigoe-dgt", len(common_dgt_cigoe))
print("Common names cigoe-ine", len(common_ine_cigoe))
print("Common names cigoe-ine-dgt", len(common_ine_cigoe_dgt))
print(common_ine_cigoe_dgt[:20])
# Out:
# Common names cigoe-dgt 1805
# Common names cigoe-ine 2591
# Common names cigoe-ine-dgt 1796
# ['samil', 'palmela', 'cochadas', 'figueira', 'moimenta', 'arcozelo', 'póvoa de atalaia', 'marmeleiro', 'apúlia', 'carrazeda de ansiães', 'fuseta', 'mamouros', 'celorico de basto', 'runa', 'aguada de baixo', 'almagreira', 'covão', 'mouriscas', 'fornelos', 'antas']

# %% [markdown]
# ## Remoção de topónimos redundantes

# %% [markdown]
# Removemos os topónimos que:
# * não tenham origem no INE
# * estejam localizados menos de um km de um topónimo do INE com o mesmo nome.
# * quando vários topónimos do INE estão a menos de 1KM, escolhe-se o mais próximo

# %%
! pip install recordlinkage
# Out:
# Requirement already satisfied: recordlinkage in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (0.15)
# Requirement already satisfied: numpy>=1.13.0 in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (from recordlinkage) (1.23.0)
# Requirement already satisfied: scipy>=1 in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (from recordlinkage) (1.8.1)
# Requirement already satisfied: pandas<2,>=1 in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (from recordlinkage) (1.4.3)
# Requirement already satisfied: jellyfish>=0.8.0 in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (from recordlinkage) (0.9.0)
# Requirement already satisfied: scikit-learn>=0.19.0 in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (from recordlinkage) (1.1.1)
# Requirement already satisfied: joblib in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (from recordlinkage) (1.1.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (from pandas<2,>=1->recordlinkage) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (from pandas<2,>=1->recordlinkage) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (from scikit-learn>=0.19.0->recordlinkage) (3.1.0)
# Requirement already satisfied: six>=1.5 in /Users/jrc/.pyenv/versions/3.9.10/envs/fauc/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas<2,>=1->recordlinkage) (1.16.0)

# %% [markdown]
# We need geopy to calculate distances

# %%
! pip install geopy
# Out:
# Collecting geopy
#   Using cached geopy-2.2.0-py3-none-any.whl (118 kB)
# Collecting geographiclib<2,>=1.49
#   Using cached geographiclib-1.52-py3-none-any.whl (38 kB)
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-1.52 geopy-2.2.0

# %% [markdown]
# ### Assinalar topónimos com o mesmo nome a menos de 1km de distância

# %% [markdown]
# Alguns misses:
#
# * DGT: Braga, distância a INE: cerca de 3km

# %%
import recordlinkage
from geopy.distance import geodesic

threshold = 1.5

origin, dataframe = ('CIGEOE',cigoe_df)

for origin, dataframe in [('CIGEOE',cigoe_df), ('DGT',dgt_df)]:
    print("Processing:",origin)
    indexer = recordlinkage.index.Block(left_on='nname', right_on='nname')
    candidates = indexer.index(ine_ine_df,dataframe)
    print(len(candidates))
    compare = recordlinkage.Compare()
    compare.string('nname','nname',method='jarowinkler', label='same_name')
    compare.geo( label='same_location',   # this seems to match up to 1km
                left_on_lat='latitude',   # not sure how to increase
                left_on_lng='longitude',
                right_on_lat='latitude',
                right_on_lng='longitude',
                method='linear'
                )
    candidates = compare.compute(candidates,ine_ine_df,dataframe)
    candidates.index.names = ('INE',origin)
    candidates['total'] = candidates.sum(axis =1)
    # we filter
    candidates = candidates[candidates.total > threshold].reset_index()
    candidates.sort_values('total', ascending=False, inplace=True)
    candidates.drop_duplicates(subset=origin, keep='first', inplace=True)
    candidates.set_index(['INE',origin], inplace=True)
    #
    # candidates[candidates.same_location>0].hist(column='total', bins=150)
    # candidates[candidates.same_location>0].describe()
    #
    # as we go by increasing order of proximity, in case of multiple matches
    #   the closest ones win.
    for (l,r), row in candidates.sort_values('same_location').iterrows():
        left = ine_2011_pop.iloc[l]
        right = ine_2011_pop.iloc[r]
        dist_meters = geodesic((left.latitude,left.longitude), (right.latitude,right.longitude)).km*1000
        ine_2011_pop.loc[r,'duplicate'] = True
        ine_2011_pop.loc[r,'same_as'] = ine_2011_pop.iloc[l]['id']
        ine_2011_pop.loc[r,'same_as_score'] = row['same_location']
        ine_2011_pop.loc[r,'same_as_distance'] = dist_meters
# Out:
# Processing: CIGEOE
# 20456
# Processing: DGT
# 83261

# %%
ine_2011_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36357 entries, 0 to 36356
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  36357 non-null  object
#  1   name                36357 non-null  object
#  2   latitude            36357 non-null  float64
#  3   longitude           36357 non-null  float64
#  4   origin              36357 non-null  object
#  5   local_id            32507 non-null  object
#  6   inspire_id          29322 non-null  object
#  7   nname               36357 non-null  object
#  8   concelho_cod        25472 non-null  object
#  9   freg_cod            25472 non-null  object
#  10  sec_cod             25472 non-null  object
#  11  lug_cod             25472 non-null  object
#  12  distrito_cod        25472 non-null  object
#  13  distrito_dsg        25472 non-null  object
#  14  concelho_dsg        25472 non-null  object
#  15  freg_dsg            25472 non-null  object
#  16  admin_dsg           25472 non-null  object
#  17  COD_UPPER_LEVEL     25472 non-null  object
#  18  name_dsg            25472 non-null  object
#  19  nucleos_familiares  25472 non-null  float64
#  20  residentes          25472 non-null  float64
#  21  duplicate           9505 non-null   object
#  22  same_as             9505 non-null   object
#  23  same_as_score       9505 non-null   float64
#  24  same_as_distance    9505 non-null   float64
# dtypes: float64(6), object(19)
# memory usage: 8.2+ MB

# %% [markdown]
# ### Análise dos topónimos autónomos do CIGEOE e DGT
#
# Em Junho 2022 o CIGEOE acrescenta 1048 topónimos
# aos dados do INE e a DGT 334.

# %%
ine_2011_pop.fillna({'duplicate':False}).groupby(['origin','duplicate'])['id'].count()
# Out:
# origin  duplicate
# CIGEOE  False         1046
#         True          2804
# DGT     False          334
#         True          6701
# INE     False        25472
# Name: id, dtype: int64

# %% [markdown]
# Os topónimos da DGT incluem também
# formações naturais (cabos, ilhas, pontas, serras)
# e construções como santuários e fortes.
#
# É possível inferir o tipo do __local_id__ incluíndo
# nos dados.
#
# Conclui-se que apenas 73 topónimos correspondem a __populatedPlace__.

# %%
dgt_filter = ine_2011_pop.origin == 'DGT'
ine_2011_pop.loc[dgt_filter,'dgt_type'] = ine_2011_pop.loc[dgt_filter,'local_id'].str.strip("CDG_k0123456789")

# %%
ine_2011_pop[(ine_2011_pop.origin == 'DGT') & (ine_2011_pop.duplicate.isnull())].groupby('dgt_type')['dgt_type'].count()
# Out:
# dgt_type
# buildingForte         23
# buildingSantuario     13
# landformCabo           7
# landformIlha          15
# landformPonta         54
# landformSerra        153
# populatedPlace        73
# Name: dgt_type, dtype: int64

# %% [markdown]
# Os lugares que não são __populatedPlace__ não devem
# participar da desduplicação.

# %%
dgt_nonpop = (ine_2011_pop.origin == 'DGT') & (ine_2011_pop.dgt_type != 'populatedPlace')
ndx = ine_2011_pop[dgt_nonpop].index.values
ine_2011_pop.loc[ndx,'duplicate'] = False
ine_2011_pop.loc[ndx][['name','origin','dgt_type','duplicate']]
# Out:
#                  name origin       dgt_type duplicate
# 35821       Alcáçovas    DGT  landformSerra     False
# 35822  Alcaria  Ruiva    DGT  landformSerra     False
# 35823     Alfeizeirao    DGT  landformSerra     False
# 35824       Alqueidao    DGT  landformSerra     False
# 35825           ALVAO    DGT  landformSerra     False
# ...               ...    ...            ...       ...
# 36352      Candeeiras    DGT  landformPonta     False
# 36353          Alheta    DGT  landformPonta     False
# 36354          Sagres    DGT  landformPonta     False
# 36355         Atalaia    DGT  landformPonta     False
# 36356        Baleeira    DGT  landformPonta     False
#
# [270 rows x 4 columns]

# %% [markdown]
# Amostra de topónimos de locais povoados
# nos dados da DGT que não estão nos dados do INE.

# %%
ine_2011_pop[(ine_2011_pop.dgt_type == 'populatedPlace') & (ine_2011_pop.duplicate.isnull())].sample(5)
# Out:
#                  id               name   latitude  longitude origin  \
# 36193  PT.GN.119187            Vinhais  41.822420  -7.003587    DGT
# 29675  PT.GN.112654     Quinta do Anjo  38.561515  -8.940780    DGT
# 32327  PT.GN.115306  Oliveira do Conde  40.425944  -7.966724    DGT
# 31194  PT.GN.114173          Alcanadas  39.624656  -8.797689    DGT
# 30686  PT.GN.113665            Atalaia  39.218905  -8.773512    DGT
#
#                          local_id inspire_id concelho_cod freg_cod sec_cod  \
# 36193  CDG200k_populatedPlace6660        NaN         0412   041235     NaN
# 29675   CDG200k_populatedPlace625        NaN         1508   150804     NaN
# 32327  CDG200k_populatedPlace3132        NaN         1802   180204     NaN
# 31194  CDG200k_populatedPlace1835        NaN         1016   101602     NaN
# 30686  CDG200k_populatedPlace1407        NaN         1416   141616     NaN
#
#        ... duplicate same_as same_as_score same_as_distance pop_rank_in_name  \
# 36193  ...       NaN     NaN           NaN              NaN              NaN
# 29675  ...       NaN     NaN           NaN              NaN              NaN
# 32327  ...       NaN     NaN           NaN              NaN              NaN
# 31194  ...       NaN     NaN           NaN              NaN              NaN
# 30686  ...       NaN     NaN           NaN              NaN              NaN
#
#       dist_bonus concelho_bonus  freg_bonus  importance        dgt_type
# 36193        0.0            1.0         1.0         NaN  populatedPlace
# 29675        0.0            0.0         1.0         NaN  populatedPlace
# 32327        0.0            0.0         1.0         NaN  populatedPlace
# 31194        0.0            0.0         0.0         NaN  populatedPlace
# 30686        0.0            0.0         0.0         NaN  populatedPlace
#
# [5 rows x 29 columns]

# %% [markdown]
# Amostra de topónimos unicamente nos dados do CIGEOE

# %%
ine_2011_pop[(ine_2011_pop.origin == 'CIGEOE') & (ine_2011_pop.duplicate.isnull())].sample(30)
# Out:
#               id                    name   latitude  longitude  origin  \
# 2202  PT.GN.2655     Parceiros da Igreja  39.453710  -8.609547  CIGEOE
# 2672  PT.GN.3126       S. Pedro de Sólis  37.493937  -7.900285  CIGEOE
# 53      PT.GN.54                  ALMADA  38.683895  -9.152606  CIGEOE
# 2917  PT.GN.3372             Aldeia Nova  41.553572  -6.232249  CIGEOE
# 359    PT.GN.812  S.ta Marta da Montanha  41.503241  -7.741672  CIGEOE
# 1996  PT.GN.2449            Pêro Martins  40.881549  -7.085159  CIGEOE
# 103    PT.GN.134     ALVERCA DO RIBATEJO  38.898391  -9.033562  CIGEOE
# 3055  PT.GN.3510                   Aguda  41.050319  -8.653840  CIGEOE
# 1870  PT.GN.2323                   Maçal  40.692956  -7.301653  CIGEOE
# 898   PT.GN.1351                    Ovil  41.180654  -8.016030  CIGEOE
# 1431  PT.GN.1884       Ribeira de Frades  40.205372  -8.499701  CIGEOE
# 1774  PT.GN.2227                Linhares  40.539026  -7.461492  CIGEOE
# 112    PT.GN.143                 LOUROSA  40.989097  -8.546415  CIGEOE
# 407    PT.GN.860               Creixomil  41.539628  -8.684508  CIGEOE
# 870   PT.GN.1323                Oliveira  41.257146  -8.201278  CIGEOE
# 704   PT.GN.1157               Messegães  42.080149  -8.365631  CIGEOE
# 3453  PT.GN.3908           Vale de Guizo  38.294103  -8.477036  CIGEOE
# 118    PT.GN.149               REBORDOSA  41.221611  -8.410530  CIGEOE
# 530    PT.GN.983                   Sande  41.703826  -8.395277  CIGEOE
# 56      PT.GN.57                  SEIXAL  38.641667  -9.101890  CIGEOE
# 2812  PT.GN.3267                   Barca  41.608423  -8.806928  CIGEOE
# 1740  PT.GN.2193            S.ta Eulália  40.415504  -7.797683  CIGEOE
# 425    PT.GN.878                 Durrães  41.639852  -8.665887  CIGEOE
# 2588  PT.GN.3042    S. João de Negrilhos  37.942120  -8.180156  CIGEOE
# 1916  PT.GN.2369                 Lordosa  40.741695  -7.902807  CIGEOE
# 1547  PT.GN.2000      Vilar de Besteiros  40.579949  -8.081016  CIGEOE
# 1599  PT.GN.2052                   Póvoa  39.940987  -7.505635  CIGEOE
# 902   PT.GN.1355                  Viariz  41.169420  -7.967684  CIGEOE
# 1416  PT.GN.1869                Paradela  40.276553  -8.181664  CIGEOE
# 1222  PT.GN.1675                 Alcofra  40.626926  -8.181636  CIGEOE
#
#      local_id inspire_id concelho_cod freg_cod sec_cod  ... duplicate same_as  \
# 2202      NaN       7191         1419   141908     NaN  ...       NaN     NaN
# 2672      NaN       7662         0209   020908     NaN  ...       NaN     NaN
# 53        NaN       4590         1503   150306     NaN  ...       NaN     NaN
# 2917      NaN       7908         0406   040608     NaN  ...       NaN     NaN
# 359       NaN       5348         1713   171309     NaN  ...       NaN     NaN
# 1996      NaN       6985         0904   090412     NaN  ...       NaN     NaN
# 103       NaN       4670         1114   111402     NaN  ...       NaN     NaN
# 3055      NaN       8046         1317   131701     NaN  ...       NaN     NaN
# 1870      NaN       6859         0903   090309     NaN  ...       NaN     NaN
# 898       NaN       5887         1302   130211     NaN  ...       NaN     NaN
# 1431      NaN       6420         0603   060327     NaN  ...       NaN     NaN
# 1774      NaN       6763         0903   090308     NaN  ...       NaN     NaN
# 112       NaN       4679         0109   010913     NaN  ...       NaN     NaN
# 407       NaN       5396         0302   030227     NaN  ...       NaN     NaN
# 870       NaN       5859         1301   130124     NaN  ...       NaN     NaN
# 704       NaN       5693         1604   160416     NaN  ...       NaN     NaN
# 3453      NaN       8444         1501   150103     NaN  ...       NaN     NaN
# 118       NaN       4685         1310   131018     NaN  ...       NaN     NaN
# 530       NaN       5519         0313   031341     NaN  ...       NaN     NaN
# 56        NaN       4593         1510   151004     NaN  ...       NaN     NaN
# 2812      NaN       7803         0306   030601     NaN  ...       NaN     NaN
# 1740      NaN       6729         0912   091214     NaN  ...       NaN     NaN
# 425       NaN       5414         0302   030229     NaN  ...       NaN     NaN
# 2588      NaN       7578         0201   020104     NaN  ...       NaN     NaN
# 1916      NaN       6905         1823   182316     NaN  ...       NaN     NaN
# 1547      NaN       6536         1821   182125     NaN  ...       NaN     NaN
# 1599      NaN       6588         0502   050218     NaN  ...       NaN     NaN
# 902       NaN       5891         1302   130220     NaN  ...       NaN     NaN
# 1416      NaN       6405         0613   061306     NaN  ...       NaN     NaN
# 1222      NaN       6211         1824   182401     NaN  ...       NaN     NaN
#
#      same_as_score same_as_distance pop_rank_in_name dist_bonus  \
# 2202           NaN              NaN              NaN        0.0
# 2672           NaN              NaN              NaN        0.0
# 53             NaN              NaN              NaN        0.0
# 2917           NaN              NaN              NaN        0.0
# 359            NaN              NaN              NaN        0.0
# 1996           NaN              NaN              NaN        0.0
# 103            NaN              NaN              NaN        0.0
# 3055           NaN              NaN              NaN        0.0
# 1870           NaN              NaN              NaN        0.0
# 898            NaN              NaN              NaN        0.0
# 1431           NaN              NaN              NaN        0.0
# 1774           NaN              NaN              NaN        0.0
# 112            NaN              NaN              NaN        0.0
# 407            NaN              NaN              NaN        0.0
# 870            NaN              NaN              NaN        0.0
# 704            NaN              NaN              NaN        0.0
# 3453           NaN              NaN              NaN        0.0
# 118            NaN              NaN              NaN        0.0
# 530            NaN              NaN              NaN        0.0
# 56             NaN              NaN              NaN        0.0
# 2812           NaN              NaN              NaN        0.0
# 1740           NaN              NaN              NaN        0.0
# 425            NaN              NaN              NaN        0.0
# 2588           NaN              NaN              NaN        0.0
# 1916           NaN              NaN              NaN        0.0
# 1547           NaN              NaN              NaN        0.0
# 1599           NaN              NaN              NaN        0.0
# 902            NaN              NaN              NaN        0.0
# 1416           NaN              NaN              NaN        0.0
# 1222           NaN              NaN              NaN        0.0
#
#      concelho_bonus  freg_bonus  importance dgt_type
# 2202            0.0         0.0         NaN      NaN
# 2672            0.0         0.0         NaN      NaN
# 53              0.0         0.0         NaN      NaN
# 2917            0.0         0.0         NaN      NaN
# 359             0.0         0.0         NaN      NaN
# 1996            0.0         0.0         NaN      NaN
# 103             0.0         0.0         NaN      NaN
# 3055            0.0         0.0         NaN      NaN
# 1870            0.0         0.0         NaN      NaN
# 898             0.0         1.0         NaN      NaN
# 1431            0.0         0.0         NaN      NaN
# 1774            0.0         1.0         NaN      NaN
# 112             0.0         0.0         NaN      NaN
# 407             0.0         1.0         NaN      NaN
# 870             0.0         1.0         NaN      NaN
# 704             0.0         1.0         NaN      NaN
# 3453            0.0         0.0         NaN      NaN
# 118             0.0         0.0         NaN      NaN
# 530             0.0         1.0         NaN      NaN
# 56              0.0         0.0         NaN      NaN
# 2812            0.0         0.0         NaN      NaN
# 1740            0.0         0.0         NaN      NaN
# 425             0.0         1.0         NaN      NaN
# 2588            0.0         0.0         NaN      NaN
# 1916            0.0         1.0         NaN      NaN
# 1547            0.0         1.0         NaN      NaN
# 1599            0.0         0.0         NaN      NaN
# 902             0.0         1.0         NaN      NaN
# 1416            0.0         1.0         NaN      NaN
# 1222            0.0         1.0         NaN      NaN
#
# [30 rows x 29 columns]

# %% [markdown]
# ### Determinação contexto administrativo aos topónimos do CIGEOE e DGT
#
# Essa atribuição pode ser relevante para utilizar o cálculo da importância
# e na criação de designações não ambíguas.
#
# Para isso localizamos a freguesia dentro da qual os topónimos se
# localizam.

# %%
! pip install shapely
# Out:
# Collecting shapely
#   Using cached Shapely-1.8.2-cp39-cp39-macosx_11_0_arm64.whl (1.1 MB)
# Installing collected packages: shapely
# Successfully installed shapely-1.8.2

# %%
import json
from shapely.geometry import shape, GeometryCollection

freguesias_file = '../extras/geocoding/caop/freguesias.geojson'
with open(freguesias_file) as f:
  features = json.load(f)["features"]
print(len(features))
# Out:
# 4050

# %%
from shapely.geometry import shape, Point
from shapely.geometry.multipolygon import MultiPolygon
from shapely.geometry.polygon import Polygon

def point_in_feature(longitude=None, latitude=None, features=None, property=None) -> dict:
    """ find features that contain a point.

    Args:
        longitude,latitude: coordinates of the point to locate
        features: list of features as GeoJSON dicts (Polygon or MultiPolygon)
        property: str,optional, name of feature property to return
                  if None return feature
        """
    for feature in features:
        geometry = feature["geometry"]
        gtype= geometry["type"]
        coordinates = geometry["coordinates"]
        # https://stackoverflow.com/questions/68820085/how-to-convert-geojson-to-shapely-polygon-solved
        boundary: dict = {'type': gtype,
                          'coordinates': coordinates}
        if gtype == 'MultiPolygon':
            fboundary: MultiPolygon = shape(boundary)
        elif gtype == 'Polygon':
            fboundary: Polygon = shape(boundary)
        else: 
            raise(ValueError("Only Polygon and MultiPolygon types accepted"))
        p: Point = Point(longitude,latitude) 
        if p.within(fboundary):
            if property is not None:
                if property not in feature['properties'].keys():
                    raise(ValueError("Property not present in feature"))
                return feature['properties'][property]
            else:
                return feature
    return None

# %%
places =ine_2011_pop[(ine_2011_pop.freg_cod.isnull()) & (ine_2011_pop.duplicate.isnull())][['freg_cod','origin','name','latitude','longitude']]
places
# Out:
# Empty DataFrame
# Columns: [freg_cod, origin, name, latitude, longitude]
# Index: []

# %%
for n in places.index.values:
    lat = ine_2011_pop.iloc[n]['latitude']
    lng = ine_2011_pop.iloc[n]['longitude']
    print(ine_2011_pop.loc[n]['name'], end='')
    freg_cod = point_in_feature(lng,lat,features, property='DICOFRE')
    if freg_cod is not None:
        ine_2011_pop.loc[n,'freg_cod'] = freg_cod
        print(" Found: ",freg_cod)
    else:
        print(" Not found")
# Out:
# PÓVOA DE VARZIM Found:  131310
# V. NOVA DE FAMALICÃO Found:  031248
# GUIMARÃES Found:  030860
# FAFE Found:  030709
# BARCELOS Found:  030214
# ESPOSENDE Found:  030605
# CHAVES Found:  170350
# VILA DO CONDE Found:  131628
# SANTO TIRSO Found:  131422
# FELGUEIRAS Found:  130320
# AMARANTE Found:  130133
# MAIA Found:  130607
# MARCO DE CANAVESES Found:  130727
# PAREDES Found:  131007
# PAÇOS DE FERREIRA Found:  130912
# PENAFIEL Found:  131124
# VALONGO Found:  131505
# PESO DA RÉGUA Found:  170807
# VILA NOVA DE GAIA Found:  131716
# GONDOMAR Found:  130409
# MATOSINHOS Found:  130806
# MIRANDELA Found:  040721
# MIRANDA DO DOURO Found:  040608
# MARINHA GRANDE Found:  101001
# FIGUEIRA DA FOZ Found:  060511
# ÁGUEDA Found:  010104
# Estelas Found:  111011
# Farilhões Found:  111409
# Fora Not found
# Baleal Found:  150401
# Rato Found:  151002
# Cavalo Found:  151101
# Pessegueiro Found:  151101
# Martinhal Found:  151101
# Culatra Found:  151204
# Barrela Found:  151201
# Armona Found:  151301
# Tavira Found:  151302
# Cabanas Found:  151302
# Boega Found:  151302
# Amores Found:  021111
# Roca Found:  021117
# Marinha Found:  021109
# Espichel Found:  021114
# Sardão Found:  080301
# S. Vicente Found:  080302
# Carvoeiro Found:  081504
# Mondego Found:  081504
# Fundões Found:  081504
# França Found:  081504
# Vale de Frades Found:  081504
# Abelheira Found:  041203
# AÇOR Found:  060111
# Agrela Found:  130916
# AIRE Found:  141909
# Aires Found:  070302
# Airó Found:  030269
# Albardos Found:  101603
# Fisga Found:  060504
# Torre Found:  100613
# Almádona Found:  100606
# Cama da Vaca Found:  100606
# Gaivota Found:  142106
# Calheta Found:  041220
# Ferrerias Found:  171314
# Piedade Found:  171207
# Altar Found:  041103
# Castelo Found:  040612
# Grande Found:  040103
# Pequena Found:  150301
# Baleeira Found:  111003
# Areia Found:  101205
# Cabedelo Found:  030358
# Gafa Found:  151101
# Covinhos Found:  080809
# Sudão Found:  070701
# Lamporeira Found:  081504
# Messapez Found:  081504
# Abelheira Found:  081504
# Navio Found:  081504
# Alta Found:  081504
# Pombeira Found:  081504
# Salmodo Found:  081503
# Sal Found:  081503
# Carneiro Found:  081502
# Rana Found:  080703
# Lage Found:  080703
# Erva Found:  080703
# Passadeira Found:  080705
# Mexilheiro Found:  080705
# Corvos Found:  080705
# S.Pedro Found:  081103
# Lagosteiros Found:  080602
# Gaivota Found:  080602
# Ladoiro Found:  080605
# Galhota Found:  080101
# Cavalo Found:  080101
# Ilha Found:  080101
# Percevera Found:  080101
# Cerva Found:  080505
# Atalaia Found:  080505
# A. do Pau Found:  080506
# Arquizes Found:  081002
# Garcia Found:  081403
# Candeeiras Found:  081405
# Alheta Found:  081602
# Sagres Found:  161006
# Atalaia Found:  161006
# Baleeira Found:  160219

# %% [markdown]
# #### Completar o contexto administrativo a partir do código da freguesia

# %%
def lookup_in_df(column='code',value=None, table=None,subset=None):
    """Lookup a value in a dataframe, return a dict or single value
    Args:
        column: column where to lookupup
        value: value to lookup
        table: data frame to use as lookup table
        subset: string or list of columns to be returned
                If none all columns returned as dict.

    Example:
        lookup_in_df('Código','151206',cat2011_df,subset=['N3_DSG','COD_UPPER_LEVEL','COD_DSG'])
        > {'N3_DSG': 'São Simão', 'COD_UPPER_LEVEL': '1512','COD_DSG': 'São Simão, Setúbal, Setúbal'}
    """
    row = table[table[column]==value].iloc[0]
    if row is None:
        raise(ValueError("Code not found in categories"))
    else:
        if subset is None:
            return row.to_dict()
        elif type(subset) is list:
            return row[subset].to_dict()
        elif type(subset) is str:
            return row[subset]
        else:
            raise(ValueError("Subset must be list,str or None"))

# %%
ine_2011_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36357 entries, 0 to 36356
# Data columns (total 29 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  36357 non-null  object
#  1   name                36357 non-null  object
#  2   latitude            36357 non-null  float64
#  3   longitude           36357 non-null  float64
#  4   origin              36357 non-null  object
#  5   local_id            32507 non-null  object
#  6   inspire_id          29322 non-null  object
#  7   concelho_cod        25472 non-null  object
#  8   freg_cod            25545 non-null  object
#  9   sec_cod             25472 non-null  object
#  10  lug_cod             25472 non-null  object
#  11  distrito_code       25472 non-null  object
#  12  distrito_dsg        25472 non-null  object
#  13  concelho_dsg        25472 non-null  object
#  14  freg_dsg            25472 non-null  object
#  15  admin_dsg           25472 non-null  object
#  16  name_dsg            25472 non-null  object
#  17  nucleos_familiares  25472 non-null  float64
#  18  residentes          25472 non-null  float64
#  19  duplicate           9297 non-null   object
#  20  same_as             9297 non-null   object
#  21  same_as_score       9297 non-null   float64
#  22  same_as_distance    9297 non-null   float64
#  23  pop_rank_in_name    25472 non-null  float64
#  24  dist_bonus          36357 non-null  float64
#  25  concelho_bonus      36357 non-null  float64
#  26  freg_bonus          36357 non-null  float64
#  27  importance          25472 non-null  float64
#  28  dgt_type            7035 non-null   object
# dtypes: float64(11), object(18)
# memory usage: 9.3+ MB

# %%
cols = ['distrito_code','distrito_dsg','concelho_cod','concelho_dsg','freg_dsg','admin_dsg']
subset=['N1_CODE','N1_DSG','N2_CODE','N2_DSG','N3_DSG','COD_DSG']

places = ine_2011_pop[ine_2011_pop.freg_cod.notnull() & (ine_2011_pop.name_dsg.isnull())]
for p,row in places.iterrows():
    ine_2011_pop.loc[p,cols] = lookup_in_df('Código',row.freg_cod,cat2011_df,subset=subset).values()
    name_dsg = row['name']+", "+ine_2011_pop.loc[p]['admin_dsg']
    ine_2011_pop.loc[p,'name_dsg'] = name_dsg

# %%
name_totals = ine_2011_pop.groupby(['name_dsg']).agg({'id':'count'}).sort_values('id', ascending=False)
repeated = name_totals[name_totals.id > 1]
repeated
# Out:
#                                                     id
# name_dsg
# Olival, Olival, Vila Nova de Gaia, Porto             3
# Torreira, Torreira, Murtosa, Aveiro                  3
# Mafra, Mafra, Mafra, Lisboa                          3
# Venda do Alcaide, Palmela, Palmela, Setúbal          2
# Cesaredas, Reguengo Grande, Lourinhã, Lisboa         2
# Pedras Salgadas, Bornes de Aguiar, Vila Pouca d...   2
# Benavente, Benavente, Benavente, Santarém            2
# Benaciate, São Bartolomeu de Messines, Silves, ...   2
# Ramalhosa, Sertã, Sertã, Castelo Branco              2
# Branca, Branca, Coruche, Santarém                    2
# Mértola, Mértola, Mértola, Beja                      2
# Vinhais, Vinhais, Vinhais, Bragança                  2
# Santa Cruz, Silveira, Torres Vedras, Lisboa          2
# Praia de Mira, Praia de Mira, Mira, Coimbra          2
# Belinho, Belinho, Esposende, Braga                   2
# Albarraque, Rio de Mouro, Sintra, Lisboa             2
# Ponte Nova, São João, Ovar, Aveiro                   2
# Avelãs de Caminho, Avelãs de Caminho, Anadia, A...   2
# Canedo, Canedo, Santa Maria da Feira, Aveiro         2
# Fonte da Vaca, Pinhal Novo, Palmela, Setúbal         2
# Nadadouro, Nadadouro, Caldas da Rainha, Leiria       2
# Avintes, Avintes, Vila Nova de Gaia, Porto           2
# Paialvo, Paialvo, Tomar, Santarém                    2
# Curcil, Croca, Penafiel, Porto                       2
# Lavra, Lavra, Matosinhos, Porto                      2
# Angeja, Angeja, Albergaria-a-Velha, Aveiro           2
# Tropeço, Tropeço, Arouca, Aveiro                     2
# Alcanede, Alcanede, Santarém, Santarém               2
# Arcos, Arcos, Ponte de Lima, Viana do Castelo        2
# Paredes da Beira, Paredes da Beira, São João da...   2
# Botequim, Charneca de Caparica, Almada, Setúbal      2
# São Pedro da Cova, São Pedro da Cova, Gondomar,...   2
# Recarei, Recarei, Paredes, Porto                     2
# Moura de Carvalhal, Abraveses, Viseu, Viseu          2
# Porto Alto, Samora Correia, Benavente, Santarém      2
# Vale de Lamas, Baçal, Bragança, Bragança             2
# Ardezubre, Lamarosa, Coimbra, Coimbra                2
# Arcozelo, Arcozelo, Vila Nova de Gaia, Porto         2
# Arcozelo, Arcozelo, Ponte de Lima, Viana do Cas...   2
# Boa Vista, Boa Vista, Leiria, Leiria                 2
# Anobra, Anobra, Condeixa-a-Nova, Coimbra             2
# São Martinho de Angueira, São Martinho de Angue...   2
# Bizorreiro, Lavos, Figueira da Foz, Coimbra          2
# Mouta, Canidelo, Vila do Conde, Porto                2
# Folgosa, Folgosa, Maia, Porto                        2
# Valongo, Valongo, Valongo, Porto                     2
# Celorico da Beira, Celorico (São Pedro), Celori...   2
# Várzea Fresca, Foros de Salvaterra, Salvaterra ...   2
# Válega, Válega, Ovar, Aveiro                         2
# Betunes, Loulé (São Clemente), Loulé, Faro           2
# São João de Loure, São João de Loure, Albergari...   2
# Alcalar, Mexilhoeira Grande, Portimão, Faro          2
# Quintã, Travanca, Oliveira de Azeméis, Aveiro        2
# São Pedro de Rates, Rates, Póvoa de Varzim, Porto    2
# Oliveira do Conde, Oliveira do Conde, Carregal ...   2
# Juromenha, Juromenha (Nossa Senhora do Loreto),...   2
# Cabeço, Carriço, Pombal, Leiria                      2
# Vila Praia de Âncora, Vila Praia de Âncora, Cam...   2
# Bairros, Bougado (Santiago), Trofa, Porto            2
# Miranda do Douro, Miranda do Douro, Miranda do ...   2
# Bajouca, Bajouca, Leiria, Leiria                     2
# Mendiga, Mendiga, Porto de Mós, Leiria               2
# Vila Franca das Naves, Vila Franca das Naves, T...   2
# S. Teotónio, São Teotónio, Odemira, Beja             2
# Lagoa Parada, Santiago da Guarda, Ansião, Leiria     2
# Runa, Runa, Torres Vedras, Lisboa                    2
# Minde, Minde, Alcanena, Santarém                     2
# Soeira, Soeira, Vinhais, Bragança                    2
# Tábua, Tábua, Tábua, Coimbra                         2
# S. Brás de Alportel, São Brás de Alportel, São ...   2
# Casal Novo, Nadadouro, Caldas da Rainha, Leiria      2
# Algeruz, Palmela, Palmela, Setúbal                   2
# Sobreira, Sobreira, Paredes, Porto                   2
# Alfambras, Aljezur, Aljezur, Faro                    2
# Troviscal, Troviscal, Sertã, Castelo Branco          2
# Tróia, Carvalhal, Grândola, Setúbal                  2
# Quinta do Anjo, Quinta do Anjo, Palmela, Setúbal     2
# Alpiarça, Alpiarça, Alpiarça, Santarém               2
# Sandim, Edral, Vinhais, Bragança                     2
# Rossas, Rossas, Vieira do Minho, Braga               2
# Rio Douro, Rio Douro, Cabeceiras de Basto, Braga     2
# Bufarda, Atouguia da Baleia, Peniche, Leiria         2
# Bunheiro, Bunheiro, Murtosa, Aveiro                  2
# Serrazola, Cacia, Aveiro, Aveiro                     2
# Darque, Darque, Viana do Castelo, Viana do Castelo   2
# Azóia, Sesimbra (Castelo), Sesimbra, Setúbal         2
# Samora Correia, Samora Correia, Benavente, Sant...   2
# Rio de Mouro, Rio de Mouro, Sintra, Lisboa           2
# Alcáçovas, Alcáçovas, Viana do Alentejo, Évora       2
# Mata Mourisca, Mata Mourisca, Pombal, Leiria         2
# Salvaterra de Magos, Salvaterra de Magos, Salva...   2
# Aldeia Nova, Miranda do Douro, Miranda do Douro...   2
# Alto do Poço, Alvor, Portimão, Faro                  2
# Vilamoura, Quarteira, Loulé, Faro                    2
# Vilamar, Vilamar, Cantanhede, Coimbra                2
# Souto da Carpalhosa, Souto da Carpalhosa, Leiri...   2
# Foros de Salvaterra, Foros de Salvaterra, Salva...   2
# Olhos de Água, Quinta do Anjo, Palmela, Setúbal      2
# Sagres, Sagres, Vila do Bispo, Faro                  2
# Quinta do Lago, Almancil, Loulé, Faro                2
# Rosmaninhal, Rosmaninhal, Idanha-a-Nova, Castel...   2
# Carnapete, Cabeçudo, Sertã, Castelo Branco           2
# Carvalhos de Figueiredo, Madalena, Tomar, Santarém   2
# Vale de Santarém, Vale de Santarém, Santarém, S...   2
# Arneiros da Gafaria, Vermoil, Pombal, Leiria         2
# Carrapatas, Carrapatas, Macedo de Cavaleiros, B...   2
# Figueira, Budens, Vila do Bispo, Faro                2
# Arga, Arga de São João, Caminha, Viana do Castelo    2
# Guilhofrei, Guilhofrei, Vieira do Minho, Braga       2
# Argoselo, Argozelo, Vimioso, Bragança                2
# Ferral, Ferral, Montalegre, Vila Real                2
# Castanheira do Vouga, Castanheira do Vouga, Águ...   2

# %%
from itertools import combinations

for name in repeated.index.values:
    print(name, end=' ')
    name_group = ine_2011_pop[ine_2011_pop['name_dsg'] == name]
    ine_place = ine_2011_pop[(ine_2011_pop['name_dsg'] == name) 
                                & (ine_2011_pop['origin'] == 'INE')]
    if len(ine_place) == 0:
        print("no INE place involved: ",name,name_group.index.values)
        continue
    else:
        ine_place = ine_place.iloc[0].name # name here is the index

    print("ine place:",ine_place)
    pairs = list(combinations(name_group.index.values,2))
    # print(pairs)
    for l,r in pairs:
        if r == ine_place:
            l, r = r, l
        elif l != ine_place:
            # neither point in the INE place name
            continue
        left = ine_2011_pop.iloc[l]
        right = ine_2011_pop.iloc[r]
        dist_meters = geodesic((left.latitude,left.longitude), (right.latitude,right.longitude)).km*1000
        # print("distance:", (l,r),dist_meters)
        ine_2011_pop.loc[r,'duplicate'] = True
        ine_2011_pop.loc[r,'same_as'] = ine_2011_pop.iloc[l]['id']
        ine_2011_pop.loc[r,'same_as_score'] = 1
# Rio de Mouro, Rio de Mouro, Sintra, Lisboa ine place: 21687
# Alcáçovas, Alcáçovas, Viana do Alentejo, Évora ine place: 23946
# Mata Mourisca, Mata Mourisca, Pombal, Leiria ine place: 16234
# Salvaterra de Magos, Salvaterra de Magos, Salvaterra de Magos, Santarém ine place: 23218
# Aldeia Nova, Miranda do Douro, Miranda do Douro, Bragança ine place: 13675
# Alto do Poço, Alvor, Portimão, Faro ine place: 24744
# Vilamoura, Quarteira, Loulé, Faro ine place: 24569
# Vilamar, Vilamar, Cantanhede, Coimbra ine place: 15182
# Souto da Carpalhosa, Souto da Carpalhosa, Leiria, Leiria ine place: 15987
# Foros de Salvaterra, Foros de Salvaterra, Salvaterra de Magos, Santarém ine place: 23220
# Olhos de Água, Quinta do Anjo, Palmela, Setúbal ine place: 21879
# Sagres, Sagres, Vila do Bispo, Faro ine place: 25075
# Quinta do Lago, Almancil, Loulé, Faro ine place: 24680
# Rosmaninhal, Rosmaninhal, Idanha-a-Nova, Castelo Branco ine place: 20032
# Carnapete, Cabeçudo, Sertã, Castelo Branco ine place: 19214
# Carvalhos de Figueiredo, Madalena, Tomar, Santarém ine place: 22535
# Vale de Santarém, Vale de Santarém, Santarém, Santarém ine place: 23351
# Arneiros da Gafaria, Vermoil, Pombal, Leiria ine place: 16174
# Carrapatas, Carrapatas, Macedo de Cavaleiros, Bragança no INE place involved:  Carrapatas, Carrapatas, Macedo de Cavaleiros, Bragança [ 1020 34981]
# Figueira, Budens, Vila do Bispo, Faro ine place: 25071
# Arga, Arga de São João, Caminha, Viana do Castelo no INE place involved:  Arga, Arga de São João, Caminha, Viana do Castelo [  661 35833]
# Guilhofrei, Guilhofrei, Vieira do Minho, Braga ine place: 8678
# Argoselo, Argozelo, Vimioso, Bragança ine place: 14164
# Ferral, Ferral, Montalegre, Vila Real ine place: 13854
# Castanheira do Vouga, Castanheira do Vouga, Águeda, Aveiro ine place: 14281

# %% [markdown]
# ## Cálculo da importância de cada topónimo
#
# Usamos um índice misto, de importância administrativa e populacional.
#
# Cada topónimo recebe um bonus de importância se o seu nome coincidir com o nome das circunscrições
# administrativas em que se insere.
#
# Quanto de maior nível for a circunscrição homónima maior o bonus (distrito=15, concelho=10, freguesia=5).
#
# Adicionalmente cada lugar recebe um bonus proporcional à dimensão da sua população dentro
# de todos os lugares com o mesmo nome (1/rank).

# %%
ine_2011_pop['pop_rank_in_name'] = ine_2011_pop[ine_2011_pop.residentes.notnull()].groupby('name')['residentes'].rank("dense", ascending=False)
ine_2011_pop.loc[ine_2011_pop.name == ine_2011_pop.distrito_dsg,'dist_bonus'] = 1
ine_2011_pop.loc[ine_2011_pop.name != ine_2011_pop.distrito_dsg,'dist_bonus'] = 0
ine_2011_pop.loc[ine_2011_pop.name == ine_2011_pop.concelho_dsg,'concelho_bonus'] = 1
ine_2011_pop.loc[ine_2011_pop.name != ine_2011_pop.concelho_dsg,'concelho_bonus'] = 0
ine_2011_pop.loc[ine_2011_pop.name == ine_2011_pop.freg_dsg,'freg_bonus'] = 1
ine_2011_pop.loc[ine_2011_pop.name != ine_2011_pop.freg_dsg,'freg_bonus'] = 0
if ine_2011_pop.pop_rank_in_name is not None:
    pop_rank = (1/ine_2011_pop.pop_rank_in_name)
else:
    pop_rank = 0
ine_2011_pop['importance'] = ine_2011_pop.dist_bonus * 15 + ine_2011_pop.concelho_bonus * 10 + ine_2011_pop.freg_bonus * 5 + pop_rank

# %%
ine_2011_pop[ine_2011_pop.name == 'Coimbra'].sort_values('importance', ascending=False)[['importance','origin','dgt_type','name','freg_cod', 'name_dsg','residentes','pop_rank_in_name']]
# Out:
#        importance origin        dgt_type     name freg_cod  \
# 15289        26.0    INE             NaN  Coimbra   060327
# 21127         0.5    INE             NaN  Coimbra   101402
# 30887         NaN    DGT  populatedPlace  Coimbra      NaN
# 31837         NaN    DGT  populatedPlace  Coimbra   060316
#
#                                            name_dsg  residentes  \
# 15289            Coimbra, Taveiro, Coimbra, Coimbra    105842.0
# 21127  Coimbra, Atouguia da Baleia, Peniche, Leiria       490.0
# 30887                                           NaN         NaN
# 31837        Coimbra, Santa Clara, Coimbra, Coimbra         NaN
#
#        pop_rank_in_name
# 15289               1.0
# 21127               2.0
# 30887               NaN
# 31837               NaN

# %%
ine_2011_pop[ine_2011_pop.name == 'Granja'].sort_values('importance', ascending=False)[['importance','duplicate','name','freg_cod','name_dsg','residentes','pop_rank_in_name']]
# Out:
#        importance duplicate    name freg_cod  \
# 23899    5.500000       NaN  Granja   070801
# 13366    5.090909       NaN  Granja   170212
# 12797    5.076923       NaN  Granja   181204
# 19846    5.058824       NaN  Granja   091309
# 21721    1.000000       NaN  Granja   111408
# 12429    0.333333       NaN  Granja   170101
# 9347     0.250000       NaN  Granja   131604
# 15616    0.200000       NaN  Granja   061302
# 13255    0.166667       NaN  Granja   171420
# 15884    0.142857       NaN  Granja   100908
# 16310    0.125000       NaN  Granja   101509
# 17146    0.111111       NaN  Granja   060904
# 29276    0.100000       NaN  Granja   030361
# 10715    0.083333       NaN  Granja   130507
# 17717    0.071429       NaN  Granja   180312
# 9397     0.066667       NaN  Granja   131613
# 6404     0.062500       NaN  Granja   030251
# 16504    0.058824       NaN  Granja   100207
# 11930    0.055556       NaN  Granja   010904
# 25856    0.052632       NaN  Granja   181303
# 5862     0.050000       NaN  Granja   160932
# 5461     0.050000       NaN  Granja   160704
# 12825    0.047619       NaN  Granja   170805
# 22844    0.045455       NaN  Granja   142108
# 13690    0.043478       NaN  Granja   040615
# 14954    0.041667       NaN  Granja   011705
# 6427     0.040000       NaN  Granja   030255
# 11513    0.038462       NaN  Granja   131109
# 10308    0.037037       NaN  Granja   180416
# 14122    0.035714       NaN  Granja   171312
# 5720     0.035714       NaN  Granja   160915
# 28900    0.034483       NaN  Granja   031306
# 4983     0.033333       NaN  Granja   160619
# 9135     0.032258       NaN  Granja   031209
# 26071    0.031250       NaN  Granja   130107
# 4314     0.030303       NaN  Granja   160301
# 11354    0.030303       NaN  Granja   131116
# 19622    0.029412       NaN  Granja   090740
# 18245    0.028571       NaN  Granja   181617
# 11656    0.027778       NaN  Granja   181301
# 20771    0.027027       NaN  Granja   100613
# 5158     0.027027       NaN  Granja   160737
# 11752    0.026316       NaN  Granja   010402
# 9849     0.025641       NaN  Granja   130203
# 26355    0.025000       NaN  Granja   131417
# 12864    0.024390       NaN  Granja   170810
# 16677    0.023810       NaN  Granja   100307
# 13810    0.023256       NaN  Granja   040815
# 20545    0.022727       NaN  Granja   110201
# 21236    0.022222       NaN  Granja   111305
# 11572    0.022222       NaN  Granja   181308
# 23821    0.021739       NaN  Granja   070403
# 500           NaN      True  Granja      NaN
# 2449          NaN      True  Granja      NaN
# 2875          NaN      True  Granja      NaN
# 3007          NaN      True  Granja      NaN
# 3104          NaN      True  Granja      NaN
# 3167          NaN       NaN  Granja   131717
# 3476          NaN      True  Granja      NaN
# 29574         NaN      True  Granja      NaN
# 30813         NaN      True  Granja      NaN
# 30837         NaN      True  Granja      NaN
# 31480         NaN      True  Granja      NaN
# 31578         NaN      True  Granja      NaN
# 32011         NaN      True  Granja      NaN
# 32253         NaN      True  Granja      NaN
# 33482         NaN      True  Granja      NaN
# 33816         NaN      True  Granja      NaN
# 34078         NaN      True  Granja      NaN
# 34119         NaN      True  Granja      NaN
# 34323         NaN      True  Granja      NaN
# 34615         NaN      True  Granja      NaN
# 35225         NaN      True  Granja      NaN
# 35502         NaN      True  Granja      NaN
#
#                                                 name_dsg  residentes  \
# 23899                      Granja, Granja, Mourão, Évora       587.0
# 13366                 Granja, Granja, Boticas, Vila Real       212.0
# 12797                    Granja, Granja, Penedono, Viseu       144.0
# 19846                   Granja, Granja, Trancoso, Guarda       127.0
# 21721      Granja, Vialonga, Vila Franca de Xira, Lisboa       928.0
# 12429                    Granja, Alijó, Alijó, Vila Real       434.0
# 9347               Granja, Azurara, Vila do Conde, Porto       354.0
# 15616      Granja, Figueira de Lorvão, Penacova, Coimbra       319.0
# 13255     Granja, Parada de Cunhos, Vila Real, Vila Real       306.0
# 15884                    Granja, Carvide, Leiria, Leiria       273.0
# 16310                     Granja, Pombal, Pombal, Leiria       251.0
# 17146          Granja, Semide, Miranda do Corvo, Coimbra       245.0
# 29276                     Granja, Vimieiro, Braga, Braga       222.0
# 10715                      Granja, Covas, Lousada, Porto       146.0
# 17717                  Granja, Mões, Castro Daire, Viseu       138.0
# 9397               Granja, Labruge, Vila do Conde, Porto       133.0
# 6404           Granja, Monte de Fralães, Barcelos, Braga       130.0
# 16504          Granja, Rego da Murta, Alvaiázere, Leiria       127.0
# 11930     Granja, Escapães, Santa Maria da Feira, Aveiro       123.0
# 25856                   Granja, Cárquere, Resende, Viseu       103.0
# 5862   Granja, Serreleis, Viana do Castelo, Viana do ...        99.0
# 5461   Granja, Arcozelo, Ponte de Lima, Viana do Castelo        99.0
# 12825         Granja, Loureiro, Peso da Régua, Vila Real        93.0
# 22844                Granja, Freixianda, Ourém, Santarém        89.0
# 13690          Granja, Silva, Miranda do Douro, Bragança        83.0
# 14954     Granja, Rocas do Vouga, Sever do Vouga, Aveiro        79.0
# 6427                      Granja, Palme, Barcelos, Braga        73.0
# 11513              Granja, Duas Igrejas, Penafiel, Porto        69.0
# 10308                    Granja, Tendais, Cinfães, Viseu        67.0
# 14122  Granja, Tresminas, Vila Pouca de Aguiar, Vila ...        64.0
# 5720   Granja, Lanheses, Viana do Castelo, Viana do C...        64.0
# 28900                 Granja, Barbudo, Vila Verde, Braga        62.0
# 4983   Granja, Sampriz, Ponte da Barca, Viana do Castelo        60.0
# 9135     Granja, Carreira, Vila Nova de Famalicão, Braga        56.0
# 26071                  Granja, Candemil, Amarante, Porto        55.0
# 4314         Granja, Alvaredo, Melgaço, Viana do Castelo        54.0
# 11354                   Granja, Lagares, Penafiel, Porto        54.0
# 19622        Granja, Jarmelo (São Pedro), Guarda, Guarda        48.0
# 18245         Granja, Valadares, São Pedro do Sul, Viseu        44.0
# 11656                    Granja, Anreade, Resende, Viseu        40.0
# 20771   Granja, Serra do Bouro, Caldas da Rainha, Leiria        39.0
# 5158   Granja, Refóios do Lima, Ponte de Lima, Viana ...        39.0
# 11752                  Granja, Alvarenga, Arouca, Aveiro        38.0
# 9849           Granja, São Tomé de Covelas, Baião, Porto        36.0
# 26355  Granja, Refojos de Riba de Ave, Santo Tirso, P...        35.0
# 12864  Granja, Vilarinho dos Freires, Peso da Régua, ...        34.0
# 16677         Granja, Santiago da Guarda, Ansião, Leiria        23.0
# 13810              Granja, Saldanha, Mogadouro, Bragança        22.0
# 20545         Granja, Arranhó, Arruda dos Vinhos, Lisboa        19.0
# 21236         Granja, Dois Portos, Torres Vedras, Lisboa        16.0
# 11572                     Granja, Ovadas, Resende, Viseu        16.0
# 23821    Granja, Estremoz (Santa Maria), Estremoz, Évora        14.0
# 500                                                  NaN         NaN
# 2449                                                 NaN         NaN
# 2875                                                 NaN         NaN
# 3007                                                 NaN         NaN
# 3104                                                 NaN         NaN
# 3167   Granja, São Félix da Marinha, Vila Nova de Gai...         NaN
# 3476                                                 NaN         NaN
# 29574                                                NaN         NaN
# 30813                                                NaN         NaN
# 30837                                                NaN         NaN
# 31480                                                NaN         NaN
# 31578                                                NaN         NaN
# 32011                                                NaN         NaN
# 32253                                                NaN         NaN
# 33482                                                NaN         NaN
# 33816                                                NaN         NaN
# 34078                                                NaN         NaN
# 34119                                                NaN         NaN
# 34323                                                NaN         NaN
# 34615                                                NaN         NaN
# 35225                                                NaN         NaN
# 35502                                                NaN         NaN
#
#        pop_rank_in_name
# 23899               2.0
# 13366              11.0
# 12797              13.0
# 19846              17.0
# 21721               1.0
# 12429               3.0
# 9347                4.0
# 15616               5.0
# 13255               6.0
# 15884               7.0
# 16310               8.0
# 17146               9.0
# 29276              10.0
# 10715              12.0
# 17717              14.0
# 9397               15.0
# 6404               16.0
# 16504              17.0
# 11930              18.0
# 25856              19.0
# 5862               20.0
# 5461               20.0
# 12825              21.0
# 22844              22.0
# 13690              23.0
# 14954              24.0
# 6427               25.0
# 11513              26.0
# 10308              27.0
# 14122              28.0
# 5720               28.0
# 28900              29.0
# 4983               30.0
# 9135               31.0
# 26071              32.0
# 4314               33.0
# 11354              33.0
# 19622              34.0
# 18245              35.0
# 11656              36.0
# 20771              37.0
# 5158               37.0
# 11752              38.0
# 9849               39.0
# 26355              40.0
# 12864              41.0
# 16677              42.0
# 13810              43.0
# 20545              44.0
# 21236              45.0
# 11572              45.0
# 23821              46.0
# 500                 NaN
# 2449                NaN
# 2875                NaN
# 3007                NaN
# 3104                NaN
# 3167                NaN
# 3476                NaN
# 29574               NaN
# 30813               NaN
# 30837               NaN
# 31480               NaN
# 31578               NaN
# 32011               NaN
# 32253               NaN
# 33482               NaN
# 33816               NaN
# 34078               NaN
# 34119               NaN
# 34323               NaN
# 34615               NaN
# 35225               NaN
# 35502               NaN

# %%
ine_2011_pop.sample(10)
# Out:
#                  id              name   latitude  longitude origin  \
# 24521  PT.GN.107498           Caliços  37.089714  -7.981599    INE
# 12089   PT.GN.95066         Moliceiro  41.003951  -8.485013    INE
# 23591  PT.GN.106568     Alter Pedroso  39.187979  -7.623203    INE
# 20051  PT.GN.103028            Fratel  39.628099  -7.746317    INE
# 30203  PT.GN.113182             Leião  38.728573  -9.295772    DGT
# 29374  PT.GN.112353           Chaveca  37.070544  -7.903504    DGT
# 4533    PT.GN.87510           Outeiro  42.002133  -8.494488    INE
# 20567  PT.GN.103544  Casal do Romanço  39.004409  -9.085017    INE
# 33168  PT.GN.116147      Vilar Torpim  40.826210  -6.951417    DGT
# 27253  PT.GN.110231    Belmonte Baixo  37.018589  -7.868579    INE
#
#                          local_id       inspire_id concelho_cod freg_cod  \
# 24521                      026118  BGRI2011_026118         0808   080801
# 12089                      011889  BGRI2011_011889         0109   010931
# 23591                      024993  BGRI2011_024993         1201   120101
# 20051                      020842  BGRI2011_020842         0511   051101
# 30203   CDG200k_populatedPlace882              NaN          NaN      NaN
# 29374    CDG200k_populatedPlace53              NaN          NaN      NaN
# 4533                       000813  BGRI2011_000813         1604   160405
# 20567                      021410  BGRI2011_021410         1102   110202
# 33168  CDG200k_populatedPlace3994              NaN          NaN      NaN
# 27253                      033188  BGRI2011_033188         0810   081004
#
#          sec_cod  ... residentes duplicate       same_as same_as_score  \
# 24521  080801003  ...      233.0       NaN           NaN           NaN
# 12089  010931002  ...       24.0       NaN           NaN           NaN
# 23591  120101003  ...       48.0       NaN           NaN           NaN
# 20051  051101003  ...      307.0       NaN           NaN           NaN
# 30203        NaN  ...        NaN      True  PT.GN.104522      0.957442
# 29374        NaN  ...        NaN      True  PT.GN.108365      0.990772
# 4533   160405001  ...       16.0       NaN           NaN           NaN
# 20567  110202001  ...      180.0       NaN           NaN           NaN
# 33168        NaN  ...        NaN      True  PT.GN.102508      0.955314
# 27253  081004006  ...      159.0       NaN           NaN           NaN
#
#       same_as_distance pop_rank_in_name dist_bonus  concelho_bonus  \
# 24521              NaN              1.0        0.0             0.0
# 12089              NaN              1.0        0.0             0.0
# 23591              NaN              1.0        0.0             0.0
# 20051              NaN              1.0        0.0             0.0
# 30203        84.982817              NaN        0.0             0.0
# 29374        18.435511              NaN        0.0             0.0
# 4533               NaN            130.0        0.0             0.0
# 20567              NaN              1.0        0.0             0.0
# 33168        89.372120              NaN        0.0             0.0
# 27253              NaN              1.0        0.0             0.0
#
#        freg_bonus importance
# 24521         0.0   1.000000
# 12089         0.0   1.000000
# 23591         0.0   1.000000
# 20051         1.0   6.000000
# 30203         0.0        NaN
# 29374         0.0        NaN
# 4533          0.0   0.007692
# 20567         0.0   1.000000
# 33168         0.0        NaN
# 27253         0.0   1.000000
#
# [10 rows x 28 columns]

# %% [markdown]
# Reexportar com deteção de duplicados e importância

# %%
ine_topo_file = cache_file
ine_2011_pop.to_csv(ine_topo_file, index=False)
print("Exporting to", cache_file)
# Out:
# Exporting to ../extras/geocoding/INE/ine_toponimia_clipped.csv

# %%
import folium
from folium.plugins import MarkerCluster
from geopy.distance import geodesic

uc_location = [40.207422, -8.4260033]
centro_pt = [39.694502, -8.130573]

cell = folium.Figure(width=950, height=900)
map = folium.Map(location=centro_pt,
                zoom_start=7, 
                control_scale=True,
                scrollWheelZoom=True).add_to(cell)
marker_cluster = MarkerCluster()
# for icons check https://github.com/lennardv2/Leaflet.awesome-markers
marker_types = { 'INE': 'bookmark',
                 'DGT':'home',
                 'CIGEOE': 'flag'}
marker_colors = ['black', 'red', 'blue', 'green', 'purple',
                 'orange', 'darkred', 'lightred', 'beige',
                 'darkblue', 'darkgreen', 'cadetblue', 'darkpurple',
                 'pink', 'lightblue', 'lightgreen', 'gray', 'lightgray']

head = 5
show =  candidates[-5:]
i = 1
for (l,r), same_name,same_location,total in show.itertuples():
    print(l,r)
    left = ine_2011_pop.iloc[l]
    right = ine_2011_pop.iloc[r]
    left_marker = marker_types[left.origin]
    right_marker = marker_types[right.origin]
    color = marker_colors[i % len(marker_colors)]
    dist_meters = geodesic((left.latitude,left.longitude), (right.latitude,right.longitude)).km*1000

    folium.Marker(location=[left.latitude,left.longitude],
                   tooltip=f"{left['name']} {left.admin_dsg}",
                   icon=folium.Icon(color=color,
                   prefix='glyphicon', icon=left_marker)).add_to(map)
    folium.Marker(location=[right.latitude,right.longitude],
                   tooltip=f"{right['name']} {right.admin_dsg}",
                   icon=folium.Icon(color=color,
                   prefix='glyphicon', icon=right_marker)).add_to(map)
    folium.PolyLine([(left.latitude,left.longitude),(right.latitude,right.longitude)],
                    tooltip=f"{dist_meters} ({same_location})",
                    color='red',
                    opacity=1
                    ).add_to(map)
    # print(f"{left}={right} {total} {left.origin} {right.origin} {color}")
    i = i + 1
# marker_cluster.add_to(map)
map
# Out:
# 13667 35859
# 16420 31114
# 12455 35964
# 15529 31984
# 11004 34518
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0acba76199a20b6640994191d1e83b08 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0acba76199a20b6640994191d1e83b08&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0acba76199a20b6640994191d1e83b08 = L.map(
#                 &quot;map_0acba76199a20b6640994191d1e83b08&quot;,
#                 {
#                     center: [39.694502, -8.130573],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: true,
#                 }
#             );
#             L.control.scale().addTo(map_0acba76199a20b6640994191d1e83b08);
#
#
#
#
#
#             var tile_layer_7f45031994c77fe04f35587788c9e8c6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0acba76199a20b6640994191d1e83b08);
#
#
#             var marker_f9ec9b106b961d9f9a4d02b25ddb764c = L.marker(
#                 [41.6231619753495, -6.27428081346741],
#                 {}
#             ).addTo(map_0acba76199a20b6640994191d1e83b08);
#
#
#             var icon_071eab986aa3928719f0c3b6e6d51b41 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bookmark&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f9ec9b106b961d9f9a4d02b25ddb764c.setIcon(icon_071eab986aa3928719f0c3b6e6d51b41);
#
#
#             marker_f9ec9b106b961d9f9a4d02b25ddb764c.bindTooltip(
#                 `&lt;div&gt;
#                      Constantim Constantim, Miranda do Douro, Bragança
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c4c21a86870065475748ab55ebc0a241 = L.marker(
#                 [41.6297719331035, -6.26648174390052],
#                 {}
#             ).addTo(map_0acba76199a20b6640994191d1e83b08);
#
#
#             var icon_543729cfb3e18cf84b36d8c8c0960b22 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c4c21a86870065475748ab55ebc0a241.setIcon(icon_543729cfb3e18cf84b36d8c8c0960b22);
#
#
#             marker_c4c21a86870065475748ab55ebc0a241.bindTooltip(
#                 `&lt;div&gt;
#                      Constantim nan
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_3fb157a6a2848178dda6eebef5a3decb = L.polyline(
#                 [[41.6231619753495, -6.27428081346741], [41.6297719331035, -6.26648174390052]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0acba76199a20b6640994191d1e83b08);
#
#
#             poly_line_3fb157a6a2848178dda6eebef5a3decb.bindTooltip(
#                 `&lt;div&gt;
#                      980.4923978941988 (0.5099930492603938)
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1eac5237e92b5993a05e710fbaf0387a = L.marker(
#                 [39.5587287138331, -8.83168663410672],
#                 {}
#             ).addTo(map_0acba76199a20b6640994191d1e83b08);
#
#
#             var icon_2ac09202cc1efec5f60ef8cd2d05689d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bookmark&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1eac5237e92b5993a05e710fbaf0387a.setIcon(icon_2ac09202cc1efec5f60ef8cd2d05689d);
#
#
#             marker_1eac5237e92b5993a05e710fbaf0387a.bindTooltip(
#                 `&lt;div&gt;
#                      Serro Ventoso Serro Ventoso, Porto de Mós, Leiria
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_54a3ac84b4c6b6642e542c9fc6b7dd91 = L.marker(
#                 [39.5498794999998, -8.83151250000024],
#                 {}
#             ).addTo(map_0acba76199a20b6640994191d1e83b08);
#
#
#             var icon_e63a0b14173b865ccc3ea24b0b1568d2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );

# %% [markdown]
# Definimos um pop-up em html

# %%
def pop_info(cluster,name,origin,id, context):
    styles="""
    <!DOCTYPE html>
    <html>
    <head>
    <style>
    table, th, td {
    border: 1px solid;
    }
    table {
     width: 100%;
     border-collapse: collapse;
    }
    </style>
    </head>
    <body>"""
    
    html=f"<table><tr><td width=50%><b>{name}</b></td><td>C{cluster}</td><td>{origin}</td><td>id:{id}</td></tr>"
    html=f'{styles}{html}<tr><td colspan=4>{context}</td></tr></table>'
    return html

# %%
import folium
from folium.plugins import MarkerCluster

uc_location = [40.207422, -8.4260033]
centro_pt = [39.694502, -8.130573]

cell = folium.Figure(width=950, height=900)
map = folium.Map(location=centro_pt,
                zoom_start=7, 
                control_scale=True,
                scrollWheelZoom=True).add_to(cell)

ncolors = len(clusters)
marker_colors = ['black', 'red', 'blue', 'green', 'purple', 'orange', 'darkred', 'lightred', 'beige', 'darkblue', 'darkgreen', 'cadetblue', 'darkpurple',  'pink', 'lightblue', 'lightgreen', 'gray', 'lightgray']
color_list = marker_colors

while len(color_list) < ncolors:
    color_list.extend(marker_colors[1:])

place_colors = dict()
i = 1
for cluster in clusters:
    for place in cluster:
        place_colors[place] = i
    i = i+1
print(place_colors)

# for icons check https://github.com/lennardv2/Leaflet.awesome-markers
marker_types = { 'INE': 'bookmark',
                 'DGT':'home',
                 'CIGEOE': 'flag'}

marker_cluster = MarkerCluster()
for i, name, origin, lat, lng, id, name_dsg,sameas, duplicate in ine_2011_pop.loc[ocorrencias.index.unique()][['name','origin','latitude','longitude','id','name_dsg','same_as','duplicate']].itertuples():
    color = place_colors.get(i,0)
    if duplicate:
        name_dsg = "duplicado de: "+sameas
    # print(i, color,name, origin, lat, lng, id)
    marker = marker_types.get(origin,'square-question')
    iframe = folium.IFrame(pop_info(color,name,origin,id,name_dsg),width=400,height=70)
    popup = folium.Popup(iframe,max_width=500)
    folium.Marker(location=[lat,lng],popup=popup,
                    icon=folium.Icon(color=marker_colors[color],
                    prefix='glyphicon', icon=marker)).add_to(marker_cluster)

marker_cluster.add_to(map)
map
# Out:
# {14265: 1, 1425: 1, 36337: 1, 14745: 2, 1054: 2, 3282: 3, 14949: 3, 4042: 4, 24766: 4, 16274: 5, 32548: 5, 33107: 6, 26478: 6, 33256: 7, 26093: 7, 12788: 8, 34286: 8, 11210: 9, 34420: 9, 13041: 10, 34570: 10, 12922: 11, 34629: 11, 11611: 12, 34780: 12, 34897: 13, 29847: 13, 10689: 14, 35062: 14, 35120: 15, 12263: 15, 12203: 15, 12375: 15, 11668: 16, 35124: 16, 35138: 17, 12174: 17, 27404: 18, 35351: 18, 35458: 19, 10237: 19, 10324: 20, 35470: 20, 35481: 21, 9385: 21, 35608: 22, 9393: 22, 35656: 23, 14031: 23, 8653: 24, 35726: 24, 7905: 25, 35743: 25, 35842: 26, 7524: 26, 7296: 27, 35917: 27, 9866: 28, 35942: 28, 8646: 29, 35974: 29, 10130: 30, 36006: 30, 10151: 30, 36027: 31, 9643: 31, 9854: 31, 36029: 32, 7206: 32, 8080: 33, 36327: 33, 7113: 34, 36413: 34, 7810: 35, 36429: 35, 7450: 36, 36443: 36, 36472: 37, 9179: 37, 9211: 37, 7744: 38, 36477: 38, 36542: 39, 7935: 39, 7641: 40, 36546: 40, 30104: 41, 6906: 41, 36607: 41, 36635: 42, 7309: 42, 6002: 43, 6355: 43, 36989: 43, 5417: 44, 37143: 44}
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_69ee663fd82842c592f60833ca072d2e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_69ee663fd82842c592f60833ca072d2e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_69ee663fd82842c592f60833ca072d2e = L.map(
#                 &quot;map_69ee663fd82842c592f60833ca072d2e&quot;,
#                 {
#                     center: [39.694502, -8.130573],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: true,
#                 }
#             );
#             L.control.scale().addTo(map_69ee663fd82842c592f60833ca072d2e);
#
#
#
#
#
#             var tile_layer_60a3807d652962cfbf2b08c03c86d9a0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_69ee663fd82842c592f60833ca072d2e);
#
#
#             var marker_cluster_0d60c3a2bd975a12a22cbb4c05ef0b41 = L.markerClusterGroup(
#                 {}
#             );
#             map_69ee663fd82842c592f60833ca072d2e.addLayer(marker_cluster_0d60c3a2bd975a12a22cbb4c05ef0b41);
#
#
#             var marker_a503c6f956f62cfacd07c930bf4eee3f = L.marker(
#                 [41.514879334221455, -8.015002734991182],
#                 {}
#             ).addTo(marker_cluster_0d60c3a2bd975a12a22cbb4c05ef0b41);
#
#
#             var icon_ebe8f5c2f6dc6f07bc3c5659cb947c9c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a503c6f956f62cfacd07c930bf4eee3f.setIcon(icon_ebe8f5c2f6dc6f07bc3c5659cb947c9c);
#
#
#         var popup_2daa3927d9ab6121d8dc0fff9549a899 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#             var i_frame_798ad43a1d8e219ccbb042b8b8988c5f = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;400&quot; style=&quot;border:none !important;&quot; height=&quot;70&quot;&gt;&lt;/iframe&gt;`)[0];
#             popup_2daa3927d9ab6121d8dc0fff9549a899.setContent(i_frame_798ad43a1d8e219ccbb042b8b8988c5f);
#
#
#         marker_a503c6f956f62cfacd07c930bf4eee3f.bindPopup(popup_2daa3927d9ab6121d8dc0fff9549a899)
#         ;
#
#
#
#
#             var marker_8293d024bf1581d9a513a5810e44011a = L.marker(
#                 [41.751662424539575, -8.785912650311925],
#                 {}
#             ).addTo(marker_cluster_0d60c3a2bd975a12a22cbb4c05ef0b41);
#
#
#             var icon_2146977327ef4846c4655e1c057478f6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8293d024bf1581d9a513a5810e44011a.setIcon(icon_2146977327ef4846c4655e1c057478f6);
#
#
#         var popup_01115bb9d485524de5117d47cf47f01c = L.popup({&quot;maxWidth&quot;: 500});
#
#
#             var i_frame_801be3426b1d75745f02c5d1cae14a0e = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;400&quot; style=&quot;border:none !important;&quot; height=&quot;70&quot;&gt;&lt;/iframe&gt;`)[0];
#             popup_01115bb9d485524de5117d47cf47f01c.setContent(i_frame_801be3426b1d75745f02c5d1cae14a0e);
#
#
#         marker_8293d024bf1581d9a513a5810e44011a.bindPopup(popup_01115bb9d485524de5117d47cf47f01c)
#         ;
#
#
#
#
#             var marker_a36a0e2b8d28d55816794048ef9aaa44 = L.marker(
#                 [41.78691684444839, -7.942827404516782],
#                 {}
#             ).addTo(marker_cluster_0d60c3a2bd975a12a22cbb4c05ef0b41);
#
#
#             var icon_a13cb11ccc99cab132c7075b695c5bed = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a36a0e2b8d28d55816794048ef9aaa44.setIcon(icon_a13cb11ccc99cab132c7075b695c5bed);
#
#
#         var popup_6ba76de40ab787f4abbedffc99e3c36a = L.popup({&quot;maxWidth&quot;: 500});
#
#
#             var i_frame_c43f0b57b77ef58142abface1c4ff242 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;400&quot; style=&quot;border:none !important;&quot; height=&quot;70&quot;&gt;&lt;/iframe&gt;`)[0];
#             popup_6ba76de40ab787f4abbedffc99e3c36a.setContent(i_frame_c43f0b57b77ef58142abfac
