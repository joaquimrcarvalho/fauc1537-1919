# %% [markdown]
# > First time use: follow instructions in the README.md file in this directory.

# %% [markdown]
# # Toponímia
#
#
# Identificação e geolocalização dos topónimos
#
# ---
#
# # Place names
#
# Identification and geocoding of place names

# %% [markdown]
# ## Setup

# %%
from timelink.api.database import TimelinkDatabase
from ucalumni.config import default_db_url

print(f"Creating TimelinkDatabase instance from {default_db_url}")
db = TimelinkDatabase(db_url=default_db_url)
# Out:
# Creating TimelinkDatabase instance from sqlite:///../database/sqlite3/fauc.db?check_same_thread=False

# %% [markdown]
# We use the results of another project that aims at geocoding and "administrative coding"
# of place names in historical sources.
# * https://github.com/joaquimrcarvalho/toponimia-portuguesa (currently private, contact joaquimcarvalho@mpu.edu.mo) for access).
#
# The results consist of two files:
#
# * `inferences/places/gngc_names_geocoded.csv` with place names currently geocoded
# * `inferences/places/gngc_changes.csv` with place names that require normalization for geocoding
#
# These files are produced by the notebook https://github.com/joaquimrcarvalho/toponimia-portuguesa/blob/9b84d476e4fd4400c3c6d748a744c13168ed72a2/001-geocoding.ipynb
#
# Get a fresh copy of those files and put them in `inferences\places|` before running this notebook

# %% [markdown]
# ### Check for update files in toponima project

# %%
import pandas as pd
# read geocoded_places from inferences/places/gngc_names_geocoded.csv
geocoded_places = pd.read_csv("../inferences/places/gngc_names_geocoded.csv")
# conver geonamesid to int
geocoded_places["geonamesid"] = pd.to_numeric(geocoded_places["geonamesid"], errors='coerce').astype('Int64')
# trim columns name and name_normalized
geocoded_places["name"] = geocoded_places["name"].str.strip()
geocoded_places["name_normalized"] = geocoded_places["name_normalized"].str.strip()
geocoded_places.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11498 entries, 0 to 11497
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pop              11498 non-null  int64
#  1   date_in          11498 non-null  object
#  2   date_max         11498 non-null  object
#  3   name             11497 non-null  object
#  4   name_normalized  11497 non-null  object
#  5   id_ine_inspire   15 non-null     object
#  6   geonamesid       4978 non-null   Int64
#  7   context_0        11497 non-null  object
#  8   context_1        4387 non-null   object
#  9   context_2        281 non-null    object
#  10  context_3        116 non-null    object
#  11  country          11498 non-null  object
#  12  gaz_id_explicit  3 non-null      object
#  13  latitude         4977 non-null   float64
#  14  longitude        4977 non-null   float64
#  15  code             4923 non-null   object
#  16  dsg              4923 non-null   object
#  17  level            4923 non-null   float64
#  18  inside           4910 non-null   object
#  19  address          4923 non-null   object
#  20  geonames_name    4977 non-null   object
#  21  gazetteer        4977 non-null   object
#  22  total_score      4977 non-null   float64
#  23  date             4977 non-null   object
#  24  wikidata_id      4978 non-null   object
# dtypes: Int64(1), float64(4), int64(1), object(19)
# memory usage: 2.2+ MB

# %%
geocoded_places.sample(5)
# Out:
#        pop     date_in    date_max                     name  \
# 665     15  1630-10-16  1885-10-13                    Belém
# 9818     1  1868-10-01  1868-10-01  São João de Aião, Porto
# 10839    1  1824-10-02  1824-10-02  Vale de Madeiros, Viseu
# 10799    1  1817-11-08  1817-11-08   Vale Mendes, Vila Real
# 8205     1  1729-12-05  1729-12-05                    Praga
#
#                                    name_normalized id_ine_inspire  geonamesid  \
# 665    Belém, Santa Maria de Belém, Lisboa, Lisboa            NaN     2270978
# 9818                       São João de Aião, Porto            NaN        <NA>
# 10839                      Vale de Madeiros, Viseu            NaN     2733105
# 10799                       Vale Mendes, Vila Real            NaN        <NA>
# 8205                                         Praga            NaN        <NA>
#
#               context_0             context_1 context_2  ...           code  \
# 665               Belém  Santa Maria de Belém    Lisboa  ...  PRT.12.7.32_1
# 9818   São João de Aião                 Porto       NaN  ...            NaN
# 10839  Vale de Madeiros                 Viseu       NaN  ...   PRT.20.9.2_1
# 10799       Vale Mendes             Vila Real       NaN  ...            NaN
# 8205              Praga                   NaN       NaN  ...            NaN
#
#                         dsg level      inside  \
# 665    Santa Maria de Belém   3.0  PRT.12.7_1
# 9818                    NaN   NaN         NaN
# 10839     Canas de Senhorim   3.0  PRT.20.9_1
# 10799                   NaN   NaN         NaN
# 8205                    NaN   NaN         NaN
#
#                                                  address     geonames_name  \
# 665          Belém, Santa Maria de Belém, Lisboa, Lisboa             Belém
# 9818                                                 NaN               NaN
# 10839  Vale de Madeiros, Canas de Senhorim, Nelas, Viseu  Vale de Madeiros
# 10799                                                NaN               NaN
# 8205                                                 NaN               NaN
#
#          gazetteer  total_score                        date wikidata_id
# 665    geonames-pt         30.0  2024-11-10 14:52:29.134665     Q376866
# 9818           NaN          NaN                         NaN         NaN
# 10839  geonames-pt         15.0  2024-11-10 14:52:32.396240  *notfound*
# 10799          NaN          NaN                         NaN         NaN
# 8205           NaN          NaN                         NaN         NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Get the change list
#
# Records where it was necessary to change the birth place in other to geocode the place name.
#
# These include spelling errors, name changes in modern times, qualification of ambiguous names by adding geographic context.
#
# The list can also be inferred by comparing columns `name` and `name_normalized`
# and keep the rows where they differ.
#
# Note some changes may involve extra spaces in the name and so not immediately evident.

# %%
# read changes from inferences/places/gngc_names_changes.csv
changes = geocoded_places[geocoded_places.name != geocoded_places.name_normalized]
changes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 593 entries, 12 to 11371
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pop              593 non-null    int64
#  1   date_in          593 non-null    object
#  2   date_max         593 non-null    object
#  3   name             592 non-null    object
#  4   name_normalized  592 non-null    object
#  5   id_ine_inspire   11 non-null     object
#  6   geonamesid       488 non-null    Int64
#  7   context_0        592 non-null    object
#  8   context_1        259 non-null    object
#  9   context_2        148 non-null    object
#  10  context_3        107 non-null    object
#  11  country          593 non-null    object
#  12  gaz_id_explicit  1 non-null      object
#  13  latitude         488 non-null    float64
#  14  longitude        488 non-null    float64
#  15  code             487 non-null    object
#  16  dsg              487 non-null    object
#  17  level            487 non-null    float64
#  18  inside           484 non-null    object
#  19  address          487 non-null    object
#  20  geonames_name    488 non-null    object
#  21  gazetteer        488 non-null    object
#  22  total_score      488 non-null    float64
#  23  date             488 non-null    object
#  24  wikidata_id      488 non-null    object
# dtypes: Int64(1), float64(4), int64(1), object(19)
# memory usage: 121.0+ KB

# %% [markdown]
# Number of recods involved in the changes

# %%
# sum column pop in df changes
print("Number of record involved in place name changes:", changes["pop"].sum())
# Out:
# Number of record involved in place name changes: 8569

# %%
changes.sample(5)
# Out:
#       pop     date_in    date_max               name  \
# 61    202  1540-10-20  1770-10-01  Arrifana de Sousa
# 7895    1  1583-10-18  1583-10-18  Pedrulha do Monte
# 646    16  1626-10-21  1842-10-31        Rio de Vide
# 597    18  1779-10-20  1848-06-05       Viana, Minho
# 313    40  1581-10-21  1876-06-06             Vieira
#
#                                        name_normalized id_ine_inspire  \
# 61                                            Penafiel            NaN
# 7895  Pedrulha, Coimbra (Santa Cruz), Coimbra, Coimbra            NaN
# 646                                           Rio Vide            NaN
# 597                                   Viana do Castelo            NaN
# 313                                    Vieira do Minho            NaN
#
#       geonamesid         context_0             context_1 context_2  ...  \
# 61       2736469          Penafiel                   NaN       NaN  ...
# 7895     2736519          Pedrulha  Coimbra (Santa Cruz)   Coimbra  ...
# 646      8011848          Rio Vide                   NaN       NaN  ...
# 597      2732773  Viana do Castelo                   NaN       NaN  ...
# 313      2732748   Vieira do Minho                   NaN       NaN  ...
#
#                 code                            dsg level       inside  \
# 61    PRT.15.11.24_1                       Penafiel   3.0  PRT.15.11_1
# 7895    PRT.7.3.13_1           Coimbra (Santa Cruz)   3.0    PRT.7.3_1
# 646      PRT.7.9.3_1                       Rio Vide   3.0    PRT.7.9_1
# 597    PRT.18.9.34_1  Viana do Castelo (Monserrate)   3.0   PRT.18.9_1
# 313    PRT.4.11.20_1                Vieira do Minho   3.0   PRT.4.11_1
#
#                                                 address     geonames_name  \
# 61                  Penafiel, Penafiel, Penafiel, Porto          Penafiel
# 7895   Pedrulha, Coimbra (Santa Cruz), Coimbra, Coimbra          Pedrulha
# 646       Rio Vide, Rio Vide, Miranda do Corvo, Coimbra          Rio Vide
# 597   Viana do Castelo, Viana do Castelo (Monserrate...  Viana do Castelo
# 313   Vieira do Minho, Vieira do Minho, Vieira do Mi...   Vieira do Minho
#
#         gazetteer  total_score                        date wikidata_id
# 61    geonames-pt         20.0  2024-11-10 14:52:29.276160   Q49287885
# 7895  geonames-pt         30.0  2024-11-10 14:52:29.117772  *notfound*
# 646   geonames-pt         15.0  2024-11-10 14:52:30.878577    Q1024471
# 597   geonames-pt         20.0  2024-11-10 14:52:29.249437   Q49278394
# 313   geonames-pt         20.0  2024-11-10 14:52:29.359670  *notfound*
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Create field information to add to the original record
#
# We produce a text snippet to add to the main record at https://pesquisa.auc.uc.pt/details?id=264605

# %%
# iterate through rows in dataframe changes
for index, row in changes.iterrows():
    # get the geonamesid
    geonamesid = row["geonamesid"]
    if pd.isna(geonamesid):
        geonamesid = None
    if geonamesid is not None:
    # get the normalized name
        name = row["name_normalized"]
        geoname_name = row['geonames_name']
        # get the address
        address = row["address"]
        country = row["country"]
        wikidata_id = row["wikidata_id"]
        snippet = f"Naturalidade designação alternativa: {name}\n"
        if address is not None and address != name:
            snippet += f"Naturalidade contexto: {address}\n"
        if country is not None:
            snippet += f"País: {country}\n"
        if geonamesid is not None:
            snippet += f"Geonames id: {geonamesid}\n"
            snippet += f"Geonames name: {geoname_name}\n"
        if wikidata_id is not None and wikidata_id != "*notfound*":
            snippet += f"Wikidata id: {wikidata_id}\n"

        # set column snippet with the snippet
        changes.loc[index, "snippet"] = snippet
# Out:
# /var/folders/x7/qzytnd752559g0w475rfwkx00000gn/T/ipykernel_9408/4130414814.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   changes.loc[index, "snippet"] = snippet

# %%
changes[['name', 'name_normalized', 'address', 'snippet']].sample(5)
# Out:
#                             name  \
# 2023          Brasil, Pernambuco
# 7220  Minas, Congonhas do Sabará
# 9648         São  Tiago de Cacém
# 835                     Correlos
# 642                     Pedrulha
#
#                                        name_normalized  \
# 2023                        Recife, Pernambuco, Brasil
# 7220                                 Congonhas, Brasil
# 9648                                São Tiago de Cacém
# 835                                           Currelos
# 642   Pedrulha, Coimbra (Santa Cruz), Coimbra, Coimbra
#
#                                                address  \
# 2023                Recife, Recife, Pernambuco, Brasil
# 7220        Congonhas, Congonhas, Minas Gerais, Brasil
# 9648                                               NaN
# 835         Currelos, Currelos, Carregal do Sal, Viseu
# 642   Pedrulha, Coimbra (Santa Cruz), Coimbra, Coimbra
#
#                                                 snippet
# 2023  Naturalidade designação alternativa: Recife, P...
# 7220  Naturalidade designação alternativa: Congonhas...
# 9648                                                NaN
# 835   Naturalidade designação alternativa: Currelos\...
# 642   Naturalidade designação alternativa: Pedrulha,...

# %%
from timelink.pandas import entities_with_attribute
from pandas import DataFrame

# iterate through rows in dataframe changes where geoanmesid is not null
see_only = 15
for index, row in changes[changes.geonamesid.notnull()].sort_values('pop',ascending=False).head(see_only).iterrows():
    # get the geonamesid
    naturalidade = row["name"]
    print("Naturalidade:", naturalidade)
    print(row["snippet"])
    people: DataFrame = entities_with_attribute(
        the_type="naturalidade",
        the_value=naturalidade,
        entity_type="person",
        dates_in=('1530-01-01', '2021-01-01'),
        show_elements=["name"],
        more_attributes=["uc-entrada", "uc-saida"],
        db=db)
    # interate through people
    print("Total de estudantes:", len(people))
    print("Amostra:")
    for index, person in people.sample(5).iterrows():
        print(index, person["name"], person["uc-entrada"], person["uc-saida"])
    print()
# Out:
# Naturalidade: Ilha da Madeira
# Naturalidade designação alternativa: Funchal (Sé), Funchal (Sé), Funchal, Madeira
# País: Portugal
# Geonames id: 8014027
# Geonames name: Funchal (Sé)
# Wikidata id: Q2190091
#
# Total de estudantes: 575
# Amostra:
# 172253 Lourenço de Matos 1648-10-09 1650-10-15
# 176565 Simão José de Oliveira 1795-10-13 1795-10-13
# Wikidata id: Q49287885
#
# Total de estudantes: 202
# Amostra:
# 234885 Simão Moreira 1642-10-28 1651-10-01
# 212335 Francisco de Lemos 1657-10-15 1666-01-23
# 189807 Simão da Rocha 1578-11-08 1579-06-24
# 228646 Manuel Ferreira da Rosa 1729-01-23 1729-01-23
# 217503 Manuel de Sousa São Tiago 1663-11-03 1672-05-11
#
# Naturalidade: Ilha de São Miguel
# Naturalidade designação alternativa: Ponta Delgada
# Naturalidade contexto: Ponta Delgada, Ponta Delgada (São Sebastião), Ponta Delgada, Azores
# País: Portugal
# Geonames id: 6941014
# Geonames name: Ponta Delgada
# Wikidata id: Q49278070
#
# Total de estudantes: 188
# Amostra:
# 216714 Manuel Rodrigues 1596-10-01 1609-04-28
# 136414 António do Rego 1577-10-03 1584-02-05
# 173218 Francisco Soares de Medeiros 1853-10-07 1853-10-07
# 235672 António Moniz de Sousa 1634-10-07 1636-10-03
# 185595 António de Bettencourt 1652-10-09 1658-05-20
#
# Naturalidade: Pernambuco
# Naturalidade designação alternativa: Recife, Pernambuco, Brasil
# Naturalidade contexto: Recife, Recife, Pernambuco, Brasil
# País: Brasil
# Geonames id: 3390760
# Geonames name: Recife
# Wikidata id: Q22061296
#
# Total de estudantes: 136
# Amostra:
# 198395 Fernão Rodrigues 1638-10-12 1638-10-12
# 150421 Agostinho de Freitas Baracho 1694-12-10 1694-12-10
# 244055 José de Almeida de Faria 1701-10-01 1707-07-28
# 163570 António José Dormentes 1767-10-01 1770-10-01
# 177391 Domingos Garcia 1647-10-17 1648-11-04
#
# Naturalidade: Condeixa
# Naturalidade designação alternativa: Condeixa-a-Nova
# Naturalidade contexto: Condeixa-a-Nova, Condeixa-a-Nova, Condeixa-a-Nova, Coimbra
# País: Portugal
# Geonames id: 2740593
# Geonames name: Condeixa-a-Nova
# Wikidata id: Q49282120
#
# Total de estudantes: 135
# Amostra:
# 157429 Luís António de Carvalho 1739-10-01 1739-10-01
# 199325 António da Costa 1616-10-07 1616-10-07
# 188156 Manuel Brás 1664-03-14 1664-03-14
# 142112 Bernardo de Almeida 1748-10-01 1751-10-01
# 185514 Manuel Brás Bernardes 1664-10-02 1673-10-29
#
# Naturalidade: Olivença
# Naturalidade designação alternativa: Olivenza, Espanha
# Naturalidade contexto: Olivenza, Olivenza, Badajoz, Extremadura
# País: Espanha
# Geonames id: 9883562
# Geonames name: Olivenza
# Wikidata id: Q120170977
#
# Total de estudantes: 134
# Amostra:
# 241664 Matias Tavares e Sousa 1657-01-11 1663-02-19
# 217246 Manuel de Santa Teresa de Jesus 1794-10-10 1802-10-09
# 142725 António de Miranda e Almeida 1782-10-05 1790-10-30
# 189218 João Peres Castela 1800-06-30 1800-07-05
# 145534 João Borja do Amaral 1770-10-01 1780-07-23
#
# Naturalidade: Celorico
# Naturalidade designação alternativa: Celorico da Beira
