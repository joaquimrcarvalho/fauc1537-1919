# %% [markdown]
# > First time use: follow instructions in the README.md file in this directory.

# %% [markdown]
# **[PT]** Português
#
# ---
#
# **[EN]** English

# %% [markdown]
# # Toponímia
#
#
# Identificação e geolocalização dos topónimos
#
# ---
#
# # Place names
#
# Identification and geocoding of place names

# %% [markdown]
# ## Setup

# %%
from timelink.api.database import TimelinkDatabase
from ucalumni.config import default_db_url

print(f"Creating TimelinkDatabase instance from {default_db_url}")
db = TimelinkDatabase(db_url=default_db_url)
# Out:
# Creating TimelinkDatabase instance from sqlite:///../database/sqlite3/fauc.db?check_same_thread=False

# %% [markdown]
# ## Lista de lugares diferentes e número de ocorrências
#
# ---
#
# ## List of different places with number of occurrences

# %%
from timelink.pandas import attribute_values

attribute = 'naturalidade'
period = ('1500-00-00','1990-00-00')

places = attribute_values(attribute,dates_between=period, db=db)
places['place_name'] = places.index.values
places.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11499 entries, Lisboa to Óvoa, Viseu
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   count       11499 non-null  int64
#  1   date_min    11499 non-null  object
#  2   date_max    11499 non-null  object
#  3   place_name  11499 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 449.2+ KB

# %% [markdown]
# ### Lugares principais
#
# ---
#
# ### Main locations

# %%
places.sort_values('count', ascending=False).head(10)
# Out:
#            count    date_min    date_max place_name
# value
# Lisboa      8784  1537-02-12  1916-07-19     Lisboa
# Coimbra     5526  1537-00-00  1915-10-12    Coimbra
# Porto       3391  1537-05-30  1917-10-22      Porto
# Braga       1608  1540-01-21  1914-07-24      Braga
# Évora       1072  1537-11-22  1910-10-10      Évora
# Viseu        986  1537-00-00  1912-07-03      Viseu
# Guimarães    980  1537-12-18  1912-07-18  Guimarães
# Lamego       972  1537-00-00  1909-10-05     Lamego
# Aveiro       790  1538-04-21  1913-10-13     Aveiro
# Vila Real    765  1537-03-07  1909-11-09  Vila Real

# %% [markdown]
# ### Lugares só com uma ocorrência
# ---
#
# ### Locations with just one occurrence

# %%
places[places['count'] == 1].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7554 entries, - Lisboa to Óvoa, Viseu
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   count       7554 non-null   int64
#  1   date_min    7554 non-null   object
#  2   date_max    7554 non-null   object
#  3   place_name  7554 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 295.1+ KB

# %%
places[places['count']==1].sample(10)
# Out:
#                                 count    date_min    date_max  \
# value
# Vilões, Ourém                       1  1762-10-01  1762-10-01
# São Miguel, São João de Areias      1  1730-10-30  1730-10-30
# Eiras, Amadora                      1  1765-10-01  1765-10-01
# Côvo                                1  1687-10-01  1687-10-01
# Lagarelhos                          1  1734-10-01  1734-10-01
# Quintiãs                            1  1823-10-21  1823-10-21
# Alagoas                             1  1725-10-01  1725-10-01
# Alfazeirão                          1  1742-01-15  1742-01-15
# Couto de Capareiros                 1  1756-10-01  1756-10-01
# Orges                               1  1765-12-01  1765-12-01
#
#                                                     place_name
# value
# Vilões, Ourém                                    Vilões, Ourém
# São Miguel, São João de Areias  São Miguel, São João de Areias
# Eiras, Amadora                                  Eiras, Amadora
# Côvo                                                      Côvo
# Lagarelhos                                          Lagarelhos
# Quintiãs                                              Quintiãs
# Alagoas                                                Alagoas
# Alfazeirão                                          Alfazeirão
# Couto de Capareiros                        Couto de Capareiros
# Orges                                                    Orges

# %% [markdown]
# # Identificação de topónimos
#
# ---
#
# # Geocoding

# %% [markdown]
# https://craftingdh.netlify.app/tutorials/folium/

# %% [markdown]
# ## Toponímia de Portugal Continental 1:200 000
#
#  ### Serviço Nacional de Informação Geográfica
#
# * Metadados https://snig.dgterritorio.gov.pt/rndg/srv/por/catalog.search#/metadata/57479cf3-df10-47a0-9860-f7e3157596b1
# * Dados: http://mapas.dgterritorio.pt/ATOM-download/SCN200k/toponimia/toponimia.zip
# * Acesso público sem restrições
# * Sempre que o utilizador publique e/ou divulgue, por meio analógico ou digital, informação geográfica propriedade da Direção-Geral do Território, ainda que parcialmente adaptada, deverá atribuir créditos com inclusão do texto "Informação geográfica cedida pela Direção-Geral do Território"
#
# Notas:
# * Inclui mapas e informação de layer formato dbf.
# * Tabela de dados não inclui coordenadas mas inclui um id  (gml_id) que pode ser usado para obter as coordenadas noutras bases.
# * Pode ser útil para corrigir problemas de ortografia nos topónimos da base de dados

# %% [markdown]
# ### Convert informação para Pandas DataFrame

# %%
# !pip install simpledbf
# Out:
# .bash_profile RUN!
# Collecting simpledbf
#   Downloading simpledbf-0.2.6.tar.gz (17 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: simpledbf
#   Building wheel for simpledbf (pyproject.toml) ... done
#   Created wheel for simpledbf: filename=simpledbf-0.2.6-py3-none-any.whl size=13784 sha256=35711c83222c74e40405863194e15eb86d61b9db67b9679506e6e627c5e7cbea
#   Stored in directory: /Users/jrc/Library/Caches/pip/wheels/37/52/21/14be45b7c160488637e82d6a317f4379458bb4dd60be21d5fa
# Successfully built simpledbf
# Installing collected packages: simpledbf
# Successfully installed simpledbf-0.2.6

# %%
import pandas as pd
from simpledbf import Dbf5

file_name = '../extras/geocoding/SNIG/portugal-continental-200k/Toponimia200k.dbf'
dbf = Dbf5(file_name)
print("Number of records:",dbf.numrec)
dbf.fields
# Out:
# Number of records: 7054
# [('DeletionFlag', 'C', 1),
#  ('gml_id', 'C', 254),
#  ('beginLifes', 'C', 20),
#  ('localId', 'C', 15),
#  ('namespace', 'C', 35),
#  ('versionId', 'N', 10),
#  ('Integer', 'N', 10),
#  ('mostDetail', 'N', 10),
#  ('language', 'C', 3),
#  ('sourceOfNa', 'C', 3),
#  ('pronunciat', 'C', 254),
#  ('text', 'C', 49),
#  ('script', 'C', 4),
#  ('relatedSpa', 'C', 27),
#  ('relatedS_1', 'C', 45),
#  ('relatedS_2', 'N', 10)]

# %% [markdown]
# These are included in the INE data. But do not overlap.

# %%
topo200K_df = dbf.to_dataframe()
topo200K_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7054 entries, 0 to 7053
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   gml_id      7054 non-null   object
#  1   beginLifes  7054 non-null   object
#  2   localId     0 non-null      float64
#  3   namespace   7054 non-null   object
#  4   versionId   7054 non-null   int64
#  5   Integer     7054 non-null   int64
#  6   mostDetail  7054 non-null   int64
#  7   language    7054 non-null   object
#  8   sourceOfNa  7054 non-null   object
#  9   pronunciat  0 non-null      float64
#  10  text        7054 non-null   object
#  11  script      7054 non-null   object
#  12  relatedSpa  7054 non-null   object
#  13  relatedS_1  0 non-null      float64
#  14  relatedS_2  0 non-null      float64
# dtypes: float64(4), int64(3), object(8)
# memory usage: 826.8+ KB

# %%
topo200K_df.sample(5)
# Out:
#             gml_id            beginLifes  localId  \
# 2241  PT.GN.114541  2015-01-01T00:00:00Z      NaN
# 3879  PT.GN.116179  2015-01-01T00:00:00Z      NaN
# 1669  PT.GN.113969  2015-01-01T00:00:00Z      NaN
# 3511  PT.GN.115811  2015-01-01T00:00:00Z      NaN
# 5460  PT.GN.117760  2015-01-01T00:00:00Z      NaN
#
#                                 namespace  versionId  Integer  mostDetail  \
# 2241  http://id.igeo.pt/so/GN/NamedPlaced       2015   577791      144447
# 3879  http://id.igeo.pt/so/GN/NamedPlaced       2015   577791      144447
# 1669  http://id.igeo.pt/so/GN/NamedPlaced       2015   577791      144447
# 3511  http://id.igeo.pt/so/GN/NamedPlaced       2015   577791      144447
# 5460  http://id.igeo.pt/so/GN/NamedPlaced       2015   577791      144447
#
#      language sourceOfNa  pronunciat          text script  \
# 2241      Por        DGT         NaN  Água Formosa   Latn
# 3879      Por        DGT         NaN      Fontinha   Latn
# 1669      Por        DGT         NaN        Areias   Latn
# 3511      Por        DGT         NaN   Santos Evos   Latn
# 5460      Por        DGT         NaN          Lixa   Latn
#
#                       relatedSpa  relatedS_1  relatedS_2
# 2241  CDG200k_populatedPlace2241         NaN         NaN
# 3879  CDG200k_populatedPlace3526         NaN         NaN
# 1669  CDG200k_populatedPlace1631         NaN         NaN
# 3511  CDG200k_populatedPlace3658         NaN         NaN
# 5460  CDG200k_populatedPlace5170         NaN         NaN

# %%
topo200K_df[topo200K_df.gml_id == 'PT.GN.50']
# Out:
# Empty DataFrame
# Columns: [gml_id, beginLifes, localId, namespace, versionId, Integer, mostDetail, language, sourceOfNa, pronunciat, text, script, relatedSpa, relatedS_1, relatedS_2]
# Index: []

# %% [markdown]
# Não vemos uma coluna a identificar o tipo de topónimo
# mas é possível inferir a partir do campo "relatedSpa"
# que tem um código único com um prefixo

# %%
topo200K_df['inferredType'] = topo200K_df.relatedSpa.str.strip("CDG_k0123456789")
topo200K_df.groupby(['inferredType'])['inferredType'].count()
# Out:
# inferredType
# buildingForte          28
# buildingSantuario      14
# landformCabo           10
# landformIlha           19
# landformPonta          58
# landformSerra         159
# populatedPlace       6766
# Name: inferredType, dtype: int64

# %%
topo200K_df[topo200K_df.inferredType.str.contains('Santuario')]
# Out:
#             gml_id            beginLifes  localId  \
# 6680  PT.GN.118980  2015-01-01T00:00:00Z      NaN
# 6681  PT.GN.118981  2015-01-01T00:00:00Z      NaN
# 6682  PT.GN.118982  2015-01-01T00:00:00Z      NaN
# 6683  PT.GN.118983  2015-01-01T00:00:00Z      NaN
# 6684  PT.GN.118984  2015-01-01T00:00:00Z      NaN
# 6685  PT.GN.118985  2015-01-01T00:00:00Z      NaN
# 6686  PT.GN.118986  2015-01-01T00:00:00Z      NaN
# 6687  PT.GN.118987  2015-01-01T00:00:00Z      NaN
# 6688  PT.GN.118988  2015-01-01T00:00:00Z      NaN
# 6689  PT.GN.118989  2015-01-01T00:00:00Z      NaN
# 6690  PT.GN.118990  2015-01-01T00:00:00Z      NaN
# 6691  PT.GN.118991  2015-01-01T00:00:00Z      NaN
# 6692  PT.GN.118992  2015-01-01T00:00:00Z      NaN
# 6693  PT.GN.118993  2015-01-01T00:00:00Z      NaN
#
#                                 namespace  versionId  Integer  mostDetail  \
# 6680  http://id.igeo.pt/so/GN/NamedPlaced       2015   577791      144447
# 6681  http://id.igeo.pt/so/GN/NamedPlaced       2015   577791      144447
# 6682  http://id.igeo.pt/so/GN/NamedPlaced       2015   577791      144447
# 6683  http://id.igeo.pt/so/GN/NamedPlaced       2015   577791      144447
# 6684  http://id.igeo.pt/so/GN/NamedPlaced       2015   577791      144447
# 6685  http://id.igeo.pt/so/GN/NamedPlaced       2015   577791      144447
# 6686  http://id.igeo.pt/so/GN/NamedPlaced       2015   577791      144447
# 6687  http://id.igeo.pt/so/GN/NamedPlaced       2015   577791      144447
# 6688  http://id.igeo.pt/so/GN/NamedPlaced       2015   577791      144447
# 6689  http://id.igeo.pt/so/GN/NamedPlaced       2015   577791      144447
# 6690  http://id.igeo.pt/so/GN/NamedPlaced       2015   577791      144447
# 6691  http://id.igeo.pt/so/GN/NamedPlaced       2015   577791      144447
# 6692  http://id.igeo.pt/so/GN/NamedPlaced       2015   577791      144447
# 6693  http://id.igeo.pt/so/GN/NamedPlaced       2015   577791      144447
#
#      language sourceOfNa  pronunciat                        text script  \
# 6680      Por        DGT         NaN                      Fátima   Latn
# 6681      Por        DGT         NaN  Imaculado Coração de Maria   Latn
# 6682      Por        DGT         NaN         N. Srª da Conceição   Latn
# 6683      Por        DGT         NaN         N. Srª dos Milagres   Latn
# 6684      Por        DGT         NaN               S. Bartolumeu   Latn
# 6685      Por        DGT         NaN                 Srª de Nazo   Latn
# 6686      Por        DGT         NaN         N. Srª dos Anúncios   Latn
# 6687      Por        DGT         NaN                  Cristo Rei   Latn
# 6688      Por        DGT         NaN            Senhora da Rocha   Latn
# 6689      Por        DGT         NaN                Srº da Pedra   Latn
# 6690      Por        DGT         NaN          Bom Jesus do Monte   Latn
# 6691      Por        DGT         NaN       Nossa Senhora do Cabo   Latn
# 6692      Por        DGT         NaN           N. Srª da Piedade   Latn
# 6693      Por        DGT         NaN    Nossa Senhora das Brotas   Latn
#
#                        relatedSpa  relatedS_1  relatedS_2       inferredType
# 6680  CDG200k_buildingSantuario28         NaN         NaN  buildingSantuario
# 6681  CDG200k_buildingSantuario29         NaN         NaN  buildingSantuario
# 6682  CDG200k_buildingSantuario30         NaN         NaN  buildingSantuario
# 6683  CDG200k_buildingSantuario31         NaN         NaN  buildingSantuario
# 6684  CDG200k_buildingSantuario32         NaN         NaN  buildingSantuario
# 6685  CDG200k_buildingSantuario33         NaN         NaN  buildingSantuario
# 6686  CDG200k_buildingSantuario34         NaN         NaN  buildingSantuario
# 6687  CDG200k_buildingSantuario35         NaN         NaN  buildingSantuario
# 6688  CDG200k_buildingSantuario36         NaN         NaN  buildingSantuario
# 6689  CDG200k_buildingSantuario37         NaN         NaN  buildingSantuario
# 6690  CDG200k_buildingSantuario38         NaN         NaN  buildingSantuario
# 6691  CDG200k_buildingSantuario39         NaN         NaN  buildingSantuario
# 6692  CDG200k_buildingSantuario40         NaN         NaN  buildingSantuario
# 6693  CDG200k_buildingSantuario41         NaN         NaN  buildingSantuario

# %%
topo200K_df.sample(10)
# Out:
#             gml_id            beginLifes  localId  \
# 2501  PT.GN.114801  2015-01-01T00:00:00Z      NaN
# 561   PT.GN.112861  2015-01-01T00:00:00Z      NaN
# 590   PT.GN.112890  2015-01-01T00:00:00Z      NaN
# 129   PT.GN.112429  2015-01-01T00:00:00Z      NaN
# 6953  PT.GN.119253  2015-01-01T00:00:00Z      NaN
# 3236  PT.GN.115536  2015-01-01T00:00:00Z      NaN
# 4239  PT.GN.116539  2015-01-01T00:00:00Z      NaN
# 4463  PT.GN.116763  2015-01-01T00:00:00Z      NaN
# 5482  PT.GN.117782  2015-01-01T00:00:00Z      NaN
# 3369  PT.GN.115669  2015-01-01T00:00:00Z      NaN
#
#                                 namespace  versionId  Integer  mostDetail  \
# 2501  http://id.igeo.pt/so/GN/NamedPlaced       2015   577791      144447
# 561   http://id.igeo.pt/so/GN/NamedPlaced       2015   577791      144447
# 590   http://id.igeo.pt/so/GN/NamedPlaced       2015   577791      144447
# 129   http://id.igeo.pt/so/GN/NamedPlaced       2015   577791      144447
# 6953  http://id.igeo.pt/so/GN/NamedPlaced       2015   577791      144447
# 3236  http://id.igeo.pt/so/GN/NamedPlaced       2015   577791      144447
# 4239  http://id.igeo.pt/so/GN/NamedPlaced       2015   577791      144447
# 4463  http://id.igeo.pt/so/GN/NamedPlaced       2015   577791      144447
# 5482  http://id.igeo.pt/so/GN/NamedPlaced       2015   577791      144447
# 3369  http://id.igeo.pt/so/GN/NamedPlaced       2015   577791      144447
#
#      language sourceOfNa  pronunciat                   text script  \
# 2501      Por        DGT         NaN      Serra das Alhadas   Latn
# 561       Por        DGT         NaN         São Bartolomeu   Latn
# 590       Por        DGT         NaN           Aldeia Ruiva   Latn
# 129       Por        DGT         NaN                Arzinha   Latn
# 6953      Por        DGT         NaN  Vila Nova de Cerveira   Latn
# 3236      Por        DGT         NaN              Vila Nova   Latn
# 4239      Por        DGT         NaN              Travassos   Latn
# 4463      Por        DGT         NaN                Sarzeda   Latn
# 5482      Por        DGT         NaN                Covilhã   Latn
# 3369      Por        DGT         NaN              São Bento   Latn
#
#                       relatedSpa  relatedS_1  relatedS_2    inferredType
# 2501  CDG200k_populatedPlace2606         NaN         NaN  populatedPlace
# 561    CDG200k_populatedPlace332         NaN         NaN  populatedPlace
# 590    CDG200k_populatedPlace361         NaN         NaN  populatedPlace
# 129    CDG200k_populatedPlace129         NaN         NaN  populatedPlace
# 6953  CDG200k_populatedPlace6726         NaN         NaN  populatedPlace
# 3236  CDG200k_populatedPlace3362         NaN         NaN  populatedPlace
# 4239  CDG200k_populatedPlace4407         NaN         NaN  populatedPlace
# 4463  CDG200k_populatedPlace4131         NaN         NaN  populatedPlace
# 5482  CDG200k_populatedPlace5192         NaN         NaN  populatedPlace
# 3369  CDG200k_populatedPlace3495         NaN         NaN  populatedPlace

# %%
topo200k_file = '../inferences/places/topo_200k.csv'
topo200K_df[['gml_id','text','sourceOfNa']].to_csv(topo200k_file,index=False)

# %% [markdown]
# ### Cruzar com topónimos da base local

# %%
# !pip install recordlinkage
# Out:
# .bash_profile RUN!
# Collecting recordlinkage
#   Downloading recordlinkage-0.16-py3-none-any.whl.metadata (8.1 kB)
# Collecting jellyfish>=1 (from recordlinkage)
#   Downloading jellyfish-1.1.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.6 kB)
# Requirement already satisfied: numpy>=1.13 in /Users/jrc/develop/fauc1537-1919/.venv/lib/python3.11/site-packages (from recordlinkage) (2.1.3)
# Requirement already satisfied: pandas<3,>=1 in /Users/jrc/develop/fauc1537-1919/.venv/lib/python3.11/site-packages (from recordlinkage) (2.2.3)
# Collecting scipy>=1 (from recordlinkage)
#   Downloading scipy-1.14.1-cp311-cp311-macosx_14_0_arm64.whl.metadata (60 kB)
# Collecting scikit-learn>=1 (from recordlinkage)
#   Downloading scikit_learn-1.5.2-cp311-cp311-macosx_12_0_arm64.whl.metadata (13 kB)
# Collecting joblib (from recordlinkage)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jrc/develop/fauc1537-1919/.venv/lib/python3.11/site-packages (from pandas<3,>=1->recordlinkage) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/jrc/develop/fauc1537-1919/.venv/lib/python3.11/site-packages (from pandas<3,>=1->recordlinkage) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/jrc/develop/fauc1537-1919/.venv/lib/python3.11/site-packages (from pandas<3,>=1->recordlinkage) (2024.2)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=1->recordlinkage)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: six>=1.5 in /Users/jrc/develop/fauc1537-1919/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1->recordlinkage) (1.16.0)
# Downloading recordlinkage-0.16-py3-none-any.whl (926 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 926.9/926.9 kB 18.4 MB/s eta 0:00:00
# Downloading jellyfish-1.1.0-cp311-cp311-macosx_11_0_arm64.whl (303 kB)
# Downloading scikit_learn-1.5.2-cp311-cp311-macosx_12_0_arm64.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 19.4 MB/s eta 0:00:00 0:00:01
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading scipy-1.14.1-cp311-cp311-macosx_14_0_arm64.whl (23.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 19.3 MB/s eta 0:00:00a 0:00:01
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, jellyfish, scikit-learn, recordlinkage
# Successfully installed jellyfish-1.1.0 joblib-1.4.2 recordlinkage-0.16 scikit-learn-1.5.2 scipy-1.14.1 threadpoolctl-3.5.0

# %%
import recordlinkage
from recordlinkage.preprocessing import clean

indexer = recordlinkage.index.SortedNeighbourhood('place_name','text',window=11)
candidates = indexer.index(places,topo200K_df)
print(len(candidates))
# Out:
# 52284

# %%
compare = recordlinkage.Compare()
compare.string('place_name','text',
    # ['jaro', 'jarowinkler', 'levenshtein', 'damerau_levenshtein', 'qgram', 'cosine', 'smith_waterman', 'lcs'].
    method='damerau_levenshtein',
    threshold=0.90,
    label='score')
features = compare.compute(candidates,places,topo200K_df)
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 52284 entries, ('Guimarães', np.int64(2792)) to ('Óbidos, Brasil', np.int64(6679))
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   score   52284 non-null  float64
# dtypes: float64(1)
# memory usage: 1.2+ MB

# %% [markdown]
# ### Total de topónimos identificados

# %%
features.sum(axis=1).value_counts().sort_index(ascending=False)
# Out:
# 1.0     3524
# 0.0    48760
# Name: count, dtype: int64

# %% [markdown]
# #### Verificar inferências

# %%
potential_matches = features[features.sum(axis=1) > 0].reset_index()

potential_matches['topo']=topo200K_df.loc[potential_matches['level_1']]['text'].values
potential_matches['topo_id']=topo200K_df.loc[potential_matches['level_1']]['gml_id'].values
potential_matches[potential_matches.value != potential_matches.topo].head(50)
# Out:
#                       value  level_1  score                     topo  \
# 0                Marmeleira     3106    1.0               Marmeleiro
# 1                Souto Covo     4944    1.0               Souto Novo
# 2                Souto Covo     6484    1.0               Souto Novo
# 3          Escalas de Baixo     2187    1.0         Escalos de Baixo
# 4      Aldeia Nossa do Cabo     2494    1.0      Aldeia Nova do Cabo
# 5                 Carvalhos     4039    1.0               Carvalhosa
# 6                 Carvalhos     5352    1.0               Carvalhosa
# 7      Reguengo de Monsaraz      270    1.0    Reguengos de Monsaraz
# 8   Santa Marinha de Zêzere     4941    1.0  Santa Marinha do Zêzere
# 9               Carvalheira     4489    1.0              Carvalheiro
# 10              Carvalheira     4990    1.0              Carvalheiro
# 11               Corredoura     6936    1.0              Corredouras
# 12            Leça de Balio     4590    1.0            Leça do Balio
# 13                Cachoeira     1147    1.0               Cachoeiras
# 14        Alvações de Tanha     4553    1.0        Alvações do Tanha
# 15               Fontainhas     1927    1.0               Fontaínhas
# 16        Granja de Ulmeiro     2955    1.0        Granja do Ulmeiro
# 17         Montemor-O-Velho     2988    1.0         Montemor-o-Velho
# 18            Santo Isidoro     2381    1.0             Santo Isidro
# 19             Vale de Açor     1389    1.0             Vale de Açôr
# 20    Vila Verde de Francos     1333    1.0   Vila Verde dos Francos
# 21       Regueira de Pontes     1536    1.0      Regueiras de Pontes
# 22            Foz da Arouce     2943    1.0            Foz de Arouce
# 23        Nogueira de Cravo     2828    1.0        Nogueira do Cravo
# 24        Nogueira de Cravo     4428    1.0        Nogueira do Cravo
# 25    Salvaterra de Extremo     2195    1.0    Salvaterra do Extremo
# 26       Canas  de Senhorim     3172    1.0        Canas de Senhorim
# 27             Cimo da Vila     4249    1.0             Cimo de Vila
# 28             Cimo da Vila     4522    1.0             Cimo de Vila
# 29             Cimo da Vila     4674    1.0             Cimo de Vila
# 30             Cimo da Vila     4914    1.0             Cimo de Vila
# 31             Cimo da Vila     5172    1.0             Cimo de Vila
# 32             Cimo da Vila     5331    1.0             Cimo de Vila
# 33             Cimo da Vila     5546    1.0             Cimo de Vila
# 34             Cimo da Vila     6361    1.0             Cimo de Vila
# 35       Ferreira de Zêzere     1971    1.0       Ferreira do Zêzere
# 36               Marmaleira     1400    1.0               Marmeleira
# 37               Marmaleira     2857    1.0               Marmeleira
# 38         Montemor- o-Novo      473    1.0          Montemor-o-Novo
# 39         Montemor-e-Velho     2988    1.0         Montemor-o-Velho
# 40        Sabrosa de Aguiar     6356    1.0        Sabroso de Aguiar
# 41           Torres  Vedras     1257    1.0            Torres Vedras
# 42         Viana de Castelo     6196    1.0         Viana do Castelo
# 43      Vila Pouca d'Aguiar     5572    1.0     Vila Pouca de Aguiar
# 44               Tortosendo     2602    1.0               Tortozendo
# 45              Santa Olaia     2778    1.0              Santa Ovaia
# 46             Ponte de Sor     1395    1.0             Ponte de Sôr
# 47                Andorinha     5916    1.0               Andorinhas
# 48              Carragosela     3457    1.0              Carragozela
# 49             Vale da Urra      138    1.0             Vale da Ursa
#
#          topo_id
# 0   PT.GN.115406
# 1   PT.GN.117244
# 2   PT.GN.118784
# 3   PT.GN.114487
# 4   PT.GN.114794
# 5   PT.GN.116339
# 6   PT.GN.117652
# 7   PT.GN.112570
# 8   PT.GN.117241
# 9   PT.GN.116789
# 10  PT.GN.117290
# 11  PT.GN.119236
# 12  PT.GN.116890
# 13  PT.GN.113447
# 14  PT.GN.116853
# 15  PT.GN.114227
# 16  PT.GN.115255
# 17  PT.GN.115288
# 18  PT.GN.114681
# 19  PT.GN.113689
# 20  PT.GN.113633
# 21  PT.GN.113836
# 22  PT.GN.115243
# 23  PT.GN.115128
# 24  PT.GN.116728
# 25  PT.GN.114495
# 26  PT.GN.115472
# 27  PT.GN.116549
# 28  PT.GN.116822
# 29  PT.GN.116974
# 30  PT.GN.117214
# 31  PT.GN.117472
# 32  PT.GN.117631
# 33  PT.GN.117846
# 34  PT.GN.118661
# 35  PT.GN.114271
# 36  PT.GN.113700
# 37  PT.GN.115157
# 38  PT.GN.112773
# 39  PT.GN.115288
# 40  PT.GN.118656
# 41  PT.GN.113557
# 42  PT.GN.118496
# 43  PT.GN.117872
# 44  PT.GN.114902
# 45  PT.GN.115078
# 46  PT.GN.113695
# 47  PT.GN.118216
# 48  PT.GN.115757
# 49  PT.GN.112438

# %% [markdown]
# Check how many not found we can match

# %%
from os.path import exists

not_found_file = '../inferences/places/osm_not_found.csv'

not_found_df: pd.DataFrame = None

if exists(not_found_file):
    not_found_df = pd.read_csv(not_found_file)
    not_found = list(not_found_df['not_found'])
else:
    not_found = []
    not_found_df = pd.DataFrame(columns=['not_found'])

# %%
nfs = not_found_df['not_found'].values
not_found_but_in_topo = potential_matches[potential_matches['value'].isin(nfs)].sort_values(['value','topo'])
not_found_but_in_topo[not_found_but_in_topo['value'] != not_found_but_in_topo['topo']]
# Out:
#                      value  level_1  score                   topo  \
# 4     Aldeia Nossa do Cabo     2494    1.0    Aldeia Nova do Cabo
# 3491            Alperdinha     2438    1.0             Alpedrinha
# 3502             Alvarelos     3056    1.0             Alvarelhos
# 3492            Carrapatos     5660    1.0             Carrapatas
# 3503  Carrazedo de Ansiães     4667    1.0   Carrazeda de Ansiães
# 60            Castre Daire     4459    1.0           Castro Daire
# 3         Escalas de Baixo     2187    1.0       Escalos de Baixo
# 3514    Figueró dos Vinhos     2222    1.0    Figueiró dos Vinhos
# 36              Marmaleira     1400    1.0             Marmeleira
# 37              Marmaleira     2857    1.0             Marmeleira
# 91          Mata dos Lobos      767    1.0         Mata dos Loios
# 3509      Mirando do Douro     5579    1.0       Miranda do Douro
# 3404  Moinho do Almoxarife     2468    1.0   Moinho de Almoxarife
# 3507      Parada do Pinhão     5493    1.0       Parada de Pinhão
# 3481        Proneça-a-Nova     2050    1.0         Proença-a-Nova
# 7     Reguengo de Monsaraz      270    1.0  Reguengos de Monsaraz
# 1               Souto Covo     4944    1.0             Souto Novo
# 2               Souto Covo     6484    1.0             Souto Novo
# 49            Vale da Urra      138    1.0           Vale da Ursa
# 3519            Verdomilho     3929    1.0             Verdemilho
# 3490           Água Nevada     3351    1.0            Água Levada
#
#            topo_id
# 4     PT.GN.114794
# 3491  PT.GN.114738
# 3502  PT.GN.115356
# 3492  PT.GN.117960
# 3503  PT.GN.116967
# 60    PT.GN.116759
# 3     PT.GN.114487
# 3514  PT.GN.114522
# 36    PT.GN.113700
# 37    PT.GN.115157
# 91    PT.GN.113067
# 3509  PT.GN.117879
# 3404  PT.GN.114768
# 3507  PT.GN.117793
# 3481  PT.GN.114350
# 7     PT.GN.112570
# 1     PT.GN.117244
# 2     PT.GN.118784
# 49    PT.GN.112438
# 3519  PT.GN.116229
# 3490  PT.GN.115651
