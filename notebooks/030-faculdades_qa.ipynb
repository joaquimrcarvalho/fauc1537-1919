# %% [markdown]
# **[PT]** Português
#
# ---
#
# **[EN]** English

# %% [markdown]
# # Correção, inferência e normalização do campo "Faculdade"
#
#
# ---
#
#
# # Correction, inference and normalization of the field "Faculdade"

# %% [markdown]
# ## Setup

# %%
from timelink.api.database import TimelinkDatabase
from ucalumni.config import default_db_url

print(f"Creating TimelinkDatabase instance from {default_db_url}")
db = TimelinkDatabase(db_url=default_db_url)
# share with other notebooks
default_db_url
# Out:
# Creating TimelinkDatabase instance from sqlite:///../database/sqlite3/fauc.db?check_same_thread=False
# 'sqlite:///../database/sqlite3/fauc.db?check_same_thread=False'

# %% [markdown]
# ## Notas de processamento
#
# As notas de processamento são criadas pelo algoritmo de extração do valor da Faculdade.
#
# Contém informação sobre inferências, correções automáticas e erros que necessitam de revisão.
#
# Em termos narrativos, o algoritmo verifica primeiro se o campo "Faculdade" tem ou não um valor; depois procede à recolha de todas as referências a faculdades no resto do registo; se ao remover os pré-requisitos da recolha algo permanece, será o valor escolhido como faculdade; se nada permanece, então o valor original é usado; alguns outros casos especiais são testados.
#
#
# ---
#
# ## Processing notes
#
# The processing notes are created to register inferences, corrections and errors that need revision.
#
# In narrative terms, the algorithm checks first if the field “Faculdade” has a value or not; it then proceeds to collect all references to “faculdades” in the rest of the record; if by removing the pre-requisites from the collection something remains, it will the chosen as the corrected or inferred “faculdade”; if nothing remains then the original value is used; some other edge cases are tested.

# %%
from timelink.pandas import entities_with_attribute

notas_proc = entities_with_attribute(
                    the_type='nota-processamento',
                    entity_type='person',
                    show_elements=['name'],
                    more_attributes=['faculdade','faculdade-original','uc-entrada', 'uc-saida','url'],
                    db=db,
                    sql_echo=False)

notas_proc['id'] = notas_proc.index.values
notas_proc.dropna(how='all', axis=1, inplace=True)
notas_proc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25025 entries, 127766 to 357161
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   name                      25025 non-null  object
#  1   nota-processamento.type   25025 non-null  object
#  2   nota-processamento        25025 non-null  object
#  3   nota-processamento.date   25025 non-null  object
#  4   nota-processamento.line   25025 non-null  int64
#  5   nota-processamento.level  25025 non-null  int64
#  6   nota-processamento.obs    25025 non-null  object
#  7   faculdade                 24350 non-null  object
#  8   faculdade.date            24350 non-null  object
#  9   faculdade.obs             24350 non-null  object
#  10  faculdade-original        12243 non-null  object
#  11  faculdade-original.date   12243 non-null  object
#  12  uc-entrada                25025 non-null  object
#  13  uc-entrada.date           25025 non-null  object
#  14  uc-saida                  25025 non-null  object
#  15  uc-saida.date             25025 non-null  object
#  16  url                       25025 non-null  object
#  17  url.date                  25025 non-null  object
#  18  id                        25025 non-null  object
# dtypes: int64(2), object(17)
# memory usage: 3.8+ MB

# %%
df = notas_proc
df['id'] = df.index.values

col = 'nota-processamento' # sub total by this column
df_totals = df.groupby(col).agg({'id':'nunique',
                                                  'uc-entrada':'min',
                                                  'uc-saida':'max'})
df_totals.loc['Total'] = df_totals['id'].sum()

df_totals.sort_values('id',ascending= False).head(30)
# Out:
#                                                        id  ...    uc-saida
# nota-processamento                                         ...
# Total                                               20263  ...       20263
# Aviso: faculdade inferida                           11356  ...  1913-07-11
# Aviso: faculdade corrigida                           6980  ...  1916-07-15
# Faculdade corrigida, combinação incomum               735  ...  1916-07-15
# Erro: não foi possível determinar a faculdade         675  ...  1912-08-02
# Erro: valor não corresponde a Faculdade nesta data    517  ...  1913-08-13
#
# [6 rows x 3 columns]

# %% [markdown]
# ### Faculdade inferida
#
# Casos em que o campo da faculdade não foi preenchido e o algoritmo sugere um valor.
#
# ---
#
# ### "Faculdade" Inferred
#
#
# Cases where the value for faculty was missing and the algoritm suggested a value.

# %%
fac_inf = notas_proc[notas_proc['nota-processamento']=='Aviso: faculdade inferida'].copy()
fac_inf.dropna(how='all', axis=1, inplace=True)
fac_inf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11759 entries, 127775 to 319862
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   name                      11759 non-null  object
#  1   nota-processamento.type   11759 non-null  object
#  2   nota-processamento        11759 non-null  object
#  3   nota-processamento.date   11759 non-null  object
#  4   nota-processamento.line   11759 non-null  int64
#  5   nota-processamento.level  11759 non-null  int64
#  6   nota-processamento.obs    11759 non-null  object
#  7   faculdade                 11759 non-null  object
#  8   faculdade.date            11759 non-null  object
#  9   faculdade.obs             11759 non-null  object
#  10  uc-entrada                11759 non-null  object
#  11  uc-entrada.date           11759 non-null  object
#  12  uc-saida                  11759 non-null  object
#  13  uc-saida.date             11759 non-null  object
#  14  url                       11759 non-null  object
#  15  url.date                  11759 non-null  object
#  16  id                        11759 non-null  object
# dtypes: int64(2), object(15)
# memory usage: 1.6+ MB

# %%
df = fac_inf
col = 'faculdade' # subotal by this column
df_totals = df.groupby(col).agg({'id':'nunique',
                                                  'uc-entrada':'min',
                                                  'uc-saida':'max'})
print("List of inferred 'faculdade'")
df_totals.sort_values('id',ascending= False).head(30)
# Out:
# List of inferred 'faculdade'
#                                       id  uc-entrada    uc-saida
# faculdade
# Cursos jurídicos (Cânones ou Leis)  6993  0000-00-00  1829-03-28
# Artes                               3005  0000-00-00  1780-07-18
# Cânones                              764  0000-00-00  1827-06-20
# Leis                                 386  0000-00-00  1828-07-01
# Teologia                             352  0000-00-00  1884-05-26
# Medicina                             185  0000-00-00  1883-10-15
# Filosofia                             28  1770-10-01  1913-07-11
# Matemática                            24  1605-10-07  1913-07-11
# Direito                               22  1836-10-14  1898-12-18

# %% [markdown]
# ### Faculdade corrigida
#
# Casos em que o campo da faculdade estava preenchido mas era inconsistente com o resto da informação.
#
# A maior parte dos casos dizem respeito a duplo percursos em Leis e Cânones e mudanças, depois de 1772,
# de faculdades de Matemática e Filosofia, que eram pre-requisitos, para as faculdades de posterior
# matrículas (Leis, Cânones, Medicina, Teologia).
#
# ---
#
# ### "Faculdade" corrected
#
# Cases where the algoritm changed the value of the field, because it was inconsistent with
# the rest of information on the record. Mostly double degres in Canon and Civil law, and
# changes from pre-requisite faculty to final graduation faculty.

# %%
fac_corr = notas_proc[notas_proc['nota-processamento']=='Aviso: faculdade corrigida'].copy()
fac_corr.dropna(how='all', axis=1, inplace=True)

# %%
import pandas as pd

df = fac_corr
col = 'nota-processamento.obs' # subotal by this column
df_totals = df.groupby(col).agg({'id':'nunique',
                                        'uc-entrada':'min',
                                        'uc-saida':'max'})
total = df_totals['id'].sum()
print("List of corrected 'faculdade'")
print("Total:",total)
df_totals['perc'] = df_totals['id']/total
pd.set_option('display.max_rows',1000)
df_totals.sort_values('id',ascending=False, inplace=True)
df_totals.head(10)
# Out:
# List of corrected 'faculdade'
# Total: 6980
#                                    id  uc-entrada    uc-saida      perc
# nota-processamento.obs
# Cânones para Cânones,Leis.       1254  1536-10-00  1821-11-12  0.179656
# Leis para Cânones,Leis.          1246  1537-00-00  1829-06-13  0.178510
# Matemática para Medicina.        1175  1772-11-28  1909-11-11  0.168338
# Direito para Leis.               1023  1687-01-05  1827-06-16  0.146562
# Filosofia para Medicina.          480  1540-10-25  1909-11-09  0.068768
# Teologia para Direito,Teologia.   232  1830-10-11  1915-10-22  0.033238
# Medicina para Cânones,Medicina.   208  1569-11-20  1778-10-20  0.029799
# Direito para Cânones.             194  1566-10-07  1835-07-20  0.027794
# Cânones para Cânones,Teologia.    166  0000-00-00  1829-05-26  0.023782
# Teologia para Cânones,Teologia.   164  1540-10-03  1822-10-31  0.023496

# %%
fac_corr_nodup = fac_corr.drop_duplicates(subset=['id', 'faculdade-original'], keep='first')

# %%
show_only = 5
for  change,row in list(df_totals.iterrows())[:10]:
    print(f"{change}: {row.id}")
    for _ndx, row in fac_corr_nodup[fac_corr_nodup['nota-processamento.obs']==change][['id','name','url','uc-entrada']].head(show_only).iterrows():
        url = row.url.strip('"')
        print(f"     {row.id:6} {row['name']} {row['uc-entrada']} {url}")
# Out:
# Cânones para Cânones,Leis.: 1254
#      127766 António Lopes Cabaço 1617-12-04 https://pesquisa.auc.uc.pt/details?id=127766
#      127769 José Cabaço 1743-10-01 https://pesquisa.auc.uc.pt/details?id=127769
#      127793 Miguel de Cabedo 1558-01-08 https://pesquisa.auc.uc.pt/details?id=127793
#      128387 João Leite Cabral 1731-10-01 https://pesquisa.auc.uc.pt/details?id=128387
#      128663 Francisco  de Caceres 1642-10-22 https://pesquisa.auc.uc.pt/details?id=128663
# Leis para Cânones,Leis.: 1246
#      127790 Jorge de Cabedo 1565-10-01 https://pesquisa.auc.uc.pt/details?id=127790
#      128146 Domingos de Figueiredo Cabral 1682-10-01 https://pesquisa.auc.uc.pt/details?id=128146
#      128242 Francisco Xavier da Silva Cabral 1776-10-29 https://pesquisa.auc.uc.pt/details?id=128242
#      128247 Gaspar Cabral 1639-10-17 https://pesquisa.auc.uc.pt/details?id=128247
#      128251 Gaspar Lopes Cabral 1642-10-25 https://pesquisa.auc.uc.pt/details?id=128251
# Matemática para Medicina.: 1175
#      127807 Manuel Joaquim do Cabo 1779-11-12 https://pesquisa.auc.uc.pt/details?id=127807
#      128094 António Policarpo Cabral 1814-10-24 https://pesquisa.auc.uc.pt/details?id=128094
#      128160 Filomeno da Câmara Melo Cabral 1862-06-01 https://pesquisa.auc.uc.pt/details?id=128160
#      129131 Eugénio Pereira de Castro Caldas 1890-10-16 https://pesquisa.auc.uc.pt/details?id=129131
#      129162 Manuel José de Brito Caldas 1821-11-05 https://pesquisa.auc.uc.pt/details?id=129162
# Direito para Leis.: 1023
#      128433 Joaquim de Azevedo Cabral 1792-10-10 https://pesquisa.auc.uc.pt/details?id=128433
#      128464 António Paulo Delgado Cacela 1779-10-19 https://pesquisa.auc.uc.pt/details?id=128464
#      128482 José Joaquim Nunes Cacela 1780-11-07 https://pesquisa.auc.uc.pt/details?id=128482
#      128544 Manuel José Delgado Cacela 1773-10-07 https://pesquisa.auc.uc.pt/details?id=128544
#      128909 Manuel Correia Pinto da Veiga Cabral 1793-10-02 https://pesquisa.auc.uc.pt/details?id=128909
# Filosofia para Medicina.: 480
#      127767 Domingos António Cabaço 1789-10-30 https://pesquisa.auc.uc.pt/details?id=127767
#      128060 António José da Silva Cabral 1884-06-14 https://pesquisa.auc.uc.pt/details?id=128060
#      128857 Luís de Sousa Faria e Melo Cabral 1882-10-14 https://pesquisa.auc.uc.pt/details?id=128857
#      129138 Francisco Manuel de Brito Caldas 1789-10-07 https://pesquisa.auc.uc.pt/details?id=129138
#      129282 António José Marques Caldeira 1712-10-16 https://pesquisa.auc.uc.pt/details?id=129282
# Teologia para Direito,Teologia.: 232
#      127806 Manuel António do Cabo 1862-10-18 https://pesquisa.auc.uc.pt/details?id=127806
#      128340 Jacinto da Costa de Vasconcelos Coutinho Cabral 1872-10-15 https://pesquisa.auc.uc.pt/details?id=128340
#      129094 Braúlio Lauro Pereira da Silva Caldas 1883-10-02 https://pesquisa.auc.uc.pt/details?id=129094
#      130167 Domingos José Fernandes de Campos 1898-10-13 https://pesquisa.auc.uc.pt/details?id=130167
#      131329 Manuel Fernandes da Silva Campos 1877-10-02 https://pesquisa.auc.uc.pt/details?id=131329
# Medicina para Cânones,Medicina.: 208
#      128316 João Martins Cabrita 1765-10-01 https://pesquisa.auc.uc.pt/details?id=128316
#      129652 Manuel Cordeiro Calhau 1741-11-15 https://pesquisa.auc.uc.pt/details?id=129652
#      130261 Francisco Manuel de Campos 1760-01-16 https://pesquisa.auc.uc.pt/details?id=130261
#      132055 Alberto Carneiro de Figueiredo 1741-10-26 https://pesquisa.auc.uc.pt/details?id=132055
#      133482 António Joaquim Delgado 1763-10-01 https://pesquisa.auc.uc.pt/details?id=133482
# Direito para Cânones.: 194
#      131274 João Batista Teixeira de Sousa Camelo 1824-10-06 https://pesquisa.auc.uc.pt/details?id=131274
#      131403 Pedro Baltasar de Campos 1812-10-23 https://pesquisa.auc.uc.pt/details?id=131403
#      131498 José Maria Pinto da Silva Camelo 1783-10-27 https://pesquisa.auc.uc.pt/details?id=131498
#      132700 Francisco de Moura Coutinho de Queirós 1776-10-00 https://pesquisa.auc.uc.pt/details?id=132700
#      132969 António Rodrigues Cardoso 1813-10-20 https://pesquisa.auc.uc.pt/details?id=132969
# Cânones para Cânones,Teologia.: 166
#      129393 Francisco de Almeida Caiado 1764-10-01 https://pesquisa.auc.uc.pt/details?id=129393
#      130383 Manuel Ferreira 1754-10-01 https://pesquisa.auc.uc.pt/details?id=130383
#      131315 Manuel de Campos 1675-03-25 https://pesquisa.auc.uc.pt/details?id=131315
#      131489 José Gaudêncio de Figueiredo Camelo 1767-10-01 https://pesquisa.auc.uc.pt/details?id=131489
#      131495 José da Glória Camelo 1737-10-01 https://pesquisa.auc.uc.pt/details?id=131495
# Teologia para Cânones,Teologia.: 164
#      128782 Joaquim Pereira Cacheta 1745-10-01 https://pesquisa.auc.uc.pt/details?id=128782
#      129330 Manuel Caetano 1761-10-01 https://pesquisa.auc.uc.pt/details?id=129330
#      130127 João Gonçalves da Câmara 1615-11-13 https://pesquisa.auc.uc.pt/details?id=130127
#      131868 António Cabral de Quadros 1695-10-01 https://pesquisa.auc.uc.pt/details?id=131868
#      132851 António da Graça Cardoso 1706-10-01 https://pesquisa.auc.uc.pt/details?id=132851

# %% [markdown]
# ### "Valor não corresponde a Faculdade nesta data"
#
# Esta lista é produzida pela comparação do valor do campo de faculdade, ou outra referência a faculdade no registo, e a lista das faculdades existentes à data do registo.
#
# Para além dos erros de ortografia e gralhas (atenção a "Cãnones" com til), também contém:
#
# * Uma grande quantidade (>300) de campos de Faculdade com "?". Verificar se é porque falta informação na ficha, ou se existe outra explicação
# * valores confundidos com Faculdade por particularidades da pontuação do registo. Nesse caso a correção a fazer pode ser na pontuação.
#    Ver por exemplo: 152975 a falta de ":" a seguir a matrícula provoca um erro no processamento da Faculdade
# * valor que correspondem a faculdades que existiram, mas não naquelas datas (por exemplo Filosofia antes de 1772 ou Cânones depois de 1834).
# * Topónimos, que serão erros de digitação que se poderão corrigir vendo a ficha original.
#
# ---
#
# ### Value does not correspond to a "Faculdade" at the time
#
# This list is produced by comparing the value of the faculty field, or other reference to faculties in the record, and the list of faculties existing at the date of the record.
#
# Apart from spelling errors and typos (watch out for tilted "Cãnones"), it also contains:
#
# * A large amount (>300) of Faculty fields with "?". Check if this is because the information is missing in the original card, or if there is another explanation.
# * Values confused with Faculty due to particularities of the register punctuation. In this case, the correction to be made may be in the punctuation.
#    See for example: 152975 the lack of ":" after the enrolment causes an error in the processing of the Faculty
# * value corresponding to faculties that existed but not on those dates (e.g. Philosophy before 1772 or "Cânones" after 1834).
# * Toponyms, which are typing errors that can be corrected by looking at the original form.

# %%
fac_error = notas_proc[notas_proc['nota-processamento']=='Erro: valor não corresponde a Faculdade nesta data'].copy()
fac_error.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 519 entries, 130413 to 317873
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     519 non-null    object
#  1   sex                      519 non-null    object
#  2   nota-processamento       519 non-null    object
#  3   nota-processamento.date  519 non-null    object
#  4   nota-processamento.obs   519 non-null    object
#  5   faculdade                519 non-null    object
#  6   faculdade.date           519 non-null    object
#  7   faculdade.obs            519 non-null    object
#  8   faculdade-original       206 non-null    object
#  9   faculdade-original.date  206 non-null    object
#  10  uc-entrada               519 non-null    object
#  11  uc-entrada.date          519 non-null    object
#  12  uc-saida                 519 non-null    object
#  13  uc-saida.date            519 non-null    object
#  14  url                      519 non-null    object
#  15  url.date                 519 non-null    object
#  16  id                       519 non-null    object
# dtypes: object(17)
# memory usage: 73.0+ KB

# %%
# currently the algorithm removed question marks, but they were there
# we have to put them back until this is fixed
fac_org_none = fac_error['faculdade-original'].isnull()
fac_error.loc[fac_org_none,'faculdade-original'] = '?'

# %%
df = fac_error
col = 'faculdade-original' # subotal by this column
df_totals = df.groupby(col).agg({'id':'nunique',
                                                  'uc-entrada':'min',
                                                  'uc-saida':'max'})

df_totals.sort_values('id',ascending= False).head(30)
# Out:
#                       id  uc-entrada    uc-saida
# faculdade-original
# ?                    313  0000-00-00  1771-01-01
# Leis                  23  1827-10-13  1909-08-03
# Cânones               22  1825-10-24  1913-08-13
# Cãnones               21  1617-11-29  1769-07-10
# Medecina              18  1654-10-15  1858-10-12
# .                     13  1604-10-17  1732-11-10
# Intituta               8  1581-03-12  1770-10-01
# Instituto              7  1694-12-15  1818-10-24
# Medicna                5  1590-10-08  1735-05-08
# Dialética              4  1540-03-09  1542-03-06
# Institua               4  1642-10-28  1733-10-01
# Telogia                4  1690-10-01  1882-06-10
# Lisboa                 4  0000-00-00  1748-06-06
# Coimbra                3  1576-06-13  1853-05-27
# Estado Eclesiástico    3  1846-11-11  1865-10-11
# Cânone                 3  1650-12-01  1770-05-30
# Direiro                3  1817-11-08  1884-06-03
# Teolgia                3  1597-10-03  1899-07-08
# Mataematica            2  1822-10-04  1893-10-14
# Mediicna               2  1690-10-01  1754-07-05
# Porto                  2  0000-00-00  1878-10-02
# Teorico                2  1540-03-07  1549-07-00
# Teórico                2  1540-02-20  1540-10-17
# Farmácia               2  1903-01-14  1904-10-12
# Évora                  2  1705-03-04  1757-10-01
# Dreito                 2  1825-10-29  1898-07-15
# Dirieito               2  1817-11-06  1889-07-19
# Direto                 2  1837-10-18  1910-08-02
# Canonês                2  1718-10-01  1743-10-01
# Tentugal               1  1749-10-01  1750-10-01

# %%
import pandas as pd
import csv

pd.set_option('display.max_rows',600)
exportar = fac_error[['faculdade','name','faculdade.date']].sort_values(['faculdade','name','faculdade.date'])
exportar.to_csv('../inferences/validation/faculdade-unkown.csv',sep=',')
exportar.head(10)
# Out:
#        faculdade               name faculdade.date
# id
# 192086       (')  António Rodrigues     1626-10-29
# 146645       (.)    António Antunes     1656-10-20
# 140542       (.)   António de Abreu     1661-10-26
# 165702       (.)     Manuel Ribeiro     1604-10-17
# 165556       (.)     Manuel Ribeiro     1612-03-23
# 165558       (.)     Manuel Ribeiro     1617-04-09
# 165781       (.)     Manuel Ribeiro     1657-10-15
# 165804       (.)     Manuel Ribeiro     1659-12-12
# 165730       (.)     Manuel Ribeiro     1683-03-24
# 165828       (.)     Manuel Ribeiro     1689-11-24

# %% [markdown]
# ### "Faculdades" com menos de 100 ocorrências.
#
# ---
#
#
# ### "Faculdades" with less than 100 stduents

# %%
from timelinknb.pandas import attribute_values


facs = attribute_values('faculdade',dates_between=('1500-00-00','1990-00-00'))
facs[facs['count']<100]
# Out:
#                           count     date_in    date_max
# value
# (Leis)                       33  1819-10-16  1906-10-02
# (Cânones)                    32  1822-10-15  1909-10-02
# (Cãnones)                    24  1572-10-01  1769-05-16
# (Medecina)                   19  1654-10-15  1858-10-12
# (.)                          16  1604-10-17  1738-12-01
# código                       12  1540-00-00  1540-12-16
# (Intituta)                    8  1581-03-12  1770-10-01
# (Instituto)                   7  1694-12-15  1818-10-24
# (Medicna)                     7  1573-10-03  1745-10-01
# (Telogia)                     7  1573-10-01  1877-10-16
# (Dialética)                   5  1540-03-09  1540-10-25
# (Coimbra)                     4  1569-11-20  1848-10-03
# (Institua)                    4  1642-10-28  1733-10-01
# (Cânone)                      3  1650-12-01  1761-10-29
# (Direiro)                     3  1817-11-08  1879-10-02
# (Estado Eclesiástico)         3  1846-11-11  1865-10-11
# (Teolgia)                     3  1597-10-03  1894-10-29
# (Canonês)                     2  1718-10-01  1743-10-01
# (Canônes)                     2  1576-10-01  1733-06-03
# (Direto)                      2  1837-10-18  1907-07-13
# (Dirieito)                    2  1817-11-06  1885-10-15
# (Dreito)                      2  1825-10-29  1893-10-24
# (Farmácia)                    2  1903-01-14  1904-10-12
# (Filosfia)                    2  1838-10-15  1880-06-08
# (Lisboa)                      2  1715-10-01  1741-10-01
# (Mataematica)                 2  1822-10-04  1893-10-14
# (Mediicna)                    2  1690-10-01  1754-07-05
# (Teorico)                     2  1540-03-07  1540-10-07
# (Teórico)                     2  1540-02-20  1540-10-17
# (Évora)                       2  1705-03-04  1754-10-01
# (')                           1  1626-10-29  1626-10-29
# (1630-10-02)                  1  1630-10-02  1630-10-02
# (1767-10-01)                  1  1767-10-01  1767-10-01
# (Basto)                       1  1738-10-01  1738-10-01
# (Cantanhede)                  1  1585-10-01  1585-10-01
# (Codigo)                      1  1540-12-02  1540-12-02
# (Conônes)                     1  1610-10-07  1610-10-07
# (Cânanes)                     1  1721-10-01  1721-10-01
# (Cânoes)                      1  1765-06-01  1765-06-01
# (Dieito)                      1  1868-10-15  1868-10-15
# (Dioreito)                    1  1807-10-12  1807-10-12
# (Direio)                      1  1814-10-31  1814-10-31
# (Direita)                     1  1902-10-04  1902-10-04
# (Eclesiástico)                1  1871-10-14  1871-10-14
# (Estado Elcesiástico)         1  1852-10-15  1852-10-15
# (Filosogia)                   1  1779-11-06  1779-11-06
# (Fiosofia)                    1  1789-10-06  1789-10-06
# (Graduação)                   1  1752-10-01  1752-10-01
# (Granática)                   1  1540-02-06  1540-02-06
# (Insituta)                    1  1598-10-27  1598-10-27
# (Instituto Eclesiástico)      1  1848-10-06  1848-10-06
# (Instiuta)                    1  1653-11-04  1653-11-04
# (Matecamtica)                 1  1869-10-13  1869-10-13
# (Matemataica)                 1  1796-10-05  1796-10-05
# (Matematíca)                  1  1868-10-05  1868-10-05
# (Matemtática)                 1  1872-10-15  1872-10-15
# (Matemátca)                   1  1815-10-14  1815-10-14
# (Matemátiica)                 1  1797-10-05  1797-10-05
# (Matrículas12.10.1629)        1  1629-10-12  1629-10-12
# (Medicína)                    1  1731-10-01  1731-10-01
# (Monsanto)                    1  1690-10-01  1690-10-01
# (Moura)                       1  1732-12-01  1732-12-01
# (Porto)                       1  1878-10-02  1878-10-02
# (Seia)                        1  1863-10-09  1863-10-09
# (Serpa)                       1  1721-05-14  1721-05-14
# (Teaologia)                   1  1847-10-08  1847-10-08
# (Tentativa)                   1  1765-10-01  1765-10-01
# (Tentugal)                    1  1749-10-01  1749-10-01
# (Teolggia)                    1  1804-10-20  1804-10-20
# (Teologi)                     1  1700-11-01  1700-11-01
# (Teóricos)                    1  1540-10-06  1540-10-06
# (de)                          1  1730-03-24  1730-03-24
# (´)                           1  1654-03-18  1654-03-18

# %%
facs_errors = facs[facs['count']<100]
show_only = 10
for f,row in facs_errors.sort_values('count',ascending=False).iterrows():
        print()
        print(f)
        students = attribute_to_df('faculdade',the_value=f,person_info=True)
        for id, aluno in students.head(show_only).iterrows():
                id_link = f'<a href="https://pesquisa.auc.uc.pt/details?id={id}">{id}</a>'
                # display(HTML(f'<code>{row.the_value:24} [{id_link:5}] {aluno.the_date} {aluno.name:44}</code>'))
                print(f"{aluno['faculdade']:24} [{id:5}] {aluno['faculdade.date']} {aluno['name']:44} https://pesquisa.auc.uc.pt/details?id={id} {aluno['faculdade.obs']}")
# Out:
# (Leis)
# (Leis)                   [188758] 1819-10-16 Manuel Joaquim de Sousa Brito                https://pesquisa.auc.uc.pt/details?id=188758 Faculdade corrigida
# (Leis)                   [215793] 1822-10-08 António Pedro Mousinho Leote                 https://pesquisa.auc.uc.pt/details?id=215793 Faculdade corrigida
# (Leis)                   [141618] 1823-10-07 Miguel Luís Henriques de Aguiar              https://pesquisa.auc.uc.pt/details?id=141618 Faculdade corrigida
# (Leis)                   [210323] 1824-10-30 Francisco de Meireles Leite                  https://pesquisa.auc.uc.pt/details?id=210323 Faculdade corrigida
# (Leis)                   [128134] 1825-10-14 Constantino António do Vale Pereira Cabral   https://pesquisa.auc.uc.pt/details?id=128134 Faculdade corrigida
# (Leis)                   [167725] 1825-10-31 Justino António de Freitas                   https://pesquisa.auc.uc.pt/details?id=167725 Faculdade corrigida
# (Leis)                   [145767] 1826-10-14 Henriques Teles da Silva Amorim              https://pesquisa.auc.uc.pt/details?id=145767 Faculdade corrigida
# (Leis)                   [237942] 1827-10-13 Heitor Pereira de Barbedo e Sousa            https://pesquisa.auc.uc.pt/details?id=237942
# (Leis)                   [308159] 1830-06-11 Francisco António da Silva Pinto             https://pesquisa.auc.uc.pt/details?id=308159
# (Leis)                   [296707] 1830-07-12 Bento Lobão Morais Castro Sarmento           https://pesquisa.auc.uc.pt/details?id=296707
#
# (Cânones)
# (Cânones)                [177589] 1822-10-15 Francisco Ferreira Gaspar                    https://pesquisa.auc.uc.pt/details?id=177589 Faculdade corrigida
# (Cânones)                [237083] 1822-10-15 José Narciso da Mota                         https://pesquisa.auc.uc.pt/details?id=237083 Faculdade corrigida
# (Cânones)                [247707] 1823-10-04 José Lourenço Pinto                          https://pesquisa.auc.uc.pt/details?id=247707 Faculdade corrigida
# (Cânones)                [145263] 1823-10-30 Cândido Maximiano de Melo e Alvim            https://pesquisa.auc.uc.pt/details?id=145263 Faculdade corrigida
# (Cânones)                [149500] 1824-10-15 José Teixeira de Azevedo                     https://pesquisa.auc.uc.pt/details?id=149500 Faculdade corrigida
# (Cânones)                [295708] 1825-10-24 Herculano Aprigio Alvares Araújo Santa Bárbara https://pesquisa.auc.uc.pt/details?id=295708
# (Cânones)                [209058] 1825-10-31 António Joaquim Nunes de Vasconcelos         https://pesquisa.auc.uc.pt/details?id=209058 Faculdade corrigida
# (Cânones)                [296843] 1830-07-13 Rafael Maria Sarmento                        https://pesquisa.auc.uc.pt/details?id=296843
# (Cânones)                [310916] 1831-07-08 João Inácio Barreto da Gama e Sousa          https://pesquisa.auc.uc.pt/details?id=310916
# (Cânones)                [317873] 1835-06-06 Manuel José de Amorim Viana                  https://pesquisa.auc.uc.pt/details?id=317873
#
# (Cãnones)
# (Cãnones)                [171325] 1572-10-01 Afonso de Matos                              https://pesquisa.auc.uc.pt/details?id=171325 Faculdade corrigida
# (Cãnones)                [135301] 1577-10-02 Gaspar de Figueiredo                         https://pesquisa.auc.uc.pt/details?id=135301 Faculdade corrigida
# (Cãnones)                [167325] 1617-11-29 Gaspar de Freitas                            https://pesquisa.auc.uc.pt/details?id=167325
# (Cãnones)                [242277] 1626-10-06 Estevão Lopes                                https://pesquisa.auc.uc.pt/details?id=242277 Faculdade corrigida
# (Cãnones)                [171324] 1626-10-17 Afonso de Matos                              https://pesquisa.auc.uc.pt/details?id=171324
# (Cãnones)                [170668] 1626-10-20 António Mascarenhas                          https://pesquisa.auc.uc.pt/details?id=170668
# (Cãnones)                [170667] 1651-11-21 António Mascarenhas                          https://pesquisa.auc.uc.pt/details?id=170667
# (Cãnones)                [164493] 1660-10-18 Bartolomeu Freire                            https://pesquisa.auc.uc.pt/details?id=164493
# (Cãnones)                [133017] 1663-10-22 Francisco Quintanilha                        https://pesquisa.auc.uc.pt/details?id=133017
# (Cãnones)                [172506] 1670-10-13 Francisco Soares Galhardo                    https://pesquisa.auc.uc.pt/details?id=172506
#
# (Medecina)
# (Medecina)               [242599] 1654-10-15 Francisco de Mesquita                        https://pesquisa.auc.uc.pt/details?id=242599
# (Medecina)               [241070] 1661-06-25 Domingos Gomes Merim                         https://pesquisa.auc.uc.pt/details?id=241070
# (Medecina)               [241122] 1674-10-01 Domingos Gomes Merim                         https://pesquisa.auc.uc.pt/details?id=241122
# (Medecina)               [175650] 1677-04-03 Henrique da Costa de Oliveira                https://pesquisa.auc.uc.pt/details?id=175650
# (Medecina)               [175643] 1681-10-01 Gonçalo Dias de Oliveira                     https://pesquisa.auc.uc.pt/details?id=175643
# (Medecina)               [176054] 1685-03-13 José Machado de Oliveira                     https://pesquisa.auc.uc.pt/details?id=176054
# (Medecina)               [241214] 1685-10-01 António de  Mesquita                         https://pesquisa.auc.uc.pt/details?id=241214
# (Medecina)               [176541] 1689-10-01 Salvador de Oliveira                         https://pesquisa.auc.uc.pt/details?id=176541
# (Medecina)               [175592] 1691-10-01 Francisco Martins de Oliveira                https://pesquisa.auc.uc.pt/details?id=175592
# (Medecina)               [176313] 1691-10-01 Manuel Gomes de Oliveira                     https://pesquisa.auc.uc.pt/details?id=176313
#
# (.)
# (.)                      [165702] 1604-10-17 Manuel Ribeiro                               https://pesquisa.auc.uc.pt/details?id=165702
# (.)                      [165556] 1612-03-23 Manuel Ribeiro                               https://pesquisa.auc.uc.pt/details?id=165556
# (.)                      [165558] 1617-04-09 Manuel Ribeiro                               https://pesquisa.auc.uc.pt/details?id=165558
# (.)                      [165694] 1633-10-15 Manuel Ribeiro                               https://pesquisa.auc.uc.pt/details?id=165694 Faculdade corrigida
# (.)                      [146645] 1656-10-20 António Antunes                              https://pesquisa.auc.uc.pt/details?id=146645
# (.)                      [165781] 1657-10-15 Manuel Ribeiro                               https://pesquisa.auc.uc.pt/details?id=165781
# (.)                      [165753] 1658-10-01 Manuel Ribeiro                               https://pesquisa.auc.uc.pt/details?id=165753 Faculdade corrigida
# (.)                      [165804] 1659-12-12 Manuel Ribeiro                               https://pesquisa.auc.uc.pt/details?id=165804
# (.)                      [140542] 1661-10-26 António de Abreu                             https://pesquisa.auc.uc.pt/details?id=140542
# (.)                      [145856] 1676-01-01 Pedro de Amorim                              https://pesquisa.auc.uc.pt/details?id=145856
#
# código
# código                   [128154] 1540-00-00 Fernão Cabral                                https://pesquisa.auc.uc.pt/details?id=128154 Código
# código                   [237346] 1540-00-00 Manuel Pereira                               https://pesquisa.auc.uc.pt/details?id=237346 Código
# código                   [224300] 1540-01-10 Álvaro da Silva                              https://pesquisa.auc.uc.pt/details?id=224300 Código
# código                   [224561] 1540-01-10 António da Silva                             https://pesquisa.auc.uc.pt/details?id=224561 Código
# código                   [185586] 1540-02-16 Manuel Betalhado                             https://pesquisa.auc.uc.pt/details?id=185586 Código
# código                   [129025] 1540-09-03 Sebastião Velho Cabral                       https://pesquisa.auc.uc.pt/details?id=129025 Código
# código                   [177320] 1540-10-20 João Garcez                                  https://pesquisa.auc.uc.pt/details?id=177320 Código
# código                   [190446] 1540-10-21 Belchior Homem                               https://pesquisa.auc.uc.pt/details?id=190446 Código
# código                   [193963] 1540-11-07 João Coelho                                  https://pesquisa.auc.uc.pt/details?id=193963 Código
# código                   [235155] 1540-11-16 Gonçalo Pereira                              https://pesquisa.auc.uc.pt/details?id=235155 Código
#
# (Intituta)
# (Intituta)               [189148] 1581-03-12 Gaspar Castanheira                           https://pesquisa.auc.uc.pt/details?id=189148
# (Intituta)               [155550] 1613-11-04 João  Rodrigues da Fonseca                   https://pesquisa.auc.uc.pt/details?id=155550
# (Intituta)               [138995] 1665-10-22 Sebastião de  Figueiredo                     https://pesquisa.auc.uc.pt/details?id=138995
# (Intituta)               [138895] 1682-10-30 Pedro de Figueiredo                          https://pesquisa.auc.uc.pt/details?id=138895
# (Intituta)               [202881] 1695-10-01 Domingos Rodrigues Leitão                    https://pesquisa.auc.uc.pt/details?id=202881
# (Intituta)               [138151] 1751-10-01 Veríssimo Aires de Figueiredo                https://pesquisa.auc.uc.pt/details?id=138151
# (Intituta)               [176905] 1765-10-01 Jerónimo Luís Faisco Ortigão                 https://pesquisa.auc.uc.pt/details?id=176905
# (Intituta)               [172587] 1770-10-01 Manuel António de Bolhão Novais              https://pesquisa.auc.uc.pt/details?id=172587
#
# (Instituto)
# (Instituto)              [159782] 1694-12-15 Pedro Correia da Fonseca                     https://pesquisa.auc.uc.pt/details?id=159782
# (Instituto)              [165081] 1724-10-01 José Godinho Freire                          https://pesquisa.auc.uc.pt/details?id=165081
# (Instituto)              [157976] 1725-10-01 Manuel da Fonseca                            https://pesquisa.auc.uc.pt/details?id=157976
# (Instituto)              [153436] 1726-10-01 Francisco Osório da Fonseca                  https://pesquisa.auc.uc.pt/details?id=153436
# (Instituto)              [214163] 1750-01-01 Lourenço de Lemos                            https://pesquisa.auc.uc.pt/details?id=214163
# (Instituto)              [211035] 1764-10-01 José Pereira da Cunha Leite                  https://pesquisa.auc.uc.pt/details?id=211035
# (Instituto)              [168030] 1818-10-24 Gabriel Martins                              https://pesquisa.auc.uc.pt/details?id=168030
#
# (Medicna)
# (Medicna)                [247305] 1573-10-03 João Lopes                                   https://pesquisa.auc.uc.pt/details?id=247305 Faculdade corrigida
# (Medicna)                [204856] 1590-10-08 Domingos Cota                                https://pesquisa.auc.uc.pt/details?id=204856
# (Medicna)                [158903] 1629-10-15 Manuel de Carvalhosa                         https://pesquisa.auc.uc.pt/details?id=158903
# (Medicna)                [252579] 1633-10-21 Domingos Fernandes Monteiro                  https://pesquisa.auc.uc.pt/details?id=252579
# (Medicna)                [201357] 1705-10-23 Gabriel Rodrigues Ledesma                    https://pesquisa.auc.uc.pt/details?id=201357
# (Medicna)                [201361] 1730-10-01 Gaspar da Silva Ledesma                      https://pesquisa.auc.uc.pt/details?id=201361
# (Medicna)                [204848] 1745-10-01 António de Sousa Cota                        https://pesquisa.auc.uc.pt/details?id=204848 Faculdade corrigida
#
# (Telogia)
# (Telogia)                [132149] 1573-10-01 António de Figueiredo                        https://pesquisa.auc.uc.pt/details?id=132149 Faculdade corrigida
# (Telogia)                [187719] 1664-10-01 Manuel Fernandes da Rocha                    https://pesquisa.auc.uc.pt/details?id=187719 Faculdade corrigida
# (Telogia)                [206007] 1690-10-01 José Coutinho                                https://pesquisa.auc.uc.pt/details?id=206007
# (Telogia)                [168762] 1703-10-01 Onofre Ribeiro                               https://pesquisa.auc.uc.pt/details?id=168762
# (Telogia)                [195492] 1788-10-08 António da Conceição                         https://pesquisa.auc.uc.pt/details?id=195492 Faculdade corrigida
# (Telogia)                [222536] 1824-10-06 Joaquim da Paixão                            https://pesquisa.auc.uc.pt/details?id=222536
# (Telogia)                [230302] 1877-10-16 António Augusto de Almeida Silvano           https://pesquisa.auc.uc.pt/details?id=230302
#
# (Dialética)
# (Dialética)              [190809] 1540-03-09 Henrique de Castro                           https://pesquisa.auc.uc.pt/details?id=190809
# (Dialética)              [138189] 1540-10-12 João Figueiró                                https://pesquisa.auc.uc.pt/details?id=138189
# (Dialética)              [223999] 1540-10-15 André Pedroso                                https://pesquisa.auc.uc.pt/details?id=223999
# (Dialética)              [254161] 1540-10-19 Francisco Luís                               https://pesquisa.auc.uc.pt/details?id=254161
# (Dialética)              [129027] 1540-10-25 Simão Cabral                                 https://pesquisa.auc.uc.pt/details?id=129027 Faculdade corrigida
#
# (Institua)
# (Institua)               [162284] 1642-10-28 Mateus Dias                                  https://pesquisa.auc.uc.pt/details?id=162284
# (Institua)               [162919] 1696-12-12 João Dinis                                   https://pesquisa.auc.uc.pt/details?id=162919
# (Institua)               [191279] 1728-10-01 Manuel Fernandes Castro                      https://pesquisa.auc.uc.pt/details?id=191279
# (Institua)               [179073] 1733-10-01 Pedro Luís Gomes                             https://pesquisa.auc.uc.pt/details?id=179073
#
# (Coimbra)
# (Coimbra)                [162569] 1569-11-20 Manuel Francisco                             https://pesquisa.auc.uc.pt/details?id=162569 Faculdade corrigida
# (Coimbra)                [162940] 1576-06-13 Pedro Francisco                              https://pesquisa.auc.uc.pt/details?id=162940
# (Coimbra)                [182307] 1724-10-01 António de Araújo Madaíl                     https://pesquisa.auc.uc.pt/details?id=182307
# (Coimbra)                [234210] 1848-10-03 Abel Augusto de Sousa                        https://pesquisa.auc.uc.pt/details?id=234210
#
# (Cânone)
# (Cânone)                 [147423] 1650-12-01 Pedro Aranha                                 https://pesquisa.auc.uc.pt/details?id=147423
# (Cânone)                 [169198] 1701-10-01 António das Neves                            https://pesquisa.auc.uc.pt/details?id=169198
# (Cânone)                 [147552] 1761-10-29 António Pereira de Araújo                    https://pesquisa.auc.uc.pt/details?id=147552
#
# (Direiro)
# (Direiro)                [240407] 1817-11-08 Sebastião da Silveira Magalhães e Menezes    https://pesquisa.auc.uc.pt/details?id=240407
# (Direiro)                [290511] 1837-06-16 António Pacheco Ribeiro Nunes                https://pesquisa.auc.uc.pt/details?id=290511
# (Direiro)                [132797] 1879-10-02 António Carlos das Neves Cardoso             https://pesquisa.auc.uc.pt/details?id=132797
#
# (Estado Eclesiástico)
# (Estado Eclesiástico)    [229914] 1846-11-11 António Gomes Rosmaninho                     https://pesquisa.auc.uc.pt/details?id=229914
# (Estado Eclesiástico)    [162950] 1852-10-27 José António Dinis                           https://pesquisa.auc.uc.pt/details?id=162950
# (Estado Eclesiástico)    [171074] 1865-10-11 Afonso Bernardino de Ochôa Mata              https://pesquisa.auc.uc.pt/details?id=171074
#
# (Teolgia)
# (Teolgia)                [137293] 1597-10-03 Manuel de Figueiredo                         https://pesquisa.auc.uc.pt/details?id=137293
# (Teolgia)                [223019] 1856-10-17 Joaquim Pedro Parente                        https://pesquisa.auc.uc.pt/details?id=223019
# (Teolgia)                [167430] 1894-10-29 João Martins de Freitas                      https://pesquisa.auc.uc.pt/details?id=167430
#
# (Filosfia)
# (Filosfia)               [210311] 1838-10-15 Fortunato Dias Leite                         https://pesquisa.auc.uc.pt/details?id=210311
# (Filosfia)               [162952] 1880-06-08 José Augusto Abranches Dinis                 https://pesquisa.auc.uc.pt/details?id=162952 Faculdade corrigida
#
# (Évora)
# (Évora)                  [166108] 1705-03-04 Matias Rodrigues Freire                      https://pesquisa.auc.uc.pt/details?id=166108
# (Évora)                  [177454] 1754-10-01 Manuel Garcia                                https://pesquisa.auc.uc.pt/details?id=177454
#
# (Teórico)
# (Teórico)                [196458] 1540-02-20 Luís Coronel                                 https://pesquisa.auc.uc.pt/details?id=196458
# (Teórico)                [222412] 1540-10-17 Marcos de Paiva                              https://pesquisa.auc.uc.pt/details?id=222412
#
# (Teorico)
# (Teorico)                [133424] 1540-03-07 Diogo Rodrigues Cardoso                      https://pesquisa.auc.uc.pt/details?id=133424
# (Teorico)                [179125] 1540-10-07 Gonçalo                                      https://pesquisa.auc.uc.pt/details?id=179125
#
# (Mediicna)
# (Mediicna)               [250566] 1690-10-01 Manuel de Proença                            https://pesquisa.auc.uc.pt/details?id=250566
# (Mediicna)               [317111] 1754-07-05 Francisco Teixeira Torres                    https://pesquisa.auc.uc.pt/details?id=317111
#
# (Lisboa)
# (Lisboa)                 [270344] 0000-00-00 Pedro de Almeida                             https://pesquisa.auc.uc.pt/details?id=270344
# (Lisboa)                 [241045] 0000-00-00 Manuel de Araújo e Sousa                     https://pesquisa.auc.uc.pt/details?id=241045
# (Lisboa)                 [175954] 1715-10-01 José Anastácio de Oliveira                   https://pesquisa.auc.uc.pt/details?id=175954
# (Lisboa)                 [183377] 1741-10-01 Joaquim Rodrigues da Maia                    https://pesquisa.auc.uc.pt/details?id=183377
#
# (Mataematica)
# (Mataematica)            [209363] 1822-10-04 Satiro Mariano Leitão                        https://pesquisa.auc.uc.pt/details?id=209363
# (Mataematica)            [195338] 1893-10-14 José Júlio Leite Lages                       https://pesquisa.auc.uc.pt/details?id=195338
#
# (Farmácia)
# (Farmácia)               [148001] 1903-01-14 Joaquim Alberto Areosa                       https://pesquisa.auc.uc.pt/details?id=148001
# (Farmácia)               [145238] 1904-10-12 Óscar Manuel Guedes Alvim                    https://pesquisa.auc.uc.pt/details?id=145238
#
# (Dreito)
# (Dreito)                 [206477] 1825-10-29 Rodrigo de Araújo Azevedo Sá Coutinho        https://pesquisa.auc.uc.pt/details?id=206477
# (Dreito)                 [206476] 1893-10-24 Ramiro Jacome da Costa Coutinho              https://pesquisa.auc.uc.pt/details?id=206476
#
# (Dirieito)
# (Dirieito)               [168784] 1817-11-06 Francisco António de Sá e Fróis              https://pesquisa.auc.uc.pt/details?id=168784
# (Dirieito)               [211160] 1885-10-15 Pedro de Carvalho Mendes Coutinho de Vasconcelos https://pesquisa.auc.uc.pt/details?id=211160
#
# (Direto)
# (Direto)                 [138596] 1837-10-18 António Alves Carneiro                       https://pesquisa.auc.uc.pt/details?id=138596
# (Direto)                 [271122] 1907-07-13 Augusto Eduardo de Norornha Freire de Andrade https://pesquisa.auc.uc.pt/details?id=271122
#
# (Canônes)
# (Canônes)                [161363] 1576-10-01 Jacome Dias                                  https://pesquisa.auc.uc.pt/details?id=161363 Faculdade corrigida
# (Canônes)                [276322] 1733-06-03 António Dias                                 https://pesquisa.auc.uc.pt/details?id=276322
#
# (Canonês)
# (Canonês)                [160142] 1718-10-01 Bernardo Álvares Ribeiro                     https://pesquisa.auc.uc.pt/details?id=160142
# (Canonês)                [160143] 1743-10-01 Bernardo António Ribeiro                     https://pesquisa.auc.uc.pt/details?id=160143
#
# (Porto)
# (Porto)                  [191527] 0000-00-00 Serafim Garcia Dinis e Castro                https://pesquisa.auc.uc.pt/details?id=191527
# (Porto)                  [220076] 1878-10-02 Roberto Guilherme Woodhonse                  https://pesquisa.auc.uc.pt/details?id=220076
#
# (Matemataica)
# (Matemataica)            [221403] 1796-10-05 João Bernardes de Lima                       https://pesquisa.auc.uc.pt/details?id=221403
#
# (Matematíca)
# (Matematíca)             [201742] 1868-10-05 Nuno Silvestre Teixeira                      https://pesquisa.auc.uc.pt/details?id=201742 Faculdade corrigida
#
# (Matemtática)
# (Matemtática)            [199696] 1872-10-15 Augusto Xavier Teixeira                      https://pesquisa.auc.uc.pt/details?id=199696
#
# (Matemátca)
# (Matemátca)              [243453] 1815-10-14 José da Costa Mesquita                       https://pesquisa.auc.uc.pt/details?id=243453 Faculdade corrigida
#
# (Matemátiica)
# (Matemátiica)            [168950] 1797-10-05 Pedro José Ribeiro                           https://pesquisa.auc.uc.pt/details?id=168950 Faculdade corrigida
#
# (Matrículas12.10.1629)
# (Matrículas12.10.1629)   [242803] 1629-10-12 João de Mesquita                             https://pesquisa.auc.uc.pt/details?id=242803
#
# (Medicína)
# (Medicína)               [161636] 1731-10-01 José Dias                                    https://pesquisa.auc.uc.pt/details?id=161636
#
# (Monsanto)
# (Monsanto)               [195934] 1690-10-01 Sebastião Rodrigues Conde                    https://pesquisa.auc.uc.pt/details?id=195934
#
# (Moura)
# (Moura)                  [244015] 1732-12-01 Francisco Lopes                              https://pesquisa.auc.uc.pt/details?id=244015
#
# (Teaologia)
# (Teaologia)              [169843] 1847-10-08 Manuel Ferreira Domingues Martins            https://pesquisa.auc.uc.pt/details?id=169843
#
# (Seia)
# (Seia)                   [213195] 1863-10-09 Amândio Eduardo da Mota Veiga                https://pesquisa.auc.uc.pt/details?id=213195
#
# (Serpa)
# (Serpa)                  [271727] 1721-05-14 António de Araújo                            https://pesquisa.auc.uc.pt/details?id=271727
#
# (Instiuta)
# (Instiuta)               [194914] 1653-11-04 Luís Pereira Lacerda                         https://pesquisa.auc.uc.pt/details?id=194914
#
# (Tentativa)
# (Tentativa)              [168987] 1765-10-01 Luís José Lourenço da Silva Neto             https://pesquisa.auc.uc.pt/details?id=168987
#
# (Tentugal)
# (Tentugal)               [181115] 1749-10-01 António de Sequeira Gusmão                   https://pesquisa.auc.uc.pt/details?id=181115
#
# (Teolggia)
# (Teolggia)               [250294] 1804-10-20 António José Lopes de Morais                 https://pesquisa.auc.uc.pt/details?id=250294 Faculdade corrigida
#
# (Teologi)
# (Teologi)                [144068] 1700-11-01 Paulo de Almeida                             https://pesquisa.auc.uc.pt/details?id=144068
#
# (Teóricos)
# (Teóricos)               [176607] 1540-10-06 Baltasar Olmedo                              https://pesquisa.auc.uc.pt/details?id=176607
#
# (de)
# (de)                     [170402] 1730-03-24 Simão Martins                                https://pesquisa.auc.uc.pt/details?id=170402
#
# (Matecamtica)
# (Matecamtica)            [232821] 1869-10-13 António Maria Botelho de Lacerda Lobo        https://pesquisa.auc.uc.pt/details?id=232821
#
# (Conônes)
# (Conônes)                [190633] 1610-10-07 Afonso Rodrigues                             https://pesquisa.auc.uc.pt/details?id=190633 Faculdade corrigida
#
# (Instituto Eclesiástico)
# (Instituto Eclesiástico) [168028] 1848-10-06 Frutuoso José Martins                        https://pesquisa.auc.uc.pt/details?id=168028
#
# (Dieito)
# (Dieito)                 [198249] 1868-10-15 José Augusto de Madureira Leal               https://pesquisa.auc.uc.pt/details?id=198249
#
# (')
# (')                      [192086] 1626-10-29 António Rodrigues                            https://pesquisa.auc.uc.pt/details?id=192086
#
# (1630-10-02)
# (1630-10-02)             [242803] 1630-10-02 João de Mesquita                             https://pesquisa.auc.uc.pt/details?id=242803 02.10.1630
#
# (1767-10-01)
# (1767-10-01)             [243376] 1767-10-01 João de Morais de Mesquita                   https://pesquisa.auc.uc.pt/details?id=243376 01.10.1767
#
# (Basto)
# (Basto)                  [225423] 1738-10-01 António Teixeira da Silva                    https://pesquisa.auc.uc.pt/details?id=225423
#
# (Cantanhede)
# (Cantanhede)             [221502] 1585-10-01 Sebastião Rodrigues                          https://pesquisa.auc.uc.pt/details?id=221502 Faculdade corrigida
#
# (Codigo)
# (Codigo)                 [163266] 1540-12-02 Diogo                                        https://pesquisa.auc.uc.pt/details?id=163266
#
# (Cânanes)
# (Cânanes)                [161476] 1721-10-01 João Dias                                    https://pesquisa.auc.uc.pt/details?id=161476
#
# (Cânoes)
# (Cânoes)                 [289988] 1765-06-01 Bernardino de Abreu Castelo Branco           https://pesquisa.auc.uc.pt/details?id=289988
#
# (Dioreito)
# (Dioreito)               [229381] 1807-10-12 Francisco Batista Lisboa                     https://pesquisa.auc.uc.pt/details?id=229381
#
# (Insituta)
# (Insituta)               [162893] 1598-10-27 Jerónimo Dinis                               https://pesquisa.auc.uc.pt/details?id=162893
#
# (Direio)
# (Direio)                 [188473] 1814-10-31 Idelfonso António Henriques                  https://pesquisa.auc.uc.pt/details?id=188473
#
# (Direita)
# (Direita)                [171633] 1902-10-04 Bernardo António da Silva Matos              https://pesquisa.auc.uc.pt/details?id=171633
#
# (Eclesiástico)
# (Eclesiástico)           [134569] 1871-10-14 António Ruivo de Figueiredo                  https://pesquisa.auc.uc.pt/details?id=134569
#
# (Estado Elcesiástico)
# (Estado Elcesiástico)    [218301] 1852-10-15 Manuel Carvalho Vieira                       https://pesquisa.auc.uc.pt/details?id=218301 Faculdade corrigida
#
# (Filosogia)
# (Filosogia)              [212175] 1779-11-06 Bento Joaquim de Lemos                       https://pesquisa.auc.uc.pt/details?id=212175 Faculdade corrigida
#
# (Fiosofia)
# (Fiosofia)               [186141] 1789-10-06 Joaquim José da Rocha                        https://pesquisa.auc.uc.pt/details?id=186141 Faculdade corrigida
#
# (Graduação)
# (Graduação)              [191271] 1752-10-01 Manuel de Coimbra Soeiro Pereira e Castro    https://pesquisa.auc.uc.pt/details?id=191271 Faculdade corrigida
#
# (Granática)
# (Granática)              [248777] 1540-02-06 Amador Pires                                 https://pesquisa.auc.uc.pt/details?id=248777
#
# (´)
# (´)                      [136573] 1654-03-18 Francisco Rego                               https://pesquisa.auc.uc.pt/details?id=136573
