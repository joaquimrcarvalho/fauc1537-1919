# %% [markdown]
# **[PT]** Para executar este ficheiro veja o ficheiro README.md nesta directoria
#
# **[EN]** To run this file: follow instructions in the README.md file in this directory.

# %% [markdown]
# # **[PT]** Correção, inferência e normalização do campo "Faculdade"
#
# # **[EN]** Correction, inference and normalization of the field "Faculdade"

# %% [markdown]
# ## Setup

# %%
from timelinknb import current_time,current_machine, get_mhk_db
import ucalumni.config as alumniconf

db_name = alumniconf.mhk_db_name
db = get_mhk_db(db_name)
print(current_machine,current_time,f'db={db_name}')
# Out:
# imac-jrc.local 2022-05-10 14:24:39.168529 db=ucalumni

# %% [markdown]
# ## **[PT]** Listagens de controle
# ## **[EN]** Control listings

# %% [markdown]
# ### **[PT]** Notas de processamento

# %%
from timelinknb.pandas import attribute_to_df

notas_proc = attribute_to_df(
                    the_type='nota-processamento',
                    person_info=True,
                    more_cols=['faculdade','faculdade-original','uc-entrada', 'uc-saida','url'],
                    sql_echo=False)

# %%
notas_proc['id'] = notas_proc.index.values
notas_proc.dropna(how='all', axis=1, inplace=True)
notas_proc.info()

# %%
df = notas_proc
df['id'] = df.index.values

col = 'nota-processamento' # sub total by this column
df_totals = df.groupby(col).agg({'id':'nunique',
                                                  'uc-entrada':'min',
                                                  'uc-saida':'max'})
df_totals.loc['Total'] = df_totals['id'].sum()

df_totals.sort_values('id',ascending= False).head(30)
# Out:
#                                                        id  uc-entrada  \
# nota-processamento
# Total                                               20263       20263
# Aviso: faculdade inferida                           11356  0000-00-00
# Aviso: faculdade corrigida                           6980  0000-00-00
# Faculdade corrigida, combinação incomum               735  0000-00-00
# Erro: não foi possível determinar a faculdade         675  1537-00-00
# Erro: valor não corresponde a Faculdade nesta data    517  0000-00-00
#
#                                                       uc-saida
# nota-processamento
# Total                                                    20263
# Aviso: faculdade inferida                           1913-07-11
# Aviso: faculdade corrigida                          1916-07-15
# Faculdade corrigida, combinação incomum             1916-07-15
# Erro: não foi possível determinar a faculdade       1912-08-02
# Erro: valor não corresponde a Faculdade nesta data  1913-08-13

# %% [markdown]
# ### **[EN]** "Faculdade" Inferred
#
# In narrative terms, the algorithm checks first if the field “Faculdade” has a value or not; it then proceeds to collect all references to “faculdades” in the rest of the record; if by removing the pre-requisites from the collection something remains, it will the chosen as the corrected or inferred “faculdade”; if nothing remains then the original value is used; some other edge cases are tested.
#
#
# ### **[PT]** "Faculdade" inferida

# %%
fac_inf = notas_proc[notas_proc['nota-processamento']=='Aviso: faculdade inferida'].copy()
fac_inf.dropna(how='all', axis=1, inplace=True)
fac_inf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11759 entries, 127775 to 319862
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     11759 non-null  object
#  1   sex                      11759 non-null  object
#  2   nota-processamento       11759 non-null  object
#  3   nota-processamento.date  11759 non-null  object
#  4   nota-processamento.obs   11759 non-null  object
#  5   faculdade                11759 non-null  object
#  6   faculdade.date           11759 non-null  object
#  7   faculdade.obs            11759 non-null  object
#  8   uc-entrada               11759 non-null  object
#  9   uc-entrada.date          11759 non-null  object
#  10  uc-saida                 11759 non-null  object
#  11  uc-saida.date            11759 non-null  object
#  12  url                      11759 non-null  object
#  13  url.date                 11759 non-null  object
#  14  id                       11759 non-null  object
# dtypes: object(15)
# memory usage: 1.4+ MB

# %%
df = fac_inf
col = 'faculdade' # subotal by this column
df_totals = df.groupby(col).agg({'id':'nunique',
                                                  'uc-entrada':'min',
                                                  'uc-saida':'max'})
print("List of inferred 'faculdade'")
df_totals.sort_values('id',ascending= False).head(30)
# Out:
# List of inferred 'faculdade'
#                                       id  uc-entrada    uc-saida
# faculdade
# Cursos jurídicos (Cânones ou Leis)  6993  0000-00-00  1829-03-28
# Artes                               3005  0000-00-00  1780-07-18
# Cânones                              764  0000-00-00  1827-06-20
# Leis                                 386  0000-00-00  1828-07-01
# Teologia                             352  0000-00-00  1884-05-26
# Medicina                             185  0000-00-00  1883-10-15
# Filosofia                             28  1770-10-01  1913-07-11
# Matemática                            24  1605-10-07  1913-07-11
# Direito                               22  1836-10-14  1898-12-18

# %% [markdown]
# ### **[PT]** Faculdade corrigida

# %%
fac_corr = notas_proc[notas_proc['nota-processamento']=='Aviso: faculdade corrigida'].copy()
fac_corr.dropna(how='all', axis=1, inplace=True)

# %%
import pandas as pd

df = fac_corr
col = 'nota-processamento.obs' # subotal by this column
df_totals = df.groupby(col).agg({'id':'nunique',
                                                  'uc-entrada':'min',
                                                  'uc-saida':'max'})
total = df_totals['id'].sum()
print("List of corrected 'faculdade'")
print("Total:",total)
df_totals['perc'] = df_totals['id']/total
pd.set_option('display.max_rows',1000)
#df_totals.sort_values('id',ascending=False, inplace=True)
df_totals.head(10)
# Out:
# List of corrected 'faculdade'
# Total: 6980
#                                                     id  uc-entrada  \
# nota-processamento.obs
# "Direito / Cânones para Cânones,Leis."               1  1814-10-05
# "Matemática / Filosofia / Medicina para Medicina."   1  1783-10-16
# . Cânones para Cânones,Leis.                         2  1577-10-29
# . Cânones para Cânones,Teologia.                     1  1684-10-01
# . Leis para Cânones,Leis.                            2  1574-10-01
# . Medicina para Medicina,Teologia.                   1  1617-10-13
# . para (.),Cânones.                                  1  1633-10-15
# . para (.),Medicina.                                 1  1658-10-01
# . para (.),Teologia.                                 1  1738-12-01
# 06.1805 (voluntário) até 08.1807 para (06.1805 ...   1  0000-00-00
#
#                                                       uc-saida      perc
# nota-processamento.obs
# "Direito / Cânones para Cânones,Leis."              1822-10-31  0.000143
# "Matemática / Filosofia / Medicina para Medicina."  1791-07-30  0.000143
# . Cânones para Cânones,Leis.                        1640-04-20  0.000287
# . Cânones para Cânones,Teologia.                    1690-10-01  0.000143
# . Leis para Cânones,Leis.                           1617-10-27  0.000287
# . Medicina para Medicina,Teologia.                  1618-11-10  0.000143
# . para (.),Cânones.                                 1654-10-21  0.000143
# . para (.),Medicina.                                1674-10-01  0.000143
# . para (.),Teologia.                                1750-10-01  0.000143
# 06.1805 (voluntário) até 08.1807 para (06.1805 ...  0000-00-00  0.000143

# %%
df_totals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 127 entries, Cânones para Cânones,Leis. to teologia para Cânones,Teologia.
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          127 non-null    int64
#  1   uc-entrada  127 non-null    object
#  2   uc-saida    127 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 4.0+ KB

# %%
fac_corr_nodup = fac_corr.drop_duplicates(subset=['id', 'faculdade-original'], keep='first')

# %%
for  change,row in list(df_totals.iterrows())[:10]:
    print(f"{change}: {row.id}")
    for _ndx, row in fac_corr_nodup[fac_corr_nodup['nota-processamento.obs']==change][['id','name','url','uc-entrada']].head(10).iterrows():
        url = row.url.strip('"')
        print(f"     {row.id:6} {row['name']} {row['uc-entrada']} {url}")
# Out:
# "Direito / Cânones para Cânones,Leis.": 1
#      153043 António Alves de Carvalho 1814-10-05 https://pesquisa.auc.uc.pt/details?id=153043
# "Matemática / Filosofia / Medicina para Medicina.": 1
#      202402 Vicente Coelho da Silva Seabra e Teles 1783-10-16 https://pesquisa.auc.uc.pt/details?id=202402
# . Cânones para Cânones,Leis.: 2
#      165691 Manuel Ribeiro 1577-10-29 https://pesquisa.auc.uc.pt/details?id=165691
#      165826 Manuel Ribeiro 1625-11-15 https://pesquisa.auc.uc.pt/details?id=165826
# . Cânones para Cânones,Teologia.: 1
#      165732 Manuel Ribeiro 1684-10-01 https://pesquisa.auc.uc.pt/details?id=165732
# . Leis para Cânones,Leis.: 2
#      165690 Manuel Ribeiro 1620-10-06 https://pesquisa.auc.uc.pt/details?id=165690
#      166337 Manuel Ribeiro 1574-10-01 https://pesquisa.auc.uc.pt/details?id=166337
# . Medicina para Medicina,Teologia.: 1
#      165782 Manuel Ribeiro 1617-10-13 https://pesquisa.auc.uc.pt/details?id=165782
# . para (.),Cânones.: 1
#      165694 Manuel Ribeiro 1633-10-15 https://pesquisa.auc.uc.pt/details?id=165694
# . para (.),Medicina.: 1
#      165753 Manuel Ribeiro 1658-10-01 https://pesquisa.auc.uc.pt/details?id=165753
# . para (.),Teologia.: 1
#      165734 Manuel Ribeiro 1738-12-01 https://pesquisa.auc.uc.pt/details?id=165734
# 06.1805 (voluntário) até 08.1807 para (06.1805 (voluntário) até 08.1807).: 1
#      198061 João Francisco Leal 0000-00-00 https://pesquisa.auc.uc.pt/details?id=198061

# %% [markdown]
# ### **[PT]** "Valor não corresponde a Faculdade nesta data"
#
# Esta lista é produzida pela comparação do valor do campo de faculdade, ou outra referência a faculdade no registo, e a lista das faculdades existentes à data do registo.
#
# Para além dos erros de ortografia e gralhas (atenção a "Cãnones" com til), também contém:
#
# * Uma grande quantidade (>300) de campos de Faculdade com "?". Verificar se é porque falta informação na ficha, ou se existe outra explicação
# * valores confundidos com Faculdade por particularidades da pontuação do registo. Nesse caso a correção a fazer pode ser na pontuação.
#    Ver por exemplo: 152975 a falta de ":" a seguir a matrícula provoca um erro no processamento da Faculdade
# * valor que correspondem a faculdades que existiram, mas não naquelas datas (por exemplo Filosofia antes de 1772 ou Cânones depois de 1834).
# * Topónimos, que serão erros de digitação que se poderão corrigir vendo a ficha original.

# %%
fac_error = notas_proc[notas_proc['nota-processamento']=='Erro: valor não corresponde a Faculdade nesta data'].copy()
fac_error.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 519 entries, 130413 to 317873
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     519 non-null    object
#  1   sex                      519 non-null    object
#  2   nota-processamento       519 non-null    object
#  3   nota-processamento.date  519 non-null    object
#  4   nota-processamento.obs   519 non-null    object
#  5   faculdade                519 non-null    object
#  6   faculdade.date           519 non-null    object
#  7   faculdade.obs            3 non-null      object
#  8   faculdade-original       206 non-null    object
#  9   faculdade-original.date  206 non-null    object
#  10  faculdade-original.obs   0 non-null      object
#  11  uc-entrada               519 non-null    object
#  12  uc-entrada.date          519 non-null    object
#  13  uc-entrada.obs           0 non-null      object
#  14  uc-saida                 519 non-null    object
#  15  uc-saida.date            519 non-null    object
#  16  uc-saida.obs             0 non-null      object
#  17  url                      519 non-null    object
#  18  url.date                 519 non-null    object
#  19  url.obs                  0 non-null      object
#  20  id                       519 non-null    object
# dtypes: object(21)
# memory usage: 89.2+ KB

# %%
# currently the algorithm removed question marks, but they were there
# we have to put them back until this is fixed
fac_org_none = fac_error['faculdade-original'].isnull()
fac_error.loc[fac_org_none,'faculdade-original'] = '?'

# %%
df = fac_error
col = 'faculdade-original' # subotal by this column
df_totals = df.groupby(col).agg({'id':'nunique',
                                                  'uc-entrada':'min',
                                                  'uc-saida':'max'})

df_totals.sort_values('id',ascending= False).head(30)
# Out:
#                       id  uc-entrada    uc-saida
# faculdade-original
# ?                    313  0000-00-00  1771-01-01
# Leis                  23  1827-10-13  1909-08-03
# Cânones               22  1825-10-24  1913-08-13
# Cãnones               21  1617-11-29  1769-07-10
# Medecina              18  1654-10-15  1858-10-12
# .                     13  1604-10-17  1732-11-10
# Intituta               8  1581-03-12  1770-10-01
# Instituto              7  1694-12-15  1818-10-24
# Medicna                5  1590-10-08  1735-05-08
# Dialética              4  1540-03-09  1542-03-06
# Institua               4  1642-10-28  1733-10-01
# Telogia                4  1690-10-01  1882-06-10
# Lisboa                 4  0000-00-00  1748-06-06
# Coimbra                3  1576-06-13  1853-05-27
# Estado Eclesiástico    3  1846-11-11  1865-10-11
# Cânone                 3  1650-12-01  1770-05-30
# Direiro                3  1817-11-08  1884-06-03
# Teolgia                3  1597-10-03  1899-07-08
# Mataematica            2  1822-10-04  1893-10-14
# Mediicna               2  1690-10-01  1754-07-05
# Porto                  2  0000-00-00  1878-10-02
# Teorico                2  1540-03-07  1549-07-00
# Teórico                2  1540-02-20  1540-10-17
# Farmácia               2  1903-01-14  1904-10-12
# Évora                  2  1705-03-04  1757-10-01
# Dreito                 2  1825-10-29  1898-07-15
# Dirieito               2  1817-11-06  1889-07-19
# Direto                 2  1837-10-18  1910-08-02
# Canonês                2  1718-10-01  1743-10-01
# Tentugal               1  1749-10-01  1750-10-01

# %%
df_totals['id'].sum()
# Out:
# 517

# %%
import pandas as pd
import csv

pd.set_option('display.max_rows',600)
exportar = erro_faculdade[['faculdade','name','faculdade.date']].sort_values(['faculdade','name','faculdade.date'])
exportar.to_csv('../inferences/validation/faculdade-unkown.csv',sep=',')
exportar.head(100)
# Out:
#            faculdade                                name faculdade.date
# id
# 192086           (')                   António Rodrigues     1626-10-29
# 146645           (.)                     António Antunes     1656-10-20
# 140542           (.)                    António de Abreu     1661-10-26
# 165702           (.)                      Manuel Ribeiro     1604-10-17
# 165556           (.)                      Manuel Ribeiro     1612-03-23
# 165558           (.)                      Manuel Ribeiro     1617-04-09
# 165781           (.)                      Manuel Ribeiro     1657-10-15
# 165804           (.)                      Manuel Ribeiro     1659-12-12
# 165730           (.)                      Manuel Ribeiro     1683-03-24
# 165828           (.)                      Manuel Ribeiro     1689-11-24
# 165699           (.)                      Manuel Ribeiro     1708-10-01
# 165775           (.)                      Manuel Ribeiro     1730-03-15
# 166341           (.)                      Manuel Ribeiro     1732-11-10
# 145856           (.)                     Pedro de Amorim     1676-01-01
# 242803  (1630-10-02)                    João de Mesquita     1630-10-02
# 243376  (1767-10-01)          João de Morais de Mesquita     1767-10-01
# 190636           (?)                    Afonso Rodrigues     1609-11-23
# 190611           (?)                    Afonso Rodrigues     1661-10-01
# 230452           (?)               Agostinho Nunes Ruela     1758-10-01
# 190700           (?)                 Agostinho Rodrigues     1625-10-20
# 190704           (?)                 Agostinho Rodrigues     1644-04-30
# 235545           (?)                   Agostinho da Mota     1708-10-01
# 190774           (?)                   Alberto Rodrigues     1651-11-09
# 251563           (?)                      Alexandre Luís     1745-10-01
# 235211           (?)          Alexandre Tavares Morilhas     1724-10-01
# 190797           (?)                 Amabrósio Rodrigues     1583-10-01
# 190795           (?)                    Amador Rodrigues     1707-04-06
# 190796           (?)                     Amaro Rodrigues     1663-10-26
# 190805           (?)                     André Rodrigues     1641-05-02
# 227626           (?)             António Botelho da Rosa     1703-11-26
# 194352           (?)          António Carvalho Rodrigues     1730-10-01
# 227649           (?)                António Dias da Rosa     1730-11-23
# 194365           (?)         António Francisco Rodrigues     1735-11-01
# 230757           (?)                António José Moreira     1764-10-01
# 194428           (?)              António José Rodrigues     1735-11-04
# 194434           (?)              António José Rodrigues     1747-10-01
# 229093           (?)                 António José Rosado     1761-10-01
# 230684           (?)                     António Moreira     1610-10-01
# 230679           (?)                     António Moreira     1649-10-26
# 230696           (?)                     António Moreira     1652-10-21
# 226578           (?)              António Ribeiro Roliça     1704-11-15
# 192118           (?)                   António Rodrigues     1596-10-16
# 192131           (?)                   António Rodrigues     1598-12-07
# 192378           (?)                   António Rodrigues     1601-03-22
# 194092           (?)                   António Rodrigues     1605-12-10
# 191401           (?)                   António Rodrigues     1607-10-30
# 191478           (?)                   António Rodrigues     1613-10-05
# 192937           (?)                   António Rodrigues     1613-10-12
# 192380           (?)                   António Rodrigues     1636-02-15
# 193524           (?)                   António Rodrigues     1636-10-03
# 191394           (?)                   António Rodrigues     1639-10-14
# 191278           (?)                   António Rodrigues     1643-11-24
# 192922           (?)                   António Rodrigues     1696-10-01
# 191353           (?)                   António Rodrigues     1701-10-31
# 191332           (?)                   António Rodrigues     1706-10-01
# 194099           (?)                   António Rodrigues     1708-10-01
# 194096           (?)                   António Rodrigues     1715-12-15
# 193210           (?)                   António Rodrigues     1733-10-01
# 191539           (?)                   António Rodrigues     1734-10-01
# 191318           (?)                   António Rodrigues     1765-12-01
# 230844           (?)           António Rodrigues Moreira     1756-10-01
# 194358           (?)          António da Costa Rodrigues     1757-10-01
# 249877           (?)                    António da Murta     1674-11-26
# 227609           (?)                     António da Rosa     1768-12-01
# 230542           (?)           António de Escobar Ruibão     1635-12-10
# 194624           (?)                Apolinário Rodrigues     1703-10-01
# 194754           (?)                  Baltasar Rodrigues     1670-10-21
# 194889           (?)                Bartolomeu Rodrigues     1656-10-20
# 194893           (?)                Bartolomeu Rodrigues     1663-10-24
# 194895           (?)                Bartolomeu Rodrigues     1674-10-01
# 194891           (?)                Bartolomeu Rodrigues     1762-12-01
# 226584           (?)                Basílio Coelho Rolim     1745-10-01
# 195140           (?)                  Belchior Rodrigues     1703-11-08
# 229133           (?)           Bernardo Francisco Rosado     1726-10-01
# 240157           (?)              Bernardo Luís de Moura     1736-10-01
# 195645           (?)                  Bernardo Rodrigues     1709-10-19
# 253611           (?)                     Crisóstomo Luís     1725-10-01
# 196390           (?)                  Custódio Rodrigues     1710-10-01
# 246981           (?)                  Diogo Alves Mourão     1692-10-01
# 196955           (?)                     Diogo Rodrigues     1609-10-20
# 196726           (?)                     Diogo Rodrigues     1621-10-25
# 240328           (?)            Diogo Rodrigues de Moura     1687-10-01
# 227845           (?)                       Diogo da Rosa     1625-10-20
# 230613           (?)          Domingos Fernandes Runagem     1728-12-10
# 253636           (?)                       Domingos Luís     1596-10-14
# 253641           (?)                       Domingos Luís     1622-01-02
# 253637           (?)                       Domingos Luís     1719-10-01
# 246990           (?)                     Domingos Mourão     1720-10-21
# 197404           (?)                  Domingos Rodrigues     1586-10-01
# 197534           (?)                  Domingos Rodrigues     1589-10-30
# 197097           (?)                  Domingos Rodrigues     1651-01-03
# 197067           (?)                  Domingos Rodrigues     1651-10-16
# 197511           (?)                  Domingos Rodrigues     1711-10-01
# 197439           (?)                  Domingos Rodrigues     1719-11-04
# 197431           (?)                  Domingos Rodrigues     1733-01-12
# 236180           (?)                    Domingos da Mota     1726-10-01
# 233130           (?)  Fernando Álvares de Castro Moreira     1694-10-01
# 198556           (?)                    Filipe Rodrigues     1625-10-07
# 236280           (?)                      Filipe da Mota     1708-10-22
# 236396           (?)            Francisco Manuel da Mota     1771-01-01

# %% [markdown]
# ### "Faculdades" com menos de 100 ocorrências.
#
# Uma parte são gralhas na digitação no nome da faculdade.
#
# Algumas poderiam ser corrigidas automaticamente, mas é preferível que o ficheiro original seja limpo destes erros.
#
# Outros casos são provocados por erros na linha a seguir ao campo "Faculdade".
#
# Quando uma linha não se inicia por um identificador de campo, o programa tenta juntar o conteúdo dessa linha aos valores do último campo processado.  Sem essa operação não seria possível processar a informação de matrículas e exames, que repetem valores em linhas sucessivas, sem indicar o campo em cada linha.
#
# Quando o campo "Matrícula(s)", que normalmente sucede "Faculdade", foi registado de forma deficiente, os valores das matrículas podem ser interpretados como dizendo respeito à faculdade.
#
# Embora seja possível corrigir alguns destes erros automaticamente, é preferível normalizar o ficheiro original, verificando quais os erros da listagem abaixo se devem a deficiente registo do campo "Matrícula(s)".

# %% [markdown]
# ### Faculdades com menos ocorrências
#
# A lista abaixo inclui, por ordem alfabética, os valores do campo "Faculdade" com menos de 100 ocorrências.

# %%
from sqlalchemy import select,distinct,func,desc, and_
from ipywidgets import HTML
from timelinknb.config import Session     
from timelinknb.pandas import get_nattribute_table

# get the named attributes table
nattr_table = get_nattribute_table()

stmt = select(nattr_table.c.the_value, func.count(distinct(nattr_table.c.id)).label("n")).\
        where(nattr_table.c.the_type == 'faculdade').\
        group_by(nattr_table.c.the_value).having(func.count()<100).\
        order_by(nattr_table.c.the_value)

print()
#print("Using code tag")
#print()
with Session() as session:
        for row in session.execute(stmt):
                stmt2 = select(nattr_table.c.id,nattr_table.c.name, nattr_table.c.the_date, nattr_table.c.pobs, nattr_table.c.aobs).\
                                where(
                                        and_(nattr_table.c.the_type == 'faculdade', 
                                        nattr_table.c.the_value == row.the_value)).\
                                order_by(nattr_table.c.name)
                result = session.execute(stmt2)
                for aluno in result:
                        id_link=  f'<a href="https://pesquisa.auc.uc.pt/details?id={aluno.id}">{aluno.id}</a>'
                        # display(HTML(f'<code>{row.the_value:24} [{id_link:5}] {aluno.the_date} {aluno.name:44}</code>'))
                        obs = aluno.aobs if aluno.aobs is not None else ''
                        print(f'{row.the_value:24} [{aluno.id:5}] {aluno.the_date} {aluno.name:44} https://pesquisa.auc.uc.pt/details?id={aluno.id} {obs}')
# Out:
# (')                      [192086] 1626-10-29 António Rodrigues                            https://pesquisa.auc.uc.pt/details?id=192086
# (. )                     [165828] 1689-11-24 Manuel Ribeiro                               https://pesquisa.auc.uc.pt/details?id=165828
# (. )                     [165775] 1730-03-15 Manuel Ribeiro                               https://pesquisa.auc.uc.pt/details?id=165775
# (. )                     [165694] 1633-10-15 Manuel Ribeiro                               https://pesquisa.auc.uc.pt/details?id=165694 Instituta: 1632-10-15 1632.10.15
# (. )                     [165753] 1658-10-01 Manuel Ribeiro                               https://pesquisa.auc.uc.pt/details?id=165753 1674.10.01
# (. )                     [165702] 1604-10-17 Manuel Ribeiro                               https://pesquisa.auc.uc.pt/details?id=165702
# (. )                     [165804] 1659-12-12 Manuel Ribeiro                               https://pesquisa.auc.uc.pt/details?id=165804
# (. )                     [165699] 1708-10-01 Manuel Ribeiro                               https://pesquisa.auc.uc.pt/details?id=165699
# (. )                     [165781] 1657-10-15 Manuel Ribeiro                               https://pesquisa.auc.uc.pt/details?id=165781
# (. )                     [165734] 1738-12-01 Manuel Ribeiro                               https://pesquisa.auc.uc.pt/details?id=165734 Matrícula(s): Teologia 1741.10.01
# (. )                     [165730] 1683-03-24 Manuel Ribeiro                               https://pesquisa.auc.uc.pt/details?id=165730
# (.)                      [146645] 1656-10-20 António Antunes                              https://pesquisa.auc.uc.pt/details?id=146645
# (.)                      [140542] 1661-10-26 António de Abreu                             https://pesquisa.auc.uc.pt/details?id=140542
# (.)                      [166341] 1732-11-10 Manuel Ribeiro                               https://pesquisa.auc.uc.pt/details?id=166341
# (.)                      [165558] 1617-04-09 Manuel Ribeiro                               https://pesquisa.auc.uc.pt/details?id=165558
# (.)                      [165556] 1612-03-23 Manuel Ribeiro                               https://pesquisa.auc.uc.pt/details?id=165556
# (.)                      [145856] 1676-01-01 Pedro de Amorim                              https://pesquisa.auc.uc.pt/details?id=145856
# (06.1805 (voluntário) até 08.1807) [198061] 1805-00-00 João Francisco Leal                          https://pesquisa.auc.uc.pt/details?id=198061
# (1630-10-02)             [242803] 1630-10-02 João de Mesquita                             https://pesquisa.auc.uc.pt/details?id=242803 02.10.1630
# (1675-10-01)             [152975] 1675-10-01 António Ribeiro                              https://pesquisa.auc.uc.pt/details?id=152975 1675.10.01
# (1675-10-01)             [152975] 1675-10-01 António Ribeiro                              https://pesquisa.auc.uc.pt/details?id=152975 1675.10.01
# (1676-10-14)             [152975] 1676-10-14 António Ribeiro                              https://pesquisa.auc.uc.pt/details?id=152975 1676.10.14
# (1677-10-15)             [152975] 1677-10-15 António Ribeiro                              https://pesquisa.auc.uc.pt/details?id=152975 1677.10.15
# (1678-10-15)             [152975] 1678-10-15 António Ribeiro                              https://pesquisa.auc.uc.pt/details?id=152975 1678.10.15
# (1767-10-01)             [243376] 1767-10-01 João de Morais de Mesquita                   https://pesquisa.auc.uc.pt/details?id=243376 01.10.1767
# (? (Gramática))          [248489] 1537-03-12 Pedro Mouro                                  https://pesquisa.auc.uc.pt/details?id=248489
# (? )                     [196726] 1621-10-25 Diogo Rodrigues                              https://pesquisa.auc.uc.pt/details?id=196726
# (Basto)                  [225423] 1738-10-01 António Teixeira da Silva                    https://pesquisa.auc.uc.pt/details?id=225423
# (Cânanes)                [161476] 1721-10-01 João Dias                                    https://pesquisa.auc.uc.pt/details?id=161476
# (Cânoes)                 [289988] 1765-06-01 Bernardino de Abreu Castelo Branco           https://pesquisa.auc.uc.pt/details?id=289988
# (Cânone)                 [169198] 1701-10-01 António das Neves                            https://pesquisa.auc.uc.pt/details?id=169198
# (Cânone)                 [147552] 1761-10-29 António Pereira de Araújo                    https://pesquisa.auc.uc.pt/details?id=147552
# (Cânone)                 [147423] 1650-12-01 Pedro Aranha                                 https://pesquisa.auc.uc.pt/details?id=147423
# (Cânones )               [149500] 1824-10-15 José Teixeira de Azevedo                     https://pesquisa.auc.uc.pt/details?id=149500
# (Cãnones)                [171323] 1689-10-01 Adriano Rodrigues de Matos                   https://pesquisa.auc.uc.pt/details?id=171323
# (Cãnones)                [171324] 1626-10-17 Afonso de Matos                              https://pesquisa.auc.uc.pt/details?id=171324
# (Cãnones)                [171325] 1572-10-01 Afonso de Matos                              https://pesquisa.auc.uc.pt/details?id=171325 Atos e graus: Exame Privado e Grau de Licenciado em Cânones 06.06.1582
# (Cãnones)                [224167] 1892-10-07 Agostinho Albano de Figueiredo Lobo e Silva  https://pesquisa.auc.uc.pt/details?id=224167
# (Cãnones)                [181636] 1909-10-02 Álvaro Manuel Santos e Silva Machado         https://pesquisa.auc.uc.pt/details?id=181636
# (Cãnones)                [170666] 1688-01-13 António de Mascarenhas                       https://pesquisa.auc.uc.pt/details?id=170666
# (Cãnones)                [276322] 1733-06-03 António Dias                                 https://pesquisa.auc.uc.pt/details?id=276322
# (Cãnones)                [209058] 1825-10-31 António Joaquim Nunes de Vasconcelos         https://pesquisa.auc.uc.pt/details?id=209058
# (Cãnones)                [179945] 1853-10-08 António Maria de Gouveia                     https://pesquisa.auc.uc.pt/details?id=179945 Exames em Direito: 3.º 11.07.1856 Aprovado Simpliciter, Atos n.º 21, fl. 158v.
# (Cãnones)                [170668] 1626-10-20 António Mascarenhas                          https://pesquisa.auc.uc.pt/details?id=170668
# (Cãnones)                [170667] 1651-11-21 António Mascarenhas                          https://pesquisa.auc.uc.pt/details?id=170667
# (Cãnones)                [279726] 1756-05-11 António Veríssimo de Larre                   https://pesquisa.auc.uc.pt/details?id=279726
# (Cãnones)                [164490] 1681-11-11 Barnabé Delgado Freire                       https://pesquisa.auc.uc.pt/details?id=164490
# (Cãnones)                [164493] 1660-10-18 Bartolomeu Freire                            https://pesquisa.auc.uc.pt/details?id=164493
# (Cãnones)                [160142] 1718-10-01 Bernardo Álvares Ribeiro                     https://pesquisa.auc.uc.pt/details?id=160142
# (Cãnones)                [160143] 1743-10-01 Bernardo António Ribeiro                     https://pesquisa.auc.uc.pt/details?id=160143
# (Cãnones)                [152495] 1868-10-10 Camilo de Araújo da Fonseca                  https://pesquisa.auc.uc.pt/details?id=152495
# (Cãnones)                [145263] 1823-10-30 Cândido Maximiano de Melo e Alvim            https://pesquisa.auc.uc.pt/details?id=145263
# (Cãnones)                [165656] 1625-11-15 Diogo da Esperança                           https://pesquisa.auc.uc.pt/details?id=165656
# (Cãnones)                [242848] 1908-10-27 Diogo de Soutomaior                          https://pesquisa.auc.uc.pt/details?id=242848
# (Cãnones)                [169040] 1727-10-01 Domingos Rodrigues Fronteira                 https://pesquisa.auc.uc.pt/details?id=169040
# (Cãnones)                [242277] 1626-10-06 Estevão Lopes                                https://pesquisa.auc.uc.pt/details?id=242277
# (Cãnones)                [177589] 1822-10-15 Francisco Ferreira Gaspar                    https://pesquisa.auc.uc.pt/details?id=177589
# (Cãnones)                [310343] 1769-05-16 Francisco José de Sousa                      https://pesquisa.auc.uc.pt/details?id=310343
# (Cãnones)                [133016] 1743-10-01 Francisco José Quintanilha                   https://pesquisa.auc.uc.pt/details?id=133016
# (Cãnones)                [133017] 1663-10-22 Francisco Quintanilha                        https://pesquisa.auc.uc.pt/details?id=133017
# (Cãnones)                [172506] 1670-10-13 Francisco Soares Galhardo                    https://pesquisa.auc.uc.pt/details?id=172506
# (Cãnones)                [135301] 1577-10-02 Gaspar de Figueiredo                         https://pesquisa.auc.uc.pt/details?id=135301
# (Cãnones)                [167325] 1617-11-29 Gaspar de Freitas                            https://pesquisa.auc.uc.pt/details?id=167325
# (Cãnones)                [278752] 1843-01-16 Henrique Hophe                               https://pesquisa.auc.uc.pt/details?id=278752
# (Cãnones)                [295708] 1825-10-24 Herculano Aprigio Alvares Araújo Santa Bárbara https://pesquisa.auc.uc.pt/details?id=295708
# (Cãnones)                [226814] 1899-10-12 Inácio da Silva                              https://pesquisa.auc.uc.pt/details?id=226814
# (Cãnones)                [161363] 1576-10-01 Jacome Dias                                  https://pesquisa.auc.uc.pt/details?id=161363 Jacome Dias (padre)
# (Cãnones)                [133018] 1694-10-01 Jerónimo do Rego Quintanilha                 https://pesquisa.auc.uc.pt/details?id=133018
# (Cãnones)                [276552] 1862-03-31 Jeronimo Estoquete                           https://pesquisa.auc.uc.pt/details?id=276552
# (Cãnones)                [254040] 1885-10-15 João Batista Rodrigues Loureiro              https://pesquisa.auc.uc.pt/details?id=254040 Matrícula(s): Medicina 13.10.1887
# (Cãnones)                [310916] 1831-07-08 João Inácio Barreto da Gama e Sousa          https://pesquisa.auc.uc.pt/details?id=310916
# (Cãnones)                [281600] 1858-06-26 Joaquim de Oliveira Branquinho               https://pesquisa.auc.uc.pt/details?id=281600
# (Cãnones)                [238738] 1886-10-15 Joaquim Pinheiro de Sousa                    https://pesquisa.auc.uc.pt/details?id=238738
# (Cãnones)                [176827] 1843-10-30 José de Alarcão Velasques Sarmento Osório    https://pesquisa.auc.uc.pt/details?id=176827 José de Alarcão Velasques Sarmento Osório (D.)
# (Cãnones)                [287046] 1850-06-11 José João Monteiro                           https://pesquisa.auc.uc.pt/details?id=287046
# (Cãnones)                [247707] 1823-10-04 José Lourenço Pinto                          https://pesquisa.auc.uc.pt/details?id=247707
# (Cãnones)                [136847] 1760-10-01 José Manuel Pereira de Figueiredo            https://pesquisa.auc.uc.pt/details?id=136847
# (Cãnones)                [237083] 1822-10-15 José Narciso da Mota                         https://pesquisa.auc.uc.pt/details?id=237083
# (Cãnones)                [272177] 1835-06-17 José Severino de Avelar Júnior               https://pesquisa.auc.uc.pt/details?id=272177
# (Cãnones)                [283528] 1853-05-24 Manuel Barata Lima                           https://pesquisa.auc.uc.pt/details?id=283528
# (Cãnones)                [268977] 1835-06-13 Manuel de Melo e Castro de Abreu             https://pesquisa.auc.uc.pt/details?id=268977
# (Cãnones)                [296406] 1835-06-20 Manuel Fernandes dos Santos                  https://pesquisa.auc.uc.pt/details?id=296406
# (Cãnones)                [130413] 1759-10-01 Manuel Ferreira                              https://pesquisa.auc.uc.pt/details?id=130413
# (Cãnones)                [293702] 1888-07-09 Manuel Inácio de Matos Mexia da Costa        https://pesquisa.auc.uc.pt/details?id=293702
# (Cãnones)                [317873] 1835-06-06 Manuel José de Amorim Viana                  https://pesquisa.auc.uc.pt/details?id=317873
# (Cãnones)                [133973] 1762-12-15 Manuel José Pimenta Ramos                    https://pesquisa.auc.uc.pt/details?id=133973
# (Cãnones)                [288097] 1835-06-30 Manuel Justino Marques Murta                 https://pesquisa.auc.uc.pt/details?id=288097
# (Cãnones)                [181556] 1904-10-07 Manuel Machado Macedo                        https://pesquisa.auc.uc.pt/details?id=181556
# (Cãnones)                [164003] 1703-10-01 Manuel Rodrigues Franco                      https://pesquisa.auc.uc.pt/details?id=164003
# (Cãnones)                [169044] 1725-10-01 Pantaleão das Neves Fronteira                https://pesquisa.auc.uc.pt/details?id=169044
# (Cãnones)                [234998] 1700-11-20 Pedro da Rocha Lobo                          https://pesquisa.auc.uc.pt/details?id=234998
# (Cãnones)                [316240] 1852-03-21 Pedro de Sousa                               https://pesquisa.auc.uc.pt/details?id=316240
# (Cãnones)                [168971] 1853-10-08 Pedro Vaz Ribeiro                            https://pesquisa.auc.uc.pt/details?id=168971
# (Cãnones)                [296843] 1830-07-13 Rafael Maria Sarmento                        https://pesquisa.auc.uc.pt/details?id=296843
# (Cantanhede)             [221502] 1585-10-01 Sebastião Rodrigues                          https://pesquisa.auc.uc.pt/details?id=221502 Instituta: Formatura 1591.03.21
# (Celas)                  [206671] 0000-00-00 Baltasar Rodrigues do Vale                   https://pesquisa.auc.uc.pt/details?id=206671
# (Código)                 [224300] 1540-01-10 Álvaro da Silva                              https://pesquisa.auc.uc.pt/details?id=224300
# (Código)                 [245479] 1540-12-16 Amador Pinto                                 https://pesquisa.auc.uc.pt/details?id=245479
# (Código)                 [224561] 1540-01-10 António da Silva                             https://pesquisa.auc.uc.pt/details?id=224561
# (Código)                 [190446] 1540-10-21 Belchior Homem                               https://pesquisa.auc.uc.pt/details?id=190446
# (Código)                 [163266] 1540-12-02 Diogo                                        https://pesquisa.auc.uc.pt/details?id=163266
# (Código)                 [248942] 1540-12-10 Diogo Pires                                  https://pesquisa.auc.uc.pt/details?id=248942
# (Código)                 [128154] 1540-00-00 Fernão Cabral                                https://pesquisa.auc.uc.pt/details?id=128154
# (Código)                 [235155] 1540-11-16 Gonçalo Pereira                              https://pesquisa.auc.uc.pt/details?id=235155
# (Código)                 [193963] 1540-11-07 João Coelho                                  https://pesquisa.auc.uc.pt/details?id=193963
# (Código)                 [177320] 1540-10-20 João Garcez                                  https://pesquisa.auc.uc.pt/details?id=177320
# (Código)                 [185586] 1540-02-16 Manuel Betalhado                             https://pesquisa.auc.uc.pt/details?id=185586
# (Código)                 [237346] 1540-00-00 Manuel Pereira                               https://pesquisa.auc.uc.pt/details?id=237346
# (Código)                 [129025] 1540-09-03 Sebastião Velho Cabral                       https://pesquisa.auc.uc.pt/details?id=129025
# (Coimbra)                [234210] 1848-10-03 Abel Augusto de Sousa                        https://pesquisa.auc.uc.pt/details?id=234210
# (Coimbra)                [182307] 1724-10-01 António de Araújo Madaíl                     https://pesquisa.auc.uc.pt/details?id=182307
# (Coimbra)                [162569] 1569-11-20 Manuel Francisco                             https://pesquisa.auc.uc.pt/details?id=162569 Cânones: 1573-10-12:1574-06-31 12.10.1573 até 31.06.1574
# (Coimbra)                [162940] 1576-06-13 Pedro Francisco                              https://pesquisa.auc.uc.pt/details?id=162940
# (Conônes)                [190633] 1610-10-07 Afonso Rodrigues                             https://pesquisa.auc.uc.pt/details?id=190633 *no-field-line*: Bacharel em Cânones 1616.07.08
# (de Cãnones)             [132428] 1651-10-08 Manuel Quaresma                              https://pesquisa.auc.uc.pt/details?id=132428
# (de)                     [170402] 1730-03-24 Simão Martins                                https://pesquisa.auc.uc.pt/details?id=170402
# (Dialética)              [223999] 1540-10-15 André Pedroso                                https://pesquisa.auc.uc.pt/details?id=223999
# (Dialética)              [254161] 1540-10-19 Francisco Luís                               https://pesquisa.auc.uc.pt/details?id=254161
# (Dialética)              [190809] 1540-03-09 Henrique de Castro                           https://pesquisa.auc.uc.pt/details?id=190809
# (Dialética)              [138189] 1540-10-12 João Figueiró                                https://pesquisa.auc.uc.pt/details?id=138189
# (Dialética)              [129027] 1540-10-25 Simão Cabral                                 https://pesquisa.auc.uc.pt/details?id=129027 02.07.1551
# (Dieito)                 [198249] 1868-10-15 José Augusto de Madureira Leal               https://pesquisa.auc.uc.pt/details?id=198249
# (Dioreito)               [229381] 1807-10-12 Francisco Batista Lisboa                     https://pesquisa.auc.uc.pt/details?id=229381
# (Direio)                 [188473] 1814-10-31 Idelfonso António Henriques                  https://pesquisa.auc.uc.pt/details?id=188473
# (Direiro )               [290511] 1837-06-16 António Pacheco Ribeiro Nunes                https://pesquisa.auc.uc.pt/details?id=290511
# (Direiro)                [132797] 1879-10-02 António Carlos das Neves Cardoso             https://pesquisa.auc.uc.pt/details?id=132797
# (Direiro)                [240407] 1817-11-08 Sebastião da Silveira Magalhães e Menezes    https://pesquisa.auc.uc.pt/details?id=240407
# (Direita)                [171633] 1902-10-04 Bernardo António da Silva Matos              https://pesquisa.auc.uc.pt/details?id=171633
# (Direto)                 [138596] 1837-10-18 António Alves Carneiro                       https://pesquisa.auc.uc.pt/details?id=138596
# (Direto)                 [271122] 1907-07-13 Augusto Eduardo de Norornha Freire de Andrade https://pesquisa.auc.uc.pt/details?id=271122
# (Dirieito)               [168784] 1817-11-06 Francisco António de Sá e Fróis              https://pesquisa.auc.uc.pt/details?id=168784
# (Dirieito)               [211160] 1885-10-15 Pedro de Carvalho Mendes Coutinho de Vasconcelos https://pesquisa.auc.uc.pt/details?id=211160
# (Dreito)                 [206476] 1893-10-24 Ramiro Jacome da Costa Coutinho              https://pesquisa.auc.uc.pt/details?id=206476
# (Dreito)                 [206477] 1825-10-29 Rodrigo de Araújo Azevedo Sá Coutinho        https://pesquisa.auc.uc.pt/details?id=206477
# (Eclesiástico)           [134569] 1871-10-14 António Ruivo de Figueiredo                  https://pesquisa.auc.uc.pt/details?id=134569
# (Estado Eclesiástico)    [171074] 1865-10-11 Afonso Bernardino de Ochôa Mata              https://pesquisa.auc.uc.pt/details?id=171074
# (Estado Eclesiástico)    [229914] 1846-11-11 António Gomes Rosmaninho                     https://pesquisa.auc.uc.pt/details?id=229914
# (Estado Eclesiástico)    [162950] 1852-10-27 José António Dinis                           https://pesquisa.auc.uc.pt/details?id=162950
# (Estado Elcesiástico)    [218301] 1852-10-15 Manuel Carvalho Vieira                       https://pesquisa.auc.uc.pt/details?id=218301 Exames em Teologia: 3.º 14.07.1855 Aprovado Nemine Discrepante, Atos n.º 6, fl. 118v.
# (Évora)                  [177454] 1754-10-01 Manuel Garcia                                https://pesquisa.auc.uc.pt/details?id=177454
# (Évora)                  [166108] 1705-03-04 Matias Rodrigues Freire                      https://pesquisa.auc.uc.pt/details?id=166108
# (Farmácia)               [148001] 1903-01-14 Joaquim Alberto Areosa                       https://pesquisa.auc.uc.pt/details?id=148001
# (Farmácia)               [145238] 1904-10-12 Óscar Manuel Guedes Alvim                    https://pesquisa.auc.uc.pt/details?id=145238
# (Filosfia)               [210311] 1838-10-15 Fortunato Dias Leite                         https://pesquisa.auc.uc.pt/details?id=210311
# (Filosfia)               [162952] 1880-06-08 José Augusto Abranches Dinis                 https://pesquisa.auc.uc.pt/details?id=162952 Medicina: 1882-10-13 13.10.1882
# (Filosofia)              [184285] 1718-10-01 Amaro Ferreira Marques                       https://pesquisa.auc.uc.pt/details?id=184285
# (Filosofia)              [216482] 1727-12-17 António Antunes de Menezes                   https://pesquisa.auc.uc.pt/details?id=216482
# (Filosofia)              [189349] 1717-10-01 António de Mesquita Castelo Branco           https://pesquisa.auc.uc.pt/details?id=189349
# (Filosofia)              [242629] 1542-07-15 António do Souto                             https://pesquisa.auc.uc.pt/details?id=242629 Grau: Doutor em Medicina em 07.07.1555
# (Filosofia)              [223811] 1759-01-29 António José Pedrosa                         https://pesquisa.auc.uc.pt/details?id=223811
# (Filosofia)              [185300] 1703-10-01 António Pessanha Beltrão                     https://pesquisa.auc.uc.pt/details?id=185300
# (Filosofia)              [180283] 1714-12-11 Dionísio Nunes da Graça                      https://pesquisa.auc.uc.pt/details?id=180283
# (Filosofia)              [167232] 1540-03-20 Fernão de Freitas                            https://pesquisa.auc.uc.pt/details?id=167232
# (Filosofia)              [190736] 1706-10-01 Francisco da Silva e Castro                  https://pesquisa.auc.uc.pt/details?id=190736
# (Filosofia)              [212155] 1540-01-31 Francisco Vaz                                https://pesquisa.auc.uc.pt/details?id=212155
# (Filosofia)              [244772] 1540-10-25 Garcia Lopes                                 https://pesquisa.auc.uc.pt/details?id=244772
# (Filosofia)              [188528] 1540-10-25 Jerónimo Henriques                           https://pesquisa.auc.uc.pt/details?id=188528 *no-field-line*: Exame Privado em Medicina 15.07.1550
# (Filosofia)              [236867] 1540-11-22 João Afonso de Vasconcelos Menezes           https://pesquisa.auc.uc.pt/details?id=236867
# (Filosofia)              [252948] 1680-10-01 João Batista Monteiro                        https://pesquisa.auc.uc.pt/details?id=252948
# (Filosofia)              [191603] 1540-11-16 João de Ilhoa                                https://pesquisa.auc.uc.pt/details?id=191603
# (Filosofia)              [198061] 0000-00-00 João Francisco Leal                          https://pesquisa.auc.uc.pt/details?id=198061
# (Filosofia)              [185704] 1719-10-01 José Caetano Bettencourt                     https://pesquisa.auc.uc.pt/details?id=185704
# (Filosofia)              [180425] 1758-10-01 José de Abreu Grilo                          https://pesquisa.auc.uc.pt/details?id=180425
# (Filosofia)              [183603] 1761-12-01 José Gomes Maleita                           https://pesquisa.auc.uc.pt/details?id=183603
# (Filosofia)              [189814] 1721-11-27 José Pessanha Castelo Branco                 https://pesquisa.auc.uc.pt/details?id=189814
# (Filosofia)              [182043] 1738-10-01 José Pinto Machado                           https://pesquisa.auc.uc.pt/details?id=182043
# (Filosofia)              [179343] 1540-02-12 Luís Gomes                                   https://pesquisa.auc.uc.pt/details?id=179343
# (Filosofia)              [182448] 1698-10-01 Manuel Alves Madeira                         https://pesquisa.auc.uc.pt/details?id=182448
# (Filosofia)              [194469] 1702-10-01 Manuel da Fonseca Coelho                     https://pesquisa.auc.uc.pt/details?id=194469
# (Filosofia)              [182446] 1668-10-01 Manuel de Aguiar Madeira                     https://pesquisa.auc.uc.pt/details?id=182446
# (Filosofia)              [196331] 1692-10-01 Manuel Rodrigues Cordeiro                    https://pesquisa.auc.uc.pt/details?id=196331
# (Filosofia)              [203554] 1540-04-28 Manuel Tomás                                 https://pesquisa.auc.uc.pt/details?id=203554
# (Filosofia)              [217267] 1540-00-00 Mateus Dias de Santarém                      https://pesquisa.auc.uc.pt/details?id=217267
# (Filosofia)              [130851] 1645-06-19 Mateus Ferreira                              https://pesquisa.auc.uc.pt/details?id=130851
# (Filosofia)              [234481] 1631-10-27 Miguel de Mendonça                           https://pesquisa.auc.uc.pt/details?id=234481
# (Filosofia)              [180844] 1746-10-01 Miguel do Couto Guerreiro                    https://pesquisa.auc.uc.pt/details?id=180844
# (Filosofia)              [239302] 1604-12-02 Paulo da Mota                                https://pesquisa.auc.uc.pt/details?id=239302 """
#                 Instituta: Incorporação em todos os Atos de teologia até á Formatura 1604.12.02 Atos e graus 21 fl. 1v caderno 1º Instituta: Incorporação em todos os Atos de teologia até á Formatura 1604.12.02 Atos e graus 21 fl. 1v caderno 1º
#             """
# (Filosofia)              [173681] 1540-12-29 Pedro Nunes                                  https://pesquisa.auc.uc.pt/details?id=173681
# (Filosofia)              [201800] 1677-10-01 Pedro Rodrigues Teixeira                     https://pesquisa.auc.uc.pt/details?id=201800
# (Filosofia)              [239012] 1540-02-03 Rodrigo Pereira                              https://pesquisa.auc.uc.pt/details?id=239012
# (Filosofia)              [139936] 1540-04-05 Rui Vaz de Resende                           https://pesquisa.auc.uc.pt/details?id=139936
# (Filosofia)              [218706] 1665-10-15 Simão de São José                            https://pesquisa.auc.uc.pt/details?id=218706
# (Filosofia)              [242285] 1704-12-19 Teotónio de Almeida e Sousa                  https://pesquisa.auc.uc.pt/details?id=242285
# (Filosogia)              [212175] 1779-11-06 Bento Joaquim de Lemos                       https://pesquisa.auc.uc.pt/details?id=212175
# (Fiosofia)               [186141] 1789-10-06 Joaquim José da Rocha                        https://pesquisa.auc.uc.pt/details?id=186141 1794.10.10
# (Graduação)              [191271] 1752-10-01 Manuel de Coimbra Soeiro Pereira e Castro    https://pesquisa.auc.uc.pt/details?id=191271 Matrícula(s): Cânones 01.10.1752
# (Granática)              [248777] 1540-02-06 Amador Pires                                 https://pesquisa.auc.uc.pt/details?id=248777
# (Insituta)               [162893] 1598-10-27 Jerónimo Dinis                               https://pesquisa.auc.uc.pt/details?id=162893
# (Institua)               [162919] 1696-12-12 João Dinis                                   https://pesquisa.auc.uc.pt/details?id=162919
# (Institua)               [191279] 1728-10-01 Manuel Fernandes Castro                      https://pesquisa.auc.uc.pt/details?id=191279
# (Institua)               [162284] 1642-10-28 Mateus Dias                                  https://pesquisa.auc.uc.pt/details?id=162284
# (Institua)               [179073] 1733-10-01 Pedro Luís Gomes                             https://pesquisa.auc.uc.pt/details?id=179073
# (Instituto Eclesiástico) [168028] 1848-10-06 Frutuoso José Martins                        https://pesquisa.auc.uc.pt/details?id=168028
# (Instituto)              [153436] 1726-10-01 Francisco Osório da Fonseca                  https://pesquisa.auc.uc.pt/details?id=153436
# (Instituto)              [168030] 1818-10-24 Gabriel Martins                              https://pesquisa.auc.uc.pt/details?id=168030
# (Instituto)              [165081] 1724-10-01 José Godinho Freire                          https://pesquisa.auc.uc.pt/details?id=165081
# (Instituto)              [211035] 1764-10-01 José Pereira da Cunha Leite                  https://pesquisa.auc.uc.pt/details?id=211035
# (Instituto)              [214163] 1750-01-01 Lourenço de Lemos                            https://pesquisa.auc.uc.pt/details?id=214163
# (Instituto)              [157976] 1725-10-01 Manuel da Fonseca                            https://pesquisa.auc.uc.pt/details?id=157976
# (Instituto)              [159782] 1694-12-15 Pedro Correia da Fonseca                     https://pesquisa.auc.uc.pt/details?id=159782
# (Instiuta)               [194914] 1653-11-04 Luís Pereira Lacerda                         https://pesquisa.auc.uc.pt/details?id=194914
# (Intituta)               [202881] 1695-10-01 Domingos Rodrigues Leitão                    https://pesquisa.auc.uc.pt/details?id=202881
# (Intituta)               [189148] 1581-03-12 Gaspar Castanheira                           https://pesquisa.auc.uc.pt/details?id=189148
# (Intituta)               [176905] 1765-10-01 Jerónimo Luís Faisco Ortigão                 https://pesquisa.auc.uc.pt/details?id=176905
# (Intituta)               [155550] 1613-11-04 João Rodrigues da Fonseca                    https://pesquisa.auc.uc.pt/details?id=155550
# (Intituta)               [172587] 1770-10-01 Manuel António de Bolhão Novais              https://pesquisa.auc.uc.pt/details?id=172587
# (Intituta)               [138895] 1682-10-30 Pedro de Figueiredo                          https://pesquisa.auc.uc.pt/details?id=138895
# (Intituta)               [138995] 1665-10-22 Sebastião de Figueiredo                      https://pesquisa.auc.uc.pt/details?id=138995
# (Intituta)               [138151] 1751-10-01 Veríssimo Aires de Figueiredo                https://pesquisa.auc.uc.pt/details?id=138151
# (Leis )                  [292791] 1845-07-01 João de Almeida de Morais Pessanha           https://pesquisa.auc.uc.pt/details?id=292791
# (Leis)                   [180766] 1884-10-02 António Joaquim Guerra                       https://pesquisa.auc.uc.pt/details?id=180766
# (Leis)                   [271758] 1835-06-20 António Maria Carvalho e Araújo              https://pesquisa.auc.uc.pt/details?id=271758
# (Leis)                   [215793] 1822-10-08 António Pedro Mousinho Leote                 https://pesquisa.auc.uc.pt/details?id=215793
# (Leis)                   [296707] 1830-07-12 Bento Lobão Morais Castro Sarmento           https://pesquisa.auc.uc.pt/details?id=296707
# (Leis)                   [287268] 1836-06-25 Bernardo José de Morais                      https://pesquisa.auc.uc.pt/details?id=287268
# (Leis)                   [128134] 1825-10-14 Constantino António do Vale Pereira Cabral   https://pesquisa.auc.uc.pt/details?id=128134
# (Leis)                   [317693] 1831-06-20 Francisco Afonso Velho                       https://pesquisa.auc.uc.pt/details?id=317693
# (Leis)                   [308159] 1830-06-11 Francisco António da Silva Pinto             https://pesquisa.auc.uc.pt/details?id=308159
# (Leis)                   [210323] 1824-10-30 Francisco de Meireles Leite                  https://pesquisa.auc.uc.pt/details?id=210323
# (Leis)                   [290725] 1836-06-04 Francisco Manuel da Fonseca e Castro         https://pesquisa.auc.uc.pt/details?id=290725
# (Leis)                   [237942] 1827-10-13 Heitor Pereira de Barbedo e Sousa            https://pesquisa.auc.uc.pt/details?id=237942
# (Leis)                   [145767] 1826-10-14 Henriques Teles da Silva Amorim              https://pesquisa.auc.uc.pt/details?id=145767
# (Leis)                   [308506] 1836-06-20 Inácio Fiel Gomes Ramalho                    https://pesquisa.auc.uc.pt/details?id=308506
# (Leis)                   [295095] 1835-06-17 João de Sande Magalhães Mexia Salema         https://pesquisa.auc.uc.pt/details?id=295095
# (Leis)                   [290909] 1835-06-15 José António Dias de Castro                  https://pesquisa.auc.uc.pt/details?id=290909
# (Leis)                   [282485] 1835-06-20 José Augusto Cameira de Gouveia              https://pesquisa.auc.uc.pt/details?id=282485
# (Leis)                   [180684] 1892-10-12 José Augusto Lobato Guerra                   https://pesquisa.auc.uc.pt/details?id=180684
# (Leis)                   [165216] 1840-10-10 José das Neves Gomes Eliseu                  https://pesquisa.auc.uc.pt/details?id=165216
# (Leis)                   [284700] 1835-06-22 José Estevão Coelho de Magalhães             https://pesquisa.auc.uc.pt/details?id=284700
# (Leis)                   [185857] 1886-10-15 José Henriques Bogalho                       https://pesquisa.auc.uc.pt/details?id=185857 Matrícula(s): Medicina 14.10.1890
# (Leis)                   [270519] 1840-06-11 José Joaquim Gomes de Araújo Álvares         https://pesquisa.auc.uc.pt/details?id=270519
# (Leis)                   [228113] 1857-10-15 José Joaquim Rebelo da Silva                 https://pesquisa.auc.uc.pt/details?id=228113
# (Leis)                   [294763] 1835-06-22 José Luís Gonçalves Ferreira da Cunha        https://pesquisa.auc.uc.pt/details?id=294763
# (Leis)                   [297842] 1850-07-05 José Pessoa da Silva Pinheiro                https://pesquisa.auc.uc.pt/details?id=297842
# (Leis)                   [228421] 1834-10-31 Justiniano Augusto Dias da Silva             https://pesquisa.auc.uc.pt/details?id=228421
# (Leis)                   [167725] 1825-10-31 Justino António de Freitas                   https://pesquisa.auc.uc.pt/details?id=167725
# (Leis)                   [286251] 1837-06-30 Luís Adelino da Cunha Dantas e Mendonça      https://pesquisa.auc.uc.pt/details?id=286251
# (Leis)                   [297055] 1836-06-16 Manuel António da Costa Seixas               https://pesquisa.auc.uc.pt/details?id=297055
# (Leis)                   [281898] 1835-06-05 Manuel Francisco de Sousa Teixeira Brochado  https://pesquisa.auc.uc.pt/details?id=281898
# (Leis)                   [188758] 1819-10-16 Manuel Joaquim de Sousa Brito                https://pesquisa.auc.uc.pt/details?id=188758
# (Leis)                   [141618] 1823-10-07 Miguel Luís Henriques de Aguiar              https://pesquisa.auc.uc.pt/details?id=141618
# (Leis)                   [206349] 1906-10-02 Paulino Joaquim Couceiro Leitão              https://pesquisa.auc.uc.pt/details?id=206349
# (Lisboa)                 [183377] 1741-10-01 Joaquim Rodrigues da Maia                    https://pesquisa.auc.uc.pt/details?id=183377
# (Lisboa)                 [175954] 1715-10-01 José Anastácio de Oliveira                   https://pesquisa.auc.uc.pt/details?id=175954
# (Lisboa)                 [241045] 0000-00-00 Manuel de Araújo e Sousa                     https://pesquisa.auc.uc.pt/details?id=241045
# (Lisboa)                 [270344] 0000-00-00 Pedro de Almeida                             https://pesquisa.auc.uc.pt/details?id=270344
# (Mataematica)            [195338] 1893-10-14 José Júlio Leite Lages                       https://pesquisa.auc.uc.pt/details?id=195338
# (Mataematica)            [209363] 1822-10-04 Satiro Mariano Leitão                        https://pesquisa.auc.uc.pt/details?id=209363
# (Matecamtica)            [232821] 1869-10-13 António Maria Botelho de Lacerda Lobo        https://pesquisa.auc.uc.pt/details?id=232821
# (Matemataica)            [221403] 1796-10-05 João Bernardes de Lima                       https://pesquisa.auc.uc.pt/details?id=221403
# (Matemátca)              [243453] 1815-10-14 José da Costa Mesquita                       https://pesquisa.auc.uc.pt/details?id=243453 Medicina: 1818-10-12 12.10.1818
# (Matematíca)             [201742] 1868-10-05 Nuno Silvestre Teixeira                      https://pesquisa.auc.uc.pt/details?id=201742 Medicina: 1872-10-03 03.10.1872
# (Matemátiica)            [168950] 1797-10-05 Pedro José Ribeiro                           https://pesquisa.auc.uc.pt/details?id=168950
# (Matemtática)            [199696] 1872-10-15 Augusto Xavier Teixeira                      https://pesquisa.auc.uc.pt/details?id=199696
# (Matriculas 1673.10.15)  [152975] 1673-10-15 António Ribeiro                              https://pesquisa.auc.uc.pt/details?id=152975
# (Matrículas12.10.1629)   [242803] 1629-10-12 João de Mesquita                             https://pesquisa.auc.uc.pt/details?id=242803
# (Medecina)               [241214] 1685-10-01 António de Mesquita                          https://pesquisa.auc.uc.pt/details?id=241214
# (Medecina)               [185199] 1853-10-08 António Manuel da Cunha Belém                https://pesquisa.auc.uc.pt/details?id=185199
# (Medecina)               [241122] 1674-10-01 Domingos Gomes Merim                         https://pesquisa.auc.uc.pt/details?id=241122
# (Medecina)               [241070] 1661-06-25 Domingos Gomes Merim                         https://pesquisa.auc.uc.pt/details?id=241070
# (Medecina)               [242599] 1654-10-15 Francisco de Mesquita                        https://pesquisa.auc.uc.pt/details?id=242599
# (Medecina)               [175592] 1691-10-01 Francisco Martins de Oliveira                https://pesquisa.auc.uc.pt/details?id=175592
# (Medecina)               [175634] 1760-02-04 Gaspar Ferreira de Oliveira                  https://pesquisa.auc.uc.pt/details?id=175634
# (Medecina)               [175643] 1681-10-01 Gonçalo Dias de Oliveira                     https://pesquisa.auc.uc.pt/details?id=175643
# (Medecina)               [175650] 1677-04-03 Henrique da Costa de Oliveira                https://pesquisa.auc.uc.pt/details?id=175650
# (Medecina)               [251147] 1723-10-01 Jerónimo de Almeida Morais                   https://pesquisa.auc.uc.pt/details?id=251147
# (Medecina)               [175970] 1756-10-01 José António de Oliveira                     https://pesquisa.auc.uc.pt/details?id=175970
# (Medecina)               [176054] 1685-03-13 José Machado de Oliveira                     https://pesquisa.auc.uc.pt/details?id=176054
# (Medecina)               [186587] 1858-10-12 Júlio César de Sande Sacadura Bote           https://pesquisa.auc.uc.pt/details?id=186587
# (Medecina)               [176299] 1738-04-16 Manuel da Fonseca de Oliveira                https://pesquisa.auc.uc.pt/details?id=176299
# (Medecina)               [182143] 1693-10-01 Manuel de Oliveira Machado                   https://pesquisa.auc.uc.pt/details?id=182143
# (Medecina)               [176313] 1691-10-01 Manuel Gomes de Oliveira                     https://pesquisa.auc.uc.pt/details?id=176313
# (Medecina)               [241051] 1695-10-01 Pedro Mergulhão                              https://pesquisa.auc.uc.pt/details?id=241051
# (Medecina)               [246061] 1703-10-01 Pedro Miguel                                 https://pesquisa.auc.uc.pt/details?id=246061
# (Medecina)               [176541] 1689-10-01 Salvador de Oliveira                         https://pesquisa.auc.uc.pt/details?id=176541
# (Medicína)               [161636] 1731-10-01 José Dias                                    https://pesquisa.auc.uc.pt/details?id=161636
# (Medicna)                [204848] 1745-10-01 António de Sousa Cota                        https://pesquisa.auc.uc.pt/details?id=204848
# (Medicna)                [204856] 1590-10-08 Domingos Cota                                https://pesquisa.auc.uc.pt/details?id=204856
# (Medicna)                [252579] 1633-10-21 Domingos Fernandes Monteiro                  https://pesquisa.auc.uc.pt/details?id=252579
# (Medicna)                [201357] 1705-10-23 Gabriel Rodrigues Ledesma                    https://pesquisa.auc.uc.pt/details?id=201357
# (Medicna)                [201361] 1730-10-01 Gaspar da Silva Ledesma                      https://pesquisa.auc.uc.pt/details?id=201361
# (Medicna)                [247305] 1573-10-03 João Lopes                                   https://pesquisa.auc.uc.pt/details?id=247305
# (Medicna)                [158903] 1629-10-15 Manuel de Carvalhosa                         https://pesquisa.auc.uc.pt/details?id=158903
# (Mediicna)               [317111] 1754-07-05 Francisco Teixeira Torres                    https://pesquisa.auc.uc.pt/details?id=317111
# (Mediicna)               [250566] 1690-10-01 Manuel de Proença                            https://pesquisa.auc.uc.pt/details?id=250566
# (Monsanto)               [195934] 1690-10-01 Sebastião Rodrigues Conde                    https://pesquisa.auc.uc.pt/details?id=195934
# (Moura)                  [244015] 1732-12-01 Francisco Lopes                              https://pesquisa.auc.uc.pt/details?id=244015
# (Porto)                  [220076] 1878-10-02 Roberto Guilherme Woodhonse                  https://pesquisa.auc.uc.pt/details?id=220076
# (Porto)                  [191527] 0000-00-00 Serafim Garcia Dinis e Castro                https://pesquisa.auc.uc.pt/details?id=191527
# (Seia)                   [213195] 1863-10-09 Amândio Eduardo da Mota Veiga                https://pesquisa.auc.uc.pt/details?id=213195
# (Serpa)                  [271727] 1721-05-14 António de Araújo                            https://pesquisa.auc.uc.pt/details?id=271727
# (Teaologia)              [169843] 1847-10-08 Manuel Ferreira Domingues Martins            https://pesquisa.auc.uc.pt/details?id=169843
# (Telogia)                [230302] 1877-10-16 António Augusto de Almeida Silvano           https://pesquisa.auc.uc.pt/details?id=230302
# (Telogia)                [195492] 1788-10-08 António da Conceição                         https://pesquisa.auc.uc.pt/details?id=195492 António da Conceição (frei religioso de Santo Agostinho Descalço)
# (Telogia)                [132149] 1573-10-01 António de Figueiredo                        https://pesquisa.auc.uc.pt/details?id=132149 António de Figueiredo (frei da Ordem de São Bernardo), vide António
# (Telogia)                [222536] 1824-10-06 Joaquim da Paixão                            https://pesquisa.auc.uc.pt/details?id=222536
# (Telogia)                [206007] 1690-10-01 José Coutinho                                https://pesquisa.auc.uc.pt/details?id=206007
# (Telogia)                [187719] 1664-10-01 Manuel Fernandes da Rocha                    https://pesquisa.auc.uc.pt/details?id=187719 1672.05.25
# (Telogia)                [168762] 1703-10-01 Onofre Ribeiro                               https://pesquisa.auc.uc.pt/details?id=168762
# (Tentativa)              [168987] 1765-10-01 Luís José Lourenço da Silva Neto             https://pesquisa.auc.uc.pt/details?id=168987
# (Tentugal)               [181115] 1749-10-01 António de Sequeira Gusmão                   https://pesquisa.auc.uc.pt/details?id=181115
# (Teolggia)               [250294] 1804-10-20 António José Lopes de Morais                 https://pesquisa.auc.uc.pt/details?id=250294
# (Teolgia)                [167430] 1894-10-29 João Martins de Freitas                      https://pesquisa.auc.uc.pt/details?id=167430
# (Teolgia)                [223019] 1856-10-17 Joaquim Pedro Parente                        https://pesquisa.auc.uc.pt/details?id=223019
# (Teolgia)                [137293] 1597-10-03 Manuel de Figueiredo                         https://pesquisa.auc.uc.pt/details?id=137293
# (Teologi)                [144068] 1700-11-01 Paulo de Almeida                             https://pesquisa.auc.uc.pt/details?id=144068
# (Teórico)                [133424] 1540-03-07 Diogo Rodrigues Cardoso                      https://pesquisa.auc.uc.pt/details?id=133424
# (Teórico)                [179125] 1540-10-07 Gonçalo                                      https://pesquisa.auc.uc.pt/details?id=179125
# (Teórico)                [196458] 1540-02-20 Luís Coronel                                 https://pesquisa.auc.uc.pt/details?id=196458
# (Teórico)                [222412] 1540-10-17 Marcos de Paiva                              https://pesquisa.auc.uc.pt/details?id=222412
# (Teóricos)               [176607] 1540-10-06 Baltasar Olmedo                              https://pesquisa.auc.uc.pt/details?id=176607
# (´)                      [136573] 1654-03-18 Francisco Rego                               https://pesquisa.auc.uc.pt/details?id=136573

# %% [markdown]
# ## Registos em mais que uma Faculdade
#
# Quando não existe uma menção explícita de faculdade o programa usa a lista de matrículas, o que pode produzir uma lista de faculdades para um mesmo aluno.
#
# Sobre as combinações de frequência de faculdades ver Fonseca, F.T. da (2000) ‘A dimensão pedagógica da reforma de 1772: alguns aspectos’, in O Marquês de Pombal e a Universidade. Coimbra: Imprensa da Universidade de Coimbra, pp. 43–68. doi:http://dx.doi.org/10.14195/978-989-26-0373-5_2.
#
# Antes de 1772 a frequência de Artes precede a Teologia (122 casos), Medicina  (112) obrigatóriamente, mas também aparece antes de
# Cânones (94) e Leis  (38) e de Cânones e Leis (23), e outras combinações
#
# Depois de 1772 a frequência de Filosofia e Matemática concide com a frequência de Direito, Cânones e Medicina.
#
# As Faculdade de Matemática e Filosofia só deveriam ser referidas autónomamente a partir de 1772.

# %% [markdown]
# ### Alunos com matrícula em mais que uma faculdade
# ### Students with more that one "Faculdade"

# %%
from sqlalchemy import select,distinct,func,desc, and_
# List of students with more than one record of faculdade
stmt = select(nattr_table.c.id, nattr_table.c.name, func.count().label("n")).\
        where(nattr_table.c.the_type == 'faculdade').\
        group_by(nattr_table.c.id, nattr_table.c.name).having(func.count()>1).\
        order_by(desc("n"))
print(stmt)
# we store each combination and number of ocurrences

combinacoes = {}

with Session() as session:
        for aluno in session.execute(stmt):
                id_link=f'<a href="https://pesquisa.auc.uc.pt/details?id={aluno.id}">{row.id}</a>'
                #display(HTML(f'<pre> [{id_link}]  {row.name} ({row.n})</pre>'))
                #print()
                stmt2 = select(nattr_table.c.the_date,nattr_table.c.the_value, nattr_table.c.pobs).\
                                where(
                                        and_(nattr_table.c.the_type == 'faculdade', 
                                        nattr_table.c.id == aluno.id)).distinct().\
                                order_by(nattr_table.c.the_value)
                result = session.execute(stmt2)
                combinacao = ''
                aluno_faculdades = []
                for fac in result:
                        #display(HTML(f'<pre>    {aluno.the_value} {aluno.the_date}</pre>'))
                        #print(f'   {aluno.the_date} {aluno.the_value} ')
                        aluno_faculdades.append((fac.the_value,fac.the_date))
                        combinacao = combinacao + ' ' + fac.the_value
                alunos = combinacoes.get(combinacao,{})
                alunos[aluno.id]={'name':aluno.name,'matriculas':aluno_faculdades}
                combinacoes[combinacao] = alunos
# Out:
# SELECT nattributes.id, nattributes.name, count(*) AS n
# FROM nattributes
# WHERE nattributes.the_type = :the_type_1 GROUP BY nattributes.id, nattributes.name
# HAVING count(*) > :count_1 ORDER BY n DESC
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/jrc/mhk-home/sources/ucalumni/notebooks/faculdades_clean.ipynb Cell 13' in <module>
#      <a href='vscode-notebook-cell:/Users/jrc/mhk-home/sources/ucalumni/notebooks/faculdades_clean.ipynb#ch0000012?line=11'>12</a> with Session() as session:
#      <a href='vscode-notebook-cell:/Users/jrc/mhk-home/sources/ucalumni/notebooks/faculdades_clean.ipynb#ch0000012?line=12'>13</a>         for aluno in session.execute(stmt):
# ---> <a href='vscode-notebook-cell:/Users/jrc/mhk-home/sources/ucalumni/notebooks/faculdades_clean.ipynb#ch0000012?line=13'>14</a>                 id_link=f'<a href="https://pesquisa.auc.uc.pt/details?id={row.id}">{row.id}</a>'
#      <a href='vscode-notebook-cell:/Users/jrc/mhk-home/sources/ucalumni/notebooks/faculdades_clean.ipynb#ch0000012?line=14'>15</a>                 #display(HTML(f'<pre> [{id_link}]  {row.name} ({row.n})</pre>'))
#      <a href='vscode-notebook-cell:/Users/jrc/mhk-home/sources/ucalumni/notebooks/faculdades_clean.ipynb#ch0000012?line=15'>16</a>                 #print()
#      <a href='vscode-notebook-cell:/Users/jrc/mhk-home/sources/ucalumni/notebooks/faculdades_clean.ipynb#ch0000012?line=16'>17</a>                 stmt2 = select(nattr_table.c.the_date,nattr_table.c.the_value, nattr_table.c.pobs).\
#      <a href='vscode-notebook-cell:/Users/jrc/mhk-home/sources/ucalumni/notebooks/faculdades_clean.ipynb#ch0000012?line=17'>18</a>                                 where(
#      <a href='vscode-notebook-cell:/Users/jrc/mhk-home/sources/ucalumni/notebooks/faculdades_clean.ipynb#ch0000012?line=18'>19</a>                                         and_(nattr_table.c.the_type == 'faculdade',
#      <a href='vscode-notebook-cell:/Users/jrc/mhk-home/sources/ucalumni/notebooks/faculdades_clean.ipynb#ch0000012?line=19'>20</a>                                         nattr_table.c.id == aluno.id)).distinct().\
#      <a href='vscode-notebook-cell:/Users/jrc/mhk-home/sources/ucalumni/notebooks/faculdades_clean.ipynb#ch0000012?line=20'>21</a>                                 order_by(nattr_table.c.the_value)
#
# AttributeError: Could not locate column in row for column 'id'

# %% [markdown]
# A lista seguinte mostra as diferentes combinações de faculdades que ocorrem para um mesmo aluno. Quando o número de alunos uma combinação específica é inferior a um certo valor o nome dos alunos é listado, para verificação de eventuais erros.
#
# As faculdades são combinadas por ordem alfabética, mas na listagem as informações referentes às matrículas são mostradas por ordem cronológica.

# %%
limiar = 10
print("Limiar utilizado para listar os alunos de uma determinada combinação: ",limiar)
for comb,alunos in sorted(combinacoes.items()):
    print()
    print(f'{len(alunos):3} {comb}' )
    n = 0

    for nome,info in alunos.items():
        aluno_id = info['id']
        print(f'       {nome} https://pesquisa.auc.uc.pt/details?id={aluno_id}')
        for matricula,data in sorted(info['matriculas'], key = lambda x: x[1]):

            print(f'          {data} {matricula}')
        n = n + 1
        if n > limiar:
            print('       ...')
            break

# %% [markdown]
# ### Aluno com '?' no campo Faculdade
#
# Presume-se que estes casos correspondem aos que não foi possível determinar a faculdade do aluno.
#
# De qualquer modo valeria a pena verificar se não há aqui, também, gralhas e cópias acidentais de valores entre registos.

# %%
# Id, data, nome
# see https://docs.sqlalchemy.org/en/14/tutorial/data_select.html#tutorial-selecting-data
from sqlalchemy import select, and_, or_, func, desc
from IPython.core.display import display, HTML


#display(HTML("<h2>Faculdade = '?'</h2>"))

stmt = select(nattr_table.c.id,nattr_table.c.name, nattr_table.c.the_date, nattr_table.c.pobs).\
        where(
                and_(nattr_table.c.the_type == 'faculdade', 
                     nattr_table.c.the_value == '?')).\
        order_by(nattr_table.c.name)
result = session.execute(stmt)
for row in result:
    id_link=  f'<a href="https://pesquisa.auc.uc.pt/details?id={row.id}">{row.id}</a>'
    line =f'<pre>[{id_link:5}] {row.the_date} {row.name}</pre>'
    #display(HTML(line))
    print(f'{row.id:5} {row.the_date} {row.name:64} https://pesquisa.auc.uc.pt/details?id={row.id}')
